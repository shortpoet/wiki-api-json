# %%
import requests
from pprint import pprint
import re
import lxml.html
from bs4 import BeautifulSoup
import pandas as pd

# %%
def log_error(line1, line2):
    _line1 = str(line1)
    _line2 = str(line2)
    diff = 0
    chars1 = len(_line1) + 10
    chars2 = len(_line2) + 10
    if chars1 > chars2:
        diff = chars1 - chars2
        if diff % 2 != 0:
            diff = int(diff - .5)
            _line2 = '# ' + _line2
        else:
            _line2 = ' ' + _line2
        main_hashes = ''.join(['#' for i in range(chars1)])
        hashes = ''.join(['#' for i in range(int(diff/2)+4)])
        log_line = (f"{main_hashes}\n"
                    f"#### {_line1} ####\n"
                    f"{hashes}{_line2} {hashes}\n"                    
                    f"{main_hashes}\n")
        return(log_line)
   
    elif chars2 > chars1:
        diff = chars2 - chars1
        if diff % 2 != 0:
            diff = int(diff - .5)
            _line1 = '# ' + _line1
        else:
            _line1 = ' ' + _line1
        main_hashes = ''.join(['#' for i in range(chars2)])
        hashes = ''.join(['#' for i in range(int(diff/2)+4)])
        log_line = (f"{main_hashes}\n"
                    
                    f"{hashes}{_line1} {hashes}\n"
                    f"#### {_line2} ####\n"
                    f"{main_hashes}\n")
        return(log_line)
        
    else:
        hashes = '####'
        main_hashes = ''.join(['#' for i in range(chars2)])
        log_line = (f"{main_hashes}\n"
                    f"#### {_line1} ####\n"
                    f"{hashes} {_line2} {hashes}\n"
                    f"{main_hashes}\n")
        return(log_line)

# %%
# init session 
S = requests.Session()

# set URL
URL = "https://en.wikipedia.org/w/api.php"

# %%
page_id = "19240761"
topic = 'street_names'
subtopic = 'valetta'

# %%
# get sections
PARAMS = {
    "action": "parse",
    "pageid": page_id,
    "format": "json",
    "prop": "sections"
}

sectionsR = S.get(url=URL, params=PARAMS)
sectionDATA = sectionsR.json()

# %%
sectionDATA
# Out:
# {'parse': {'title': 'List of streets and piazzas in Valletta',
#   'pageid': 19240761,
#   'sections': [{'toclevel': 1,
#     'level': '2',
#     'line': 'Main thoroughfares',
#     'number': '1',
#     'index': '1',
#     'fromtitle': 'List_of_streets_and_piazzas_in_Valletta',
#     'byteoffset': 271,
#     'anchor': 'Main_thoroughfares'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'Piazzas',
#     'number': '2',
#     'index': '2',
#     'fromtitle': 'List_of_streets_and_piazzas_in_Valletta',
#     'byteoffset': 4145,
#     'anchor': 'Piazzas'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'Bastions',
#     'number': '3',
#     'index': '3',
#     'fromtitle': 'List_of_streets_and_piazzas_in_Valletta',
#     'byteoffset': 5696,
#     'anchor': 'Bastions'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': "Historical names of Valletta's streets and squares",
#     'number': '4',
#     'index': '4',
#     'fromtitle': 'List_of_streets_and_piazzas_in_Valletta',
#     'byteoffset': 6427,
#     'anchor': "Historical_names_of_Valletta's_streets_and_squares"},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'References',
#     'number': '5',
#     'index': '5',
#     'fromtitle': 'List_of_streets_and_piazzas_in_Valletta',
#     'byteoffset': 8457,
#     'anchor': 'References'}]}}

# %%
sections = [sec['anchor'] for sec in sectionDATA["parse"]["sections"]]

# %%
# create section list filtering out non-data sections
filt = [
    'References',
    #'See_also',
    #'External_links'.
    "Historical_names_of_Valletta's_streets_and_squares"
]

incl = [
    'Schemes',
    'Tropes'
]

sec_list = [sec for sec in sectionDATA["parse"]["sections"] if not sec['anchor'] in filt]
# sec_list = [sec for sec in sectionDATA["parse"]["sections"] if sec['anchor'] in incl]


len(sec_list)
sec_list
# Out:
# [{'toclevel': 1,
#   'level': '2',
#   'line': 'Main thoroughfares',
#   'number': '1',
#   'index': '1',
#   'fromtitle': 'List_of_streets_and_piazzas_in_Valletta',
#   'byteoffset': 271,
#   'anchor': 'Main_thoroughfares'},
#  {'toclevel': 1,
#   'level': '2',
#   'line': 'Piazzas',
#   'number': '2',
#   'index': '2',
#   'fromtitle': 'List_of_streets_and_piazzas_in_Valletta',
#   'byteoffset': 4145,
#   'anchor': 'Piazzas'},
#  {'toclevel': 1,
#   'level': '2',
#   'line': 'Bastions',
#   'number': '3',
#   'index': '3',
#   'fromtitle': 'List_of_streets_and_piazzas_in_Valletta',
#   'byteoffset': 5696,
#   'anchor': 'Bastions'}]

# %%
for index, line in enumerate(lines):
    print(index, line)

# %%
# create nested section_dict dictionary from section list based on toclevel
# refactored
section_dict = {}
current_parent = None
for i in range(len(sec_list)):
    if i == 0:
        if sec_list[i]['toclevel'] < sec_list[i + 1]['toclevel']:
            section_dict[sec_list[i]['line']] = {}
            current_grandparent = sec_list[i]['line']
        else:
            section_dict[sec_list[i]['line']] = []

    elif i != len(sec_list) - 1:
        if sec_list[i - 1]['toclevel'] < sec_list[i]['toclevel'] and sec_list[i]['toclevel'] < sec_list[i + 1]['toclevel']:
            section_dict[current_grandparent][sec_list[i]['line']] = {}
            current_parent = section_dict[current_grandparent][sec_list[i]['line']]
            
        elif sec_list[i]['toclevel'] == sec_list[i + 1]['toclevel'] or sec_list[i]['toclevel'] > sec_list[i + 1]['toclevel']:
            if current_parent != None:
                current_parent[sec_list[i]['line']] = []
            else: section_dict[sec_list[i]['line']] = []
            
        elif sec_list[i]['toclevel'] < sec_list[i + 1]['toclevel']:
            section_dict[current_grandparent][sec_list[i]['line']] = {}
            current_parent = section_dict[current_grandparent][sec_list[i]['line']]
            
    else:
        if sec_list[i]['toclevel'] == sec_list[i - 1]['toclevel']:
            section_dict[sec_list[i]['line']] = []
        else:
            section_dict[sec_list[i]['line']] = []
              

#pprint(section_dict)

# %%
section_dict
# Out:
# {'Main thoroughfares': [], 'Piazzas': [], 'Bastions': []}

# %%
# hard coded name for section in section dict bec inconsistent wikipedia format
section_dict = {'San Jose': []}

# %%
# create nested section_dict dictionary from section list based on toclevel
# adding 'Z' section by hand consider refactor
section_dict = {}
is_new_parent = True
parent = ''
for i in range(len(sec_list) - 1):
    if sec_list[i]['toclevel'] == 1 and sec_list[i + 1]['toclevel'] == 1:
        section_dict[sec_list[i]['anchor']] = []
    elif sec_list[i]['toclevel'] == 1 and sec_list[i + 1]['toclevel'] == 2:
        section_dict[sec_list[i]['anchor']] = {}
        parent = sec_list[i]['anchor']
    elif sec_list[i]['toclevel'] == 2:
        section_dict[parent][sec_list[i]['anchor']] = []
section_dict['Z'] = []
#section_dict

# %%
# make list of top level sections
secs = [sec for sec, val in section_dict.items()]

# %%
# make section dict if no nested sections
section_dict = {sec['anchor']:[] for sec in sec_list}

# %%
# get links
PARAMS = {
    "action": "parse",
    "pageid": page_id,
    "format": "json",
    "prop": "links"
}

linkR = S.get(url=URL, params=PARAMS)
linkDATA = linkR.json()

pprint(linkDATA["parse"]["links"])

# %%
links = [link['*'] for link in linkDATA["parse"]["links"]]
for i, link in enumerate(links):
    print(i, link)

# %%
# visualize link data
for link in links[3:4]:
    # get page info
    PARAMS = {
        "action": "query",
        "titles": link,
        "format": "json",
        "prop": "info",
        'inprop': "displaytitle"
    }

    infoR = S.get(url=URL, params=PARAMS)
    infoDATA = infoR.json()
    pprint(infoDATA)

# %%
# get data
PARAMS = {
    "action": "parse",
    "pageid": page_id,
    "format": "json",
    "prop": "wikitext"
}

textR = S.get(url=URL, params=PARAMS)
textDATA = textR.json()

# %%
# parse data

lines = textDATA["parse"]["wikitext"]["*"].split('\n')

# %%
for index, line in enumerate(lines[:155]):
    print(index, line)
# Out:
# 0 [[Image:Valletta OldTreasuryStr BibliotecaArcade.jpg|thumb|200px|right|The [[Arcade (architecture)|arcades]] outside the [[National Library of Malta|Bibliotecha]], on ''Old Treasury Road'']]
# 1 This page lists some streets and piazzas (squares) in [[Valletta]], [[Malta]].
# 2
# 3 ==Main thoroughfares==
# 4 *Archbishop Street ({{lang-mt|Triq l-Arċisqof; alt. Strada Vescovo}})
# 5 *Battery Street (Triq il-Batterija)
# 6 *Bishop Lane (Sqaq l-Isqof)
# 7 *Carmelo Street (Triq Tal-Karmnu)
# 8 *Carts Street (Triq il-Karrijiet)
# 9 *Castile Place ({{lang-mt|Pjazza Kastilja}})
# 10 *St Elmo Place ({{lang-mt|Misraħ Sant'Iermu}})
# 11 *Old Bakery Street ({{lang-mt|Triq l-Ifran; alt. Strada Forni}})
# 12 *St. Biagio Street (Triq San Bjaġju)
# 13 *Boat Street ({{lang-mt|Triq il-Lanċa}})
# 14 *Bounty Street (Triq l-Għajnuna)
# 15 *Bull Street (Triq il-Gendus)
# 16 *Eagle Street ({{lang-mt|Triq l-Ajkla; alt. Strada Aquila}})
# 17 *East Street ({{lang-mt|Triq il-Lvant; alt. Strada Levante}})
# 18 *Engineers Lane (Sqaq l-Inġinieri)
# 19 *Felix Street (Triq Feliċ)
# 20 *G. Cassar Road (Triq Ġirolomu Cassar)
# 21 *West Street ({{lang-mt|Triq il-Punent; alt. Strada Ponente}})
# 22 *Knight Street (Triq il-Kavallier)
# 23 *M.A. Vassalli Street (Triq Mikiel Anton Vassalli)
# 24 *Mediterranean Street ({{lang-mt|Triq il-Mediterran}})
# 25 *New Street (Triq il-Ġdida)
# 26 *Republic Street ({{lang-mt|Triq ir-Repubblika; alt. Strada Rjali, Kingsway}})
# 27 *Old Hospital Street (Triq l-Isptar)
# 28 *Old Mint Street (Triq Żekka; alt. Strada Zecca)
# 29 *Old Treasury Street (Triq it-Teżorerija)
# 30 *Old Theater Lane (Sqaq tat-Teatru l-Antik)
# 31 *Old Theater Street ({{lang-mt|Triq it-Teatru l-Antik; Strada Teatro}})
# 32 *Ordinance Street (Triq l-Ordinanza)
# 33 *Great Siege Road ({{lang-mt|Triq l-Assedju l-Kbir}})
# 34 *King's Garden Street ({{lang-mt|Daħlet Ġnien is-Sultan}})
# 35 *Lascaris Wharf (Xatt Lascaris)
# 36 *Liesse Hill (Telgħet Liesse)
# 37 *Lower Barrakka Lane (Sqaq il-Barrakka t'Isfel)
# 38 *Marsamxett Street ({{lang-mt|Triq Marsamxett}})
# 39 *Melita Street ({{lang-mt|Triq Melita}})
# 40 *Merchants Street (Triq il-Merkanti; alt. Strada Mercanti)
# 41 *Mill Street (Triq il-Mitħna)
# 42 *Nelson Avenue (Vjal Nelson)
# 43 *Nix Mangiari Steps (Taraġ Nix Mangiari)
# 44 *North Street (Triq it-Tramuntana)
# 45 *Pope Pius V Street (Triq il-Papa Piju V)
# 46 *Scots Street (M.A.Vassalli; alt. Strada Scozzese)
# 47 *South Street (Triq Nofsinhar; alt. Strada Mezzodì)
# 48 *St Andrew's Street (Triq Sant'Andrija)
# 49 *St Anne's Street (Triq Sant' Anna; alt. Strada Sant'Anna)
# 50 *St Anthony's Street (Triq Sant'Antnin)
# 51 *St Barbara's Bastion (Is-Sur ta' Santa Barbara)
# 52 *St Charles Street (Triq San Karlu; alt. Strada San Carlo)
# 53 *St Dominic's Street (Triq San Duminku; alt. Strada San Domenico)
# 54 *St Fredrick's Street (Triq San Federiku; alt. Strada San Federico)
# 55 *St George's Street (Triq San Ġorġ)
# 56 *St John's Street (Triq San Ġwann; alt. Strada San Giovanni)
# 57 *St John's Cavalier Street (Triq il-Kavallier ta' San Ġwann)
# 58 *St Joseph Street (Triq San Ġużepp)
# 59 *St Lucy Street (Triq Santa Luċija)
# 60 *St Michael's Street (Triq San Mikiel)
# 61 *St Nicholas Street (Triq San Nikola)
# 62 *St Paul Street (Triq San Pawl; Strada San Paolo)
# 63 *St Patrick's Street (Triq San Patrizju)
# 64 *St Sebastian Street ({{lang-mt|Triq San Bastjan}})
# 65 *St Ursula Street (Triq Sant' Orsola; alt. Strada Sant'Orsola)
# 66 *Zachary Street (Triq Żakkarija; Strada Zaccaria)
# 67 *Christopher Street<ref>Christopher Street in Valletta was first named "Strada della Fontana" as a spring or fountain of fresh water was struck in its vicinity whilst a well for the storage of water was being excavated during the building of Valletta. The French Republican Government altered the name to "Rue des Droits de l'Homme". The British Colonial Government then changed the name to "Strada Cristoforo"; Victor F. Denaro, ''The Houses of Valletta'', Malta, 1967.</ref> ({{lang-mt|Triq San Kristofru}})
# 68 *St Mark Street ({{lang-mt|Triq San Mark}})
# 69 *Spur Street ({{lang-mt|Triq l-Ixpruna}})
# 70 *Fountain Street (Triq l-Għajn)
# 71 *Steps Street (Triq it-Turġien)
# 72 *Strait Street (Triq id-Dejqa; alt. Strada Stretta)
# 73 *Quarry Wharf ({{lang-mt|Xatt il-Barriera}})
# 74 *St Dominic Street ({{lang-mt|Triq San Duminku}})
# 75 *Toni Bajada Lane (Sqaq Toni Bajada)
# 76 *Victory Street (Triq il-Vitorja)
# 77 *Wells Street (Triq l-Ibjar)
# 78
# 79 ==Piazzas==
# 80 A piazza ({{lang-mt|pjazza, misraħ}}) is a public [[market square|square]]. A number of formerly existing square in Valletta no longer exist.<ref>[[Giovanni Bonello|Bonello, Giovanni]] (2000). [http://www.patrimonju.org/content.aspx?id=119835&subId=114434 Art in Malta - Discoveries and Recoveries]. Fondazzjoni Patrimonju Malti. p. 51. {{ISBN|99909-959-7-4}}. {{ISBN|99909-959-8-2}}.</ref>
# 81 *[[St Elmo's Square]] ({{lang-mt|Misraħ Sant' Iermu}})
# 82 *[[St John's Square]] ({{lang-mt|Misraħ San Ġwann}})
# 83 *[[St George's Square (Valletta)|St George's Square]] ({{lang-mt|Misraħ San Ġorġ}}), also known as Palace Square ({{lang-mt|Misraħ il-Palazz}})
# 84 *[[Republic Square, Valletta|Republic Square]] ({{lang-mt|Misraħ ir-Repubblika}}), also known as Queen's Square  ({{lang-mt|Pjazza Reġina}}, {{lang-it|Piazza Regina}}) and {{lang-it|Piazza Tesoreria}}<ref name=1929map>[https://www.discusmedia.com/upload/resize_cache/iblock/c9e/620_2000_101501c60d97e3a56b67806f8f0d90c9a/c9e13aa9f3cba78934e0f144f2a2d7ce.jpg 1929 Map of Valletta]</ref>
# 85 *[[Great Siege Square]] ({{lang-mt|Misraħ l-Assedju l-Kbir}})
# 86 *[[Parliament House (Malta)#Site|Freedom Square]] ({{lang-mt|Misraħ il-Ħelsien}})
# 87 *[[Jean Parisot de Valette#Jean De Valette Square|Jean De Valette Square]] (Misraħ De Valette)
# 88 *[[Castille Square]] ({{lang-mt|Misraħ Kastilja}}), also known for a while as {{lang-it|Piazza Regina}}<ref name=1929map/>
# 89 *[[Independence Square (Malta)|Independence Square]] ({{lang-mt|Misraħ Indipendenza}})
# 90 *[[Mattia Preti Square]] ({{lang-mt|Misraħ Mattia Preti}})
# 91
# 92 ==Bastions==
# 93 {{main|Fortifications of Valletta#Layout}}
# 94 *Abercrombie's Bastion (Is-Sur ta' Abercrombie)
# 95 *Ball's Bastion (Is-Sur ta' Ball)
# 96 *Castile Bastion (Is-Sur ta' Castile)
# 97 *English Curtain (Is-Sur tal-Ingliżi)
# 98 *French Curtain (Is-Sur tal-Franċiżi)
# 99 *German Curtain (Is-Sur tal-Ġermaniżi)
# 100 *[[Lascaris Battery|Lascaris Bastion]] (Is-Sur ta' Lascaris)
# 101 *Lower Castile Bastion (Is-Sur ta' Isfel ta' Castile)
# 102 *St Barbara's Bastion (Is-Sur ta' Santa Barbara)
# 103 *St Gregory's Bastion (Is-Sur ta' San Girgor)
# 104 *St James Bastion (Is-Sur ta' San Ġakbu)
# 105 *St John's Bastion (Is-Sur ta' San Ġwann)
# 106 *St Lazarus Bastion (Is-Sur ta' San Lażżru)
# 107 *St Michael Bastion (Is-Sur ta' San Mikiel)
# 108 *St Sebastian's Bastion (Is-Sur ta' San Bastjan)
# 109
# 110 == Historical names of Valletta's streets and squares ==
# 111 {| class="wikitable"
# 112 |-
# 113 ! ''Original	!! Informal	!! French	!! British	!! British post-1926	!! Maltese ''<ref>[https://timesofmalta.com/articles/view/where-the-streets-have-four-names.570511 times of Malta]</ref><ref>[https://cilialacorte.com/Valletta_Street_Names.htm Cilia Lacorte]</ref>
# 114 |-
# 115 | Porta di San Giorgio|| || Porte Nationale|| Porta Reale|| Kingsgate|| Putirjal/Bieb il-Belt
# 116 |-
# 117 |Piazza San Giorgio	||Piazza dei Cavallieri	||Place de la Liberté	|| ||	Palace Square	||Pjazza San Ġorġ
# 118 |-
# 119 |Piazza dei Cavallieri	||Piazza della Città	||Place de l’Egalité	||Piazza Regina	||Victoria Square	||[[Republic Square, Valletta| Pjazza Repubblika]]
# 120 |-
# 121 |Strada San Giorgio 	||Strada delle Corse	||Rue Nationale	||Strada Reale	||Kingsway 	||[[Republic Street, Valletta|Triq ir-Repubblika]]
# 122 |-
# 123 |Strada San Giacomo	||Strada di Castiglia	||Rue de Marchands	||Strada Mercanti	||Merchants Street	||Triq il-Merkanti
# 124 |-
# 125 |Strada San Luigi	||Strada Sant’Aloisio	||Rue de la Constitution	||Strada Levante	||East Street	||Triq Lvant
# 126 |-
# 127 |Strada San Paolo	||-	||Rue de la Constitution	||Strada San Paolo	||St Paul Street	||Triq San Pawl
# 128 |-
# 129 |Strada San Pietro	||Strada della Chiesa di San Rocco	||Rue de la Barraque 	||Strada St Ursula	||St Ursula Street	||Triq Sant’Ursula
# 130 |-
# 131 |Strada San Giovanni Battista	||-	||Rue des Fours	||Strada Forni	||Old Bakery Street	||Triq l-Ifran
# 132 |-
# 133 |Strada San Sebastiano	||Strada Toro	||Rue de la Monnaie	||Strada Zecca	||Old Mint Street	||Triq Żekka
# 134 |-
# 135 |Strada Stretta	||Strada Vanella	||Rue Etroite	||Strada Stretta	||Strait Street	||Triq id-Dejqa
# 136 |-
# 137 |Strada Pia	||Strada del Gran Falconiere	||Rue de la Félicité Publique	||Strada Britannica	||Britannia Street	||Triq Melita
# 138 |-
# 139 |Strada di Monte	||Strada dei Carcerati	||Rue de Peuple	||Strada San Giovanni	||St John Street	||Triq San Ġwann / In-Niżla tal-Ganċ
# 140 |-
# 141 |Strada del Popolo	||Strada di Aragona / Strada dei Greci	||Rue des Libérateurs	||Strada Vescovo	||Archbishop Street	||Triq l-Arċisqof
# 142 |}
# 143
# 144 ==References==
# 145 {{reflist}}
# 146
# 147 {{Valletta}}
# 148
# 149 {{DEFAULTSORT:Streets and piazzas in Valletta}}
# 150 [[Category:Malta-related lists|Valletta]]
# 151 [[Category:Valletta]]
# 152 [[Category:Roads in Malta|Valletta]]
# 153 [[Category:Transport in Malta|Valletta]]
# 154 [[Category:Lists of streets by city|Valletta]]

# %%
# parse 
#       WikiText
# data


debug = False
special = True

this_sec = ''
this_item = ''


for index, line in enumerate(lines[:154]):
    #print(line)
    if debug: print("$$-3-$$")
   
    if re.match('=+\w', line[0:5]):
        if debug: print("$$-0-$$")
        if this_sec != None:
            if debug: print("$$-1-$$")

    if re.match('==\w', line[0:5]):
        if debug: print("$$-2-$$")
        this_sec = line.strip().replace("=", "")

    if debug:
        if index != 0: 
            print('$\n' + str(index -1) + '\n' + lines[index - 1] + '\n' + str(index) + '\n' + line + '\n$')
            print(index, re.match('\|\-', lines[index - 1][0:2]))
            print(line)
            print(index,re.match('\!\w+', line[0:2]))

    if this_sec != None:
        if debug: print("$$-3-$$")
        if re.match('\*', line[0:1]):
            #print(index)
            if debug: print("$$-4-$$")
            if '–' in line:
                #print(f"$0$-{index}")
                this_item = re.search(r'\*\s(.*?)\s–', line).group(1)
            else:
                #print(f"$1$-{index}")
                this_item = re.search(r'\*(.*?)\(', line).group(1).strip()
            section_dict[this_sec].append(this_item)

# %%
#section_dict

# %%
# make 1 list
all_items = [item for section, items in section_dict.items() for item in items]
# make 2 lists, nested
# all_items = [item for section, item in section_dict.items()]
# flatten lists 2 ways
# all_items = [lyst1 for lyst2 in all_items for lyst1 in lyst2]
#all_items = [item for items in all_items for item in items]
all_items
# Out:
# ['Archbishop Street',
#  'Battery Street',
#  'Bishop Lane',
#  'Carmelo Street',
#  'Carts Street',
#  'Castile Place',
#  'St Elmo Place',
#  'Old Bakery Street',
#  'St. Biagio Street',
#  'Boat Street',
#  'Bounty Street',
#  'Bull Street',
#  'Eagle Street',
#  'East Street',
#  'Engineers Lane',
#  'Felix Street',
#  'G. Cassar Road',
#  'West Street',
#  'Knight Street',
#  'M.A. Vassalli Street',
#  'Mediterranean Street',
#  'New Street',
#  'Republic Street',
#  'Old Hospital Street',
#  'Old Mint Street',
#  'Old Treasury Street',
#  'Old Theater Lane',
#  'Old Theater Street',
#  'Ordinance Street',
#  'Great Siege Road',
#  "King's Garden Street",
#  'Lascaris Wharf',
#  'Liesse Hill',
#  'Lower Barrakka Lane',
#  'Marsamxett Street',
#  'Melita Street',
#  'Merchants Street',
#  'Mill Street',
#  'Nelson Avenue',
#  'Nix Mangiari Steps',
#  'North Street',
#  'Pope Pius V Street',
#  'Scots Street',
#  'South Street',
#  "St Andrew's Street",
#  "St Anne's Street",
#  "St Anthony's Street",
#  "St Barbara's Bastion",
#  'St Charles Street',
#  "St Dominic's Street",
#  "St Fredrick's Street",
#  "St George's Street",
#  "St John's Street",
#  "St John's Cavalier Street",
#  'St Joseph Street',
#  'St Lucy Street',
#  "St Michael's Street",
#  'St Nicholas Street',
#  'St Paul Street',
#  "St Patrick's Street",
#  'St Sebastian Street',
#  'St Ursula Street',
#  'Zachary Street',
#  'Christopher Street<ref>Christopher Street in Valletta was first named "Strada della Fontana" as a spring or fountain of fresh water was struck in its vicinity whilst a well for the storage of water was being excavated during the building of Valletta. The French Republican Government altered the name to "Rue des Droits de l\'Homme". The British Colonial Government then changed the name to "Strada Cristoforo"; Victor F. Denaro, \'\'The Houses of Valletta\'\', Malta, 1967.</ref>',
#  'St Mark Street',
#  'Spur Street',
#  'Fountain Street',
#  'Steps Street',
#  'Strait Street',
#  'Quarry Wharf',
#  'St Dominic Street',
#  'Toni Bajada Lane',
#  'Victory Street',
#  'Wells Street',
#  'Archbishop Street',
#  'Battery Street',
#  'Bishop Lane',
#  'Carmelo Street',
#  'Carts Street',
#  'Castile Place',
#  'St Elmo Place',
#  'Old Bakery Street',
#  'St. Biagio Street',
#  'Boat Street',
#  'Bounty Street',
#  'Bull Street',
#  'Eagle Street',
#  'East Street',
#  'Engineers Lane',
#  'Felix Street',
#  'G. Cassar Road',
#  'West Street',
#  'Knight Street',
#  'M.A. Vassalli Street',
#  'Mediterranean Street',
#  'New Street',
#  'Republic Street',
#  'Old Hospital Street',
#  'Old Mint Street',
#  'Old Treasury Street',
#  'Old Theater Lane',
#  'Old Theater Street',
#  'Ordinance Street',
#  'Great Siege Road',
#  "King's Garden Street",
#  'Lascaris Wharf',
#  'Liesse Hill',
#  'Lower Barrakka Lane',
#  'Marsamxett Street',
#  'Melita Street',
#  'Merchants Street',
#  'Mill Street',
#  'Nelson Avenue',
#  'Nix Mangiari Steps',
#  'North Street',
#  'Pope Pius V Street',
#  'Scots Street',
#  'South Street',
#  "St Andrew's Street",
#  "St Anne's Street",
#  "St Anthony's Street",
#  "St Barbara's Bastion",
#  'St Charles Street',
#  "St Dominic's Street",
#  "St Fredrick's Street",
#  "St George's Street",
#  "St John's Street",
#  "St John's Cavalier Street",
#  'St Joseph Street',
#  'St Lucy Street',
#  "St Michael's Street",
#  'St Nicholas Street',
#  'St Paul Street',
#  "St Patrick's Street",
#  'St Sebastian Street',
#  'St Ursula Street',
#  'Zachary Street',
#  'Christopher Street<ref>Christopher Street in Valletta was first named "Strada della Fontana" as a spring or fountain of fresh water was struck in its vicinity whilst a well for the storage of water was being excavated during the building of Valletta. The French Republican Government altered the name to "Rue des Droits de l\'Homme". The British Colonial Government then changed the name to "Strada Cristoforo"; Victor F. Denaro, \'\'The Houses of Valletta\'\', Malta, 1967.</ref>',
#  'St Mark Street',
#  'Spur Street',
#  'Fountain Street',
#  'Steps Street',
#  'Strait Street',
#  'Quarry Wharf',
#  'St Dominic Street',
#  'Toni Bajada Lane',
#  'Victory Street',
#  'Wells Street',
#  "[[St Elmo's Square]]",
#  "[[St John's Square]]",
#  "[[St George's Square",
#  '[[Republic Square, Valletta|Republic Square]]',
#  '[[Great Siege Square]]',
#  '[[Parliament House',
#  '[[Jean Parisot de Valette#Jean De Valette Square|Jean De Valette Square]]',
#  '[[Castille Square]]',
#  '[[Independence Square',
#  '[[Mattia Preti Square]]',
#  "[[St Elmo's Square]]",
#  "[[St John's Square]]",
#  "[[St George's Square",
#  '[[Republic Square, Valletta|Republic Square]]',
#  '[[Great Siege Square]]',
#  '[[Parliament House',
#  '[[Jean Parisot de Valette#Jean De Valette Square|Jean De Valette Square]]',
#  '[[Castille Square]]',
#  '[[Independence Square',
#  '[[Mattia Preti Square]]',
#  "Abercrombie's Bastion",
#  "Ball's Bastion",
#  'Castile Bastion',
#  'English Curtain',
#  'French Curtain',
#  'German Curtain',
#  '[[Lascaris Battery|Lascaris Bastion]]',
#  'Lower Castile Bastion',
#  "St Barbara's Bastion",
#  "St Gregory's Bastion",
#  'St James Bastion',
#  "St John's Bastion",
#  'St Lazarus Bastion',
#  'St Michael Bastion',
#  "St Sebastian's Bastion",
#  "Abercrombie's Bastion",
#  "Ball's Bastion",
#  'Castile Bastion',
#  'English Curtain',
#  'French Curtain',
#  'German Curtain',
#  '[[Lascaris Battery|Lascaris Bastion]]',
#  'Lower Castile Bastion',
#  "St Barbara's Bastion",
#  "St Gregory's Bastion",
#  'St James Bastion',
#  "St John's Bastion",
#  'St Lazarus Bastion',
#  'St Michael Bastion',
#  "St Sebastian's Bastion"]

# %%
with open(f"../output/street_type_designations.txt", 'r+', encoding="utf-8") as filepath:
    doc = filepath.read()
street_types = doc.split('\n')
street_types
# Out:
# ['Highway',
#  'Autobahn',
#  'Auto-estrada',
#  'Autoroute',
#  'Autostrada',
#  'Autostrasse',
#  'Bypass',
#  'Expressway',
#  'Freeway',
#  'Motorway',
#  'Pike',
#  'Turnpike',
#  'Avenue',
#  'Boulevard',
#  'Parade',
#  'Road',
#  'Street',
#  'Arcade',
#  'Alley',
#  'Bay',
#  'Branch',
#  'Brook',
#  'Burg',
#  'Byway',
#  'Camp',
#  'Center',
#  'Club',
#  'Common',
#  'Corner',
#  'Course',
#  'Dale',
#  'Divide',
#  'Drive',
#  'Estate',
#  'Flat',
#  'Forge',
#  'Fork',
#  'Fort',
#  'Gardens',
#  'Gate',
#  'Gateway',
#  'Glen',
#  'Green',
#  'Grove',
#  'Harbor',
#  'Haven',
#  'Heights',
#  'Highlands',
#  'Hollow',
#  'Key',
#  'Knoll',
#  'Landing',
#  'Lane',
#  'Light',
#  'Loaf',
#  'Lock',
#  'Lodge',
#  'Manor',
#  'Meadow',
#  'Mews',
#  'Mill',
#  'Mission',
#  'Neck',
#  'Orchard',
#  'Passage',
#  'Path',
#  'Pathway',
#  'Ranch',
#  'Rapid',
#  'Rest',
#  'Route',
#  'Row',
#  'Rue',
#  'Run',
#  'Station',
#  'Terrace',
#  'Throughway',
#  'Trace',
#  'Track',
#  'Trafficway',
#  'Trail',
#  'Trailer',
#  'Union',
#  'Vale',
#  'View',
#  'Village',
#  'Ville',
#  'Vista',
#  'Walk',
#  'Wall',
#  'Way',
#  'Well',
#  'Wynd',
#  'Cul-de-sac',
#  'Close',
#  'Court',
#  'Place',
#  'Cove',
#  'Bend',
#  'Circle',
#  'Crescent',
#  'Diagonal',
#  'Loop',
#  'Oval',
#  'Quadrant',
#  'Radial',
#  'Square',
#  'Bayou',
#  'Beach',
#  'Bluff',
#  'Bottom',
#  'Canyon',
#  'Cape',
#  'Cay',
#  'Causeway',
#  'Cliff',
#  'Creek',
#  'Crest',
#  'Curve',
#  'Fall',
#  'Field',
#  'Ford',
#  'Forest',
#  'Grade',
#  'Hill',
#  'Inlet',
#  'Island',
#  'Isle',
#  'Lake',
#  'Land',
#  'Mount',
#  'Mountain',
#  'Park',
#  'Parkway',
#  'Pass',
#  'Pine',
#  'Plain',
#  'Point',
#  'Prairie',
#  'Ridge',
#  'River',
#  'Shoal',
#  'Shore',
#  'Spring',
#  'Stream',
#  'Summit',
#  'Valley',
#  'Annex',
#  'Approach',
#  'Bridge',
#  'Bypass',
#  'Crossing',
#  'Crossroad',
#  'Dam',
#  'Esplanade',
#  'Extension',
#  'Ferry',
#  'Frontage road',
#  'Junction',
#  'Mall',
#  'Overpass',
#  'Parade',
#  'Park',
#  'Plaza',
#  'Port',
#  'Promenade',
#  'Quay',
#  'Ramp',
#  'Skyway',
#  'Spur',
#  'Stravenue',
#  'Tunnel',
#  'Underpass',
#  'Viaduct',
#  '']

# %%
all_items = []
for section, items in section_dict.items():
    for index, item in enumerate(items):
        #print(item)
        item = re.sub(r'\[|\]', '', item)
        if '<ref' in item:
            #print(item)
            all_items.append(re.search(r'(.*)\<ref', item).group(1))
        elif '|' in item:
            #print(item)
            #all_items.append(re.search(r'\|(.*)', item).group(1))
            for ytem in item.split('|'):
                all_items.append(ytem.strip())
        elif 'and ' in item:
            print(f"### and-split {index}")
            if ',' in item:
                #print(f"comma-split{item.split(',')}")
                item = re.sub(r'and ', ',', item)
                #print(f"### comma-split {index}")
                for ytem in item.split(','):
                    all_items.append(ytem.strip())
            else:
                #print(f"and-split{item.split('and')}")
                #print(f"### and-split {index}")
                for ytem in item.split('and '):
                    all_items.append(ytem.strip())
        elif '& ' in item:
            for ytem in item.split('& '):
                    all_items.append(ytem.strip())
        elif ',' in item:
            #print(f"comma-split{item.split(',')}")
            print(f"### comma-split {index}")
            for ytem in item.split(','):
                all_items.append(ytem.strip())

        else:
            all_items.append(item)

# %%
#for index,item in enumerate(all_items): print(index, item)

# %%
for index, item in enumerate(all_items):
    if '#' in item:
        #print(item)
        #print([ytem for ytem in item.split('#')])
        #print(all_items[:index])
        #print(all_items[index + 1:])
        all_items = all_items[:index-1] + [ytem for ytem in item.split('#')] + all_items[index + 1:]
    if ',' in item:
        all_items = all_items[:index-1] + [ytem for ytem in item.split(',')] + all_items[index + 1:]
            
all_items
# Out:
# ['Archbishop',
#  'Battery',
#  'Bishop',
#  'Carmelo',
#  'Carts',
#  'Castile',
#  'St Elmo',
#  'Old Bakery',
#  'St. Biagio',
#  'Boat',
#  'Bounty',
#  'Bull',
#  'Eagle',
#  'East',
#  'Engineers',
#  'Felix',
#  'G. Cassar',
#  'West',
#  'Knight',
#  'M.A. Vassalli',
#  'Mediterranean',
#  'New',
#  'Republic',
#  'Old Hospital',
#  'Old Mint',
#  'Old Treasury',
#  'Old Theater',
#  'Old Theater',
#  'Ordinance',
#  'Great Siege',
#  "King's Garden",
#  'Lascaris Wharf',
#  'Liesse',
#  'Lower Barrakka',
#  'Marsamxett',
#  'Melita',
#  'Merchants',
#  'Mill',
#  'Nelson',
#  'Nix Mangiari Steps',
#  'North',
#  'Pope Pius V',
#  'Scots',
#  'South',
#  "St Andrew's",
#  "St Anne's",
#  "St Anthony's",
#  "St Barbara's Bastion",
#  'St Charles',
#  "St Dominic's",
#  "St Fredrick's",
#  "St George's",
#  "St John's",
#  "St John's Cavalier",
#  'St Joseph',
#  'St Lucy',
#  "St Michael's",
#  'St Nicholas',
#  'St Paul',
#  "St Patrick's",
#  'St Sebastian',
#  'St Ursula',
#  'Zachary',
#  'Christopher',
#  'St Mark',
#  'Spur',
#  'Fountain',
#  'Steps',
#  'Strait',
#  'Quarry Wharf',
#  'St Dominic',
#  'Toni Bajada',
#  'Victory',
#  'Wells',
#  'Archbishop',
#  'Battery',
#  'Bishop',
#  'Carmelo',
#  'Carts',
#  'Castile',
#  'St Elmo',
#  'Old Bakery',
#  'St. Biagio',
#  'Boat',
#  'Bounty',
#  'Bull',
#  'Eagle',
#  'East',
#  'Engineers',
#  'Felix',
#  'G. Cassar',
#  'West',
#  'Knight',
#  'M.A. Vassalli',
#  'Mediterranean',
#  'New',
#  'Republic',
#  'Old Hospital',
#  'Old Mint',
#  'Old Treasury',
#  'Old Theater',
#  'Old Theater',
#  'Ordinance',
#  'Great Siege',
#  "King's Garden",
#  'Lascaris Wharf',
#  'Liesse',
#  'Lower Barrakka',
#  'Marsamxett',
#  'Melita',
#  'Merchants',
#  'Mill',
#  'Nelson',
#  'Nix Mangiari Steps',
#  'North',
#  'Pope Pius V',
#  'Scots',
#  'South',
#  "St Andrew's",
#  "St Anne's",
#  "St Anthony's",
#  "St Barbara's Bastion",
#  'St Charles',
#  "St Dominic's",
#  "St Fredrick's",
#  "St George's",
#  "St John's",
#  "St John's Cavalier",
#  'St Joseph',
#  'St Lucy',
#  "St Michael's",
#  'St Nicholas',
#  'St Paul',
#  "St Patrick's",
#  'St Sebastian',
#  'St Ursula',
#  'Zachary',
#  'Christopher',
#  'St Mark',
#  'Spur',
#  'Fountain',
#  'Steps',
#  'Strait',
#  'Quarry Wharf',
#  'St Dominic',
#  'Toni Bajada',
#  'Victory',
#  'Wells',
#  "St Elmo's",
#  "St John's",
#  'Republic Square',
#  ' Valletta',
#  'Republic',
#  'Great Siege',
#  'Jean Parisot de Valette',
#  'Jean De Valette',
#  'Jean De Valette',
#  'Castille',
#  'Independence',
#  'Mattia Preti',
#  "St Elmo's",
#  "St John's",
#  'Republic Square',
#  ' Valletta',
#  'Republic',
#  'Great Siege',
#  'Jean Parisot de Valette',
#  'Jean De Valette',
#  'Jean De Valette',
#  'Castille',
#  'Independence',
#  'Mattia Preti',
#  "Abercrombie's Bastion",
#  "Ball's Bastion",
#  'Castile Bastion',
#  'English Curtain',
#  'French Curtain',
#  'German Curtain',
#  'Lascaris Battery',
#  'Lascaris Bastion',
#  'Lower Castile Bastion',
#  "St Barbara's Bastion",
#  "St Gregory's Bastion",
#  'St James Bastion',
#  "St John's Bastion",
#  'St Lazarus Bastion',
#  'St Michael Bastion',
#  "St Sebastian's Bastion",
#  "Abercrombie's Bastion",
#  "Ball's Bastion",
#  'Castile Bastion',
#  'English Curtain',
#  'French Curtain',
#  'German Curtain',
#  'Lascaris Battery',
#  'Lascaris Bastion',
#  'Lower Castile Bastion',
#  "St Barbara's Bastion",
#  "St Gregory's Bastion",
#  'St James Bastion',
#  "St John's Bastion",
#  'St Lazarus Bastion',
#  'St Michael Bastion',
#  "St Sebastian's Bastion"]

# %%
if '#' in 'Jean Parisot de Valette#Jean De Valette Square': print('yes')
# Out:
# yes

# %%
for index, item in enumerate(all_items):
    #remove digits
    item = re.sub('\d', '', item).strip()
    # remove comments in parens
    item = re.sub(r'\((.*)\)', '', item).strip()
    # check if last word is street type
    # sometimes both words in street types will have to revalidate when creating
    if len(item.split(' ')) > 1:
        last_word = item.split(' ')[-1]
    if last_word in street_types:
        #print(last_word)
        #print(item)
        all_items[index] = item.replace(last_word, '').strip()
    else:
        all_items[index] = item
        
        #print(item)
all_items
# Out:
# ['Archbishop',
#  'Battery',
#  'Bishop',
#  'Carmelo',
#  'Carts',
#  'Castile',
#  'St Elmo',
#  'Old Bakery',
#  'St. Biagio',
#  'Boat',
#  'Bounty',
#  'Bull',
#  'Eagle',
#  'East',
#  'Engineers',
#  'Felix',
#  'G. Cassar',
#  'West',
#  'Knight',
#  'M.A. Vassalli',
#  'Mediterranean',
#  'New',
#  'Republic',
#  'Old Hospital',
#  'Old Mint',
#  'Old Treasury',
#  'Old Theater',
#  'Old Theater',
#  'Ordinance',
#  'Great Siege',
#  "King's Garden",
#  'Lascaris Wharf',
#  'Liesse',
#  'Lower Barrakka',
#  'Marsamxett',
#  'Melita',
#  'Merchants',
#  'Mill',
#  'Nelson',
#  'Nix Mangiari Steps',
#  'North',
#  'Pope Pius V',
#  'Scots',
#  'South',
#  "St Andrew's",
#  "St Anne's",
#  "St Anthony's",
#  "St Barbara's Bastion",
#  'St Charles',
#  "St Dominic's",
#  "St Fredrick's",
#  "St George's",
#  "St John's",
#  "St John's Cavalier",
#  'St Joseph',
#  'St Lucy',
#  "St Michael's",
#  'St Nicholas',
#  'St Paul',
#  "St Patrick's",
#  'St Sebastian',
#  'St Ursula',
#  'Zachary',
#  'Christopher',
#  'St Mark',
#  'Spur',
#  'Fountain',
#  'Steps',
#  'Strait',
#  'Quarry Wharf',
#  'St Dominic',
#  'Toni Bajada',
#  'Victory',
#  'Wells',
#  'Archbishop',
#  'Battery',
#  'Bishop',
#  'Carmelo',
#  'Carts',
#  'Castile',
#  'St Elmo',
#  'Old Bakery',
#  'St. Biagio',
#  'Boat',
#  'Bounty',
#  'Bull',
#  'Eagle',
#  'East',
#  'Engineers',
#  'Felix',
#  'G. Cassar',
#  'West',
#  'Knight',
#  'M.A. Vassalli',
#  'Mediterranean',
#  'New',
#  'Republic',
#  'Old Hospital',
#  'Old Mint',
#  'Old Treasury',
#  'Old Theater',
#  'Old Theater',
#  'Ordinance',
#  'Great Siege',
#  "King's Garden",
#  'Lascaris Wharf',
#  'Liesse',
#  'Lower Barrakka',
#  'Marsamxett',
#  'Melita',
#  'Merchants',
#  'Mill',
#  'Nelson',
#  'Nix Mangiari Steps',
#  'North',
#  'Pope Pius V',
#  'Scots',
#  'South',
#  "St Andrew's",
#  "St Anne's",
#  "St Anthony's",
#  "St Barbara's Bastion",
#  'St Charles',
#  "St Dominic's",
#  "St Fredrick's",
#  "St George's",
#  "St John's",
#  "St John's Cavalier",
#  'St Joseph',
#  'St Lucy',
#  "St Michael's",
#  'St Nicholas',
#  'St Paul',
#  "St Patrick's",
#  'St Sebastian',
#  'St Ursula',
#  'Zachary',
#  'Christopher',
#  'St Mark',
#  'Spur',
#  'Fountain',
#  'Steps',
#  'Strait',
#  'Quarry Wharf',
#  'St Dominic',
#  'Toni Bajada',
#  'Victory',
#  'Wells',
#  "St Elmo's",
#  "St John's",
#  'Republic',
#  'Valletta',
#  'Republic',
#  'Great Siege',
#  'Jean Parisot de Valette',
#  'Jean De Valette',
#  'Jean De Valette',
#  'Castille',
#  'Independence',
#  'Mattia Preti',
#  "St Elmo's",
#  "St John's",
#  'Republic',
#  'Valletta',
#  'Republic',
#  'Great Siege',
#  'Jean Parisot de Valette',
#  'Jean De Valette',
#  'Jean De Valette',
#  'Castille',
#  'Independence',
#  'Mattia Preti',
#  "Abercrombie's Bastion",
#  "Ball's Bastion",
#  'Castile Bastion',
#  'English Curtain',
#  'French Curtain',
#  'German Curtain',
#  'Lascaris Battery',
#  'Lascaris Bastion',
#  'Lower Castile Bastion',
#  "St Barbara's Bastion",
#  "St Gregory's Bastion",
#  'St James Bastion',
#  "St John's Bastion",
#  'St Lazarus Bastion',
#  'St Michael Bastion',
#  "St Sebastian's Bastion",
#  "Abercrombie's Bastion",
#  "Ball's Bastion",
#  'Castile Bastion',
#  'English Curtain',
#  'French Curtain',
#  'German Curtain',
#  'Lascaris Battery',
#  'Lascaris Bastion',
#  'Lower Castile Bastion',
#  "St Barbara's Bastion",
#  "St Gregory's Bastion",
#  'St James Bastion',
#  "St John's Bastion",
#  'St Lazarus Bastion',
#  'St Michael Bastion',
#  "St Sebastian's Bastion"]

# %%
dedupe_all_items = []
for item in all_items:
    if item not in dedupe_all_items:
        dedupe_all_items.append(item)
dedupe_all_items
# Out:
# ['Archbishop',
#  'Battery',
#  'Bishop',
#  'Carmelo',
#  'Carts',
#  'Castile',
#  'St Elmo',
#  'Old Bakery',
#  'St. Biagio',
#  'Boat',
#  'Bounty',
#  'Bull',
#  'Eagle',
#  'East',
#  'Engineers',
#  'Felix',
#  'G. Cassar',
#  'West',
#  'Knight',
#  'M.A. Vassalli',
#  'Mediterranean',
#  'New',
#  'Republic',
#  'Old Hospital',
#  'Old Mint',
#  'Old Treasury',
#  'Old Theater',
#  'Ordinance',
#  'Great Siege',
#  "King's Garden",
#  'Lascaris Wharf',
#  'Liesse',
#  'Lower Barrakka',
#  'Marsamxett',
#  'Melita',
#  'Merchants',
#  'Mill',
#  'Nelson',
#  'Nix Mangiari Steps',
#  'North',
#  'Pope Pius V',
#  'Scots',
#  'South',
#  "St Andrew's",
#  "St Anne's",
#  "St Anthony's",
#  "St Barbara's Bastion",
#  'St Charles',
#  "St Dominic's",
#  "St Fredrick's",
#  "St George's",
#  "St John's",
#  "St John's Cavalier",
#  'St Joseph',
#  'St Lucy',
#  "St Michael's",
#  'St Nicholas',
#  'St Paul',
#  "St Patrick's",
#  'St Sebastian',
#  'St Ursula',
#  'Zachary',
#  'Christopher',
#  'St Mark',
#  'Spur',
#  'Fountain',
#  'Steps',
#  'Strait',
#  'Quarry Wharf',
#  'St Dominic',
#  'Toni Bajada',
#  'Victory',
#  'Wells',
#  "St Elmo's",
#  'Valletta',
#  'Jean Parisot de Valette',
#  'Jean De Valette',
#  'Castille',
#  'Independence',
#  'Mattia Preti',
#  "Abercrombie's Bastion",
#  "Ball's Bastion",
#  'Castile Bastion',
#  'English Curtain',
#  'French Curtain',
#  'German Curtain',
#  'Lascaris Battery',
#  'Lascaris Bastion',
#  'Lower Castile Bastion',
#  "St Gregory's Bastion",
#  'St James Bastion',
#  "St John's Bastion",
#  'St Lazarus Bastion',
#  'St Michael Bastion',
#  "St Sebastian's Bastion"]

# %%
# remove empty string if caused eg 'Pellier Avenue & Court'
dedupe_all_items = [item for item in dedupe_all_items if item != '']
dedupe_all_items
# Out:
# ['Archbishop',
#  'Battery',
#  'Bishop',
#  'Carmelo',
#  'Carts',
#  'Castile',
#  'St Elmo',
#  'Old Bakery',
#  'St. Biagio',
#  'Boat',
#  'Bounty',
#  'Bull',
#  'Eagle',
#  'East',
#  'Engineers',
#  'Felix',
#  'G. Cassar',
#  'West',
#  'Knight',
#  'M.A. Vassalli',
#  'Mediterranean',
#  'New',
#  'Republic',
#  'Old Hospital',
#  'Old Mint',
#  'Old Treasury',
#  'Old Theater',
#  'Ordinance',
#  'Great Siege',
#  "King's Garden",
#  'Lascaris Wharf',
#  'Liesse',
#  'Lower Barrakka',
#  'Marsamxett',
#  'Melita',
#  'Merchants',
#  'Mill',
#  'Nelson',
#  'Nix Mangiari Steps',
#  'North',
#  'Pope Pius V',
#  'Scots',
#  'South',
#  "St Andrew's",
#  "St Anne's",
#  "St Anthony's",
#  "St Barbara's Bastion",
#  'St Charles',
#  "St Dominic's",
#  "St Fredrick's",
#  "St George's",
#  "St John's",
#  "St John's Cavalier",
#  'St Joseph',
#  'St Lucy',
#  "St Michael's",
#  'St Nicholas',
#  'St Paul',
#  "St Patrick's",
#  'St Sebastian',
#  'St Ursula',
#  'Zachary',
#  'Christopher',
#  'St Mark',
#  'Spur',
#  'Fountain',
#  'Steps',
#  'Strait',
#  'Quarry Wharf',
#  'St Dominic',
#  'Toni Bajada',
#  'Victory',
#  'Wells',
#  "St Elmo's",
#  'Valletta',
#  'Jean Parisot de Valette',
#  'Jean De Valette',
#  'Castille',
#  'Independence',
#  'Mattia Preti',
#  "Abercrombie's Bastion",
#  "Ball's Bastion",
#  'Castile Bastion',
#  'English Curtain',
#  'French Curtain',
#  'German Curtain',
#  'Lascaris Battery',
#  'Lascaris Bastion',
#  'Lower Castile Bastion',
#  "St Gregory's Bastion",
#  'St James Bastion',
#  "St John's Bastion",
#  'St Lazarus Bastion',
#  'St Michael Bastion',
#  "St Sebastian's Bastion"]

# %%
limit = 'all'
with open(f"../output/{topic}_{subtopic}_{limit}.txt", 'w+', encoding="utf-8") as fp:
    for item in dedupe_all_items:
        fp.write(item + '\n')

# %%
# use if items all are/begin with list of links [[link]]

items = []
descriptions = []
with open(topic + '_error_log.txt', 'w+', encoding="utf-8") as filepath:
    for index, line in enumerate(lines[77:291]):
        
        if re.match('\*\s*\[\[', line[0:5]):
            #print("%%%Match%%%")
            #print(line)
            try:
                line = re.sub(r'\<ref.*?\</ref>|\<ref.*\/>', '', line)
                
            except:
                topic_error_line = f"{topic} line sub parse error"
                item_line = f"{str(index)}, {line}"
                print(log_error(topic_error_line, item_line))
                
            try:
                
                item = re.search(r'\[\[(.*?)\]\]', line).group(1)
                
            except:
                topic_error_line = f"{topic} item parse error"
                item_line = f"{str(index)}, {line}"
                print(log_error(topic_error_line, item_line))
                
            try:
                
                description = re.search(r'\]\]\:*(.*)', line).group(1)
                
                
            except:
                topic_error_line = f"{topic} description parse error"
                item_line = f"{str(index)}, {line}"
                print(log_error(topic_error_line, item_line))
                
            items.append(item)
            descriptions.append(description)
        else:
            continue
            #print("%%%No%%%")
            #print(line)

# %%
items = [re.sub(r'\:wiktionary\:', '', item) for item in items]
items = [re.sub(r'\|.*', '', item) for item in items]
items

# %%
# use to find info page for each item/link and rank 
item_infos = []
for index, title in enumerate(items):
    with open(topic + '_error_log.txt', 'w+', encoding="utf-8") as filepath:
        
        url = 'https://en.wikipedia.org/w/index.php?title=' + title + '&action=info'

        #print(url)
        response = requests.get(url)
        doc = lxml.html.fromstring(response.content)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        try:
            # info_table = doc.xpath('//*[@class="wikitable mw-page-info"]')[0]
            watchers = doc.xpath('//*[@id="mw-pageinfo-watchers"]')[0][1].text
            
        except:
            topic_error_line = f"watchers parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            watchers = "#error#"

        try:
            redirects = doc.xpath('//*[contains(text(),"redirects")]/../../td')[1].text
            #redirects = doc.xpath('//*[contains(text(),"redirects")]/parent::node()/parent::node()')
            #redirects = doc.xpath('/html/body/div[3]/div[3]/div[3]/table[2]/tr[9]/td')[1].text
            
        except:
            topic_error_line = f"redirects parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            redirects = "#error#"
             
        try:
            views = doc.xpath('//*[@id="mw-pvi-month-count"]/td/div')[0].text
            
        except:
            topic_error_line = f"views parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            views = "#error#"        
        
        try:
            edits = doc.xpath('//*[@id="mw-pageinfo-edits"]/td')[1].text
            #edits = doc.xpath('/html/body/div[3]/div[3]/div[3]/table[4]/tr[5]/td')[1].text
    
        except:
            topic_error_line = f"edits parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            edits = "#error#"
        
        item_infos.append({
            topic: title,
            'watchers': watchers,
            'redirects': redirects,
            'views': views,
            'edits': edits
        })

# %%
# transfer item_infos to json file
import json
with open(topic + '_infos.json', 'w') as filepath:
    json.dump(item_infos, filepath)

# %%
error_items = [item[topic] for item in item_infos if item['views'] == '#error#']

for index, title in enumerate(error_items):
    with open('info_error_log.txt', 'w+', encoding="utf-8") as filepath:
        #print(title)
        del_idx = 0
        for index, item in enumerate(item_infos):
            if item[topic] == title:
                del_idx = index
                #del item_infos[index]
        #print(item)
        
        
        if re.match(r'\W*', title):
            print('%%%')
            search = re.search(r'(\w+)?', title).group(1)
            print(search)
            title = search
        
        print(title)
        
        url = 'https://en.wikipedia.org/w/index.php?title=' + title + '&action=info'

        #print(url)
        response = requests.get(url)
        doc = lxml.html.fromstring(response.content)
        soup = BeautifulSoup(response.content, 'html.parser')
  
        try:
            # info_table = doc.xpath('//*[@class="wikitable mw-page-info"]')[0]
            watchers = doc.xpath('//*[@id="mw-pageinfo-watchers"]')[0][1].text
            
        except:
            topic_error_line = f"watchers parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            watchers = "#error#"

        try:
            redirects = doc.xpath('//*[contains(text(),"redirects")]/../../td')[1].text
            #redirects = doc.xpath('//*[contains(text(),"redirects")]/parent::node()/parent::node()')
            #redirects = doc.xpath('/html/body/div[3]/div[3]/div[3]/table[2]/tr[9]/td')[1].text
            
        except:
            topic_error_line = f"redirects parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            redirects = "#error#"
             
        try:
            views = doc.xpath('//*[@id="mw-pvi-month-count"]/td/div')[0].text
            
        except:
            topic_error_line = f"views parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            views = "#error#"        
        
        try:
            edits = doc.xpath('//*[@id="mw-pageinfo-edits"]/td')[1].text
            #edits = doc.xpath('/html/body/div[3]/div[3]/div[3]/table[4]/tr[5]/td')[1].text
    
        except:
            topic_error_line = f"edits parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            edits = "#error#"
            
        item_infos[del_idx] = {
            topic: title,
            'watchers': watchers,
            'redirects': redirects,
            'views': views,
            'edits': edits
        }

# %%
with open('mineral_infos.json', 'r') as jfile:
    data=jfile.read()

# parse file
item_infos = json.loads(data)

# %%
_item_infos = item_infos
len(_item_infos)

# %%
#item_infos = [{item['views']: int(item['views'].replace(',', ''))} for item in item_infos]
for index, item in enumerate(_item_infos):
    if item['views'] != '#error#':
        if item['watchers'] == 'Fewer than 30 watchers':
            item['watchers'] = '29'
        item['views'] = int(item['views'].replace(',', ''))
        item['watchers'] = int(item['watchers'].replace(',', ''))
        #item['edits'] = int(item['edits'].replace(',', ''))

# %%
by_views = sorted(_item_infos, key=lambda k : k['views'], reverse=True)
for index, item in enumerate(by_views):
    item['view_rank'] = index

# %%
by_edits = sorted(_item_infos, key=lambda k : k['edits'], reverse=True)
for index, item in enumerate(by_edits):
    item['edit_rank'] = index

# %%
by_watchers = sorted(_item_infos, key=lambda k : k['watchers'], reverse=True)
for index, item in enumerate(by_watchers):
    item['watcher_rank'] = index

# %%
for item in _item_infos:
    #item['total_rank'] = (item['view_rank'] + item['edit_rank'] + item['watcher_rank']) / 3
    item['total_rank'] = (item['view_rank'] + item['watcher_rank']) / 2

# %%
by_total = sorted(_item_infos, key=lambda k : k['total_rank'], reverse=True)

# %%
dedupe = []
for item in by_total:
    if item[topic] not in dedupe:
        dedupe.append(item[topic])

# %%
start = 0
limit = 44
top_items = dedupe[start:limit]

# %%
with open(f"{topic}_{limit}.txt", 'w+', encoding="utf-8") as fp:
    for item in top_items:
        fp.write(item + '\n')

# %%
min_df = pd.DataFrame(_item_infos)
min_df.head()
min_df.sort_values(by=['total_rank'], ascending=False).head(100)

# %%
min_df = pd.DataFrame(_item_infos)
min_df.head()
min_df.sort_values(by=['views'], ascending=False).head(100)

# %%
min_df.sort_values(by=['watchers'], ascending=False).head(100)

# %%
min_df.sort_values(by=['edits'], ascending=False).head(100)

# %%
# parse data

lines = textDATA["parse"]["wikitext"]["*"].split('\n')[3:-10] # [::-1]
this_sec = {}
sec = ''
sub_sec = ''
with open('error_lines.txt', 'w+', encoding="utf-8") as filepath:
    for index, line in enumerate(lines):
        if index == 23:
            print(line)
        if re.match('==\w', line[0:3]):
            sec = line.strip().replace("=", "")
            if len(this_sec) > 0:
                section_dict[secs[secs.index(sec) - 1]] = this_sec
            this_sec = {}
        if type(section_dict[sec]).__name__ == 'list':
            if re.match('\*\[\[', line[0:3]):
                try:
                    poet = re.search(r'\[\[(.*?)\]\]', line).group(1)
                    #print(poet)

                except:
                    print("##########################")
                    print("#### poet parse error ####")
                    print(poet_method, index, line)
                    filepath.write(line + '\n')
                    print(line[-2:])
                    print("##########################")

                date_m = re.search('\((.*)\)', line)

                try:
                    date = date_m.group(0)
                except:
                    print("##########################")
                    print("#### date parse error ####")
                    print(index, line)
                    filepath.write(line + '\n')
                    date = ""
                    print("##########################")
                try:
                    # description = re.search('\)*,*.*', line).group(1)
                    # description = re.search('\),+.*', line).group(1)
                    # description = re.search('\]\s.*\)(.*)', line).group(1)
                    description = re.search('\]\](\)*,*.*)', line).group(1)
                except Exception as e:
                    print("#################################")
                    print("#### description parse error ####")
                    print(e)
                    print(index, line)
                    filepath.write(line + '\n')
                    print("#################################")
                # print(this_sec)
                # print(sub_sec)
                section_dict[sec].append({
                    'poet': poet,
                    'date': date,
                    'description': description
                })
        else:
            #print(sec)
            if re.match('===\w', line[0:4]):
                sub_sec = line.strip().replace("=", "")
                #print(sub_sec)
            if line.strip().replace("=", "") in section_dict[sec]:
                #print(sub_sec)
                this_sec[sub_sec] = []
            if sub_sec != '':
                if re.match('\*\[\[', line[0:3]):
                    try:
                        poet = re.search(r'\[\[(.*?)\]\]', line).group(1)
                        #print(poet)
                    except:
                        print("##########################")
                        print("#### poet parse error ####")
                        print(index, line)
                        filepath.write(line + '\n')
                        print(line[-2:])
                        print("##########################")
                    date_m = re.search('\((.*)\)', line)
                    try:
                        date = date_m.group(0)
                    except Exception as e:
                        print("##########################")
                        print("#### date parse error ####")
                        print(e)
                        print(index, line)
                        filepath.write(line + '\n')
                        date = ""
                        print("##########################")
                    try:
                        # description = re.search('\)*,*.*', line).group(1)
                        # description = re.search('\),+.*', line).group(0)
                        # description = re.search('\]\s.*\)(.*)', line).group(0)
                        description = re.search('\]\](\)*,*.*)', line).group(1)

                    except Exception as e:
                        print("#################################")
                        print("#### description parse error ####")
                        print(e)
                        print(index, line)
                        filepath.write(line + '\n')
                        description = ""
                        print("#################################")

                    this_sec[sub_sec].append({
                        'poet': poet,
                        'date': date,
                        'description': description
                    })
