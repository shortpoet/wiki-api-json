# %%
import requests
from pprint import pprint
import re
import lxml.html
from bs4 import BeautifulSoup
import pandas as pd

# %%
def log_error(line1, line2):
    _line1 = str(line1)
    _line2 = str(line2)
    diff = 0
    chars1 = len(_line1) + 10
    chars2 = len(_line2) + 10
    if chars1 > chars2:
        diff = chars1 - chars2
        if diff % 2 != 0:
            diff = int(diff - .5)
            _line2 = '# ' + _line2
        else:
            _line2 = ' ' + _line2
        main_hashes = ''.join(['#' for i in range(chars1)])
        hashes = ''.join(['#' for i in range(int(diff/2)+4)])
        log_line = (f"{main_hashes}\n"
                    f"#### {_line1} ####\n"
                    f"{hashes}{_line2} {hashes}\n"                    
                    f"{main_hashes}\n")
        return(log_line)
   
    elif chars2 > chars1:
        diff = chars2 - chars1
        if diff % 2 != 0:
            diff = int(diff - .5)
            _line1 = '# ' + _line1
        else:
            _line1 = ' ' + _line1
        main_hashes = ''.join(['#' for i in range(chars2)])
        hashes = ''.join(['#' for i in range(int(diff/2)+4)])
        log_line = (f"{main_hashes}\n"
                    
                    f"{hashes}{_line1} {hashes}\n"
                    f"#### {_line2} ####\n"
                    f"{main_hashes}\n")
        return(log_line)
        
    else:
        hashes = '####'
        main_hashes = ''.join(['#' for i in range(chars2)])
        log_line = (f"{main_hashes}\n"
                    f"#### {_line1} ####\n"
                    f"{hashes} {_line2} {hashes}\n"
                    f"{main_hashes}\n")
        return(log_line)

# %%
# init session 
S = requests.Session()

# set URL
URL = "https://en.wikipedia.org/w/api.php"

# %%
page_id = "404534"
topic = 'trees'

# %%
# get sections
PARAMS = {
    "action": "parse",
    "pageid": page_id,
    "format": "json",
    "prop": "sections"
}

sectionsR = S.get(url=URL, params=PARAMS)
sectionDATA = sectionsR.json()

# %%
sectionDATA
# Out:
# {'parse': {'title': 'List of individual trees',
#   'pageid': 404534,
#   'sections': [{'toclevel': 1,
#     'level': '2',
#     'line': 'Real forests and individual trees',
#     'number': '1',
#     'index': '1',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 435,
#     'anchor': 'Real_forests_and_individual_trees'},
#    {'toclevel': 2,
#     'level': '3',
#     'line': 'Africa',
#     'number': '1.1',
#     'index': '2',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 474,
#     'anchor': 'Africa'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Living',
#     'number': '1.1.1',
#     'index': '3',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 488,
#     'anchor': 'Living'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Historical',
#     'number': '1.1.2',
#     'index': '4',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 3941,
#     'anchor': 'Historical'},
#    {'toclevel': 2,
#     'level': '3',
#     'line': 'Asia',
#     'number': '1.2',
#     'index': '5',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 4926,
#     'anchor': 'Asia'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Living',
#     'number': '1.2.1',
#     'index': '6',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 4938,
#     'anchor': 'Living_2'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Historical',
#     'number': '1.2.2',
#     'index': '7',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 11885,
#     'anchor': 'Historical_2'},
#    {'toclevel': 2,
#     'level': '3',
#     'line': 'Europe',
#     'number': '1.3',
#     'index': '8',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 16100,
#     'anchor': 'Europe'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Living',
#     'number': '1.3.1',
#     'index': '9',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 16114,
#     'anchor': 'Living_3'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Historical',
#     'number': '1.3.2',
#     'index': '10',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 31462,
#     'anchor': 'Historical_3'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Petrified',
#     'number': '1.3.3',
#     'index': '11',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 35694,
#     'anchor': 'Petrified'},
#    {'toclevel': 2,
#     'level': '3',
#     'line': 'North America',
#     'number': '1.4',
#     'index': '12',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 35842,
#     'anchor': 'North_America'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Living',
#     'number': '1.4.1',
#     'index': '13',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 35974,
#     'anchor': 'Living_4'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Historical',
#     'number': '1.4.2',
#     'index': '14',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 62871,
#     'anchor': 'Historical_4'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Petrified',
#     'number': '1.4.3',
#     'index': '15',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 74981,
#     'anchor': 'Petrified_2'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Other',
#     'number': '1.4.4',
#     'index': '16',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 76235,
#     'anchor': 'Other'},
#    {'toclevel': 2,
#     'level': '3',
#     'line': 'Central America',
#     'number': '1.5',
#     'index': '17',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 77374,
#     'anchor': 'Central_America'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Living',
#     'number': '1.5.1',
#     'index': '18',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 77397,
#     'anchor': 'Living_5'},
#    {'toclevel': 2,
#     'level': '3',
#     'line': 'South America',
#     'number': '1.6',
#     'index': '19',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 77551,
#     'anchor': 'South_America'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Living',
#     'number': '1.6.1',
#     'index': '20',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 77572,
#     'anchor': 'Living_6'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Historical',
#     'number': '1.6.2',
#     'index': '21',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 80005,
#     'anchor': 'Historical_5'},
#    {'toclevel': 2,
#     'level': '3',
#     'line': 'Oceania',
#     'number': '1.7',
#     'index': '22',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 80196,
#     'anchor': 'Oceania'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Living',
#     'number': '1.7.1',
#     'index': '23',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 80211,
#     'anchor': 'Living_7'},
#    {'toclevel': 3,
#     'level': '4',
#     'line': 'Historical',
#     'number': '1.7.2',
#     'index': '24',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 85464,
#     'anchor': 'Historical_6'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'Mythological and religious',
#     'number': '2',
#     'index': '25',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 87152,
#     'anchor': 'Mythological_and_religious'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'See also',
#     'number': '3',
#     'index': '26',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 88161,
#     'anchor': 'See_also'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'References',
#     'number': '4',
#     'index': '27',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 88473,
#     'anchor': 'References'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'External links',
#     'number': '5',
#     'index': '28',
#     'fromtitle': 'List_of_individual_trees',
#     'byteoffset': 88501,
#     'anchor': 'External_links'}]}}

# %%
sections = [sec['anchor'] for sec in sectionDATA["parse"]["sections"]]

# %%
# create section list filtering out non-data sections
filt = [
    'References',
    'See_also',
    'External_links'
]

incl = [
    'Schemes',
    'Tropes'
]

sec_list = [sec for sec in sectionDATA["parse"]["sections"] if not sec['anchor'] in filt]
# sec_list = [sec for sec in sectionDATA["parse"]["sections"] if sec['anchor'] in incl]


len(sec_list)
sec_list
# Out:
# [{'toclevel': 1,
#   'level': '2',
#   'line': 'Real forests and individual trees',
#   'number': '1',
#   'index': '1',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 435,
#   'anchor': 'Real_forests_and_individual_trees'},
#  {'toclevel': 2,
#   'level': '3',
#   'line': 'Africa',
#   'number': '1.1',
#   'index': '2',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 474,
#   'anchor': 'Africa'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Living',
#   'number': '1.1.1',
#   'index': '3',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 488,
#   'anchor': 'Living'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Historical',
#   'number': '1.1.2',
#   'index': '4',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 3941,
#   'anchor': 'Historical'},
#  {'toclevel': 2,
#   'level': '3',
#   'line': 'Asia',
#   'number': '1.2',
#   'index': '5',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 4926,
#   'anchor': 'Asia'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Living',
#   'number': '1.2.1',
#   'index': '6',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 4938,
#   'anchor': 'Living_2'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Historical',
#   'number': '1.2.2',
#   'index': '7',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 11885,
#   'anchor': 'Historical_2'},
#  {'toclevel': 2,
#   'level': '3',
#   'line': 'Europe',
#   'number': '1.3',
#   'index': '8',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 16100,
#   'anchor': 'Europe'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Living',
#   'number': '1.3.1',
#   'index': '9',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 16114,
#   'anchor': 'Living_3'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Historical',
#   'number': '1.3.2',
#   'index': '10',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 31462,
#   'anchor': 'Historical_3'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Petrified',
#   'number': '1.3.3',
#   'index': '11',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 35694,
#   'anchor': 'Petrified'},
#  {'toclevel': 2,
#   'level': '3',
#   'line': 'North America',
#   'number': '1.4',
#   'index': '12',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 35842,
#   'anchor': 'North_America'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Living',
#   'number': '1.4.1',
#   'index': '13',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 35974,
#   'anchor': 'Living_4'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Historical',
#   'number': '1.4.2',
#   'index': '14',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 62871,
#   'anchor': 'Historical_4'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Petrified',
#   'number': '1.4.3',
#   'index': '15',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 74981,
#   'anchor': 'Petrified_2'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Other',
#   'number': '1.4.4',
#   'index': '16',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 76235,
#   'anchor': 'Other'},
#  {'toclevel': 2,
#   'level': '3',
#   'line': 'Central America',
#   'number': '1.5',
#   'index': '17',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 77374,
#   'anchor': 'Central_America'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Living',
#   'number': '1.5.1',
#   'index': '18',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 77397,
#   'anchor': 'Living_5'},
#  {'toclevel': 2,
#   'level': '3',
#   'line': 'South America',
#   'number': '1.6',
#   'index': '19',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 77551,
#   'anchor': 'South_America'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Living',
#   'number': '1.6.1',
#   'index': '20',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 77572,
#   'anchor': 'Living_6'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Historical',
#   'number': '1.6.2',
#   'index': '21',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 80005,
#   'anchor': 'Historical_5'},
#  {'toclevel': 2,
#   'level': '3',
#   'line': 'Oceania',
#   'number': '1.7',
#   'index': '22',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 80196,
#   'anchor': 'Oceania'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Living',
#   'number': '1.7.1',
#   'index': '23',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 80211,
#   'anchor': 'Living_7'},
#  {'toclevel': 3,
#   'level': '4',
#   'line': 'Historical',
#   'number': '1.7.2',
#   'index': '24',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 85464,
#   'anchor': 'Historical_6'},
#  {'toclevel': 1,
#   'level': '2',
#   'line': 'Mythological and religious',
#   'number': '2',
#   'index': '25',
#   'fromtitle': 'List_of_individual_trees',
#   'byteoffset': 87152,
#   'anchor': 'Mythological_and_religious'}]

# %%
for index, line in enumerate(lines):
    print(index, line)
# Out:
# 0 {{distinguish|List of trees and shrubs by taxonomic family}}
# 1 The following is a '''list of notable trees''' from around the world. Trees listed here are regarded as important or specific by their historical, national, locational, natural or mythological context.  The list includes actual [[tree]]s located throughout the world, as well as [[#Mythological and religious|trees from myths]].
# 2
# 3 {{Dynamic list}}
# 4 {{GeoGroup}}
# 5 {{TOC left}}
# 6
# 7 ==Real forests and individual trees==
# 8
# 9 ===Africa===
# 10
# 11 ====Living====
# 12 {| class="wikitable"
# 13 |-
# 14 !Name
# 15 !Species
# 16 !Location
# 17 !Age (years)
# 18 !Notes
# 19 |-
# 20 |[[Lost Tree]]
# 21 |[[Acacia]]
# 22 |[[Sahara desert]] <br/><small> {{Coord|20.645|N|11.249|E|name=Lost Tree}}</small>
# 23 | -
# 24 |A very isolated tree and important landmark
# 25 |-
# 26 |[[Cotton Tree (Sierra Leone)|The Cotton Tree]]
# 27 |[[Ceiba pentandra|Kapok]] (''[[Ceiba pentandra]]'')
# 28 |[[Freetown]], [[Sierra Leone]] <br/><small>{{Coord|8.4872|N|13.2356|W|name=The Cotton Tree}}
# 29 | -
# 30 | [[File:Cotton Tree (Sierra Leone).jpg|100px|left]] Historic symbol of Freetown.
# 31 |-
# 32 | [[Wonderboom (tree)|Wonderboom tree in Pretoria]]
# 33 | [[Ficus salicifolia|Wonderboom]] (''[[Ficus salicifolia]]'')
# 34 | [[Pretoria]], [[South Africa]] <br/><small> {{coord|-25.6870|28.1918|name=Wonderboom tree}}</small>
# 35 | -
# 36 | [[File:Wonderboom wiki.jpg|100px|left]] A sprawling fig tree in [[Pretoria]], South Africa.
# 37 |-
# 38 |[[El Drago Milenario]]
# 39 | [[Dragon Tree]] (''[[Dracaena draco]]'')
# 40 |[[Icod de los Vinos]], [[Tenerife]] <br/><small> {{Coord|28.3666|-16.72222|name=El Drago Milenario}} </small>
# 41 | -
# 42 | [[File:Dracaena draco.jpg|100px|left]] Has been a local tourist attraction for more than a hundred years (mentioned by [[Alexander von Humboldt]], for instance).
# 43 |-
# 44 |[[Sunland Baobab]]
# 45 |[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')
# 46 |[[Limpopo Province]], [[South Africa]]<br/><small>{{coord|23|37|16|S|30|11|53|E|name=Sunland Baobab}}</small>
# 47 |1060
# 48 | [[File:Sunland Baobab, Limpopo, South Africa (5613316944).jpg|100px|left]] A giant and ancient baobab tree, with a [[pub]] in the hollow.
# 49 |-
# 50 |[[Sagole Baobab]]
# 51 |[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')
# 52 |Near [[Tshipise]], in [[Vendaland]], Limpopo Province, South Africa <br/> <small> {{coord|22|30|00|S|30|38|00|E|name=Sagole Baobab}}</small>
# 53 |
# 54 |[[File:Sagole Baobab.jpg|100px|left]] Largest baobab in South Africa
# 55 |-
# 56 |[[Glencoe Baobab]]
# 57 |[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')
# 58 |[[Hoedspruit]], South Africa <br/><small>{{coord|24|22|25|S|30|51|24|E|name=Glencoe Baobab}}</small>
# 59 |1835
# 60 |Stoutest and second largest baobab in South Africa
# 61 |-
# 62 |[[Ombalantu baobab tree]]
# 63 |[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')
# 64 |[[Outapi]], Namibia<br/><small>{{coord|17|30|43|S|14|59|16|E|name=Ombalantu baobab tree}} </small>
# 65 |800
# 66 |[[File:Ombalantu Baobab Tree.jpg|100px|left]] Has served as a chapel, post office, house, and place of hiding.
# 67 |-
# 68 |[[Omukwiyugwemanya]]
# 69 |Fig tree
# 70 |[[Oshigambo]], Namibia <br/> <small>{{coord|-17.7870|16.0740|name=Omukwiyugwemanya}}</small>
# 71 |
# 72 |Tourist attraction
# 73 |-
# 74 |[[Post Office Tree]]
# 75 |[[Sideroxylon inerme|White Milkwood]] (''[[Sideroxylon inerme]]'')
# 76 |[[Mosselbay]], South Africa <br/><small>{{coord|-34.180363|22.141382|name=Post Office Tree}}</small>
# 77 |c.600
# 78 |[[File:The Post Office Tree.JPG|100px|left]] Acted as a "post office" in earlier times and now has a boot shaped postbox.
# 79 |-
# 80 |[[Treaty Tree]]
# 81 |[[Sideroxylon inerme|White Milkwood]] (''[[Sideroxylon inerme]]'')
# 82 |[[Woodstock, Cape Town]], South Africa <br/> <small> {{coord|-33.92626|18.45130|name=Treaty Tree}} </small>
# 83 |c.500
# 84 |[[File:Photo 5 Treaty Tree. Cnr Treaty and Spring St, Woodstock. Cape Town..JPG|100px|left]] Site of Peace Treaty in 1806.
# 85 |-
# 86 |[[Big Tree in Chirinda Forest]]
# 87 |[[Khaya anthotheca|Nyasa Redwood]] (''Khaya anthotheca '')
# 88 |[[Chirinda Forest]], Zimbabwe <br/> <small> {{coordinates|20|26|29|S|32|42|15|E|name=Big Tree in Chirinda Forest}} </small>
# 89 |1000+
# 90 |Declared a National Monument
# 91 |-
# 92 |}
# 93
# 94 ====Historical====
# 95 {| class="wikitable"
# 96 |-
# 97 !Name
# 98 !Species
# 99 !Location
# 100 !Age (years)
# 101 !Notes
# 102 |-
# 103 |[[Arbre du Ténéré]]
# 104 |Acacia
# 105 |[[Sahara desert]]<br/><small>{{coord|17|45|00|N|10|04|00|E|name=Arbre du Ténéré}}</small>
# 106 |
# 107 | [[File:Arbre-du-tenere-1961.jpg|100px|left]] A very isolated tree in the Sahara desert, notable before 1934, in [[Niger]], destroyed in 1973.
# 108 |-
# 109 |Panke Baobab
# 110 |[[Adansonia digitata|African Baobab]]
# 111 |[[Zimbabwe]]
# 112 | 2,419
# 113 | Oldest documented non-clonal [[angiosperm]].  Tree fell in 2011.<ref>Adrian Patrut et al. (2018) The demise of the largest and oldest African baobabs. Nature Plants 4: 423–426. DOI: 10.1038/s41477-018-0170-5</ref>
# 114 |-
# 115 |Chapman's Baobab
# 116 |[[Adansonia digitata|African Baobab]]
# 117 |[[Botswana]]
# 118 |
# 119 | [[File:Chapman's_baobab_(4954708191).jpg|100px|left]] Found and named after James Chapman and marked by explorer [[David Livingstone]].  Tree fell in 2016.<ref>https://africageographic.com/blog/chapmans-baobob-one-of-africas-largest-trees-falls/</ref>
# 120 |}
# 121
# 122 ===Asia===
# 123
# 124 ====Living====
# 125 {|class="wikitable"
# 126 |-
# 127 !Name
# 128 !Species
# 129 !Location
# 130 !Age (years)
# 131 !Notes
# 132 |-
# 133 |[[Sarv-e Abarkuh|Cypress of Abarkuh]]
# 134 |[[Cypress]] (''[[Cupressus sempervirens]]'')
# 135 |[[Abarkuh]], [[Yazd Province]], [[Iran]]
# 136 |4,500
# 137 | Cypress of Abarkuh is the second oldest living tree in the world.
# 138 |-
# 139 |[[Sisters Olive Trees of Noah]]
# 140 |[[Olive Tree]] (''[[Olea europaea]]'')
# 141 |[[Bcheale]], [[Batroun District]], [[Lebanon]]
# 142 | Claimed to be 5,000 to 6,000
# 177 |[[Anuradhapura]], [[Sri Lanka]] <br/><small> {{coord|8|20|41|N|80|23|48|E|name=Jaya Sri Maha Bodhi}}</small>
# 178 |2300
# 179 |[[File:Jaya Sri Maha Bodhi.jpg|100px|left]] A [[sacred fig]] propagated from the [[Bodhi tree]] under which [[Lord Buddha]] became enlightened. It was planted in 288 BC.<ref>{{cite web|url= http://www.sundayobserver.lk/2011/07/03/spe01.asp|title= ''Caring for the Jaya Sri Maha Bodhi ''|accessdate= 2012-01-30|author= Shanika Sriyananda|date= 2011-07-03|url-status= dead|archiveurl= https://web.archive.org/web/20130413143127/http://www.sundayobserver.lk/2011/07/03/spe01.asp|archivedate= 2013-04-13}}</ref>
# 180 |-
# 181 |[[Jōmon Sugi]]
# 182 |[[Cryptomeria|Japanese Cedar]] (''[[Cryptomeria japonica]]'')
# 183 |[[Yakushima]] island, [[Japan]] <br/><small> {{coord|30|21|40.76|N|130|31|55.81|E|name=Jōmon Sugi}}</small>
# 184 | -
# 185 | [[File:Jomon Sugi Panorama.jpg|100px|left]] Ancient specimen
# 186 |-
# 187 |[[Great sugi of Kayano]]
# 188 |Cryptomeria|Japanese Cedar (''Cryptomeria japonica'')
# 189 |[[Kaga, Ishikawa|Kaga]], [[Ishikawa Prefecture]], Japan <br/><small> {{coord|36|13|39|N|136|21|36|E|name=Great sugi of Kayano}}</small>
# 190 |2,300
# 191 | [[File:Kayano Ōsugi 20070814.jpg|100px|left]]
# 192 |-
# 193 |[[Natural monuments of South Korea#51-100|Ginkgo Tree of the Confucian Shrine of Seoul]]
# 194 |[[Ginkgo]] (''[[Ginkgo biloba]]'')
# 195 |[[Sungkyunkwan University]], [[Seoul]], [[South Korea]]
# 196 |500
# 197 |A pair of ginkgo trees
# 198 |-
# 199 |[[Big Banyan Tree]]
# 200 |Banyan (''Ficus benghalensis'')
# 201 |[[Ramohalli]], [[Bangalore]], India <br/><small> {{coord|12|54|34|N|77|23|44|E|name=Dodda Aladha Mara}}</small>
# 202 |400
# 203 |[[File:Dod alada mara.jpg|100px|left]]
# 204 |-
# 205 |[[Tree of Life, Bahrain|Tree of Life]]
# 206 |[[Prosopis cineraria|Mesquite]] (''[[Prosopis cineraria]]'')
# 207 |[[Bahrain]] <br/><small> {{coord|25.994073|N|50.583235|E|name=Tree of Life}}</small>
# 208 |400
# 209 | [[File:Tree of Life Bahrain.jpg|100px|left]]
# 210 |-
# 211 |[[Chankiri Tree]] (Killing tree)
# 212 |[[Samanea saman|Samanea saman/Albizzia saman]]<ref>{{cite web |url=http://www.cafaca.com/index.php?option=com_cafaca&view=treetype&id=12&Itemid=110&lang=en}}</ref>
# 213 |[[Cambodia]]n [[Killing Fields]]
# 214 | -
# 215 | [[File:ChoeungEk-Darter-7.jpg|100px|left]] A tree in the [[Killing Fields]] against which children and infants were slung to kill them.
# 216 |-
# 217 |[[Rahmat tree]]
# 218 |[[Platanus|Plane Tree]] (''[[Platanus]]'')
# 219 |[[Kermanshah]], [[Kermanshah Province|Kermanshahan Province]], [[Iran]]
# 220 |700
# 221 |Located in the historical area of [[Taq Bostan]].
# 222 |-
# 223 |The Ying Ke Pine
# 224 |[[Huangshan pine]] (''[[Pinus hwangshanensis]]'')
# 225 |[[Huangshan]], [[China]]
# 226 | Thought to be 1,500
# 227 | [[File:Huangshan pic 2.jpg|100px|left]] Ying Ke, meaning "Welcoming-Guests" pine on Huangshan.
# 228 |-
# 229 |
# 230 |[[Tembusu]] (''[[Fagraea fragrans]]'')
# 231 |[[Singapore Botanical Gardens]], [[Singapore]]
# 232 |100
# 233 |The tree is featured on the reverse of a [[Singapore Portrait Series currency notes#Specifications|$5]] Singapore note.
# 234 |-
# 235 |[[Judean date palm#Germination of 2000-year-old seed|Methuselah]]
# 236 |[[Judean date palm]] (''[[Phoenix dactylifera]]'')
# 237 |[[Israel]]
# 238 | About 12
# 239 | [[File:JudeanDatePalmMethuselah.JPG|100px|left]] The formerly extinct tree was sprouted from a 2,000-year-old seed.
# 240 |-
# 241 |[[Hathi ka pedh]]
# 242 |[[Baobab]] (''Adansonia digitata'')
# 243 |[[Purana Qila]], [[Hyderabad]], [[Telangana]], [[India]]
# 244 | 320
# 245 | A gift from African traders, this huge tree is an iconic landmark of the erstwhile [[Qutb Shahi]] era.
# 246 |-
# 247 |[[Takeshi Kaneshiro Tree]]<br>(金城武樹)
# 248 |[[Bishop wood]] ([[Bischofia javanica]])
# 249 |[[Chishang, Taitung|Chishang]], [[Taitung County|Taitung]], [[Taiwan]]
# 250 | About 40
# 251 | [[File:金城武樹 (14545001530).jpg|100px|left]] Made famous by advertisements for [[EVA Air]] with [[Takeshi Kaneshiro]] made in June 2013 under this tree.
# 252 |}
# 253
# 254 ====Historical====
# 255 {|class="wikitable"
# 256 |-
# 257 !Name
# 258 !Species
# 259 !Location
# 260 !Age (years)
# 261 !Notes
# 262 |-
# 263 |Alishan Sacred Tree
# 264 |[[Cypress]]
# 265 |[[Alishan, Chiayi|Alishan]] train station, [[Taiwan]]
# 266 |3,000
# 267 |The tree fell on July 1, 1997.
# 268 |-
# 269 | The [[Bodhi tree]]
# 270 |Sacred fig (''Ficus religiosa'')
# 271 |[[Bodh Gaya]], India<br/><small>{{coord|24|41|45.29|N|84|59|29.29|E|name=Bodhi Tree}}</small>
# 272 | -
# 273 |The tree under which [[Gautama Buddha|Buddha]] obtained enlightenment. The current tree at the site is a replacement.
# 274 |-
# 275 |[[Guilty Chinese Scholartree]]
# 276 |[[Pagoda Tree]] (''[[Styphnolobium japonicum]]'')
# 277 |[[Jingshan park]]<br/><small>{{coord|39|55|23.22|N|116|23|33.64|E|name=Guilty Chinese Scholartree}}</small>
# 278 |
# 279 |[[File:Guilty Chinese Scholar Tree.jpg|100px|left]] The tree on which the [[Chongzhen Emperor]] hanged himself shortly after escaping the [[Forbidden City]] in [[Beijing]], [[China]]. The original tree died and was replaced by a replica.
# 280 |-
# 281 |[[Changi Tree]]
# 282 |Either
# 283
# 284 ''[[Hopea sangal]]''
# 285
# 286 or
# 287
# 288 ''[[Sindora| Sindora wallichii]]''
# 289
# 290 |[[Singapore]]
# 291 |
# 329 |-
# 330 |
# 331 |Ginkgo (''Ginkgo biloba'')
# 332 |[[Tsurugaoka Hachiman-gū]], [[Kamakura, Kanagawa|Kamakura]], [[Kanagawa Prefecture]], [[Japan]]
# 333 |1,000
# 334 |[[File:Fallen Ginkgo - roots.jpg|100px|left]] The ancient tree was uprooted in a storm in 2010.
# 335 |}
# 336
# 337 ===Europe===
# 338
# 339 ====Living====
# 340 {| class="wikitable"
# 341 |-
# 342 !Name
# 343 !Species
# 344 !Location
# 345 !Age (years)
# 346 !Notes
# 347 |-
# 348 |[[Old Tjikko]]
# 349 |[[Norway spruce]] (''[[Picea abies]]'')
# 350 |[[Dalarna]] [[Sweden]] <br/><small>{{coord|61|35|N|12|40|E|name=Old Tjikko (approximate location)}}</small>
# 351 | {{age nts|-7542|04|17}}<ref name=bbc>{{cite news |url=http://news.bbc.co.uk/2/hi/europe/7353357.stm |title=Swedes find 'world's oldest tree' |date=17 April 2008 |accessdate=6 May 2008 |publisher=[[BBC News]] }}</ref>
# 352 | [[File:Old-Tjikko-2011-07-19-001.jpg|100px|left]] The oldest known individual clonal tree in the world.
# 353 |-
# 354 |[[Stara Maslina]]
# 355 |Olive Tree (''Olea europaea'')
# 356 |Bar, Montenegro <br/><small> {{coord|42|04|48|N|19|07|46|E|name=Stara Maslina}}</small>
# 357 |2240
# 358 |
# 359 |-
# 360 |[[Ballyconnell Yew]]
# 361 |[[Taxaceae|Yew]]
# 362 | Grounds of [[Ballyconnell]] House, [[Annagh, County Cavan|Annagh]] townland, [[County Cavan]], [[Ireland]]
# 363 | >2,000
# 364 | Ancient tree reckoned to be well over 2,000 years old with a massive girth.
# 365 |-
# 366 |[[Craigends Yew]] (''Taxus Baccata'')
# 367 |[[Taxaceae|Yew]]
# 368 | Grounds of the old [[Craigends]] estate, [[Houston, Renfrewshire]], [[Scotland]] <br/> <small> {{Coord|55.862413|N|4.5262771|W|name=Craigends Yew}} </small>
# 369 | >700
# 370 | [[File:Craigends Yew grove, Houston, Renfrewshire - view from the old ice house.jpg|100px|left]] Largest layering yew tree in Scotland with a 100-metre circumference of the crown
# 371 |-
# 372 |
# 373 |[[Scots pine]] (''[[Pinus sylvestris]]'')
# 374 |[[Urho Kekkonen National Park]], [[Lapland (Finland)]], [[Finland]]
# 375 | 770
# 376 | Considered one of the oldest trees in Finland. Probably the oldest Scots pine in the world.
# 377 |-
# 378 |[[Fortingall Yew]]
# 379 |[[European yew]] (''[[Taxus baccata]]'')
# 380 |Churchyard of the village of [[Fortingall]] in [[Perthshire]], [[Scotland]]  <br/><small> {{coord|56.598158|N|4.051007|W|name=Fortingall Yew}}</small>
# 381 |2,000–5,000
# 382 | Various estimates have put its age at between 2,000 and 5,000 years.
# 383 |-
# 384 |[[Florencecourt Yew]]
# 385 |[[Irish Yew]] (''Taxus baccata'')
# 386 |[[Florence Court]] estate near [[Enniskillen]], [[Fermanagh]], [[Northern Ireland]] <br/><small> {{coord|54.261004|-7.727313|name=Florencecourt Yew}}</small>
# 387 |{{age|1740|1|1}}
# 388 |Replanted in 1740 as a sapling. Following commercial propagation of the tree after 1820, it is believed that the majority of Irish Yews outside Ireland are derived from this one tree.
# 389 |-
# 390 |[[Bermiego Yew]]
# 391 |European yew (''Taxus baccata'')
# 392 |[[Bermiego]], Asturias, Spain <br/><small>{{coord|43.200930|-5.984258|name=Bermiego Yew }}</small>
# 393 |c.2000
# 394 |[[File:Texu.jpg|100px|left]] Considered one of the oldest yews in Europe.
# 395 |-
# 396 |[[Caesarsboom]] (Caesar's Tree)
# 397 |European yew (''Taxus baccata'')
# 398 | [[Lo, Belgium]] <br/><small> {{coord|50.98028|2.74554|name=Caesarsboom}}</small>
# 399 |
# 400 | [[File:Lo - Caesarsboom.jpg|100px|left]] Noted for the legend that [[Julius Caesar]] tethered his horse to it during his conquest of the region.
# 401 |-
# 402 |Estry Yew
# 403 |Yew
# 404 |[[Estry]], [[Normandy]], [[France]] <br/><small> {{coord|48.896988|-0.734029|name=Estry Yew}} </small>
# 405 | > 1,600
# 406 | Considered one of the oldest trees in France. Its hollow trunk can contain 30 people.
# 407 |-
# 408 |La-Haye-de-Routot Yews
# 409 |Yews
# 410 |[[La Haye-de-Routot]], Normandy, France <br/> <small> {{coord|49|24|19.1|N|0|43|41.9|E|name=La-Haye-de_routot Yews}}</small>
# 411 | ~ 1,500
# 412 |[[File:LaHayeDeRoutotIf1.JPG|100px|left]] A chapel with a door was designed in one of them.
# 413 |-
# 414 |[[Forest swastika]]
# 415 |[[Larch]]
# 416 |[[Zernikow (Uckermark)|Zernikow]], [[Germany]].
# 417 |
# 418 |  A patch of carefully arranged larch trees covering a {{convert|60|yd|adj=on}} square area of [[pine]] forest.
# 419 |-
# 420 |[[The Old Elm]]
# 421 |[[Field Elm]] (''[[Ulmus minor]]'')
# 422 |Center of [[Sliven]], [[Bulgaria]]
# 423 | 1100
# 424 | The Old Elm won the 2014 European Tree of the Year Award. The tree has sat in the center of Sliven for 1100 years, serving as a gathering point and a historical marker. It is also part of the city coat of arms.<ref>{{cite web|title=2014 European Tree of the Year|url=https://www.treeoftheyear.org/Minule-rocniky/2014/Stary-jilm.aspx|accessdate=17 October 2017|date=2014}}</ref>
# 425 |-
# 426 |[[Granit Oak]]
# 427 |[[English Oak]] (''[[Quercus robur]]'')
# 428 |Granit village near [[Stara Zagora]], [[Bulgaria]] <br/><small> {{coord|42.254067|25.136080|name=Granit oak}}</small>
# 429 |1,650
# 430 |One of the oldest trees in [[Europe]], estimated to be about 1,650 years old. Its crown spread covers an area of 1,017 square metres, its girth is 7.45 m, and its height is 23.4 m.
# 431 |-
# 432 |[[Bartek (oak)|Bartek]]
# 433 |[[Oak]]
# 434 |[[Zagnańsk]], [[Świętokrzyskie Province]], [[Poland]] <br/><small> {{coord|50|59|N|20|40|E|name=Bartek}}</small>
# 435 |650–670
# 436 |[[File:Dab Bartek.jpg|100px|left]] A famous tree in [[Poland]], visited by kings, said to be about 1,200 years old (actually 650–670 years according to recent studies{{citation needed|date=February 2013}}). It is 30 m tall, 13.5 m in girth near the ground, with a crown spread of 40 m.
# 437 |-
# 438 |[[Gernikako Arbola]]
# 439 |Oak
# 440 |[[Guernica (town)|Guernica]], [[Basque Country (autonomous community)|Basque Country]], [[Spain]] <br/><small> {{coord|43|18|53|N|2|40|47|W|name=Gernikako Arbola }}</small>
# 441 |
# 442 |[[File:P5393 Guernica Gernikako Arbola Tregenza.jpg|100px|left]] An oak representing the [[Basques|Basque people]]
# 443 |-
# 444 |[[The Great Sequoia]]
# 445 |Sequoia (''Sequoiadendron giganteum'')
# 446 |[[Vitoria-Gasteiz]], [[Basque Country (autonomous community)|Basque Country]], [[Spain]] <br/><small> {{coord|42.846584|-2.678167|name=Great Sequoia}}</small>
# 447 |160
# 448 |[[File:Sequoiadesdeabajo.jpg|100px|left]] Symbol of the city
# 449 |-
# 450 |[[Queen Elizabeth Oak]]
# 451 |English Oak (''Quercus robur'')
# 452 |[[Royal Palace of Hatfield]], [[Hertfordshire]], [[England]] <br/><small> {{coord|50.99613|-0.70066|name=Queen Elizabeth Oak}}</small>
# 453 |800–1000
# 454 |[[File:Queen Elizabeth oak, Cowdray Park, near Lodsworth - geograph.org.uk - 970020.jpg|100px|left]] Said to be the location where [[Elizabeth I of England]] was told she was queen in 1558.
# 455 |-
# 456 |[[Darley Oak]]
# 457 |[[Pedunculate oak]] (''Quercus robur'')
# 458 |[[Darleyford]], Cornwall, England <br/><small> {{coord|50.53396|N|4.43382|W|name=Darley Oak}} </small>
# 459 |1000+
# 460 |Folk tradition attributes healing properties to the tree
# 461 |-
# 462 |[[Kongeegen]] (the King Oak)
# 463 |[[Pedunculate Oak]] (''Quercus robur'')
# 464 |Jægerspris Nordskov, [[Sjælland]], [[Denmark]] <br/><small> {{coord|55|54|37|N|11|59|21|E|name=Kongeegen}}</small>
# 465 |1,200
# 466 |[[File:Kongeegen.jpg|100px|left]] The oldest tree in Denmark.
# 467 |-
# 468 |[[Chêne chapelle]]
# 469 |[[Pedunculate Oak]] (''Quercus robur'')
# 470 |[[Allouville-Bellefosse]], Normandy, France <br/> <small> {{coord|49|35|47|N|0|40|35|E|name=Chêne chapelle}}
# 471 |1,200
# 472 |[[File:Chnedallouville6.jpg|100px|left]] An 800- to 1,200-year-old pedunculate oak, under which [[William the Conqueror]] is to have stopped, according to a local legend. There are two chapels inside.
# 473 |-
# 474 |Poltava Oak
# 475 |Oak
# 476 |[[Poltava]], [[Ukraine]]
# 477 |600
# 478 |An oak under which tsar [[Peter the Great|Peter I]] rested at the [[Battle of Poltava]] in 1709.{{citation needed|date=April 2010}}
# 479 |-
# 480 |Stoke Gabriel Yew
# 481 |Yew
# 482 |[[Stoke Gabriel]] churchyard [[Devon]], [[England]]<br/> <small> {{coord|50.402854|N|3.621049|W|name=Stoke Gabriel Yew}}
# 483 |c.1000
# 484 |[[File:Yew Tree - geograph.org.uk - 787460.jpg|100px|left]] Said to be the oldest tree in England.
# 485 |-
# 486 |[[Major Oak]]
# 487 |Pedunculate Oak (''Quercus robur'')
# 488 |[[Sherwood Forest]], [[Nottinghamshire]], England <br/><small> {{coord|53|12|17|N|1|4|20.80|W|name=Major Oak}} </small>
# 489 |800
# 490 |[[File:Major Oak.JPG|100px|left]] The most famous and most visited tree of [[Great Britain]]. About 800 years old, with a girth at breast height of 10.5 m.
# 491 |-
# 492 |[[Gilwell Oak]]
# 493 |Pedunculate Oak (''Quercus robur'')
# 494 |[[Gilwell Park]], [[Epping Forest]], Essex, United Kingdom <br/> <small> {{coord|51|39|1|N|0|0|8|E|name=Gilwell Oak}} <small>
# 495 |circa 500
# 496 |[[File:Gilwell Oak (5948293396).jpg|100px|left]] Oak tree associated with the early history of the [[Scout Association]]
# 497 |-
# 498 |Ivenack Oak
# 499 |Pedunculate Oak (''Quercus robur'')
# 500 |Ivenack, [[Mecklenburg-Western Pomerania]], [[Germany]]
# 501 |800
# 502 |[[File:Oak Ivenack 08 2015.JPG|100px|left]] A huge and ancient Pedunculate oak thought to be about 800 years old, 35 m tall, 11 m in girth at breast height and 16.5 m near the ground. The largest oak in Germany and (in wood volume) probably in Europe.
# 503 |-
# 504 |[[Baikushev's pine]]
# 505 |[[Bosnian Pine]] (''[[Pinus heldreichii]]'')
# 506 |[[Pirin]] mountains near [[Bansko]], [[Bulgaria]]
# 507 |1,300
# 508 |[[File:Bajkusheva mura1.jpg|100px|left]] An ancient tree estimated to be 1,300 years old. It is one of the oldest trees of Bulgaria and stands 24 m tall with a girth of 6.9 m at breast height.
# 509 |-
# 510 |[[Stelmužė Oak]]
# 511 |Pedunculate Oak (''Quercus robur'')
# 512 |[[Stelmužė]], [[Zarasai district]], [[Lithuania]] <br/> <small> {{coord|55.8299811|26.2175894|name=Stelmužė Oak}} </small>
# 513 |1,500
# 514 |[[File:Stelmužė oak.jpg|100px|left]] Measures a girth at breast height of 9.58 m and 13 m near the ground. The oldest tree in Lithuania and the [[Baltic States]].
# 515 |-
# 516 |[[Chestnut Tree of One Hundred Horses]]
# 517 |[[Sweet Chestnut]] (''[[Castanea sativa]]'')
# 518 |[[Sant'Alfio]], the eastern slope of [[Mount Etna]], [[Italy]] <br/> <small> {{coord|37|45|00.7|N|15|7|49.4|E|name=Chestnut Tree of One Hundred Horses}} </small>
# 519 |2000-4000
# 520 |[[File:Castagno dei Cento Cavalli.jpg|100px|left]] Probably the world's oldest and largest [[chestnut]].
# 521 |-
# 522 |[[Bialbero de Casorzo]] (Grana Double Tree)
# 523 |Outer: [[Mulberry]]
# 524 Inner: [[Cherry|Cherry Tree]]
# 525 |[[Grana, Piedmont|Grana]], [[Piemont]], [[Italy]]
# 526 |
# 527 |[[File:Bialbero di Casorzo.jpg|100px|left]] a tree which grows in a hollow tree near Grana, Piemont, Italy [http://atlasobscura.com/places/grana-double-tree]
# 528 |-
# 529 |Le Gros chêne de [[Liernu]] (the big oak of Liernu)
# 530 |Oak
# 531 | 15 north from [[Namur (city)|Namur]], Belgium <br/> <small> {{coord|50|35|03|N|4|49|40|E|name=Le Gros chêne de Liernu}}
# 532 |900
# 533 |[[File:Liernu JPG01b.jpg|100px|left]] Known as the oldest oak in [[Belgium]]. It is estimated at certainly 800 or 900 years old, maybe more than 1,000 years.
# 534 |-
# 535 |[[Lech, Czech and Rus#Oaks of Rogalin|The Oaks of Rogalin]]
# 536 |Oak
# 537 |[[Rogalin]], [[Greater Poland]]
# 538 |1,000
# 539 |[[File:RogalinOaks.jpg|100px|left]] Thousand-year-old trees named after the three mythic founders of the Slavic nations.
# 540 |-
# 541 |[[Olive tree of Vouves|The Olive tree of Vouves]]
# 542 |Olive Tree (''Olea europaea'')
# 543 |Village of [[Ano Vouves]], [[Kolymvari]], [[Chania (regional unit)|Chania regional unit]], [[Crete]], [[Greece]]<br/><small> {{coord|35|29|12|N|23|47|13|E|name=Olive tree of Vouves}}</small>
# 544 |2,000
# 545 |[[File:Olive tree of Vouves.jpg|100px|left]]  It is confirmed to be at least 2000 years old based on [[Dendrochronology|tree ring analysis]], but it is claimed to be between 3000–4000 years old.
# 546 |-
# 547 |[[Mulberry of the Patriarchate of Peć]]
# 548 |[[Mulberry]]
# 549 |[[Peć, Kosovo]].
# 550 |800
# 551 |One of the oldest verified living trees in Serbia, located in the courtyard of the church complex of the [[Monastery of the Patriarchate of Peć|Patriarchate of Peć]]. It was brought from the [[Syria (region)|Shām]] region by Archbishop Saint [[Sava II]] during his pilgrimage to the [[Holy Land]] and planted between 1263 and 1272.
# 552 |-
# 553 |[[Old Oak]]
# 554 |Oak
# 555 |Exactly 100&nbsp;km from [[Belgrade]], [[Serbia]], next to [[European route E75|E-75]] highway.
# 556 |600
# 557 |
# 558 [[File:Zapis-0002-Markovac-Stari-Hrast 20111114 7960.jpg|100px|left]]
# 559 |-
# 560 |[[Divljana Oak]]
# 561 |Oak
# 562 |[[Divljana]], [[Serbia]]
# 563 |over 1000
# 564 |[[File:Divljanski stari hrast.jpg|100px|left]]
# 565 |-
# 566 |[[Koča's oak]]
# 567 |
# 568 | near [[Jagodina]], [[Serbia]]
# 569 |
# 570 | Named after [[Koča Anđelković]].
# 571 |-
# 572 |[[Veliki Popovac oak]]
# 573 |
# 574 |Village of [[Veliki Popovac]], Serbia
# 575 |
# 576 |
# 577 |-
# 578 |[[Prince Miloš's Residence|Plane tree at Miloš's Residence]]
# 579 |[[Plane tree]]
# 580 |[[Belgrade]], Serbia
# 581 |
# 582 | The oldest plane tree in Belgrade.
# 583 |-
# 584 |[[Cvetni trg#History|Flower Square oak]]
# 585 |English Oak (''Quercus robur'')
# 586 |Belgrade, Serbia
# 587 |~200
# 588 |[[File:Quercus robur at Flower Square, Belgrade.jpg|100px|left]] Around two centuries old, the last remaining of the forest that covered the area.
# 589 |-
# 590 |[[Brian Boru's Oak]]
# 591 |Oak
# 592 |[[Raheen Woods]], [[County Clare]], [[Ireland]]
# 593 |1,000
# 594 |A reputedly 1000-year-old oak tree planted by [[Brian Boru]], Last King of Ireland.
# 595 |-
# 596 |[[Pi de les Tres Branques]]
# 597 |Scots Pine (''Pinus sylvestris'')
# 598 |[[Catalonia]], [[Spain]]
# 599 |
# 600 |[[File:Pi de les Tres Branques 1905.jpg|100px|left]] Regarded as symbolising the unity of the [[Catalan countries]]
# 601 |-
# 602 |[[Midland Oak]]
# 603 |Oak
# 604 |[[Leamington Spa]], [[Warwickshire]], England <br/> <small> {{coord|52.300062|N|1.529750|W|name=Midland Oak}} </small>
# 605 |
# 606 |[[File:Midland Oak.jpg|100px|left]] Reputed to mark the [[centre of England]]. grown from an acorn from the original tree.
# 607 |-
# 608 |[[Najevnikov lipovec|Najevnik Linden Tree]]
# 609 |[[Tilia cordata|Small-leaved Lime]] (''[[Tilia cordata]]'')
# 610 |Najevnik Farm in [[Ludranski Vrh]], [[Municipality of Črna na Koroškem]], northern Slovenia
# 611 |~700
# 612 |[[File:NajevskaLipa1.JPG|100px|left]]The tree with the largest girth in Slovenia (10.70 meters; its height is 24 m). Estimated to be 700 years old. The traditional meeting place of Slovene politicians and a cultural venue.
# 613 |-
# 614 |[[Tamme-Lauri oak]]
# 615 |Oak
# 616 |[[Urvaste Parish]], [[Võru County]], [[Estonia]]
# 617 |690
# 618 |[[File:Tamme-Lauri Tamm suvel.jpg|100px|left]] Thickest and oldest tree in Estonia.
# 619 |-
# 620 |[[Viiralti Oak]]
# 621 |Oak
# 622 |[[Vana-Võidu]] village in [[Viljandi County]], [[Estonia]]
# 623 |400
# 624 |[[File:Viiralti tamm.jpg|100px|left]] Known from the graphic work of [[Eduard Wiiralt]] from 1943
# 625 |-
# 626 |Orissaare Stadium oak
# 627 |Pedunculate Oak (''Quercus robur'')
# 628 |[[Orissaare]], [[Saare County]], [[Estonia]] <br/> <small> {{coord|58|33|32.2|N|23|4|49|E|name=Orissaare Stadium oak}} </small>
# 629 |
# 630 |[[File:Orissaare staadioni tamm.JPG|80px|left]] Grows in the middle of Orissaare stadium. [[European Tree of the Year]] 2015
# 631 |-
# 632 |King's Pine
# 633 |Scots Pine (''Pinus sylvestris'')
# 634 |[[Järvselja]] village, [[Peipsiääre Parish]], [[Tartu County]], [[Estonia]]
# 635 |380
# 636 |[[File:Järvselja kuningamänd 2013 09 2.jpg|80px|left]] This pine has height of 33 m and volume of 11,5 m<sup>3</sup> (1999)
# 637 |-
# 638 |Kelchi linden
# 639 |[[Tilia|Linden]]
# 640 |[[Tallinn]], [[Estonia]]
# 641 |360
# 642 |[[File:Kelchi pärn, 2012.jpg|80px|left]] Named after pastor Christian Kelch who was buried under the linden in 1710
# 643 |-
# 644 |Waldtraut vom Mühlenwald
# 645 |[[Douglas fir]]
# 646 |[[Arboretum Freiburg-Günterstal]] near [[Freiburg im Breisgau]], Germany
# 647 |107 (in 2017)<ref name=":0">{{Cite web|url=https://www.sueddeutsche.de/news/wissen/wissenschaft-waldtraut-ist-deutschlands-hoechster-baum-dpa.urn-newsml-dpa-com-20090101-170424-99-179709|title="Waldtraut" ist Deutschlands höchster Baum - Wissen-News|last=Germany|first=Süddeutsche de GmbH, Munich|website=Süddeutsche.de|language=de|access-date=2019-01-02}}</ref>
# 648 |[[File:Waltraut von Mühlenwald.jpg|95px|left]] Tallest tree in Germany with a heights of 66.58 meters in 2017<ref name=":0" /><ref>{{Cite web|url=https://www.stuttgarter-zeitung.de/inhalt.douglasie-im-schwarzwald-deutschlands-hoechster-baum-heisst-waldtraud.908f3393-cd14-4b28-81c5-f5d7058f4857.html|title=Douglasie im Schwarzwald: Deutschlands höchster Baum heißt Waldtraud|last=Germany|first=Stuttgarter Zeitung, Stuttgart|website=stuttgarter-zeitung.de|language=de|access-date=2019-01-02}}</ref><ref>{{Cite web|url=http://www.badische-zeitung.de/freiburg/freiburgs-waldtraut-ist-der-hoechste-baum-deutschlands|title=Freiburgs Waldtraut ist der höchste Baum Deutschlands|last=Zeitung|first=Badische|website=www.badische-zeitung.de|language=de|access-date=2019-01-02}}</ref>
# 649 |}
# 650
# 651 ====Historical====
# 652 {|class="wikitable"
# 653 |-
# 654 !Name
# 655 !Species
# 656 !Location
# 657 !Age (years)
# 658 !Notes
# 659 |-
# 660 |[[Anne Frank Tree]]
# 661 |[[Horse-chestnut]] (''[[Aesculus hippocastanum]]'')
# 662 |City center of [[Amsterdam]], [[Netherlands]]<br/><small>{{coord|52|22|30.7|N|4|53|4.7|E|name=Ann Frank Tree (former)}}</small>
# 663 |
# 664 | [[File:Annefranktree edit1.jpg|100px|left]] Featured in [[Anne Frank]]'s ''[[The Diary of a Young Girl]]''. The tree was destroyed in a gale in the late summer of 2010.
# 665 |-
# 666 |[[Merlin's Oak]]
# 667 |
# 668 |[[Carmarthen, Wales|Carmarthen]], [[Wales]]
# 669 |
# 670 |
# 671 |-
# 672 |[[Glastonbury Abbey#Glastonbury Thorn|Glastonbury Thorn]]
# 673 |[[Common Hawthorn]] (''[[Crataegus monogyna]]'')
# 674 |
# 675 |
# 676 | Reputed to have been planted by [[Joseph of Arimathea]].
# 677 |-
# 678 |[[Thor's Oak]]
# 679 |Oak
# 680 |
# 681 |
# 682 | a tree sacred to the [[Germanic peoples|Germanic tribe]] of the [[Chatti]], ancestors of the [[Hesse|Hessians]].
# 683 |-
# 684 |[[Sacred tree at Uppsala]]
# 685 |
# 686 | [[Temple at Uppsala]], [[Sweden]]
# 687 |
# 688 |It was a [[sacred tree]] venerated by [[Norse pagan]]s, still extant in the second half of the 11th century.
# 689 |-
# 690 |[[Royal Oak (tree)|Royal Oak]]
# 691 |Pedunculate Oak (''Quercus robur'')
# 692 |[[Boscobel, Shropshire|Boscobel]], England
# 693 |
# 694 | [[Charles II of England|King Charles II]] hid in the tree to escape the [[Roundheads]] following the [[Battle of Worcester]] in 1651. The tree deceased and is replaced by a descendant.
# 695 |-
# 696 |[[Shakespeare]]'s mulberry tree
# 697 |[[Mulberry]]
# 698 |New Place, [[Stratford-upon-Avon]], England
# 699 |
# 700 | Cut down in the mid-18th century and fashioned into mementos.
# 701 |-
# 702 |[[Tree of Hippocrates]]
# 703 |[[Oriental Plane]] (''[[Platanus orientalis]]'')
# 704 |[[Kos]], [[Greece]]
# 705 |
# 706 |The tree under which [[Hippocrates]] is supposed to have taught.
# 707 |-
# 708 |[[Red Forest]]
# 709 |Pines
# 710 |[[Chernobyl Nuclear Power Plant]], [[Ukraine]]
# 711 |
# 712 | Formerly the Worm Wood Forest, refers to the trees growing in the 10&nbsp;km<sup>2</sup> surrounding the Chernobyl Nuclear Power Plant and is one of several of the [[Chernobyl disaster effects]] on April 26, 1986. The name 'Red Forest' comes from the ginger brown colour of the pine trees after they died following the absorption of high levels of radiation.
# 713 |-
# 714 |[[TV-eken]]
# 715 | Oak
# 716 | Stockholm, Sweden
# 717 |
# 718 |The TV-oak or TV-eken was a tree in front of the offices of [[Sveriges Television]]. It was felled in 2011 despite a massive campaign to preserve it.<ref name="expressen">{{cite news|title=Här fälls tv-eken |url=http://www.expressen.se/nyheter/1.2632469/har-falls-tv-eken |work=Expressen |access-date=November 25, 2011}}</ref>
# 719 |-
# 720 |[[Danger Tree]]
# 721 |
# 722 |[[Beaumont-Hamel]], France
# 723 |
# 724 |Marks the area of highest casualties suffered by the [[Royal Newfoundland Regiment]] during their attack at [[Beaumont-Hamel Newfoundland Memorial|Beaumont Hamel]] during the [[Battle of the Somme]].  The current 'tree' is a concrete replica, however growth around the replica may be from the same root system as the original tree.
# 725 |-
# 726 |[[Takovo bush]]
# 727 |Oak
# 728 |[[Takovo]], Serbia
# 729 |
# 730 |Tree under which [[Miloš Obrenović]] started the [[Second Serbian Uprising]].
# 731 |-
# 732 |[[Pine of Tsar Dušan]]
# 733 |Bosnian Pine (''Pinus heldreichii'')
# 734 |[[Uroševac]], Serbia
# 735 |{{age|1336|6|1|1999|6|1}}
# 736 |Planted in 1336 by [[Tsar Dušan]], destroyed by Albanian extremists in 1999.{{citation needed|date=January 2013}}
# 737 |-
# 738 |[[Poplar of Horror]]
# 739 |[[Populus|Poplar]]
# 740 |[[Donja Gradina]], [[Bosnia and Herzegovina]]
# 741 |
# 742 |Used for mass executions of inmates of the [[Jasenovac concentration camp]].
# 743 |-
# 744 |[[Buttington Oak]]
# 745 |Oak
# 746 |[[Buttington]], [[Powys]], Wales
# 747 |
# 748 |Said to have been planted to commemorate the [[Battle of Buttington]] in 893, fell in February 2018
# 749 |-
# 750 |[[Oak at the Gate of the Dead]]
# 751 |Pedunculate Oak (''Quercus robur'')
# 752 |near [[Wrexham]], Wales
# 753 |Circa 1,000
# 754 |[[File:The Oak At The Gate Of The Dead.jpg|100px|left]] Sited on the burial ground of the 1165 [[Battle of Crogen]]
# 755 |-
# 756 |[[Brimmon Oak]]
# 757 |Pedunculate Oak (''Quercus robur'')
# 758 |[[Newtown, Powys]], Wales
# 759 |Circa 500
# 760 |A campaign to save it forced the diversion of the [[A483 road|A483 Newtown Bypass]]
# 761 |-
# 762 |[[Bicycle Tree]]
# 763 |Sycamore (''Acer pseudoplatanus'')
# 764 |[[Brig o' Turk]], Scotland
# 765 |Circa 110–150
# 766 |A landmark tree with a bicycle embedded within it
# 767 |-
# 768 |[[Robin Hood's Larder]]
# 769 |Oak
# 770 |[[Sherwood Forest]]
# 771 |
# 772 |Reputed to have been used by Robin Hood to store food
# 773 |}
# 774
# 775 ====Petrified====
# 776 {|class="wikitable"
# 777 |-
# 778 !Name
# 779 !Species
# 780 !Location
# 781 !Age
# 782 !Notes
# 783 |-
# 784 ||[[Petrified Forest of Lesvos]]
# 785 |
# 786 |[[Lesvos]], [[Greece]]
# 787 |
# 788 |
# 789 |}
# 790
# 791 ===North America===
# 792 {{GeoGroup}} <!--- to display coords. A coord form:  <br/><small>{{coord||||N||||W|name=}}</small>  --->
# 793 {{-}}
# 794
# 795 ====Living====
# 796 {|class="wikitable"
# 797 |-
# 798 !Name
# 799 !Species
# 800 !Location
# 801 !Age
# 802 !Notes
# 803 |-
# 804 |[[Allen Russell (tree)|Allen Russell]]
# 805 |[[Giant sequoia]] (''[[Sequoiadendron giganteum]]'')
# 806 |[[Balch Park]], [[Tulare County, California]], [[US]]
# 807 |
# 808 |The 33rd largest tree worldwide, named in dedication to park ranger Allen I. Russell.
# 809 |-
# 810 |[[Angel Oak]]
# 811 |[[Southern live oak]] (''[[Quercus virginiana]]'')
# 812 |[[Johns Island, South Carolina]], near [[Charleston, South Carolina]], [[US]]<br/><small>{{coord|32|43|4|N|80|4|46|W|name=Angel Oak}}</small>
# 813 |400–500
# 814 |[[File:Angel Oak Tree in SC.jpg|100px|left]]It stands 66.5&nbsp;ft (20 m) tall, measures 28&nbsp;ft (8.5 m) in circumference, and produces shade that covers 17,200 square feet (1,600 m<sup>2</sup>). Its longest branch distance is 187&nbsp;ft.The tree and surrounding park have been owned by the neighboring city of Charleston since 1991.
# 815 |-
# 816
# 817 |Bedford Oak
# 818 |[[Quercus alba|White Oak (''Quercus alba'')]]
# 819 |[[Bedford (town), New York|Bedford, New York]]
# 820 |300–500
# 821 |[[File:Bedford Oak, Bedford, NY - July 2012.jpg|100px|left]]In 1987, this tree was officially recognized by the National Arborist Association and International Society of Arboriculture as a significant tree that was alive at the time of the signing of the United States Constitution.<ref>{{cite news|last1=Fullam|first1=Anne C.|title=Bedford panel considers tougher tree law|work=New York Times|date=September 22, 1996|page=WC8}}</ref><ref>{{cite news|last1=Melvin|first1=Tessa|title=If You're Thinking of Living in/Bedford Village; 'New England' 44 Miles From Broadway|url=https://www.nytimes.com/1993/11/07/realestate/if-you-re-thinking-living-bedford-village-new-england-44-miles-broadway.html?n=Top%2FClassifieds%2FReal%20Estate%2FColumns%2FLiving%20In|accessdate=3 March 2017|work=The New York Times|date=November 7, 1993|quote=The large tree at Hook and Cantitoe Roads is depicted on the Bedford town seal and predates the town's founding in 1680.}}</ref> Its measurements are: circumference {{convert|20.5|ft|m}}; height {{convert|69|ft|m}}; average spread {{convert|100|ft|m}}.
# 822 |-
# 823 |[[Bennett Juniper]]
# 824 |[[Grand Juniper]] (''[[Juniperus grandis]]'')
# 825 |[[Stanislaus National Forest]], [[Tuolumne County, California]] US<br/><small>{{coord|38|18|32|N|119|47|49.56|W|name=Bennett Juniper}}</small>
# 826 |2,000–6,000 (est.)
# 827 |The largest known Juniper in the United States.
# 828 |-
# 829 |[[The Big Oak]]
# 830 |Southern Live Oak (''Quercus virginiana'')
# 831 |[[Thomasville, Georgia]], US
# 832 |
# 833 |One of the oldest Live Oak trees east of the [[Mississippi river]].
# 834 |-
# 835 |[[The Big Tree, Rockport|The Big Tree - Goose Island]]
# 836 |Southern Live Oak (''Quercus virginiana'')
# 837 |[[Rockport, Texas]], US
# 838 |
# 839 |Located in Goose Island State Park.
# 840 |-
# 841 |Bogey's Tree
# 842 |
# 843 |[[Pacific Palisades, Los Angeles|Pacific Palisades, California]], US
# 844 |
# 845 |A tree on the 12th hole at [[Riviera Country Club]], named after [[Humphrey Bogart]].
# 846 |-
# 847 |[[Boyington Oak]]
# 848 |Southern Live Oak (''Quercus virginiana'')
# 849 |[[Mobile, Alabama]], US
# 850 |{{age|1835|2|20}}
# 851 |Reportedly grew from the grave of Charles Boyington in the [[potter's field]] just outside the walls of [[Church Street Graveyard]].  Boyington was tried and executed for the murder of his friend, Nathaniel Frost, on February 20, 1835.  He stated that a tree would spring from his grave as proof of his innocence.<ref>{{cite book |last=Windham |first=Kathryn Tucker |year =1982 |title=Jeffrey's Latest 13: More Alabama Ghosts |publisher=Strode Publishers |location=Huntsville, Alabama |pages=21–32 |isbn=0-8173-0380-4 }}</ref><ref>{{cite web|last=Borland |first=Timothy |title=Mobile Tree Hugger, Part II: The Legend Of The Charles Boyington Oak |publisher=Mobile Bay Magazine |date=June 27, 2011 |url=http://www.mobilebaymag.com/Mobile-Bay/Bay-Buzz/Blog-2011/Mobile-Tree-Hugger-Part-II/ |accessdate=November 9, 2012 |url-status=dead |archiveurl=https://web.archive.org/web/20140512075932/http://www.mobilebaymag.com/Mobile-Bay/Bay-Buzz/Blog-2011/Mobile-Tree-Hugger-Part-II/ |archivedate=May 12, 2014 }}</ref>
# 852 |-
# 853 |[[Buttonball Tree]]
# 854 |[[American sycamore]] (''[[Platanus occidentalis]]'')
# 855 |[[Sunderland, Massachusetts|Sunderland]], [[Massachusetts|MA]], US {{coord|42|28|07.83|N|72|34|42.14|W|type:landmark_region:US|display=inline}}
# 856 | 350–400 (est.)
# 857 |[[File:Buttonball Sycamore - sycamore tree in Sunderland, Massachusetts, May 2012.jpg|100px|left]]Large tourist attraction of the town; the tree is believed to be the largest tree of its kind on the East Coast, or as locals put it, "The widest tree this side of the Mississippi." This tree's measurements are: circumference {{convert|25|ft|m}}; height {{convert|111|ft|m}}; average spread {{convert|140|ft|m}}.
# 858 |-
# 859 |[[Candler Oak Tree]]
# 860 |Oak
# 861 | [[Savannah, Georgia]]
# 862 | ~300
# 863 |[[File:Candler Oak Tree.jpg|100px|left]]A Georgia Landmark and Historic Tree.  It is owned by the [[Savannah Law School]] which protects the tree with fences and security surveillance. The tree serves as the law school's logo.
# 864
# 865 |-
# 866 |[[Chandelier Tree]]
# 867 |[[Coast Redwood]] (''[[Sequoia sempervirens]]'')
# 868 | [[Leggett, California]]
# 869 | ~2,000
# 870 |[[Image:CarRedwoodLeggett01-05.jpg|left|100px]]
# 871 A Coast redwood with a passage for cars cut through.   It is {{convert|276|ft|m|adj = on}} high and {{convert|16|ft|m|adj = on}} ft. in diameter. The name "Chandelier Tree" comes from its unique limbs that resemble a chandelier.
# 872 |-
# 873 |[[Circus Trees]]
# 874 |Various
# 875 |[[California]]
# 876 |
# 877 |A group of trees shaped into artistic forms by arborist [[Axel Erlandson]].
# 878 |-
# 879 |[[Comfort Maple]]
# 880 |[[Sugar maple]] (''[[Acer saccharum]]'')
# 881 |[[Pelham, Ontario]], Canada
# 882 |500
# 883 |A {{convert|24.5|m|ft|adj = on}} tall, approximately 500-year-old Sugar maple.
# 884 |-
# 885
# 886 |[[Council Oak Tree (Hollywood, Florida)|Council Oak Tree]]
# 887 |[[Oak]]
# 888 |[[Hollywood, Florida]]
# 889 |
# 890 |[[image:Council Oak Tree Site on the Hollywood Seminole Indian Reservation 04.JPG|100px|left]]A historic oak tree on the [[Hollywood Seminole Indian Reservation]] that was added to the [[National Register of Historic Places]] in 2012.
# 891 |-
# 892
# 893 |[[Creek Council Oak Tree]]
# 894 |[[White oak]]
# 895 |[[Tulsa, Oklahoma]], US
# 896 |
# 897 |[[image:Creek Council Tree Site.jpg|100px|left]]A large oak tree marking the founding of Tulsa by the Lochapoka Clan of the [[Creek Nation]] in 1836.  Listed in the [[National Register of Historic Places]].
# 898 |-
# 899
# 900 |[[Davie Poplar]]
# 901 |[[Tulip poplar]] (''[[Liriodendron tulipifera]]'')
# 902 |[[Chapel Hill, North Carolina]], US
# 903 |300–375
# 904 |A large tree on the campus of the [[University of North Carolina at Chapel Hill]], it was named in honor of Revolutionary War general and founder of the University [[William Richardson Davie]]. Many legends are associated with the tree.
# 905 |-
# 906
# 907 |[[Devil's Tree]]
# 908 |[[Oak]]
# 909 |[[Bernards Township, New Jersey]], US
# 910 |
# 911 |[[Image:The Devil's Tree.jpg|100px|left]]
# 912 The tree is said to be [[curse]]d.  Local legend says those who damage or disrespect the tree will soon thereafter come to some sort of harm, often in the form of a [[motor vehicle accident|car accident]] or major breakdown as they leave.
# 913 |-
# 914
# 915 |Dewey Oak
# 916 |[[White oak|White oak (''Quercus alba'')]]
# 917 |[[Granby, Connecticut]], US
# 918 | 250–450
# 919 |[[File:Dewey Oak Tree - White Oak, Granby, CT - October 17, 2010.jpg|100px|left]]The Town of [[Granby, Connecticut]] uses an outline of this tree as their town seal, and Connecticut's Notable Trees uses a photo of it on their certificates. This tree was damaged in the [[2011 Halloween nor'easter|October 2011 snow storm (Storm Alfred)]], but it is still alive. This tree's measurements are: circumference {{cvt|20.5|ft}} height {{cvt|78|ft}} average spread {{cvt|129|ft}}.
# 920 |-
# 921 |[[Duffie Oak]]
# 922 |
# 923 |Mobile, [[Alabama]], US
# 924 |300
# ...
# 1452 |approx. 500
# 1453 |The largest American sycamore in the U.S. state of West Virginia until its felling in 2010.
# 1454 |-
# 1455 |Wethersfield Elm
# 1456 |
# 1457 |
# 1458 |
# 1459 |
# 1460 |-
# 1461 |[[Wye Oak]]
# 1462 |[[White oak]]
# 1463 |[[Maryland]], US
# 1464 |
# 1465 |Was the honorary state tree of [[Maryland]], and the largest white oak tree in the United States.
# 1466 |}
# 1467
# 1468 ====Petrified====
# 1534 |[[Montezuma Cypress]] (''[[Taxodium mucronatum]]'')
# 1535 |[[Santa María del Tule]], [[Oaxaca]], [[Mexico]]<br /><small>{{coord|17|02|47.4|N|96|38|10|W|name=Árbol del Tule}}</small>
# 1536 | 1,433–1,600 years (est)
# 1537 |[[File:ArbordeTuleOaxaca MX.jpg|left|100px]]The stoutest tree in the world. Its trunk has a [[circumference]] of {{convert|42.0|m|ft|abbr=on}}, equating to a [[diameter]] of {{convert|14.05|m|ft|abbr=on}}. In 2001 it was placed on a [[UNESCO]] tentative list of World Heritage Sites.
# 1538 |-
# 1539 |El Arbolito (The Little Tree)
# 1540 |
# 1541 |[[Managua]], [[Nicaragua]]
# 1542 |
# 1543 |A traditional landmark used to give directions in Managua.<ref>{{cite web|url=https://www.elnuevodiario.com.ni/nacionales/managua/429925-arbolito-madrono-que-es-referencia-testigo/|title=El Arbolito, un madroño que es referencia y testigo|date=5 June 2017|last1=González|first1=Mauricio|publisher=El Nuevo Diario}}</ref>
# 1544 |-
# 1545 |[[Gloomy Night Tree]] ([[Árbol de la Noche Triste]])
# 1546 |
# 1547 |[[Tlacopan|Tacuba]], [[Mexico City]], [[Mexico]]
# 1548 |
# 1549 | An old tree where [[Hernán Cortés]] allegedly mourned after being expelled from [[Tenochtitlan]] before taking the city by force.
# 1550 |-
# 1551 |[[Cashew of Pirangi]]
# 1552 |[[Cashew]]
# 1553 | {{coord|5.978657|S|35.123372|W|name=Cashew of Pirangi}}
# 1554 |
# 1555 | major tourist attraction in [[Natal, Rio Grande do Norte|Natal]], [[Brazil]]. Believed to be the biggest cashew in the world.<br/><small></small><small></small>
# 1556 |-
# 1557 |[[Cajueiro da Praia|Cashew of A Praia]]
# 1558 |[[Cashew]]
# 1559 | [[Cajueiro da Praia]]
# 1560 |
# 1561 |
# 1562 |-
# 1563 |Gran Abuelo
# 1564 | ''[[Fitzroya|Fitzroya cupressoides]]''
# 1565 | [[Alerce Costero National Park]], Chile
# 1566 | ca. 3600<ref>{{cite journal|title=A 3620-Year Temperature Record from Fitzroya cupressoides Tree Rings in Southern South America|first1=Antonio|last1=Lara|first2=Ricardo|last2=Villalba|author-link2=Ricardo Villalba|journal=Science |date=21 May 1993 |volume=260|issue=5111|pages=1104–1106|doi=10.1126/science.260.5111.1104|pmid=17806339}}</ref><ref>{{cite web|url=http://www.conaf.cl/parques/parque-nacional-alerce-costero/|title=Parque Nacional Alerce Costero|website=Conaf.cl|publisher=[[National Forest Corporation (Chile)|National Forest Corporation]]|accessdate=16 March 2014|language=Spanish|url-status=dead|archiveurl=https://web.archive.org/web/20141006104430/http://www.conaf.cl/parques/parque-nacional-alerce-costero/|archivedate=6 October 2014}}</ref>
# 1567 |
# 1568 |}
# 1569
# 1570 ====Historical====
# 1571 {|class="wikitable"
# 1572 |-
# 1573 !Name
# 1574 !Species
# 1575 !Location
# 1576 !Age
# 1577 !Notes
# 1578 |-
# 1579 |[[Arbol de Guacari]]
# 1580 |[[Samanea saman]]
# 1581 |[[Guacarí]], Colombia
# 1582 |
# 1583 |Famous tree engraved in the $500 coin
# 1584 |}
# 1585
# 1586 ===Oceania===
# 1587
# 1588 ====Living====
# 1589 {|class="wikitable"
# 1590 |-
# 1591 !Name
# 1592 !Species
# 1593 !Location
# 1594 !Age
# 1595 !Notes
# 1596
# 1597 |-
# 1598 |[[Banyan tree in Lahaina|The Banyan Tree]]
# 1599 |Banyan (''Ficus benghalensis'')
# 1600 |[[Lahaina, Hawaii]]<br/><small>{{coord|20.886111|N|156.674722|W|name=The Banyan Tree}}</small>
# 1601 | ~150
# 1602 | Planted in the 1860s, it covers an entire city block in the waterfront in Lahaina.
# 1603 |-|[[Dave Evans Bicentennial Tree]]
# 1604 |[[Karri]] (''[[Eucalyptus diversicolor]]'')
# 1605 |near [[Pemberton, Western Australia]]<br><small>{{coord|34|29|35|S|115|58|22|E|name=Dave Evans Bicentennial Tree}}</small>
# 1606 |
# 1607 |Forest fire lookout tree with accessible platform,
# 1608
# 1609 |-
# 1610 |[[Diamond Tree]]
# 1611 |Karri (''Eucalyptus diversicolor'')
# 1612 |10&nbsp;km from [[Manjimup, Western Australia]]
# 1613 |
# 1614 |Forest fire lookout tree with accessible wooden platform (52 m high).
# 1615 |-
# 1616 |[[Dig tree|Dig Tree]]
# 1617 |
# 1618 |[[Cooper Creek]], [[Queensland]], Australia
# 1619 |
# 1620 |[[File:Burke and Wills dig tree 2.JPG|100px|left]]Used as a marker by members of the ill-fated [[Burke and Wills expedition]].
# 1621 |-
# 1622 |[[El Grande (tree)|El Grande]]
# 1623 |
# 1624 |
# 1625 |
# 1626 |At one time, the world's largest flowering plant.
# 1627 |-
# 1628 |Lone Gum
# 1629 |[[Eucalyptus coolabah|Coolabah]] (''[[Eucalyptus coolabah]]'')
# 1630 |[[Simpson Desert]], [[South Australia]], Australia
# 1631 |
# 1632 |A solitary Coolabah, far from the nearest watercourse, normally grows in heavy clay soils. There is no other tree of its kind in the region and how it came to be there remains a mystery.<ref>[http://www.environment.sa.gov.au/parks/Find_a_park/Browse_by_region/Flinders_Ranges_Outback/Simpson_Desert_Conservation_Park_and_Regional_Reserve/Attractions Attractions - Department of Environment, Water and Natural Resources (DEWNR)<!-- Bot generated title -->] {{webarchive|url=https://archive.today/20131008025803/http://www.environment.sa.gov.au/parks/Find_a_park/Browse_by_region/Flinders_Ranges_Outback/Simpson_Desert_Conservation_Park_and_Regional_Reserve/Attractions |date=2013-10-08 }}</ref>
# 1633 |-
# 1634 |[[Gloucester Tree]]
# 1635 |Karri (''Eucalyptus diversicolor'')
# 1636 |[[Gloucester National Park]] [[Pemberton, Western Australia]]
# 1637 |
# 1638 | [[File:ClimbingTheGloucesterTree_2005_SeanMcClean.jpg|left|100px]] [[Western Australia]]'s most famous Karri tree, with accessible aluminium platform, in (61 m high).
# 1639 |-
# 1640 |[[Old Jarrah Tree]]
# 1641 |[[Jarrah]] (''[[Eucalyptus marginata]]'')
# 1642 |[[Perth, Western Australia]]
# 1643 |
# 1644 |
# 1645 |-
# 1646 |King Jarrah
# 1647 |Jarrah (''Eucalyptus marginata'')
# 1648 |[[Manjimup, Western Australia]]
# 1649 |
# 1650 |Giant Jarrah saved by the National Trust upon overhearing two foresters bragging at the pub about a mighty tree they were going to chop down the next morning.{{citation needed|date=April 2012}}
# 1651 |-
# 1652 |[[Curtain Fig Tree]]
# 1653 |[[Strangler Fig]]
# 1654 |Near [[Cairns]], Australia.
# 1655 |
# 1656 |One of the largest trees in North Queensland. The roots dangle 15 metres to the ground to create a curtain-like effect.
# 1657 |-
# 1658 |Cathedral Fig Tree<ref>{{cite web|url=http://www.queensland.com/attraction/cathedral-fig-tree |title=Cathedral Fig Tree |publisher=Queensland}}</ref><ref>{{cite web|url=http://www.nprsr.qld.gov.au/parks/danbulla/about.html |title=About Danbulla|publisher=Queensland}}</ref>
# 1659 |[[Strangler fig]]
# 1660 |[[Yungaburra]], Tablelands Area, Queensland, Australia
# 1661 |500
# 1662 |"A gigantic 500 year old strangler tree", like the Curtain Fig Tree.  Another massive ''Ficus virens'' in the Danbulla Forest.
# 1663 |-
# 1664 |[[Tane Mahuta]] ('Lord of the Forest')
# 1665 |[[Kauri]]
# 1666 |[[Northland Region]], [[New Zealand]]
# 1667 |1,250–2,500
# 1668 |[[File:00_29_0496_Waipoua_Forest_NZ_-_Kauri_Baum_Tane_Mahuta.jpg|left|100px]]It is estimated to be between 1,250 and 2,500 years old.
# 1669 |-
# 1670 |[[Te Matua Ngahere]] ('Father of the Forest')
# 1671 |Kauri
# 1672 |Northland Region, New Zealand.
# 1673 |
# 1674 |
# 1675 |-
# 1676 |[[Bland Oak]]
# 1677 |[[Quercus virginiana]]
# 1678 |[[Sydney]], Australia
# 1679 |>170
# 1680 |[[File:Blandoaktree.jpg|left|100px]]Planted in 1842 by [[William Bland]], it is one of the largest and oldest trees in Sydney. Was the largest in Australia until 1940 when a storm struck parts of it.<ref name="mobbaymag">{{cite web |last=Boulous |first=Chris |title=Nothing Bland about our Oak tree |work=Fairfield City Champion|publisher=[[Fairfax Media]]|date=April 20, 2018 |url=https://www.fairfieldchampion.com.au/story/5354072/nothing-bland-about-our-oak-tree/#slide=2 |accessdate=August 29, 2018}}</ref>
# 1681 |-
# 1682 |[[Boab Prison Tree, Derby]]
# 1683 |[[Adansonia gregorii|Boab tree]] (''[[Adansonia gregorii]]'')
# 1684 | South of [[Derby, Western Australia]]
# 1685 |
# 1686 |[[File:A213, Derby, Western Australia, Prison Boab tree, 2007.JPG|left|100px]]Was used as a prison for [[Indigenous Australian]] prisoners on their way to Derby for sentencing.
# 1687 |-
# 1688 |[[Boab Prison Tree, Wyndham]]
# 1689 |Boab tree (''Adansonia gregorii'')
# 1690 |[[Wyndham, Western Australia]]
# 1691 |
# 1692 | Also used as a prison.
# 1693 |-
# 1694 |[[Centurion (tree)|Centurion]]
# 1695 |''[[Eucalyptus regnans]]''
# 1696 | [[Tasmania]], Australia
# 1697 |
# 1698 | [[File:Centurion_tree_99.82.jpg|100px|left]]At 99.6 metres, it is tallest known eucalypt and the tallest known [[angiosperm]] in the world, second tallest tree species in the world.
# 1699 |-
# 1731 *The [[Zaqqum]] Tree
# 1732
# 1733 ==See also==
# 1734 {{portal|Ecology}}
# 1735 *[[List of superlative trees]]
# 1736 *[[List of oldest trees]]
# 1737 *[[List of long-living organisms]]
# 1738 *[[Elm#Notable elm trees|Notable elm trees]]
# 1739 *[[List of famous Eucalypt trees]]
# 1740 *[[List of Great British Trees]]
# 1741 *[[Gerichtslinde]]
# 1742 *[[List of tree genera]]
# 1743 *[[Veteran tree]]
# 1744 *[[Bonsai]]
# 1745
# 1746 ==References==
# 1747 {{reflist}}
# 1748
# 1749 ==External links==
# 1750 *[https://web.archive.org/web/20070429233415/http://www.platial.com/tracy_the_astonishing/map/20992 Map of this list] (in progress)
# 1751 *[http://www.nbcnews.com/id/18178917 World’s first tree reconstructed] 385 million-year-old tree
# 1752
# 1753 {{DEFAULTSORT:Trees}}
# 1754 [[Category:Individual trees|*]]
# 1755 [[Category:Lists of trees| ]]
# 1756 [[Category:Lists of fictional things]]
# 1757
# 1758 [[de:Liste markanter und alter Baumexemplare]]
# 1759 [[fr:Liste des arbres remarquables]]
# 1760 [[lt:Sąrašas:Išskirtiniai medžiai]]
# 1761 [[hu:Híres fák listája]]
# 1762 [[ru:Список знаменитых и легендарных деревьев]]

# %%
# create nested section_dict dictionary from section list based on toclevel
# refactored
section_dict = {}
for i in range(len(sec_list)):
    if i == 0:
        if sec_list[i]['toclevel'] < sec_list[i + 1]['toclevel']:
            section_dict[sec_list[i]['line']] = {}
            current_grandparent = sec_list[i]['line']

    elif i != len(sec_list) - 1:
        if sec_list[i - 1]['toclevel'] < sec_list[i]['toclevel'] and sec_list[i]['toclevel'] < sec_list[i + 1]['toclevel']:
            section_dict[current_grandparent][sec_list[i]['line']] = {}
            current_parent = section_dict[current_grandparent][sec_list[i]['line']]
            
        elif sec_list[i]['toclevel'] == sec_list[i + 1]['toclevel'] or sec_list[i]['toclevel'] > sec_list[i + 1]['toclevel']:
            current_parent[sec_list[i]['line']] = []
            
        elif sec_list[i]['toclevel'] < sec_list[i + 1]['toclevel']:
            section_dict[current_grandparent][sec_list[i]['line']] = {}
            current_parent = section_dict[current_grandparent][sec_list[i]['line']]
            
    else:
        if sec_list[i]['toclevel'] == sec_list[i - 1]['toclevel']:
            section_dict[sec_list[i]['line']] = []
        else:
            section_dict[sec_list[i]['line']] = []
              

#pprint(section_dict)

# %%
# parse 
#       WikiTable
# data

this_item_start = None
this_sec = None
this_item = None
new_cols = False
cols = []

debug = False
special = True

with open('error_lines.txt', 'w+', encoding="utf-8") as filepath:
    for index, line in enumerate(lines):
        #print(line)
        if re.match('=+\w', line[0:5]):
            if debug or special: print("$-0-$$")
            if this_sec != None:
                if debug or special: print("$-1-$$")
                #print(cols)
                #print(this_sec)
                #print(index, line)
                print(this_sec)
                section_dict[current_greatgrandparent][current_grandparent][current_parent] = this_sec
                print(current_greatgrandparent)
                print(current_grandparent)
                print(current_parent)

                
                print(section_dict)
                this_item = None
                this_item_start = None
                
                this_sec = None
                cols = []
                new_cols = False
                
        if re.match('==\w', line[0:5]):
            if debug: print("$-2-$$")
            current_greatgrandparent = line.strip().replace("=", "")
            
        elif re.match('===\w', line[0:5]):
            if debug: print("$-3-$$")
            current_grandparent = line.strip().replace("=", "")
            
        elif re.match('====\w', line[0:5]):
            if debug: print("$-4-$$")
            current_parent = line.strip().replace("=", "")
                
        if re.match('\{\|', line[0:2]):
            if debug: print("$-5-$$")
            start_table = index
            cols = []
        
        if debug:
            if index != 0: 
                print('$\n' + str(index -1) + '\n' + lines[index - 1] + '\n' + str(index) + '\n' + line + '\n$')
                print(index, re.match('\|\-', lines[index - 1][0:2]))
                print(line)
                print(index,re.match('\!\w+', line[0:2]))
            
        
        if re.match('\|\-', lines[index - 1][0:2]) and re.match('\!\w+', line[0:2]):
            if debug: print("$-6-$$")
            new_cols = True
            

        if re.match('\!\w+', lines[index - 1][0:2]) and re.match('\|\-', line[0:2]):
            if debug or special: print("$-7-$$")
            new_cols = False
            #this_sec_start = index + 2
            
        if new_cols == True:
            if debug: print("$-8-$$")
            cols.append(re.search(r'\!(\w+)', line).group(1))
            #print(cols)
            
        
        if len(cols) > 0 and new_cols == False:
            if debug: print("$-9-$$")
            this_sec = []
            #if index == this_sec_start:
                #this_sec = []

        if this_sec != None:
            if debug or special: print("$-10-$$")
            if re.match('\|\-', line[0:2]) and not re.match('\|\}', lines[index + 1][0:2]):
                print(index)
                if debug or special: print("$-11-$$")
                this_item_start = index + 1
                this_item = {col: '' for col in cols}
                #print(this_item)
                
        if this_item != None:
            if debug or special: print("$-12-$$")
            for i in range(len(cols)):
                #print(this_item)
                #print(index)
                if this_item[cols[i]] == '':
                    if debug or special: print("$-13-$$")
                    #print(index)    
                    this_item[cols[i]] = re.search(r'\|(.*)', lines[this_item_start + i]).group(1)
                    print(this_item)
        
        if this_item_start != None:
            if debug or special: print("$-14-$$")
            print(index)
            print(this_item_start)
            
            if index - this_item_start % len(cols) == 0:
                if debug or special: print("$-15-$$")
                print(this_sec)
                this_sec.append(this_item)
# Out:
# $-0-$$
# $-0-$$
# $-0-$$
# $-7-$$
# $-10-$$
# 19
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Lost Tree]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Lost Tree]]', 'Species': '[[Acacia]]', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Lost Tree]]', 'Species': '[[Acacia]]', 'Location': '[[Sahara desert]] <br/><small> {{Coord|20.645|N|11.249|E|name=Lost Tree}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Lost Tree]]', 'Species': '[[Acacia]]', 'Location': '[[Sahara desert]] <br/><small> {{Coord|20.645|N|11.249|E|name=Lost Tree}}</small>', 'Age': ' -', 'Notes': ''}
# $-13-$$
# {'Name': '[[Lost Tree]]', 'Species': '[[Acacia]]', 'Location': '[[Sahara desert]] <br/><small> {{Coord|20.645|N|11.249|E|name=Lost Tree}}</small>', 'Age': ' -', 'Notes': 'A very isolated tree and important landmark'}
# $-14-$$
# 19
# 20
# $-10-$$
# $-12-$$
# $-14-$$
# 20
# 20
# $-10-$$
# $-12-$$
# $-14-$$
# 21
# 20
# $-10-$$
# $-12-$$
# $-14-$$
# 22
# 20
# $-10-$$
# $-12-$$
# $-14-$$
# 23
# 20
# $-10-$$
# $-12-$$
# $-14-$$
# 24
# 20
# $-10-$$
# 25
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Cotton Tree (Sierra Leone)|The Cotton Tree]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Cotton Tree (Sierra Leone)|The Cotton Tree]]', 'Species': "[[Ceiba pentandra|Kapok]] (''[[Ceiba pentandra]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Cotton Tree (Sierra Leone)|The Cotton Tree]]', 'Species': "[[Ceiba pentandra|Kapok]] (''[[Ceiba pentandra]]'')", 'Location': '[[Freetown]], [[Sierra Leone]] <br/><small>{{Coord|8.4872|N|13.2356|W|name=The Cotton Tree}}', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Cotton Tree (Sierra Leone)|The Cotton Tree]]', 'Species': "[[Ceiba pentandra|Kapok]] (''[[Ceiba pentandra]]'')", 'Location': '[[Freetown]], [[Sierra Leone]] <br/><small>{{Coord|8.4872|N|13.2356|W|name=The Cotton Tree}}', 'Age': ' -', 'Notes': ''}
# $-13-$$
# {'Name': '[[Cotton Tree (Sierra Leone)|The Cotton Tree]]', 'Species': "[[Ceiba pentandra|Kapok]] (''[[Ceiba pentandra]]'')", 'Location': '[[Freetown]], [[Sierra Leone]] <br/><small>{{Coord|8.4872|N|13.2356|W|name=The Cotton Tree}}', 'Age': ' -', 'Notes': ' [[File:Cotton Tree (Sierra Leone).jpg|100px|left]] Historic symbol of Freetown.'}
# $-14-$$
# 25
# 26
# $-10-$$
# $-12-$$
# $-14-$$
# 26
# 26
# $-10-$$
# $-12-$$
# $-14-$$
# 27
# 26
# $-10-$$
# $-12-$$
# $-14-$$
# 28
# 26
# $-10-$$
# $-12-$$
# $-14-$$
# 29
# 26
# $-10-$$
# $-12-$$
# $-14-$$
# 30
# 26
# $-10-$$
# 31
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': ' [[Wonderboom (tree)|Wonderboom tree in Pretoria]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': ' [[Wonderboom (tree)|Wonderboom tree in Pretoria]]', 'Species': " [[Ficus salicifolia|Wonderboom]] (''[[Ficus salicifolia]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': ' [[Wonderboom (tree)|Wonderboom tree in Pretoria]]', 'Species': " [[Ficus salicifolia|Wonderboom]] (''[[Ficus salicifolia]]'')", 'Location': ' [[Pretoria]], [[South Africa]] <br/><small> {{coord|-25.6870|28.1918|name=Wonderboom tree}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': ' [[Wonderboom (tree)|Wonderboom tree in Pretoria]]', 'Species': " [[Ficus salicifolia|Wonderboom]] (''[[Ficus salicifolia]]'')", 'Location': ' [[Pretoria]], [[South Africa]] <br/><small> {{coord|-25.6870|28.1918|name=Wonderboom tree}}</small>', 'Age': ' -', 'Notes': ''}
# $-13-$$
# {'Name': ' [[Wonderboom (tree)|Wonderboom tree in Pretoria]]', 'Species': " [[Ficus salicifolia|Wonderboom]] (''[[Ficus salicifolia]]'')", 'Location': ' [[Pretoria]], [[South Africa]] <br/><small> {{coord|-25.6870|28.1918|name=Wonderboom tree}}</small>', 'Age': ' -', 'Notes': ' [[File:Wonderboom wiki.jpg|100px|left]] A sprawling fig tree in [[Pretoria]], South Africa.'}
# $-14-$$
# 31
# 32
# $-10-$$
# $-12-$$
# $-14-$$
# 32
# 32
# $-10-$$
# $-12-$$
# $-14-$$
# 33
# 32
# $-10-$$
# $-12-$$
# $-14-$$
# 34
# 32
# $-10-$$
# $-12-$$
# $-14-$$
# 35
# 32
# $-10-$$
# $-12-$$
# $-14-$$
# 36
# 32
# $-10-$$
# 37
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[El Drago Milenario]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[El Drago Milenario]]', 'Species': " [[Dragon Tree]] (''[[Dracaena draco]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[El Drago Milenario]]', 'Species': " [[Dragon Tree]] (''[[Dracaena draco]]'')", 'Location': '[[Icod de los Vinos]], [[Tenerife]] <br/><small> {{Coord|28.3666|-16.72222|name=El Drago Milenario}} </small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[El Drago Milenario]]', 'Species': " [[Dragon Tree]] (''[[Dracaena draco]]'')", 'Location': '[[Icod de los Vinos]], [[Tenerife]] <br/><small> {{Coord|28.3666|-16.72222|name=El Drago Milenario}} </small>', 'Age': ' -', 'Notes': ''}
# $-13-$$
# {'Name': '[[El Drago Milenario]]', 'Species': " [[Dragon Tree]] (''[[Dracaena draco]]'')", 'Location': '[[Icod de los Vinos]], [[Tenerife]] <br/><small> {{Coord|28.3666|-16.72222|name=El Drago Milenario}} </small>', 'Age': ' -', 'Notes': ' [[File:Dracaena draco.jpg|100px|left]] Has been a local tourist attraction for more than a hundred years (mentioned by [[Alexander von Humboldt]], for instance).'}
# $-14-$$
# 37
# 38
# $-10-$$
# $-12-$$
# $-14-$$
# 38
# 38
# $-10-$$
# $-12-$$
# $-14-$$
# 39
# 38
# $-10-$$
# $-12-$$
# $-14-$$
# 40
# 38
# $-10-$$
# $-12-$$
# $-14-$$
# 41
# 38
# $-10-$$
# $-12-$$
# $-14-$$
# 42
# 38
# $-10-$$
# 43
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Sunland Baobab]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Sunland Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Sunland Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': '[[Limpopo Province]], [[South Africa]]<br/><small>{{coord|23|37|16|S|30|11|53|E|name=Sunland Baobab}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Sunland Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': '[[Limpopo Province]], [[South Africa]]<br/><small>{{coord|23|37|16|S|30|11|53|E|name=Sunland Baobab}}</small>', 'Age': '1060', 'Notes': ''}
# $-13-$$
# {'Name': '[[Sunland Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': '[[Limpopo Province]], [[South Africa]]<br/><small>{{coord|23|37|16|S|30|11|53|E|name=Sunland Baobab}}</small>', 'Age': '1060', 'Notes': ' [[File:Sunland Baobab, Limpopo, South Africa (5613316944).jpg|100px|left]] A giant and ancient baobab tree, with a [[pub]] in the hollow.'}
# $-14-$$
# 43
# 44
# $-10-$$
# $-12-$$
# $-14-$$
# 44
# 44
# $-10-$$
# $-12-$$
# $-14-$$
# 45
# 44
# $-10-$$
# $-12-$$
# $-14-$$
# 46
# 44
# $-10-$$
# $-12-$$
# $-14-$$
# 47
# 44
# $-10-$$
# $-12-$$
# $-14-$$
# 48
# 44
# $-10-$$
# 49
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Sagole Baobab]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Sagole Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Sagole Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': 'Near [[Tshipise]], in [[Vendaland]], Limpopo Province, South Africa <br/> <small> {{coord|22|30|00|S|30|38|00|E|name=Sagole Baobab}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Sagole Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': 'Near [[Tshipise]], in [[Vendaland]], Limpopo Province, South Africa <br/> <small> {{coord|22|30|00|S|30|38|00|E|name=Sagole Baobab}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Sagole Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': 'Near [[Tshipise]], in [[Vendaland]], Limpopo Province, South Africa <br/> <small> {{coord|22|30|00|S|30|38|00|E|name=Sagole Baobab}}</small>', 'Age': '', 'Notes': '[[File:Sagole Baobab.jpg|100px|left]] Largest baobab in South Africa'}
# $-14-$$
# 49
# 50
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Sagole Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': 'Near [[Tshipise]], in [[Vendaland]], Limpopo Province, South Africa <br/> <small> {{coord|22|30|00|S|30|38|00|E|name=Sagole Baobab}}</small>', 'Age': '', 'Notes': '[[File:Sagole Baobab.jpg|100px|left]] Largest baobab in South Africa'}
# $-14-$$
# 50
# 50
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Sagole Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': 'Near [[Tshipise]], in [[Vendaland]], Limpopo Province, South Africa <br/> <small> {{coord|22|30|00|S|30|38|00|E|name=Sagole Baobab}}</small>', 'Age': '', 'Notes': '[[File:Sagole Baobab.jpg|100px|left]] Largest baobab in South Africa'}
# $-14-$$
# 51
# 50
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Sagole Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': 'Near [[Tshipise]], in [[Vendaland]], Limpopo Province, South Africa <br/> <small> {{coord|22|30|00|S|30|38|00|E|name=Sagole Baobab}}</small>', 'Age': '', 'Notes': '[[File:Sagole Baobab.jpg|100px|left]] Largest baobab in South Africa'}
# $-14-$$
# 52
# 50
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Sagole Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': 'Near [[Tshipise]], in [[Vendaland]], Limpopo Province, South Africa <br/> <small> {{coord|22|30|00|S|30|38|00|E|name=Sagole Baobab}}</small>', 'Age': '', 'Notes': '[[File:Sagole Baobab.jpg|100px|left]] Largest baobab in South Africa'}
# $-14-$$
# 53
# 50
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Sagole Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': 'Near [[Tshipise]], in [[Vendaland]], Limpopo Province, South Africa <br/> <small> {{coord|22|30|00|S|30|38|00|E|name=Sagole Baobab}}</small>', 'Age': '', 'Notes': '[[File:Sagole Baobab.jpg|100px|left]] Largest baobab in South Africa'}
# $-14-$$
# 54
# 50
# $-10-$$
# 55
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Glencoe Baobab]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Glencoe Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Glencoe Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': '[[Hoedspruit]], South Africa <br/><small>{{coord|24|22|25|S|30|51|24|E|name=Glencoe Baobab}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Glencoe Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': '[[Hoedspruit]], South Africa <br/><small>{{coord|24|22|25|S|30|51|24|E|name=Glencoe Baobab}}</small>', 'Age': '1835', 'Notes': ''}
# $-13-$$
# {'Name': '[[Glencoe Baobab]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': '[[Hoedspruit]], South Africa <br/><small>{{coord|24|22|25|S|30|51|24|E|name=Glencoe Baobab}}</small>', 'Age': '1835', 'Notes': 'Stoutest and second largest baobab in South Africa'}
# $-14-$$
# 55
# 56
# $-10-$$
# $-12-$$
# $-14-$$
# 56
# 56
# $-10-$$
# $-12-$$
# $-14-$$
# 57
# 56
# $-10-$$
# $-12-$$
# $-14-$$
# 58
# 56
# $-10-$$
# $-12-$$
# $-14-$$
# 59
# 56
# $-10-$$
# $-12-$$
# $-14-$$
# 60
# 56
# $-10-$$
# 61
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Ombalantu baobab tree]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Ombalantu baobab tree]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Ombalantu baobab tree]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': '[[Outapi]], Namibia<br/><small>{{coord|17|30|43|S|14|59|16|E|name=Ombalantu baobab tree}} </small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Ombalantu baobab tree]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': '[[Outapi]], Namibia<br/><small>{{coord|17|30|43|S|14|59|16|E|name=Ombalantu baobab tree}} </small>', 'Age': '800', 'Notes': ''}
# $-13-$$
# {'Name': '[[Ombalantu baobab tree]]', 'Species': "[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')", 'Location': '[[Outapi]], Namibia<br/><small>{{coord|17|30|43|S|14|59|16|E|name=Ombalantu baobab tree}} </small>', 'Age': '800', 'Notes': '[[File:Ombalantu Baobab Tree.jpg|100px|left]] Has served as a chapel, post office, house, and place of hiding. '}
# $-14-$$
# 61
# 62
# $-10-$$
# $-12-$$
# $-14-$$
# 62
# 62
# $-10-$$
# $-12-$$
# $-14-$$
# 63
# 62
# $-10-$$
# $-12-$$
# $-14-$$
# 64
# 62
# $-10-$$
# $-12-$$
# $-14-$$
# 65
# 62
# $-10-$$
# $-12-$$
# $-14-$$
# 66
# 62
# $-10-$$
# 67
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Omukwiyugwemanya]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Omukwiyugwemanya]]', 'Species': 'Fig tree', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Omukwiyugwemanya]]', 'Species': 'Fig tree', 'Location': '[[Oshigambo]], Namibia <br/> <small>{{coord|-17.7870|16.0740|name=Omukwiyugwemanya}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Omukwiyugwemanya]]', 'Species': 'Fig tree', 'Location': '[[Oshigambo]], Namibia <br/> <small>{{coord|-17.7870|16.0740|name=Omukwiyugwemanya}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Omukwiyugwemanya]]', 'Species': 'Fig tree', 'Location': '[[Oshigambo]], Namibia <br/> <small>{{coord|-17.7870|16.0740|name=Omukwiyugwemanya}}</small>', 'Age': '', 'Notes': 'Tourist attraction'}
# $-14-$$
# 67
# 68
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Omukwiyugwemanya]]', 'Species': 'Fig tree', 'Location': '[[Oshigambo]], Namibia <br/> <small>{{coord|-17.7870|16.0740|name=Omukwiyugwemanya}}</small>', 'Age': '', 'Notes': 'Tourist attraction'}
# $-14-$$
# 68
# 68
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Omukwiyugwemanya]]', 'Species': 'Fig tree', 'Location': '[[Oshigambo]], Namibia <br/> <small>{{coord|-17.7870|16.0740|name=Omukwiyugwemanya}}</small>', 'Age': '', 'Notes': 'Tourist attraction'}
# $-14-$$
# 69
# 68
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Omukwiyugwemanya]]', 'Species': 'Fig tree', 'Location': '[[Oshigambo]], Namibia <br/> <small>{{coord|-17.7870|16.0740|name=Omukwiyugwemanya}}</small>', 'Age': '', 'Notes': 'Tourist attraction'}
# $-14-$$
# 70
# 68
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Omukwiyugwemanya]]', 'Species': 'Fig tree', 'Location': '[[Oshigambo]], Namibia <br/> <small>{{coord|-17.7870|16.0740|name=Omukwiyugwemanya}}</small>', 'Age': '', 'Notes': 'Tourist attraction'}
# $-14-$$
# 71
# 68
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Omukwiyugwemanya]]', 'Species': 'Fig tree', 'Location': '[[Oshigambo]], Namibia <br/> <small>{{coord|-17.7870|16.0740|name=Omukwiyugwemanya}}</small>', 'Age': '', 'Notes': 'Tourist attraction'}
# $-14-$$
# 72
# 68
# $-10-$$
# 73
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Post Office Tree]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Post Office Tree]]', 'Species': "[[Sideroxylon inerme|White Milkwood]] (''[[Sideroxylon inerme]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Post Office Tree]]', 'Species': "[[Sideroxylon inerme|White Milkwood]] (''[[Sideroxylon inerme]]'')", 'Location': '[[Mosselbay]], South Africa <br/><small>{{coord|-34.180363|22.141382|name=Post Office Tree}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Post Office Tree]]', 'Species': "[[Sideroxylon inerme|White Milkwood]] (''[[Sideroxylon inerme]]'')", 'Location': '[[Mosselbay]], South Africa <br/><small>{{coord|-34.180363|22.141382|name=Post Office Tree}}</small>', 'Age': 'c.600', 'Notes': ''}
# $-13-$$
# {'Name': '[[Post Office Tree]]', 'Species': "[[Sideroxylon inerme|White Milkwood]] (''[[Sideroxylon inerme]]'')", 'Location': '[[Mosselbay]], South Africa <br/><small>{{coord|-34.180363|22.141382|name=Post Office Tree}}</small>', 'Age': 'c.600', 'Notes': '[[File:The Post Office Tree.JPG|100px|left]] Acted as a "post office" in earlier times and now has a boot shaped postbox.'}
# $-14-$$
# 73
# 74
# $-10-$$
# $-12-$$
# $-14-$$
# 74
# 74
# $-10-$$
# $-12-$$
# $-14-$$
# 75
# 74
# $-10-$$
# $-12-$$
# $-14-$$
# 76
# 74
# $-10-$$
# $-12-$$
# $-14-$$
# 77
# 74
# $-10-$$
# $-12-$$
# $-14-$$
# 78
# 74
# $-10-$$
# 79
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Treaty Tree]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Treaty Tree]]', 'Species': "[[Sideroxylon inerme|White Milkwood]] (''[[Sideroxylon inerme]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Treaty Tree]]', 'Species': "[[Sideroxylon inerme|White Milkwood]] (''[[Sideroxylon inerme]]'')", 'Location': '[[Woodstock, Cape Town]], South Africa <br/> <small> {{coord|-33.92626|18.45130|name=Treaty Tree}} </small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Treaty Tree]]', 'Species': "[[Sideroxylon inerme|White Milkwood]] (''[[Sideroxylon inerme]]'')", 'Location': '[[Woodstock, Cape Town]], South Africa <br/> <small> {{coord|-33.92626|18.45130|name=Treaty Tree}} </small>', 'Age': 'c.500', 'Notes': ''}
# $-13-$$
# {'Name': '[[Treaty Tree]]', 'Species': "[[Sideroxylon inerme|White Milkwood]] (''[[Sideroxylon inerme]]'')", 'Location': '[[Woodstock, Cape Town]], South Africa <br/> <small> {{coord|-33.92626|18.45130|name=Treaty Tree}} </small>', 'Age': 'c.500', 'Notes': '[[File:Photo 5 Treaty Tree. Cnr Treaty and Spring St, Woodstock. Cape Town..JPG|100px|left]] Site of Peace Treaty in 1806.'}
# $-14-$$
# 79
# 80
# $-10-$$
# $-12-$$
# $-14-$$
# 80
# 80
# $-10-$$
# $-12-$$
# $-14-$$
# 81
# 80
# $-10-$$
# $-12-$$
# $-14-$$
# 82
# 80
# $-10-$$
# $-12-$$
# $-14-$$
# 83
# 80
# $-10-$$
# $-12-$$
# $-14-$$
# 84
# 80
# $-10-$$
# 85
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Big Tree in Chirinda Forest]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Big Tree in Chirinda Forest]]', 'Species': "[[Khaya anthotheca|Nyasa Redwood]] (''Khaya anthotheca '')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Big Tree in Chirinda Forest]]', 'Species': "[[Khaya anthotheca|Nyasa Redwood]] (''Khaya anthotheca '')", 'Location': '[[Chirinda Forest]], Zimbabwe <br/> <small> {{coordinates|20|26|29|S|32|42|15|E|name=Big Tree in Chirinda Forest}} </small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Big Tree in Chirinda Forest]]', 'Species': "[[Khaya anthotheca|Nyasa Redwood]] (''Khaya anthotheca '')", 'Location': '[[Chirinda Forest]], Zimbabwe <br/> <small> {{coordinates|20|26|29|S|32|42|15|E|name=Big Tree in Chirinda Forest}} </small>', 'Age': '1000+', 'Notes': ''}
# $-13-$$
# {'Name': '[[Big Tree in Chirinda Forest]]', 'Species': "[[Khaya anthotheca|Nyasa Redwood]] (''Khaya anthotheca '')", 'Location': '[[Chirinda Forest]], Zimbabwe <br/> <small> {{coordinates|20|26|29|S|32|42|15|E|name=Big Tree in Chirinda Forest}} </small>', 'Age': '1000+', 'Notes': 'Declared a National Monument'}
# $-14-$$
# 85
# 86
# $-10-$$
# $-12-$$
# $-14-$$
# 86
# 86
# $-10-$$
# $-12-$$
# $-14-$$
# 87
# 86
# $-10-$$
# $-12-$$
# $-14-$$
# 88
# 86
# $-10-$$
# $-12-$$
# $-14-$$
# 89
# 86
# $-10-$$
# $-12-$$
# $-14-$$
# 90
# 86
# $-10-$$
# $-12-$$
# $-14-$$
# 91
# 86
# $-10-$$
# $-12-$$
# $-14-$$
# 92
# 86
# $-10-$$
# $-12-$$
# $-14-$$
# 93
# 86
# $-0-$$
# $-1-$$
# []
# Real forests and individual trees
# Africa
# Living
# {'Real forests and individual trees': {'Africa': {'Living': [], 'Historical': []}, 'Asia': {'Living': [], 'Historical': []}, 'Europe': {'Living': [], 'Historical': [], 'Petrified': []}, 'North America': {'Living': [], 'Historical': [], 'Petrified': [], 'Other': []}, 'Central America': {'Living': []}, 'South America': {'Living': [], 'Historical': []}, 'Oceania': {'Living': [], 'Historical': []}}, 'Mythological and religious': []}
# $-7-$$
# $-10-$$
# 102
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Arbre du Ténéré]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Arbre du Ténéré]]', 'Species': 'Acacia', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Arbre du Ténéré]]', 'Species': 'Acacia', 'Location': '[[Sahara desert]]<br/><small>{{coord|17|45|00|N|10|04|00|E|name=Arbre du Ténéré}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Arbre du Ténéré]]', 'Species': 'Acacia', 'Location': '[[Sahara desert]]<br/><small>{{coord|17|45|00|N|10|04|00|E|name=Arbre du Ténéré}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Arbre du Ténéré]]', 'Species': 'Acacia', 'Location': '[[Sahara desert]]<br/><small>{{coord|17|45|00|N|10|04|00|E|name=Arbre du Ténéré}}</small>', 'Age': '', 'Notes': ' [[File:Arbre-du-tenere-1961.jpg|100px|left]] A very isolated tree in the Sahara desert, notable before 1934, in [[Niger]], destroyed in 1973.'}
# $-14-$$
# 102
# 103
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Arbre du Ténéré]]', 'Species': 'Acacia', 'Location': '[[Sahara desert]]<br/><small>{{coord|17|45|00|N|10|04|00|E|name=Arbre du Ténéré}}</small>', 'Age': '', 'Notes': ' [[File:Arbre-du-tenere-1961.jpg|100px|left]] A very isolated tree in the Sahara desert, notable before 1934, in [[Niger]], destroyed in 1973.'}
# $-14-$$
# 103
# 103
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Arbre du Ténéré]]', 'Species': 'Acacia', 'Location': '[[Sahara desert]]<br/><small>{{coord|17|45|00|N|10|04|00|E|name=Arbre du Ténéré}}</small>', 'Age': '', 'Notes': ' [[File:Arbre-du-tenere-1961.jpg|100px|left]] A very isolated tree in the Sahara desert, notable before 1934, in [[Niger]], destroyed in 1973.'}
# $-14-$$
# 104
# 103
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Arbre du Ténéré]]', 'Species': 'Acacia', 'Location': '[[Sahara desert]]<br/><small>{{coord|17|45|00|N|10|04|00|E|name=Arbre du Ténéré}}</small>', 'Age': '', 'Notes': ' [[File:Arbre-du-tenere-1961.jpg|100px|left]] A very isolated tree in the Sahara desert, notable before 1934, in [[Niger]], destroyed in 1973.'}
# $-14-$$
# 105
# 103
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Arbre du Ténéré]]', 'Species': 'Acacia', 'Location': '[[Sahara desert]]<br/><small>{{coord|17|45|00|N|10|04|00|E|name=Arbre du Ténéré}}</small>', 'Age': '', 'Notes': ' [[File:Arbre-du-tenere-1961.jpg|100px|left]] A very isolated tree in the Sahara desert, notable before 1934, in [[Niger]], destroyed in 1973.'}
# $-14-$$
# 106
# 103
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Arbre du Ténéré]]', 'Species': 'Acacia', 'Location': '[[Sahara desert]]<br/><small>{{coord|17|45|00|N|10|04|00|E|name=Arbre du Ténéré}}</small>', 'Age': '', 'Notes': ' [[File:Arbre-du-tenere-1961.jpg|100px|left]] A very isolated tree in the Sahara desert, notable before 1934, in [[Niger]], destroyed in 1973.'}
# $-14-$$
# 107
# 103
# $-10-$$
# 108
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': 'Panke Baobab', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': 'Panke Baobab', 'Species': '[[Adansonia digitata|African Baobab]]', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': 'Panke Baobab', 'Species': '[[Adansonia digitata|African Baobab]]', 'Location': '[[Zimbabwe]]', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': 'Panke Baobab', 'Species': '[[Adansonia digitata|African Baobab]]', 'Location': '[[Zimbabwe]]', 'Age': ' 2,419', 'Notes': ''}
# $-13-$$
# {'Name': 'Panke Baobab', 'Species': '[[Adansonia digitata|African Baobab]]', 'Location': '[[Zimbabwe]]', 'Age': ' 2,419', 'Notes': ' Oldest documented non-clonal [[angiosperm]].  Tree fell in 2011.<ref>Adrian Patrut et al. (2018) The demise of the largest and oldest African baobabs. Nature Plants 4: 423–426. DOI: 10.1038/s41477-018-0170-5</ref>'}
# $-14-$$
# 108
# 109
# $-10-$$
# $-12-$$
# $-14-$$
# 109
# 109
# $-10-$$
# $-12-$$
# $-14-$$
# 110
# 109
# $-10-$$
# $-12-$$
# $-14-$$
# 111
# 109
# $-10-$$
# $-12-$$
# $-14-$$
# 112
# 109
# $-10-$$
# $-12-$$
# $-14-$$
# 113
# 109
# $-10-$$
# 114
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': "Chapman's Baobab", 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': "Chapman's Baobab", 'Species': '[[Adansonia digitata|African Baobab]]', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': "Chapman's Baobab", 'Species': '[[Adansonia digitata|African Baobab]]', 'Location': '[[Botswana]]', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': "Chapman's Baobab", 'Species': '[[Adansonia digitata|African Baobab]]', 'Location': '[[Botswana]]', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': "Chapman's Baobab", 'Species': '[[Adansonia digitata|African Baobab]]', 'Location': '[[Botswana]]', 'Age': '', 'Notes': " [[File:Chapman's_baobab_(4954708191).jpg|100px|left]] Found and named after James Chapman and marked by explorer [[David Livingstone]].  Tree fell in 2016.<ref>https://africageographic.com/blog/chapmans-baobob-one-of-africas-largest-trees-falls/</ref>"}
# $-14-$$
# 114
# 115
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': "Chapman's Baobab", 'Species': '[[Adansonia digitata|African Baobab]]', 'Location': '[[Botswana]]', 'Age': '', 'Notes': " [[File:Chapman's_baobab_(4954708191).jpg|100px|left]] Found and named after James Chapman and marked by explorer [[David Livingstone]].  Tree fell in 2016.<ref>https://africageographic.com/blog/chapmans-baobob-one-of-africas-largest-trees-falls/</ref>"}
# $-14-$$
# 115
# 115
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': "Chapman's Baobab", 'Species': '[[Adansonia digitata|African Baobab]]', 'Location':
# $-14-$$
# 156
# 157
# $-10-$$
# $-12-$$
# $-14-$$
# 157
# 157
# $-10-$$
# $-12-$$
# $-14-$$
# 158
# 157
# $-10-$$
# $-12-$$
# $-14-$$
# 159
# 157
# $-10-$$
# $-12-$$
# $-14-$$
# 160
# 157
# $-10-$$
# $-12-$$
# $-14-$$
# 161
# 157
# $-10-$$
# 162
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '', 'Species': '[[Balete tree]]', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '', 'Species': '[[Balete tree]]', 'Location': 'OISCA Farm in [[Canlaon City]], [[Philippines]]', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '', 'Species': '[[Balete tree]]', 'Location': 'OISCA Farm in [[Canlaon City]], [[Philippines]]', 'Age': '1,300', 'Notes': ''}
# $-13-$$
# {'Name': '', 'Species': '[[Balete tree]]', 'Location': 'OISCA Farm in [[Canlaon City]], [[Philippines]]', 'Age': '1,300', 'Notes': 'The over 1,300-year-old [[balete tree]] (related to [[banyan]] trees) located in is probably the oldest known tree in the country as estimated by [[botanist]]s from [[Silliman University]].<ref>[http://www.dumagueteinfo.com/the-oldest-tree.php "The Oldest Tree - Canlaon - Negros Oriental - Philippines"]. Dumaguete Info. Retrieved on 2011-04-28.</ref>'}
# $-14-$$
# 162
# 163
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '', 'Species': '[[Balete tree]]', 'Location': 'OISCA Farm in [[Canlaon City]], [[Philippines]]', 'Age': '1,300', 'Notes': 'The over 1,300-year-old [[balete tree]] (related to [[banyan]] trees) located in is probably the oldest known tree in the country as estimated by [[botanist]]s from [[Silliman University]].<ref>[http://www.dumagueteinfo.com/the-oldest-tree.php "The Oldest Tree - Canlaon - Negros Oriental - Philippines"]. Dumaguete Info. Retrieved on 2011-04-28.</ref>'}
# $-14-$$
# 163
# 163
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '', 'Species': '[[Balete tree]]', 'Location': 'OISCA Farm in [[Canlaon City]], [[Philippines]]', 'Age': '1,300', 'Notes': 'The over 1,300-year-old [[balete tree]] (related to [[banyan]] trees) located in is probably the oldest known tree in the country as estimated by [[botanist]]s from [[Silliman University]].<ref>[http://www.dumagueteinfo.com/the-oldest-tree.php "The Oldest Tree - Canlaon - Negros Oriental - Philippines"]. Dumaguete Info. Retrieved on 2011-04-28.</ref>'}
# $-14-$$
# 164
# 163
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '', 'Species': '[[Balete tree]]', 'Location': 'OISCA Farm in [[Canlaon City]], [[Philippines]]', 'Age': '1,300', 'Notes': 'The over 1,300-year-old [[balete tree]] (related to [[banyan]] trees) located in is probably the oldest known tree in the country as estimated by [[botanist]]s from [[Silliman University]].<ref>[http://www.dumagueteinfo.com/the-oldest-tree.php "The Oldest Tree - Canlaon - Negros Oriental - Philippines"]. Dumaguete Info. Retrieved on 2011-04-28.</ref>'}
# $-14-$$
# 165
# 163
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '', 'Species': '[[Balete tree]]', 'Location': 'OISCA Farm in [[Canlaon City]], [[Philippines]]', 'Age': '1,300', 'Notes': 'The over 1,300-year-old [[balete tree]] (related to [[banyan]] trees) located in is probably the oldest known tree in the country as estimated by [[botanist]]s from [[Silliman University]].<ref>[http://www.dumagueteinfo.com/the-oldest-tree.php "The Oldest Tree - Canlaon - Negros Oriental - Philippines"]. Dumaguete Info. Retrieved on 2011-04-28.</ref>'}
# $-14-$$
# 166
# 163
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '', 'Species': '[[Balete tree]]', 'Location': 'OISCA Farm in [[Canlaon City]], [[Philippines]]', 'Age': '1,300', 'Notes': 'The over 1,300-year-old [[balete tree]] (related to [[banyan]] trees) located in is probably the oldest known tree in the country as estimated by [[botanist]]s from [[Silliman University]].<ref>[http://www.dumagueteinfo.com/the-oldest-tree.php "The Oldest Tree - Canlaon - Negros Oriental - Philippines"]. Dumaguete Info. Retrieved on 2011-04-28.</ref>'}
# $-14-$$
# 167
# 163
# $-10-$$
# 168
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Hibakujumoku]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Hibakujumoku]]', 'Species': 'Various', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Hibakujumoku]]', 'Species': 'Various', 'Location': '[[Hiroshima]], [[Japan]]', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Hibakujumoku]]', 'Species': 'Various', 'Location': '[[Hiroshima]], [[Japan]]', 'Age': 'Various', 'Notes': ''}
# $-13-$$
# {'Name': '[[Hibakujumoku]]', 'Species': 'Various', 'Location': '[[Hiroshima]], [[Japan]]', 'Age': 'Various', 'Notes': '170 trees that survived the [[atomic bombing of Hiroshima]]'}
# $-14-$$
# 168
# 169
# $-10-$$
# $-12-$$
# $-14-$$
# 169
# 169
# $-10-$$
# $-12-$$
# $-14-$$
# 170
# 169
# $-10-$$
# $-12-$$
# $-14-$$
# 171
# 169
# $-10-$$
# $-12-$$
# $-14-$$
# 172
# 169
# $-10-$$
# $-12-$$
# $-14-$$
# 173
# 169
# $-10-$$
# 174
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Jaya Sri Maha Bodhi]] ', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Jaya Sri Maha Bodhi]] ', 'Species': "[[Sacred fig]] (''[[Ficus religiosa]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Jaya Sri Maha Bodhi]] ', 'Species': "[[Sacred fig]] (''[[Ficus religiosa]]'')", 'Location': '[[Anuradhapura]], [[Sri Lanka]] <br/><small> {{coord|8|20|41|N|80|23|48|E|name=Jaya Sri Maha Bodhi}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Jaya Sri Maha Bodhi]] ', 'Species': "[[Sacred fig]] (''[[Ficus religiosa]]'')", 'Location': '[[Anuradhapura]], [[Sri Lanka]] <br/><small> {{coord|8|20|41|N|80|23|48|E|name=Jaya Sri Maha Bodhi}}</small>', 'Age': '2300', 'Notes': ''}
# $-13-$$
# {'Name': '[[Jaya Sri Maha Bodhi]] ', 'Species': "[[Sacred fig]] (''[[Ficus religiosa]]'')", 'Location': '[[Anuradhapura]], [[Sri Lanka]] <br/><small> {{coord|8|20|41|N|80|23|48|E|name=Jaya Sri Maha Bodhi}}</small>', 'Age': '2300', 'Notes': "[[File:Jaya Sri Maha Bodhi.jpg|100px|left]] A [[sacred fig]] propagated from the [[Bodhi tree]] under which [[Lord Buddha]] became enlightened. It was planted in 288 BC.<ref>{{cite web|url= http://www.sundayobserver.lk/2011/07/03/spe01.asp|title= ''Caring for the Jaya Sri Maha Bodhi ''|accessdate= 2012-01-30|author= Shanika Sriyananda|date= 2011-07-03|url-status= dead|archiveurl= https://web.archive.org/web/20130413143127/http://www.sundayobserver.lk/2011/07/03/spe01.asp|archivedate= 2013-04-13}}</ref>"}
# $-14-$$
# 174
# 175
# $-10-$$
# $-12-$$
# $-14-$$
# 175
# 175
# $-10-$$
# $-12-$$
# $-14-$$
# 176
# 175
# $-10-$$
# $-12-$$
# $-14-$$
# 177
# 175
# $-10-$$
# $-12-$$
# $-14-$$
# 178
# 175
# $-10-$$
# $-12-$$
# $-14-$$
# 179
# 175
# $-10-$$
# 180
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Jōmon Sugi]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Jōmon Sugi]]', 'Species': "[[Cryptomeria|Japanese Cedar]] (''[[Cryptomeria japonica]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Jōmon Sugi]]', 'Species': "[[Cryptomeria|Japanese Cedar]] (''[[Cryptomeria japonica]]'')", 'Location': '[[Yakushima]] island, [[Japan]] <br/><small> {{coord|30|21|40.76|N|130|31|55.81|E|name=Jōmon Sugi}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Jōmon Sugi]]', 'Species': "[[Cryptomeria|Japanese Cedar]] (''[[Cryptomeria japonica]]'')", 'Location': '[[Yakushima]] island, [[Japan]] <br/><small> {{coord|30|21|40.76|N|130|31|55.81|E|name=Jōmon Sugi}}</small>', 'Age': ' -', 'Notes': ''}
# $-13-$$
# {'Name': '[[Jōmon Sugi]]', 'Species': "[[Cryptomeria|Japanese Cedar]] (''[[Cryptomeria japonica]]'')", 'Location': '[[Yakushima]] island, [[Japan]] <br/><small> {{coord|30|21|40.76|N|130|31|55.81|E|name=Jōmon Sugi}}</small>', 'Age': ' -', 'Notes': ' [[File:Jomon Sugi Panorama.jpg|100px|left]] Ancient specimen'}
# $-14-$$
# 180
# 181
# $-10-$$
# $-12-$$
# $-14-$$
# 181
# 181
# $-10-$$
# $-12-$$
# $-14-$$
# 182
# 181
# $-10-$$
# $-12-$$
# $-14-$$
# 183
# 181
# $-10-$$
# $-12-$$
# $-14-$$
# 184
# 181
# $-10-$$
# $-12-$$
# $-14-$$
# 185
# 181
# $-10-$$
# 186
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Great sugi of Kayano]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Great sugi of Kayano]]', 'Species': "Cryptomeria|Japanese Cedar (''Cryptomeria japonica'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Great sugi of Kayano]]', 'Species': "Cryptomeria|Japanese Cedar (''Cryptomeria japonica'')", 'Location': '[[Kaga, Ishikawa|Kaga]], [[Ishikawa Prefecture]], Japan <br/><small> {{coord|36|13|39|N|136|21|36|E|name=Great sugi of Kayano}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Great sugi of Kayano]]', 'Species': "Cryptomeria|Japanese Cedar (''Cryptomeria japonica'')", 'Location': '[[Kaga, Ishikawa|Kaga]], [[Ishikawa Prefecture]], Japan <br/><small> {{coord|36|13|39|N|136|21|36|E|name=Great sugi of Kayano}}</small>', 'Age': '2,300', 'Notes': ''}
# $-13-$$
# {'Name': '[[Great sugi of Kayano]]', 'Species': "Cryptomeria|Japanese Cedar (''Cryptomeria japonica'')", 'Location': '[[Kaga, Ishikawa|Kaga]], [[Ishikawa Prefecture]], Japan <br/><small> {{coord|36|13|39|N|136|21|36|E|name=Great sugi of Kayano}}</small>', 'Age': '2,300', 'Notes': ' [[File:Kayano Ōsugi 20070814.jpg|100px|left]]'}
# $-14-$$
# 186
# 187
# $-10-$$
# $-12-$$
# $-14-$$
# 187
# 187
# $-10-$$
# $-12-$$
# $-14-$$
# 188
# 187
# $-10-$$
# $-12-$$
# $-14-$$
# 189
# 187
# $-10-$$
# $-12-$$
# $-14-$$
# 190
# 187
# $-10-$$
# $-12-$$
# $-14-$$
# 191
# 187
# $-10-$$
# 192
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Natural monuments of South Korea#51-100|Ginkgo Tree of the Confucian Shrine of Seoul]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Natural monuments of South Korea#51-100|Ginkgo Tree of the Confucian Shrine of Seoul]]', 'Species': "[[Ginkgo]] (''[[Ginkgo biloba]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Natural monuments of South Korea#51-100|Ginkgo Tree of the Confucian Shrine of Seoul]]', 'Species': "[[Ginkgo]] (''[[Ginkgo biloba]]'')", 'Location': '[[Sungkyunkwan University]], [[Seoul]], [[South Korea]]', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Natural monuments of South Korea#51-100|Ginkgo Tree of the Confucian Shrine of Seoul]]', 'Species': "[[Ginkgo]] (''[[Ginkgo biloba]]'')", 'Location': '[[Sungkyunkwan University]], [[Seoul]], [[South Korea]]', 'Age': '500', 'Notes': ''}
# $-13-$$
# {'Name': '[[Natural monuments of South Korea#51-100|Ginkgo Tree of the Confucian Shrine of Seoul]]', 'Species': "[[Ginkgo]] (''[[Ginkgo biloba]]'')", 'Location': '[[Sungkyunkwan University]], [[Seoul]], [[South Korea]]', 'Age': '500', 'Notes': 'A pair of ginkgo trees'}
# $-14-$$
# 192
# 193
# $-10-$$
# $-12-$$
# $-14-$$
# 193
# 193
# $-10-$$
# $-12-$$
# $-14-$$
# 194
# 193
# $-10-$$
# $-12-$$
# $-14-$$
# 195
# 193
# $-10-$$
# $-12-$$
# $-14-$$
# 196
# 193
# $-10-$$
# $-12-$$
# $-14-$$
# 197
# 193
# $-10-$$
# 198
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Big Banyan Tree]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Big Banyan Tree]]', 'Species': "Banyan (''Ficus benghalensis'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Big Banyan Tree]]', 'Species': "Banyan (''Ficus benghalensis'')", 'Location': '[[Ramohalli]], [[Bangalore]], India <br/><small> {{coord|12|54|34|N|77|23|44|E|name=Dodda Aladha Mara}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Big Banyan Tree]]', 'Species': "Banyan (''Ficus benghalensis'')", 'Location': '[[Ramohalli]], [[Bangalore]], India <br/><small> {{coord|12|54|34|N|77|23|44|E|name=Dodda Aladha Mara}}</small>', 'Age': '400', 'Notes': ''}
# $-13-$$
# {'Name': '[[Big Banyan Tree]]', 'Species': "Banyan (''Ficus benghalensis'')", 'Location': '[[Ramohalli]], [[Bangalore]], India <br/><small> {{coord|12|54|34|N|77|23|44|E|name=Dodda Aladha Mara}}</small>', 'Age': '400', 'Notes': '[[File:Dod alada mara.jpg|100px|left]]'}
# $-14-$$
# 198
# 199
# $-10-$$
# $-12-$$
# $-14-$$
# 199
# 199
# $-10-$$
# $-12-$$
# $-14-$$
# 200
# 199
# $-10-$$
# $-12-$$
# $-14-$$
# 201
# 199
# $-10-$$
# $-12-$$
# $-14-$$
# 202
# 199
# $-10-$$
# $-12-$$
# $-14-$$
# 203
# 199
# $-10-$$
# 204
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Tree of Life, Bahrain|Tree of Life]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Tree of Life, Bahrain|Tree of Life]]', 'Species': "[[Prosopis cineraria|Mesquite]] (''[[Prosopis cineraria]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Tree of Life, Bahrain|Tree of Life]]', 'Species': "[[Prosopis cineraria|Mesquite]] (''[[Prosopis cineraria]]'')", 'Location': '[[Bahrain]] <br/><small> {{coord|25.994073|N|50.583235|E|name=Tree of Life}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Tree of Life, Bahrain|Tree of Life]]', 'Species': "[[Prosopis cineraria|Mesquite]] (''[[Prosopis cineraria]]'')", 'Location': '[[Bahrain]] <br/><small> {{coord|25.994073|N|50.583235|E|name=Tree of Life}}</small>', 'Age': '400 ', 'Notes': ''}
# $-13-$$
# {'Name': '[[Tree of Life, Bahrain|Tree of Life]]', 'Species': "[[Prosopis cineraria|Mesquite]] (''[[Prosopis cineraria]]'')", 'Location': '[[Bahrain]] <br/><small> {{coord|25.994073|N|50.583235|E|name=Tree of Life}}</small>', 'Age': '400 ', 'Notes': ' [[File:Tree of Life Bahrain.jpg|100px|left]]'}
# $-14-$$
# 204
# 205
# $-10-$$
# $-12-$$
# $-14-$$
# 205
# 205
# $-10-$$
# $-12-$$
# $-14-$$
# 206
# 205
# $-10-$$
# $-12-$$
# $-14-$$
# 207
# 205
# $-10-$$
# $-12-$$
# $-14-$$
# 208
# 205
# $-10-$$
# $-12-$$
# $-14-$$
# 209
# 205
# $-10-$$
# 210
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Chankiri Tree]] (Killing tree)', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Chankiri Tree]] (Killing tree)', 'Species': '[[Samanea saman|Samanea saman/Albizzia saman]]<ref>{{cite web |url=http://www.cafaca.com/index.php?option=com_cafaca&view=treetype&id=12&Itemid=110&lang=en}}</ref>', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Chankiri Tree]] (Killing tree)', 'Species': '[[Samanea saman|Samanea saman/Albizzia saman]]<ref>{{cite web |url=http://www.cafaca.com/index.php?option=com_cafaca&view=treetype&id=12&Itemid=110&lang=en}}</ref>', 'Location': '[[Cambodia]]n [[Killing Fields]]', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Chankiri Tree]] (Killing tree)', 'Species': '[[Samanea saman|Samanea saman/Albizzia saman]]<ref>{{cite web |url=http://www.cafaca.com/index.php?option=com_cafaca&view=treetype&id=12&Itemid=110&lang=en}}</ref>', 'Location': '[[Cambodia]]n [[Killing Fields]]', 'Age': ' -', 'Notes': ''}
# $-13-$$
# {'Name': '[[Chankiri Tree]] (Killing tree)', 'Species': '[[Samanea saman|Samanea saman/Albizzia saman]]<ref>{{cite web |url=http://www.cafaca.com/index.php?option=com_cafaca&view=treetype&id=12&Itemid=110&lang=en}}</ref>', 'Location': '[[Cambodia]]n [[Killing Fields]]', 'Age': ' -', 'Notes': ' [[File:ChoeungEk-Darter-7.jpg|100px|left]] A tree in the [[Killing Fields]] against which children and infants were slung to kill them.'}
# $-14-$$
# 210
# 211
# $-10-$$
# $-12-$$
# $-14-$$
# 211
# 211
# $-10-$$
# $-12-$$
# $-14-$$
# 212
# 211
# $-10-$$
# $-12-$$
# $-14-$$
# 213
# 211
# $-10-$$
# $-12-$$
# $-14-$$
# 214
# 211
# $-10-$$
# $-12-$$
# $-14-$$
# 215
# 211
# $-10-$$
# 216
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Rahmat tree]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Rahmat tree]]', 'Species': "[[Platanus|Plane Tree]] (''[[Platanus]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Rahmat tree]]', 'Species': "[[Platanus|Plane Tree]] (''[[Platanus]]'')", 'Location': '[[Kermanshah]], [[Kermanshah Province|Kermanshahan Province]], [[Iran]]', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Rahmat tree]]', 'Species': "[[Platanus|Plane Tree]] (''[[Platanus]]'')", 'Location': '[[Kermanshah]], [[Kermanshah Province|Kermanshahan Province]], [[Iran]]', 'Age': '700', 'Notes': ''}
# $-13-$$
# {'Name': '[[Rahmat tree]]', 'Species': "[[Platanus|Plane Tree]] (''[[Platanus]]'')", 'Location': '[[Kermanshah]], [[Kermanshah Province|Kermanshahan Province]], [[Iran]]', 'Age': '700', 'Notes': 'Located in the historical area of [[Taq Bostan]].'}
# $-14-$$
# 216
# 217
# $-10-$$
# $-12-$$
# $-14-$$
# 217
# 217
# $-10-$$
# $-12-$$
# $-14-$$
# 218
# 217
# $-10-$$
# $-12-$$
# $-14-$$
# 219
# 217
# $-10-$$
# $-12-$$
# $-14-$$
# 220
# 217
# $-10-$$
# $-12-$$
# $-14-$$
# 221
# 217
# $-10-$$
# 222
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': 'The Ying Ke Pine', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': 'The Ying Ke Pine', 'Species': "[[Huangshan pine]] (''[[Pinus hwangshanensis]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': 'The Ying Ke Pine', 'Species': "[[Huangshan pine]] (''[[Pinus hwangshanensis]]'')", 'Location': '[[Huangshan]], [[China]]', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': 'The Ying Ke Pine', 'Species': "[[Huangshan pine]] (''[[Pinus hwangshanensis]]'')", 'Location': '[[Huangshan]], [[China]]', 'Age': ' Thought to be 1,500', 'Notes': ''}
# $-13-$$
# {'Name': 'The Ying Ke Pine', 'Species': "[[Huangshan pine]] (''[[Pinus hwangshanensis]]'')", 'Location': '[[Huangshan]], [[China]]', 'Age': ' Thought to be 1,500', 'Notes': ' [[File:Huangshan pic 2.jpg|100px|left]] Ying Ke, meaning "Welcoming-Guests" pine on Huangshan.'}
# $-14-$$
# 222
# 223
# $-10-$$
# $-12-$$
# $-14-$$
# 223
# 223
# $-10-$$
# $-12-$$
# $-14-$$
# 224
# 223
# $-10-$$
# $-12-$$
# $-14-$$
# 225
# 223
# $-10-$$
# $-12-$$
# $-14-$$
# 226
# 223
# $-10-$$
# $-12-$$
# $-14-$$
# 227
# 223
# $-10-$$
# 228
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': ' ', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': ' ', 'Species': "[[Tembusu]] (''[[Fagraea fragrans]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': ' ', 'Species': "[[Tembusu]] (''[[Fagraea fragrans]]'')", 'Location': '[[Singapore Botanical Gardens]], [[Singapore]]', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': ' ', 'Species': "[[Tembusu]] (''[[Fagraea fragrans]]'')", 'Location': '[[Singapore Botanical Gardens]], [[Singapore]]', 'Age': '100', 'Notes': ''}
# $-13-$$
# {'Name': ' ', 'Species': "[[Tembusu]] (''[[Fagraea fragrans]]'')", 'Location': '[[Singapore Botanical Gardens]], [[Singapore]]', 'Age': '100', 'Notes': 'The tree is featured on the reverse of a [[Singapore Portrait Series currency notes#Specifications|$5]] Singapore note.'}
# $-14-$$
# 228
# 229
# $-10-$$
# $-12-$$
# $-14-$$
# 229
# 229
# $-10-$$
# $-12-$$
# $-14-$$
# 230
# 229
# $-10-$$
# $-12-$$
# $-14-$$
# 231
# 229
# $-10-$$
# $-12-$$
# $-14-$$
# 232
# 229
# $-10-$$
# $-12-$$
# $-14-$$
# 233
# 229
# $-10-$$
# 234
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Judean date palm#Germination of 2000-year-old seed|Methuselah]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Judean date palm#Germination of 2000-year-old seed|Methuselah]]', 'Species': "[[Judean date palm]] (''[[Phoenix dactylifera]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Judean date palm#Germination of 2000-year-old seed|Methuselah]]', 'Species': "[[Judean date palm]] (''[[Phoenix dactylifera]]'')", 'Location': '[[Israel]]', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Judean date palm#Germination of 2000-year-old seed|Methuselah]]', 'Species': "[[Judean date palm]] (''[[Phoenix dactylifera]]'')", 'Location': '[[Israel]]', 'Age': ' About 12', 'Notes': ''}
# $-13-$$
# {'Name': '[[Judean date palm#Germination of 2000-year-old seed|Methuselah]]', 'Species': "[[Judean date palm]] (''[[Phoenix dactylifera]]'')", 'Location': '[[Israel]]', 'Age': ' About 12', 'Notes': ' [[File:JudeanDatePalmMethuselah.JPG|100px|left]] The formerly extinct tree was sprouted from a 2,000-year-old seed.'}
# $-14-$$
# 234
# 235
# $-10-$$
# $-12-$$
# $-14-$$
# 235
# 235
# $-10-$$
# $-12-$$
# $-14-$$
# 236
# 235
# $-10-$$
# $-12-$$
# $-14-$$
# 237
# 235
# $-10-$$
# $-12-$$
# $-14-$$
# 238
# 235
# $-10-$$
# $-12-$$
# $-14-$$
# 239
# 235
# $-10-$$
# 240
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Hathi ka pedh]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Hathi ka pedh]]', 'Species': "[[Baobab]] (''Adansonia digitata'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Hathi ka pedh]]', 'Species': "[[Baobab]] (''Adansonia digitata'')", 'Location': '[[Purana Qila]], [[Hyderabad]], [[Telangana]], [[India]] ', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Hathi ka pedh]]', 'Species': "[[Baobab]] (''Adansonia digitata'')", 'Location': '[[Purana Qila]], [[Hyderabad]], [[Telangana]], [[India]] ', 'Age': ' 320', 'Notes': ''}
# $-13-$$
# {'Name': '[[Hathi ka pedh]]', 'Species': "[[Baobab]] (''Adansonia digitata'')", 'Location': '[[Purana Qila]], [[Hyderabad]], [[Telangana]], [[India]] ', 'Age': ' 320', 'Notes': ' A gift from African traders, this huge tree is an iconic landmark of the erstwhile [[Qutb Shahi]] era. '}
# $-14-$$
# 240
# 241
# $-10-$$
# $-12-$$
# $-14-$$
# 241
# 241
# $-10-$$
# $-12-$$
# $-14-$$
# 242
# 241
# $-10-$$
# $-12-$$
# $-14-$$
# 243
# 241
# $-10-$$
# $-12-$$
# $-14-$$
# 244
# 241
# $-10-$$
# $-12-$$
# $-14-$$
# 245
# 241
# $-10-$$
# 246
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Takeshi Kaneshiro Tree]]<br>(金城武樹)', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Takeshi Kaneshiro Tree]]<br>(金城武樹)', 'Species': '[[Bishop wood]] ([[Bischofia javanica]])', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Takeshi Kaneshiro Tree]]<br>(金城武樹)', 'Species': '[[Bishop wood]] ([[Bischofia javanica]])', 'Location': '[[Chishang, Taitung|Chishang]], [[Taitung County|Taitung]], [[Taiwan]]', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[
}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': ' The [[Bodhi tree]]', 'Species': "Sacred fig (''Ficus religiosa'')", 'Location': '[[Bodh Gaya]], India<br/><small>{{coord|24|41|45.29|N|84|59|29.29|E|name=Bodhi Tree}}</small>', 'Age': ' -', 'Notes': ''}
# $-13-$$
# {'Name': ' The [[Bodhi tree]]', 'Species': "Sacred fig (''Ficus religiosa'')", 'Location': '[[Bodh Gaya]], India<br/><small>{{coord|24|41|45.29|N|84|59|29.29|E|name=Bodhi Tree}}</small>', 'Age': ' -', 'Notes': 'The tree under which [[Gautama Buddha|Buddha]] obtained enlightenment. The current tree at the site is a replacement.'}
# $-14-$$
# 268
# 269
# $-10-$$
# $-12-$$
# $-14-$$
# 269
# 269
# $-10-$$
# $-12-$$
# $-14-$$
# 270
# 269
# $-10-$$
# $-12-$$
# $-14-$$
# 271
# 269
# $-10-$$
# $-12-$$
# $-14-$$
# 272
# 269
# $-10-$$
# $-12-$$
# $-14-$$
# 273
# 269
# $-10-$$
# 274
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Guilty Chinese Scholartree]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Guilty Chinese Scholartree]]', 'Species': "[[Pagoda Tree]] (''[[Styphnolobium japonicum]]'')", 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Guilty Chinese Scholartree]]', 'Species': "[[Pagoda Tree]] (''[[Styphnolobium japonicum]]'')", 'Location': '[[Jingshan park]]<br/><small>{{coord|39|55|23.22|N|116|23|33.64|E|name=Guilty Chinese Scholartree}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Guilty Chinese Scholartree]]', 'Species': "[[Pagoda Tree]] (''[[Styphnolobium japonicum]]'')", 'Location': '[[Jingshan park]]<br/><small>{{coord|39|55|23.22|N|116|23|33.64|E|name=Guilty Chinese Scholartree}}</small>', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Guilty Chinese Scholartree]]', 'Species': "[[Pagoda Tree]] (''[[Styphnolobium japonicum]]'')", 'Location': '[[Jingshan park]]<br/><small>{{coord|39|55|23.22|N|116|23|33.64|E|name=Guilty Chinese Scholartree}}</small>', 'Age': '', 'Notes': '[[File:Guilty Chinese Scholar Tree.jpg|100px|left]] The tree on which the [[Chongzhen Emperor]] hanged himself shortly after escaping the [[Forbidden City]] in [[Beijing]], [[China]]. The original tree died and was replaced by a replica.'}
# $-14-$$
# 274
# 275
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Guilty Chinese Scholartree]]', 'Species': "[[Pagoda Tree]] (''[[Styphnolobium japonicum]]'')", 'Location': '[[Jingshan park]]<br/><small>{{coord|39|55|23.22|N|116|23|33.64|E|name=Guilty Chinese Scholartree}}</small>', 'Age': '', 'Notes': '[[File:Guilty Chinese Scholar Tree.jpg|100px|left]] The tree on which the [[Chongzhen Emperor]] hanged himself shortly after escaping the [[Forbidden City]] in [[Beijing]], [[China]]. The original tree died and was replaced by a replica.'}
# $-14-$$
# 275
# 275
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Guilty Chinese Scholartree]]', 'Species': "[[Pagoda Tree]] (''[[Styphnolobium japonicum]]'')", 'Location': '[[Jingshan park]]<br/><small>{{coord|39|55|23.22|N|116|23|33.64|E|name=Guilty Chinese Scholartree}}</small>', 'Age': '', 'Notes': '[[File:Guilty Chinese Scholar Tree.jpg|100px|left]] The tree on which the [[Chongzhen Emperor]] hanged himself shortly after escaping the [[Forbidden City]] in [[Beijing]], [[China]]. The original tree died and was replaced by a replica.'}
# $-14-$$
# 276
# 275
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Guilty Chinese Scholartree]]', 'Species': "[[Pagoda Tree]] (''[[Styphnolobium japonicum]]'')", 'Location': '[[Jingshan park]]<br/><small>{{coord|39|55|23.22|N|116|23|33.64|E|name=Guilty Chinese Scholartree}}</small>', 'Age': '', 'Notes': '[[File:Guilty Chinese Scholar Tree.jpg|100px|left]] The tree on which the [[Chongzhen Emperor]] hanged himself shortly after escaping the [[Forbidden City]] in [[Beijing]], [[China]]. The original tree died and was replaced by a replica.'}
# $-14-$$
# 277
# 275
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Guilty Chinese Scholartree]]', 'Species': "[[Pagoda Tree]] (''[[Styphnolobium japonicum]]'')", 'Location': '[[Jingshan park]]<br/><small>{{coord|39|55|23.22|N|116|23|33.64|E|name=Guilty Chinese Scholartree}}</small>', 'Age': '', 'Notes': '[[File:Guilty Chinese Scholar Tree.jpg|100px|left]] The tree on which the [[Chongzhen Emperor]] hanged himself shortly after escaping the [[Forbidden City]] in [[Beijing]], [[China]]. The original tree died and was replaced by a replica.'}
# $-14-$$
# 278
# 275
# $-10-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Guilty Chinese Scholartree]]', 'Species': "[[Pagoda Tree]] (''[[Styphnolobium japonicum]]'')", 'Location': '[[Jingshan park]]<br/><small>{{coord|39|55|23.22|N|116|23|33.64|E|name=Guilty Chinese Scholartree}}</small>', 'Age': '', 'Notes': '[[File:Guilty Chinese Scholar Tree.jpg|100px|left]] The tree on which the [[Chongzhen Emperor]] hanged himself shortly after escaping the [[Forbidden City]] in [[Beijing]], [[China]]. The original tree died and was replaced by a replica.'}
# $-14-$$
# 279
# 275
# $-10-$$
# 280
# $-11-$$
# $-12-$$
# $-13-$$
# {'Name': '[[Changi Tree]]', 'Species': '', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# {'Name': '[[Changi Tree]]', 'Species': 'Either', 'Location': '', 'Age': '', 'Notes': ''}
# $-13-$$
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-157-9bd0befe1d00> in <module>
#     101                     if debug or special: print("$-13-$$")
#     102                     #print(index)
# --> 103                     this_item[cols[i]] = re.search(r'\|(.*)', lines[this_item_start + i]).group(1)
#     104                     print(this_item)
#     105
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
section_dict
# Out:
# {'Real forests and individual trees': {'Africa': {'Living': [],
#    'Historical': []},
#   'Asia': {'Living': [], 'Historical': []},
#   'Europe': {'Living': [], 'Historical': [], 'Petrified': []},
#   'North America': {'Living': [],
#    'Historical': [],
#    'Petrified': [],
#    'Other': []},
#   'Central America': {'Living': []},
#   'South America': {'Living': [], 'Historical': []},
#   'Oceania': {'Living': [], 'Historical': []}},
#  'Mythological and religious': []}

# %%
cols = []
this_item = None
this_item

# %%
# create nested section_dict dictionary from section list based on toclevel
# adding 'Z' section by hand consider refactor
section_dict = {}
is_new_parent = True
parent = ''
for i in range(len(sec_list) - 1):
    if sec_list[i]['toclevel'] == 1 and sec_list[i + 1]['toclevel'] == 1:
        section_dict[sec_list[i]['anchor']] = []
    elif sec_list[i]['toclevel'] == 1 and sec_list[i + 1]['toclevel'] == 2:
        section_dict[sec_list[i]['anchor']] = {}
        parent = sec_list[i]['anchor']
    elif sec_list[i]['toclevel'] == 2:
        section_dict[parent][sec_list[i]['anchor']] = []
section_dict['Z'] = []
#section_dict

# %%
# make list of top level sections
secs = [sec for sec, val in section_dict.items()]

# %%
# make section dict if no nested sections
section_dict = {sec['anchor']:[] for sec in sec_list}

# %%
# get links
PARAMS = {
    "action": "parse",
    "pageid": page_id,
    "format": "json",
    "prop": "links"
}

linkR = S.get(url=URL, params=PARAMS)
linkDATA = linkR.json()

pprint(linkDATA["parse"]["links"])
# Out:
# [{'*': 'Category:Articles with unsourced statements from February 2013',
#   'exists': '',
#   'ns': 14},
#  {'*': 'Category:Articles with unsourced statements from April 2010',
#   'exists': '',
#   'ns': 14},
#  {'*': 'Category:Articles with unsourced statements from January 2013',
#   'exists': '',
#   'ns': 14},
#  {'*': 'Category:Articles with unsourced statements from May 2019',
#   'exists': '',
#   'ns': 14},
#  {'*': 'Category:Articles with unsourced statements from April 2012',
#   'exists': '',
#   'ns': 14},
#  {'*': 'Portal:Ecology', 'exists': '', 'ns': 100},
#  {'*': "2011 Halloween nor'easter", 'exists': '', 'ns': 0},
#  {'*': '50 State Quarters', 'exists': '', 'ns': 0},
#  {'*': 'A483 road', 'exists': '', 'ns': 0},
#  {'*': 'Abarkuh', 'exists': '', 'ns': 0},
#  {'*': 'Abraham Lincoln', 'exists': '', 'ns': 0},
#  {'*': 'Acacia', 'exists': '', 'ns': 0},
#  {'*': 'Acer saccharum', 'exists': '', 'ns': 0},
#  {'*': 'Ada, Oklahoma', 'exists': '', 'ns': 0},
#  {'*': 'Adansonia digitata', 'exists': '', 'ns': 0},
#  {'*': 'Aesculus hippocastanum', 'exists': '', 'ns': 0},
#  {'*': 'Alabama', 'exists': '', 'ns': 0},
#  {'*': 'Alexander the Great', 'exists': '', 'ns': 0},
#  {'*': 'Alexander von Humboldt', 'exists': '', 'ns': 0},
#  {'*': 'Alishan, Chiayi', 'exists': '', 'ns': 0},
#  {'*': 'Allen Russell (tree)', 'exists': '', 'ns': 0},
#  {'*': 'Allouville-Bellefosse', 'exists': '', 'ns': 0},
#  {'*': 'American Elm', 'exists': '', 'ns': 0},
#  {'*': 'American Revolutionary War', 'exists': '', 'ns': 0},
#  {'*': 'American elm', 'exists': '', 'ns': 0},
#  {'*': 'American sycamore', 'exists': '', 'ns': 0},
#  {'*': 'Amherst, Massachusetts', 'exists': '', 'ns': 0},
#  {'*': 'Amsterdam', 'exists': '', 'ns': 0},
#  {'*': 'Andhra Pradesh', 'exists': '', 'ns': 0},
#  {'*': 'Angel Oak', 'exists': '', 'ns': 0},
#  {'*': 'Angiosperm', 'exists': '', 'ns': 0},
#  {'*': 'Annagh, County Cavan', 'exists': '', 'ns': 0},
#  {'*': 'Anne Frank', 'exists': '', 'ns': 0},
#  {'*': 'Anne Frank Tree', 'exists': '', 'ns': 0},
#  {'*': 'Anthem Christmas tree', 'exists': '', 'ns': 0},
#  {'*': 'Anuradhapura', 'exists': '', 'ns': 0},
#  {'*': 'Arboretum Freiburg-Günterstal', 'exists': '', 'ns': 0},
#  {'*': 'Arbre du Ténéré', 'exists': '', 'ns': 0},
#  {'*': 'Big Tree (Washington)', 'exists': '', 'ns': 0},
#  {'*': 'Big Tree in Chirinda Forest', 'exists': '', 'ns': 0},
#  {'*': 'Bischofia javanica', 'exists': '', 'ns': 0},
#  {'*': 'Bishop wood', 'exists': '', 'ns': 0},
#  {'*': 'Black Hawk (chief)', 'exists': '', 'ns': 0},
#  {'*': 'Black Hawk Tree', 'exists': '', 'ns': 0},
#  {'*': 'Black walnut', 'exists': '', 'ns': 0},
#  {'*': 'Black willow', 'exists': '', 'ns': 0},
#  {'*': 'Bloomington, Illinois', 'exists': '', 'ns': 0},
#  {'*': 'Blue spruce', 'exists': '', 'ns': 0},
#  {'*': 'Bodh Gaya', 'exists': '', 'ns': 0},
#  {'*': 'Bodhi tree', 'exists': '', 'ns': 0},
#  {'*': 'Bonsai', 'exists': '', 'ns': 0},
#  {'*': 'Boscobel, Shropshire', 'exists': '', 'ns': 0},
#  {'*': 'Bosnia and Herzegovina', 'exists': '', 'ns': 0},
#  {'*': 'Bosnian Pine', 'exists': '', 'ns': 0},
#  {'*': 'Boston, Massachusetts', 'exists': '', 'ns': 0},
#  {'*': 'Boston Christmas Tree', 'exists': '', 'ns': 0},
#  {'*': 'Boston Common', 'exists': '', 'ns': 0},
#  {'*': 'Boston Common (park)', 'exists': '', 'ns': 0},
#  {'*': 'Botanist', 'exists': '', 'ns': 0},
#  {'*': 'Botswana', 'exists': '', 'ns': 0},
#  {'*': 'Boyington Oak', 'exists': '', 'ns': 0},
#  {'*': 'Brian Boru', 'exists': '', 'ns': 0},
#  {'*': "Brig o' Turk", 'exists': '', 'ns': 0},
#  {'*': 'Brimmon Oak', 'exists': '', 'ns': 0},
#  {'*': 'British Columbia', 'exists': '', 'ns': 0},
#  {'*': 'Brooklyn', 'exists': '', 'ns': 0},
#  {'*': 'Bulacan', 'exists': '', 'ns': 0},
#  {'*': 'Bulgaria', 'exists': '', 'ns': 0},
#  {'*': 'Burmis tree', 'exists': '', 'ns': 0},
#  {'*': 'Buttington', 'exists': '', 'ns': 0},
#  {'*': 'Buttington Oak', 'exists': '', 'ns': 0},
#  {'*': 'Buttonball Tree', 'exists': '', 'ns': 0},
#  {'*': 'Buttonwood Agreement', 'exists': '', 'ns': 0},
#  {'*': 'Cache National Forest', 'exists': '', 'ns': 0},
#  {'*': 'Caesarsboom', 'exists': '', 'ns': 0},
#  {'*': 'Calaveras Big Trees State Park', 'exists': '', 'ns': 0},
#  {'*': 'California', 'exists': '', 'ns': 0},
#  {'*': 'California live oak', 'exists': '', 'ns': 0},
#  {'*': 'Callery Pear', 'exists': '', 'ns': 0},
#  {'*': 'Callixylon tree', 'exists': '', 'ns': 0},
#  {'*': 'Cambodia', 'exists': '', 'ns': 0},
#  {'*': 'Candler Oak Tree', 'exists': '', 'ns': 0},
#  {'*': 'Canlaon City', 'exists': '', 'ns': 0},
#  {'*': 'Capitol Christmas Tree', 'exists': '', 'ns': 0},
#  {'*': 'Carmarthen, Wales', 'exists': '', 'ns': 0},
#  {'*': 'Castanea sativa', 'exists': '', 'ns': 0},
#  {'*': 'Hoedspruit', 'exists': '', 'ns': 0},
#  {'*': 'Hollow Log (Balch Park)', 'exists': '', 'ns': 0},
#  {'*': 'Hollywood, Florida', 'exists': '', 'ns': 0},
#  {'*': 'Hollywood Seminole Indian Reservation', 'exists': '', 'ns': 0},
#  {'*': 'Holy Land', 'exists': '', 'ns': 0},
#  {'*': 'Honeymoon Bay, British Columbia', 'exists': '', 'ns': 0},
#  {'*': 'Hooker Oak', 'exists': '', 'ns': 0},
#  {'*': 'Hopea sangal', 'exists': '', 'ns': 0},
#  {'*': 'Horse-chestnut', 'exists': '', 'ns': 0},
#  {'*': 'Houston, Renfrewshire', 'exists': '', 'ns': 0},
#  {'*': 'Huangshan', 'exists': '', 'ns': 0},
#  {'*': 'Huangshan pine', 'exists': '', 'ns': 0},
#  {'*': 'Hugh Mercer', 'exists': '', 'ns': 0},
#  {'*': 'Humboldt County, California', 'exists': '', 'ns': 0},
#  {'*': 'Humphrey Bogart', 'exists': '', 'ns': 0},
#  {'*': 'Hurricane Sandy', 'exists': '', 'ns': 0},
#  {'*': 'Hyderabad', 'exists': '', 'ns': 0},
#  {'*': 'Hyperion (tree)', 'exists': '', 'ns': 0},
#  {'*': 'I-17 Mystery Christmas Tree', 'exists': '', 'ns': 0},
#  {'*': 'Icod de los Vinos', 'exists': '', 'ns': 0},
#  {'*': 'Iluvatar (tree)', 'exists': '', 'ns': 0},
#  {'*': 'Immigrants', 'exists': '', 'ns': 0},
#  {'*': 'India', 'exists': '', 'ns': 0},
#  {'*': 'International Society for Krishna Consciousness',
#   'exists': '',
#   'ns': 0},
#  {'*': 'International World War Peace Tree', 'exists': '', 'ns': 0},
#  {'*': 'Interstate 17', 'exists': '', 'ns': 0},
#  {'*': 'Iran', 'exists': '', 'ns': 0},
#  {'*': 'Ireland', 'exists': '', 'ns': 0},
#  {'*': 'Irish Yew', 'exists': '', 'ns': 0},
#  {'*': 'Ishikawa Prefecture', 'exists': '', 'ns': 0},
#  {'*': 'Israel', 'exists': '', 'ns': 0},
#  {'*': 'Italy', 'exists': '', 'ns': 0},
#  {'*': 'Jacksonville, Florida', 'exists': '', 'ns': 0},
#  {'*': 'Jagodina', 'exists': '', 'ns': 0},
#  {'*': 'Japan', 'exists': '', 'ns': 0},
#  {'*': 'Jardine Juniper', 'exists': '', 'ns': 0},
#  {'*': 'Jasenovac concentration camp', 'exists': '', 'ns': 0},
#  {'*': 'Jaya Sri Maha Bodhi', 'exists': '', 'ns': 0},
#  {'*': 'Jedediah Smith Redwoods State Park', 'exists': '', 'ns': 0},
#  {'*': 'Jingshan park', 'exists': '', 'ns': 0},
#  {'*': 'John Endecott', 'exists': '', 'ns': 0},
#  {'*': 'Johns Island, South Carolina', 'exists': '', 'ns': 0},
#  {'*': 'Joseph of Arimathea', 'exists': '', 'ns': 0},
#  {'*': 'Joshua tree', 'exists': '', 'ns': 0},
#  {'*': 'Judean date palm', 'exists': '', 'ns': 0},
#  {'*': 'Juglans nigra', 'exists': '', 'ns': 0},
#  {'*': 'Pinus heldreichii', 'exists': '', 'ns': 0},
#  {'*': 'Pinus hwangshanensis', 'exists': '', 'ns': 0},
#  {'*': 'Pinus longaeva', 'exists': '', 'ns': 0},
#  {'*': 'Pinus ponderosa', 'exists': '', 'ns': 0},
#  {'*': 'Pinus sylvestris', 'exists': '', 'ns': 0},
#  {'*': 'Pinus taeda', 'exists': '', 'ns': 0},
#  {'*': 'Pioneer Cabin Tree', 'exists': '', 'ns': 0},
#  {'*': 'Pirin', 'exists': '', 'ns': 0},
#  {'*': 'Plane tree', 'exists': '', 'ns': 0},
#  {'*': 'Platanus', 'exists': '', 'ns': 0},
#  {'*': 'Platanus occidentalis', 'exists': '', 'ns': 0},
#  {'*': 'Platanus orientalis', 'exists': '', 'ns': 0},
#  {'*': 'Poland', 'exists': '', 'ns': 0},
#  {'*': 'Poltava', 'exists': '', 'ns': 0},
#  {'*': 'Pond cypress', 'exists': '', 'ns': 0},
#  {'*': 'Ponderosa Pine', 'exists': '', 'ns': 0},
#  {'*': 'Ponderosa pine', 'exists': '', 'ns': 0},
#  {'*': 'Populus', 'exists': '', 'ns': 0},
#  {'*': 'Populus deltoides', 'exists': '', 'ns': 0},
#  {'*': 'Populus sect. Aegiros', 'exists': '', 'ns': 0},
#  {'*': 'Populus tremuloides', 'exists': '', 'ns': 0},
#  {'*': 'Port Renfrew', 'exists': '', 'ns': 0},
#  {'*': 'Post Oak', 'exists': '', 'ns': 0},
#  {'*': 'Post Office Tree', 'exists': '', 'ns': 0},
#  {'*': "Potter's field", 'exists': '', 'ns': 0},
#  {'*': 'Powys', 'exists': '', 'ns': 0},
#  {'*': 'Prairie Creek Redwoods State Park', 'exists': '', 'ns': 0},
#  {'*': 'Prairie du Chien, Wisconsin', 'exists': '', 'ns': 0},
#  {'*': 'Presbyterian Church in Basking Ridge', 'exists': '', 'ns': 0},
#  {'*': "President's Park", 'exists': '', 'ns': 0},
#  {'*': 'Pretoria', 'exists': '', 'ns': 0},
#  {'*': "Prince Miloš's Residence", 'exists': '', 'ns': 0},
#  {'*': 'Princeton, New Jersey', 'exists': '', 'ns': 0},
#  {'*': 'Princeton Battlefield State Park', 'exists': '', 'ns': 0},
#  {'*': 'Prometheus (tree)', 'exists': '', 'ns': 0},
#  {'*': 'Prosopis cineraria', 'exists': '', 'ns': 0},
#  {'*': 'Pub', 'exists': '', 'ns': 0},
#  {'*': 'Purana Qila', 'exists': '', 'ns': 0},
#  {'*': 'Pyrus calleryana', 'exists': '', 'ns': 0},
#  {'*': 'Pyrus communis', 'exists': '', 'ns': 0},
#  {'*': 'Quaking Aspen', 'exists': '', 'ns': 0},
#  {'*': 'Quebec', 'exists': '', 'ns': 0},
#  {'*': 'Queen Charlotte Islands', 'exists': '', 'ns': 0},
#  {'*': 'Queen Elizabeth Oak', 'exists': '', 'ns': 0},
#  {'*': 'Queens, New York', 'exists': '', 'ns': 0},
#  {'*': 'Queens Giant', 'exists': '', 'ns': 0},
#  {'*': 'Quercus agrifolia', 'exists': '', 'ns': 0},
#  {'*': 'Treaty of Greenville', 'exists': '', 'ns': 0},
#  {'*': 'Treaty of Medicine Creek', 'exists': '', 'ns': 0},
#  {'*': 'Tree', 'exists': '', 'ns': 0},
#  {'*': 'Tree That Owns Itself', 'exists': '', 'ns': 0},
#  {'*': 'Tree That Owns Itself (Alabama)', 'exists': '', 'ns': 0},
#  {'*': 'Tree of Hippocrates', 'exists': '', 'ns': 0},
#  {'*': 'Tree of Life, Bahrain', 'exists': '', 'ns': 0},
#  {'*': 'Tsar Dušan', 'exists': '', 'ns': 0},
#  {'*': 'Tshipise', 'exists': '', 'ns': 0},
#  {'*': 'Tsurugaoka Hachiman-gū', 'exists': '', 'ns': 0},
#  {'*': 'Tulare County, California', 'exists': '', 'ns': 0},
#  {'*': 'Tulip-tree', 'exists': '', 'ns': 0},
#  {'*': 'Tulip poplar', 'exists': '', 'ns': 0},
#  {'*': 'Tulsa, Oklahoma', 'exists': '', 'ns': 0},
#  {'*': 'Tuolumne County, California', 'exists': '', 'ns': 0},
#  {'*': 'Turkey', 'exists': '', 'ns': 0},
#  {'*': 'Turkish Pine', 'exists': '', 'ns': 0},
#  {'*': 'U2', 'exists': '', 'ns': 0},
#  {'*': 'US', 'exists': '', 'ns': 0},
#  {'*': 'Ukraine', 'exists': '', 'ns': 0},
#  {'*': 'Ulmus americana', 'exists': '', 'ns': 0},
#  {'*': 'Ulmus minor', 'exists': '', 'ns': 0},
#  {'*': 'United States Capitol', 'exists': '', 'ns': 0},
#  {'*': 'United States National Arboretum', 'exists': '', 'ns': 0},
#  {'*': 'University of Massachusetts Amherst', 'exists': '', 'ns': 0},
#  {'*': 'University of North Carolina at Chapel Hill', 'exists': '', 'ns': 0},
#  {'*': 'University of Southern Mississippi', 'exists': '', 'ns': 0},
#  {'*': 'Urho Kekkonen National Park', 'exists': '', 'ns': 0},
#  {'*': 'Uroševac', 'exists': '', 'ns': 0},
#  {'*': 'Urvaste Parish', 'exists': '', 'ns': 0},
#  {'*': 'Utah', 'exists': '', 'ns': 0},
#  {'*': 'Valley Oak', 'exists': '', 'ns': 0},
#  {'*': 'Vana-Võidu', 'exists': '', 'ns': 0},
#  {'*': 'Vancouver Island', 'exists': '', 'ns': 0},
#  {'*': 'Veliki Popovac', 'exists': '', 'ns': 0},
#  {'*': 'Vendaland', 'exists': '', 'ns': 0},
#  {'*': 'Viljandi County', 'exists': '', 'ns': 0},
#  {'*': 'Vitoria-Gasteiz', 'exists': '', 'ns': 0},
#  {'*': 'Vizcaíno-Serra Oak', 'exists': '', 'ns': 0},
#  {'*': 'Võru County', 'exists': '', 'ns': 0},
#  {'*': 'Wales', 'exists': '', 'ns': 0},
#  {'*': 'Wall Street', 'exists': '', 'ns': 0},
#  {'*': 'Warwickshire', 'exists': '', 'ns': 0},
#  {'*': 'Washington, D.C.', 'exists': '', 'ns': 0},
#  {'*': 'Washington (state)', 'exists': '', 'ns': 0},
#  {'*': 'Washington Oak', 'exists': '', 'ns': 0},
#  {'*': 'Washington Square Park', 'exists': '', 'ns': 0},
#  {'*': 'Washington Territory', 'exists': '', 'ns': 0},
#  {'*': 'Poplar of Horror', 'ns': 0},
#  {'*': 'Donja Gradina', 'ns': 0},
#  {'*': 'Lewisberg, Louisiana', 'ns': 0},
#  {'*': 'Salem Oak', 'ns': 0},
#  {'*': 'Geneseo Big Tree', 'ns': 0},
#  {'*': 'Inspiration Oak', 'ns': 0},
#  {'*': 'Adansonia gregorii', 'exists': '', 'ns': 0},
#  {'*': 'Al-Mutawakkil', 'exists': '', 'ns': 0},
#  {'*': 'Alerce Costero National Park', 'exists': '', 'ns': 0},
#  {'*': 'Archive.today', 'exists': '', 'ns': 0},
#  {'*': 'Auckland', 'exists': '', 'ns': 0},
#  {'*': 'Australian Labor Party', 'exists': '', 'ns': 0},
#  {'*': 'Axis mundi', 'exists': '', 'ns': 0},
#  {'*': 'BBC News', 'exists': '', 'ns': 0},
#  {'*': 'Banyan tree in Lahaina', 'exists': '', 'ns': 0},
#  {'*': 'Barcaldine, Queensland', 'exists': '', 'ns': 0},
#  {'*': 'Bedourie, Queensland', 'exists': '', 'ns': 0},
#  {'*': 'Belize', 'exists': '', 'ns': 0},
#  {'*': 'Bland Oak', 'exists': '', 'ns': 0},
#  {'*': 'Blue Mountains (New South Wales)', 'exists': '', 'ns': 0},
#  {'*': 'Boab Prison Tree, Derby', 'exists': '', 'ns': 0},
#  {'*': 'Boab Prison Tree, Wyndham', 'exists': '', 'ns': 0},
#  {'*': 'Bodhi Tree', 'exists': '', 'ns': 0},
#  {'*': 'Brazil', 'exists': '', 'ns': 0},
#  {'*': 'Buddhism', 'exists': '', 'ns': 0},
#  {'*': 'Bulahdelah', 'exists': '', 'ns': 0},
#  {'*': 'Burke and Wills expedition', 'exists': '', 'ns': 0},
#  {'*': 'Cairns', 'exists': '', 'ns': 0},
#  {'*': 'Cajueiro da Praia', 'exists': '', 'ns': 0},
#  {'*': 'Cashew', 'exists': '', 'ns': 0},
#  {'*': 'Cashew of Pirangi', 'exists': '', 'ns': 0},
#  {'*': 'Centurion (tree)', 'exists': '', 'ns': 0},
#  {'*': 'Christianity', 'exists': '', 'ns': 0},
#  {'*': 'Circumference', 'exists': '', 'ns': 0},
#  {'*': 'Cooper Creek', 'exists': '', 'ns': 0},
#  {'*': 'Curtain Fig Tree', 'exists': '', 'ns': 0},
#  {'*': 'Cutting of the elm', 'exists': '', 'ns': 0},
#  {'*': 'Derby, Western Australia', 'exists': '', 'ns': 0},
#  {'*': 'Diameter', 'exists': '', 'ns': 0},
#  {'*': 'Diamond Tree', 'exists': '', 'ns': 0},
#  {'*': 'Dig tree', 'exists': '', 'ns': 0},
#  {'*': 'Digital object identifier', 'exists': '', 'ns': 0},
#  {'*': "Disney's Animal Kingdom", 'exists': '', 'ns': 0},
#  {'*': 'El Grande (tree)', 'exists': '', 'ns': 0},
#  {'*': 'Enterolobium cyclocarpum', 'exists': '', 'ns': 0},
#  {'*': 'Eucalyptus coolabah', 'exists': '', 'ns': 0},
#  {'*': 'Eucalyptus diversicolor', 'exists': '', 'ns': 0},
#  {'*': 'Eucalyptus grandis', 'exists': '', 'ns': 0},
#  {'*': 'Eucalyptus marginata', 'exists': '', 'ns': 0},
#  {'*': 'Eucalyptus regnans', 'exists': '', 'ns': 0},
#  {'*': 'Explorers tree', 'exists': '', 'ns': 0},
#  {'*': 'Fairfax Media', 'exists': '', 'ns': 0},
#  {'*': 'Fitzroya', 'exists': '', 'ns': 0},
#  {'*': 'Florida', 'exists': '', 'ns': 0},
#  {'*': 'Gerichtslinde', 'exists': '', 'ns': 0},
#  {'*': 'Gisors', 'exists': '', 'ns': 0},
#  {'*': 'Glenelg, South Australia', 'exists': '', 'ns': 0},
#  {'*': 'Glengyle Station', 'exists': '', 'ns': 0},
#  {'*': 'Gloucester National Park', 'exists': '', 'ns': 0},
#  {'*': 'Gloucester Tree', 'exists': '', 'ns': 0},
#  {'*': 'Guacarí', 'exists': '', 'ns': 0},
#  {'*': 'Guanacaste National Park (Belize)', 'exists': '', 'ns': 0},
#  {'*': 'Hernán Cortés', 'exists': '', 'ns': 0},
#  {'*': 'Indigenous Australian', 'exists': '', 'ns': 0},
#  {'*': 'International Standard Book Number', 'exists': '', 'ns': 0},
#  {'*': 'Irminsul', 'exists': '', 'ns': 0},
#  {'*': 'Jacaranda, University of Sydney', 'exists': '', 'ns': 0},
#  {'*': 'Jarrah', 'exists': '', 'ns': 0},
#  {'*': 'Jievaras', 'exists': '', 'ns': 0},
#  {'*': 'Judaism', 'exists': '', 'ns': 0},
#  {'*': 'Karri', 'exists': '', 'ns': 0},
#  {'*': 'Kauri', 'exists': '', 'ns': 0},
#  {'*': "Kidman's Tree of Knowledge", 'exists': '', 'ns': 0},
#  {'*': 'Lahaina, Hawaii', 'exists': '', 'ns': 0},
#  {'*': 'List of Great British Trees', 'exists': '', 'ns': 0},
#  {'*': 'List of famous Eucalypt trees', 'exists': '', 'ns': 0},
#  {'*': 'List of long-living organisms', 'exists': '', 'ns': 0},
#  {'*': 'List of oldest trees', 'exists': '', 'ns': 0},
#  {'*': 'List of superlative trees', 'exists': '', 'ns': 0},
#  {'*': 'List of tree genera', 'exists': '', 'ns': 0},
#  {'*': 'Lithuanian mythology', 'exists': '', 'ns': 0},
#  {'*': 'Man-eating tree', 'exists': '', 'ns': 0},
#  {'*': 'Managua', 'exists': '', 'ns': 0},
#  {'*': 'Manjimup, Western Australia', 'exists': '', 'ns': 0},
#  {'*': 'Melbourne, Victoria', 'exists': '', 'ns': 0},
#  {'*': 'Mexico', 'exists': '', 'ns': 0},
#  {'*': 'Mexico City', 'exists': '', 'ns': 0},
#  {'*': 'Montezuma Cypress', 'exists': '', 'ns': 0},
#  {'*': 'Natal, Rio Grande do Norte', 'exists': '', 'ns': 0},
#  {'*': 'National Forest Corporation (Chile)', 'exists': '', 'ns': 0},
#  {'*': 'New South Wales', 'exists': '', 'ns': 0},
#  {'*': 'New Zealand', 'exists': '', 'ns': 0},
#  {'*': 'Nicaragua', 'exists': '', 'ns': 0},
#  {'*': 'Norse mythology', 'exists': '', 'ns': 0},
#  {'*': 'Northland Region', 'exists': '', 'ns': 0},
#  {'*': 'Árbol de la Noche Triste', 'ns': 0},
#  {'*': 'Arbol de Guacari', 'ns': 0},
#  {'*': 'Wikipedia:Citation needed', 'exists': '', 'ns': 4},
#  {'*': 'Wikipedia:Reliable sources', 'exists': '', 'ns': 4},
#  {'*': 'Wikipedia:WikiProject Lists', 'exists': '', 'ns': 4},
#  {'*': 'Help:CS1 errors', 'exists': '', 'ns': 12}]

# %%
links = [link['*'] for link in linkDATA["parse"]["links"]]
for i, link in enumerate(links):
    print(i, link)
# Out:
# 0 Category:Articles with unsourced statements from February 2013
# 1 Category:Articles with unsourced statements from April 2010
# 2 Category:Articles with unsourced statements from January 2013
# 3 Category:Articles with unsourced statements from May 2019
# 4 Category:Articles with unsourced statements from April 2012
# 5 Portal:Ecology
# 6 2011 Halloween nor'easter
# 7 50 State Quarters
# 8 A483 road
# 9 Abarkuh
# 10 Abraham Lincoln
# 11 Acacia
# 12 Acer saccharum
# 13 Ada, Oklahoma
# 14 Adansonia digitata
# 15 Aesculus hippocastanum
# 16 Alabama
# 17 Alexander the Great
# 18 Alexander von Humboldt
# 19 Alishan, Chiayi
# 20 Allen Russell (tree)
# 21 Allouville-Bellefosse
# 22 American Elm
# 23 American Revolutionary War
# 24 American elm
# 25 American sycamore
# 26 Amherst, Massachusetts
# 27 Amsterdam
# 28 Andhra Pradesh
# 29 Angel Oak
# 30 Angiosperm
# 31 Annagh, County Cavan
# 32 Anne Frank
# 33 Anne Frank Tree
# 34 Anthem Christmas tree
# 35 Anuradhapura
# 36 Arboretum Freiburg-Günterstal
# 37 Arbre du Ténéré
# 38 Arizona
# 39 Athens, Georgia
# 40 Atomic bombing of Hiroshima
# 41 Augusta, Georgia
# 42 Augusta National Golf Club
# 43 Austin, Texas
# 44 Axe Murder Incident
# 45 Axel Erlandson
# 46 Bahrain
# 47 Baikushev's pine
# 48 Balch Park
# 49 Balete tree
# 50 Ballyconnell
# 51 Balmville, New York
# 52 Balmville Tree
# 53 Baltic States
# 54 Bangalore
# 55 Bansko
# 56 Banyan
# 57 Baobab
# 58 Bartek (oak)
# 59 Basque Country (autonomous community)
# 60 Basques
# 61 Batroun District
# 62 Battle of Buttington
# 63 Battle of Crogen
# 64 Battle of Lone Pine
# 65 Battle of Poltava
# 66 Battle of Princeton
# 67 Battle of Worcester
# 68 Battle of the Somme
# 69 Bcheale
# 70 Beaman Oak
# 71 Beaumont-Hamel
# 72 Beaumont-Hamel Newfoundland Memorial
# 73 Bedford (town), New York
# 74 Beijing
# 75 Belgium
# 76 Belgrade
# 77 Bennett Juniper
# 78 Bermiego
# 79 Bermiego Yew
# 80 Bernards Township, New Jersey
# 81 Bialbero de Casorzo
# 82 Bible
# 83 Bicycle Tree
# 84 Big Banyan Tree
# 85 Big Tree (Washington)
# 86 Big Tree in Chirinda Forest
# 87 Bischofia javanica
# 88 Bishop wood
# 89 Black Hawk (chief)
# 90 Black Hawk Tree
# 91 Black walnut
# 92 Black willow
# 93 Bloomington, Illinois
# 94 Blue spruce
# 95 Bodh Gaya
# 96 Bodhi tree
# 97 Bonsai
# 98 Boscobel, Shropshire
# 99 Bosnia and Herzegovina
# 100 Bosnian Pine
# 101 Boston, Massachusetts
# 102 Boston Christmas Tree
# 103 Boston Common
# 104 Boston Common (park)
# 105 Botanist
# 106 Botswana
# 107 Boyington Oak
# 108 Brian Boru
# 109 Brig o' Turk
# 110 Brimmon Oak
# 111 British Columbia
# 112 Brooklyn
# 113 Bulacan
# 114 Bulgaria
# 115 Burmis tree
# 116 Buttington
# 117 Buttington Oak
# 118 Buttonball Tree
# 119 Buttonwood Agreement
# 120 Cache National Forest
# 121 Caesarsboom
# 122 Calaveras Big Trees State Park
# 123 California
# 124 California live oak
# 125 Callery Pear
# 126 Callixylon tree
# 127 Cambodia
# 128 Candler Oak Tree
# 129 Canlaon City
# 130 Capitol Christmas Tree
# 131 Carmarthen, Wales
# 132 Castanea sativa
# 133 Catalan countries
# 134 Catalonia
# 135 Cedars of God
# 136 Cedrus libani
# 137 Ceiba pentandra
# 138 Centre of England
# 139 Chandelier Tree
# 140 Changi Tree
# 141 Chania (regional unit)
# 142 Chankiri Tree
# 143 Chapel Hill, North Carolina
# 144 Charles II of England
# 145 Charleston, South Carolina
# 146 Charter Oak
# 147 Chatti
# 148 Chernobyl Nuclear Power Plant
# 149 Chernobyl disaster effects
# 150 Cherry
# 151 Chestnut
# 152 Chestnut Tree of One Hundred Horses
# 153 Chicago
# 154 Chicago Christmas Tree
# 155 Chico, California
# 156 China
# 157 Chinese juniper
# 158 Chirinda Forest
# 159 Chishang, Taitung
# 160 Chongzhen Emperor
# 161 Christmas tree
# 162 Church Street Graveyard
# 163 Chêne chapelle
# 164 Circus Trees
# 165 Clonal colony
# 166 Coast Redwood
# 167 Coast live oak
# 168 Comfort Maple
# 169 Common Hawthorn
# 170 Connecticut
# 171 Copperpod
# 172 Cotton Tree (Sierra Leone)
# 173 Council Oak Tree (Hollywood, Florida)
# 174 County Cavan
# 175 County Clare
# 176 Craigends
# 177 Craigends Yew
# 178 Crataegus monogyna
# 179 Creek Council Oak Tree
# 180 Creek Nation
# 181 Crete
# 182 Crowsnest Highway
# 183 Crowsnest Pass, Alberta
# 184 Cryptomeria
# 185 Cryptomeria japonica
# 186 Cupressus macrocarpa
# 187 Cupressus sempervirens
# 188 Curse
# 189 Cvetni trg
# 190 Cypress
# 191 Cypress of Kashmar
# 192 Dalarna
# 193 Daley Plaza
# 194 Danger Tree
# 195 Danvers, Massachusetts
# 196 Darius III
# 197 Darley Oak
# 198 Darleyford
# 199 Darmstadt, Indiana
# 200 David Livingstone
# 201 Davie Poplar
# 202 Dendrochronology
# 203 Denmark
# 204 Devil's Tree
# 205 Devon
# 206 Divljana
# 207 Douglas Fir
# 208 Douglas fir
# 209 Downtown Jacksonville
# 210 Downtown Seattle
# 211 Dracaena draco
# 212 Dragon Tree
# 213 Dry tree
# 214 Duffie Oak
# 215 Dutch elm disease
# 216 Dwight D. Eisenhower
# 217 EVA Air
# 218 East Village, Manhattan
# 219 Eastern Cottonwood
# 220 Eastern United States
# 821 Świętokrzyskie Province
# 822 Osmania Lifesaver
# 823 Hathi ka pedh
# 824 Isidoro Torres
# 825 Mariano Sevilla
# 826 Basilia Tantoco
# 827 Kannimara Teak
# 828 Ballyconnell Yew
# 829 Zernikow (Uckermark)
# 830 The Old Elm
# 831 Ano Vouves
# 832 Mulberry of the Patriarchate of Peć
# 833 Peć, Kosovo
# 834 Old Oak
# 835 Divljana Oak
# 836 Koča's oak
# 837 Veliki Popovac oak
# 838 Brian Boru's Oak
# 839 Raheen Woods
# 840 Viiralti Oak
# 841 TV-eken
# 842 Takovo bush
# 843 Poplar of Horror
# 844 Donja Gradina
# 845 Lewisberg, Louisiana
# 846 Salem Oak
# 847 Geneseo Big Tree
# 848 Inspiration Oak
# 849 Adansonia gregorii
# 850 Al-Mutawakkil
# 851 Alerce Costero National Park
# 852 Archive.today
# 853 Auckland
# 854 Australian Labor Party
# 855 Axis mundi
# 856 BBC News
# 857 Banyan tree in Lahaina
# 858 Barcaldine, Queensland
# 859 Bedourie, Queensland
# 860 Belize
# 861 Bland Oak
# 862 Blue Mountains (New South Wales)
# 863 Boab Prison Tree, Derby
# 864 Boab Prison Tree, Wyndham
# 865 Bodhi Tree
# 866 Brazil
# 867 Buddhism
# 868 Bulahdelah
# 869 Burke and Wills expedition
# 870 Cairns
# 871 Cajueiro da Praia
# 872 Cashew
# 873 Cashew of Pirangi
# 874 Centurion (tree)
# 875 Christianity
# 876 Circumference
# 877 Cooper Creek
# 878 Curtain Fig Tree
# 879 Cutting of the elm
# 880 Derby, Western Australia
# 881 Diameter
# 882 Diamond Tree
# 883 Dig tree
# 884 Digital object identifier
# 885 Disney's Animal Kingdom
# 886 El Grande (tree)
# 887 Enterolobium cyclocarpum
# 888 Eucalyptus coolabah
# 889 Eucalyptus diversicolor
# 890 Eucalyptus grandis
# 891 Eucalyptus marginata
# 892 Eucalyptus regnans
# 893 Explorers tree
# 894 Fairfax Media
# 895 Fitzroya
# 896 Florida
# 897 Gerichtslinde
# 898 Gisors
# 899 Glenelg, South Australia
# 900 Glengyle Station
# 901 Gloucester National Park
# 902 Gloucester Tree
# 903 Guacarí
# 904 Guanacaste National Park (Belize)
# 905 Hernán Cortés
# 906 Indigenous Australian
# 907 International Standard Book Number
# 908 Irminsul
# 909 Jacaranda, University of Sydney
# 910 Jarrah
# 911 Jievaras
# 912 Judaism
# 913 Karri
# 914 Kauri
# 915 Kidman's Tree of Knowledge
# 916 Lahaina, Hawaii
# 917 List of Great British Trees
# 918 List of famous Eucalypt trees
# 919 List of long-living organisms
# 920 List of oldest trees
# 921 List of superlative trees
# 922 List of tree genera
# 923 Lithuanian mythology
# 924 Man-eating tree
# 925 Managua
# 926 Manjimup, Western Australia
# 927 Melbourne, Victoria
# 928 Mexico
# 929 Mexico City
# 930 Montezuma Cypress
# 931 Natal, Rio Grande do Norte
# 932 National Forest Corporation (Chile)
# 933 New South Wales
# 934 New Zealand
# 935 Nicaragua
# 936 Norse mythology
# 937 Northland Region
# 938 Oaxaca
# 939 Old Jarrah Tree
# 940 One Tree Hill, New Zealand
# 941 Pemberton, Western Australia
# 942 Perth, Western Australia
# 943 PubMed Identifier
# 944 Queensland
# 945 Radiata pine
# 946 Ricardo Villalba
# 947 Royal Botanic Gardens Victoria
# 948 Santa María del Tule
# 949 Separation Tree
# 950 Shire of Diamantina
# 951 Sidney Kidman
# 952 Sidrat al-Muntaha
# 953 Simpson Desert
# 954 South Australia
# 955 Strangler Fig
# 956 Strangler fig
# 957 Sydney
# 958 Tane Mahuta
# 959 Tasmania
# 960 Taxodium mucronatum
# 961 Te Matua Ngahere
# 962 Tenochtitlan
# 963 The Old Gum Tree
# 964 The Tree of Life (Disney)
# 965 Tlacopan
# 966 Tree of Knowledge (Australia)
# 967 Tree of Knowledge of Good and Evil
# 968 Tree of Life
# 969 Trees in mythology
# 970 UNESCO
# 971 Veteran tree
# 972 Victoria (Australia)
# 973 Walt Disney World
# 974 Western Australia
# 975 William Bland
# 976 World Tree
# 977 World tree
# 978 Wyndham, Western Australia
# 979 Yggdrasil
# 980 Yungaburra
# 981 Zaqqum
# 982 Árbol del Tule
# 983 Égig érő fa
# 984 Gloomy Night Tree
# 985 Árbol de la Noche Triste
# 986 Arbol de Guacari
# 987 Wikipedia:Citation needed
# 988 Wikipedia:Reliable sources
# 989 Wikipedia:WikiProject Lists
# 990 Help:CS1 errors

# %%
# visualize link data
for link in links[3:4]:
    # get page info
    PARAMS = {
        "action": "query",
        "titles": link,
        "format": "json",
        "prop": "info",
        'inprop': "displaytitle"
    }

    infoR = S.get(url=URL, params=PARAMS)
    infoDATA = infoR.json()
    pprint(infoDATA)

# %%
# get data
PARAMS = {
    "action": "parse",
    "pageid": page_id,
    "format": "json",
    "prop": "wikitext"
}

textR = S.get(url=URL, params=PARAMS)
textDATA = textR.json()

# %%
# parse data

lines = textDATA["parse"]["wikitext"]["*"].split('\n')

# %%
for index, line in enumerate(lines):
    print(index, line)
# Out:
# 0 {{distinguish|List of trees and shrubs by taxonomic family}}
# 1 The following is a '''list of notable trees''' from around the world. Trees listed here are regarded as important or specific by their historical, national, locational, natural or mythological context.  The list includes actual [[tree]]s located throughout the world, as well as [[#Mythological and religious|trees from myths]].
# 2
# 3 {{Dynamic list}}
# 4 {{GeoGroup}}
# 5 {{TOC left}}
# 6
# 7 ==Real forests and individual trees==
# 8
# 9 ===Africa===
# 10
# 11 ====Living====
# 12 {| class="wikitable"
# 13 |-
# 14 !Name
# 15 !Species
# 16 !Location
# 17 !Age (years)
# 18 !Notes
# 19 |-
# 20 |[[Lost Tree]]
# 21 |[[Acacia]]
# 22 |[[Sahara desert]] <br/><small> {{Coord|20.645|N|11.249|E|name=Lost Tree}}</small>
# 23 | -
# 24 |A very isolated tree and important landmark
# 25 |-
# 26 |[[Cotton Tree (Sierra Leone)|The Cotton Tree]]
# 27 |[[Ceiba pentandra|Kapok]] (''[[Ceiba pentandra]]'')
# 28 |[[Freetown]], [[Sierra Leone]] <br/><small>{{Coord|8.4872|N|13.2356|W|name=The Cotton Tree}}
# 29 | -
# 30 | [[File:Cotton Tree (Sierra Leone).jpg|100px|left]] Historic symbol of Freetown.
# 31 |-
# 32 | [[Wonderboom (tree)|Wonderboom tree in Pretoria]]
# 33 | [[Ficus salicifolia|Wonderboom]] (''[[Ficus salicifolia]]'')
# 34 | [[Pretoria]], [[South Africa]] <br/><small> {{coord|-25.6870|28.1918|name=Wonderboom tree}}</small>
# 35 | -
# 36 | [[File:Wonderboom wiki.jpg|100px|left]] A sprawling fig tree in [[Pretoria]], South Africa.
# 37 |-
# 38 |[[El Drago Milenario]]
# 39 | [[Dragon Tree]] (''[[Dracaena draco]]'')
# 40 |[[Icod de los Vinos]], [[Tenerife]] <br/><small> {{Coord|28.3666|-16.72222|name=El Drago Milenario}} </small>
# 41 | -
# 42 | [[File:Dracaena draco.jpg|100px|left]] Has been a local tourist attraction for more than a hundred years (mentioned by [[Alexander von Humboldt]], for instance).
# 43 |-
# 44 |[[Sunland Baobab]]
# 45 |[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')
# 46 |[[Limpopo Province]], [[South Africa]]<br/><small>{{coord|23|37|16|S|30|11|53|E|name=Sunland Baobab}}</small>
# 47 |1060
# 48 | [[File:Sunland Baobab, Limpopo, South Africa (5613316944).jpg|100px|left]] A giant and ancient baobab tree, with a [[pub]] in the hollow.
# 49 |-
# 50 |[[Sagole Baobab]]
# 51 |[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')
# 52 |Near [[Tshipise]], in [[Vendaland]], Limpopo Province, South Africa <br/> <small> {{coord|22|30|00|S|30|38|00|E|name=Sagole Baobab}}</small>
# 53 |
# 54 |[[File:Sagole Baobab.jpg|100px|left]] Largest baobab in South Africa
# 55 |-
# 56 |[[Glencoe Baobab]]
# 57 |[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')
# 58 |[[Hoedspruit]], South Africa <br/><small>{{coord|24|22|25|S|30|51|24|E|name=Glencoe Baobab}}</small>
# 59 |1835
# 60 |Stoutest and second largest baobab in South Africa
# 61 |-
# 62 |[[Ombalantu baobab tree]]
# 63 |[[Adansonia digitata|Baobab]] (''[[Adansonia digitata]]'')
# 64 |[[Outapi]], Namibia<br/><small>{{coord|17|30|43|S|14|59|16|E|name=Ombalantu baobab tree}} </small>
# 65 |800
# 66 |[[File:Ombalantu Baobab Tree.jpg|100px|left]] Has served as a chapel, post office, house, and place of hiding.
# 67 |-
# 68 |[[Omukwiyugwemanya]]
# 69 |Fig tree
# 70 |[[Oshigambo]], Namibia <br/> <small>{{coord|-17.7870|16.0740|name=Omukwiyugwemanya}}</small>
# 71 |
# 72 |Tourist attraction
# 73 |-
# 74 |[[Post Office Tree]]
# 75 |[[Sideroxylon inerme|White Milkwood]] (''[[Sideroxylon inerme]]'')
# 76 |[[Mosselbay]], South Africa <br/><small>{{coord|-34.180363|22.141382|name=Post Office Tree}}</small>
# 77 |c.600
# 78 |[[File:The Post Office Tree.JPG|100px|left]] Acted as a "post office" in earlier times and now has a boot shaped postbox.
# 79 |-
# 80 |[[Treaty Tree]]
# 81 |[[Sideroxylon inerme|White Milkwood]] (''[[Sideroxylon inerme]]'')
# 82 |[[Woodstock, Cape Town]], South Africa <br/> <small> {{coord|-33.92626|18.45130|name=Treaty Tree}} </small>
# 83 |c.500
# 84 |[[File:Photo 5 Treaty Tree. Cnr Treaty and Spring St, Woodstock. Cape Town..JPG|100px|left]] Site of Peace Treaty in 1806.
# 85 |-
# 86 |[[Big Tree in Chirinda Forest]]
# 87 |[[Khaya anthotheca|Nyasa Redwood]] (''Khaya anthotheca '')
# 88 |[[Chirinda Forest]], Zimbabwe <br/> <small> {{coordinates|20|26|29|S|32|42|15|E|name=Big Tree in Chirinda Forest}} </small>
# 89 |1000+
# 90 |Declared a National Monument
# 91 |-
# 92 |}
# 93
# 94 ====Historical====
# 95 {| class="wikitable"
# 96 |-
# 97 !Name
# 98 !Species
# 99 !Location
# 100 !Age (years)
# 101 !Notes
# 102 |-
# 103 |[[Arbre du Ténéré]]
# 104 |Acacia
# 105 |[[Sahara desert]]<br/><small>{{coord|17|45|00|N|10|04|00|E|name=Arbre du Ténéré}}</small>
# 106 |
# 107 | [[File:Arbre-du-tenere-1961.jpg|100px|left]] A very isolated tree in the Sahara desert, notable before 1934, in [[Niger]], destroyed in 1973.
# 108 |-
# 109 |Panke Baobab
# 110 |[[Adansonia digitata|African Baobab]]
# 111 |[[Zimbabwe]]
# 112 | 2,419
# 113 | Oldest documented non-clonal [[angiosperm]].  Tree fell in 2011.<ref>Adrian Patrut et al. (2018) The demise of the largest and oldest African baobabs. Nature Plants 4: 423–426. DOI: 10.1038/s41477-018-0170-5</ref>
# 114 |-
# 115 |Chapman's Baobab
# 116 |[[Adansonia digitata|African Baobab]]
# 117 |[[Botswana]]
# 118 |
# 119 | [[File:Chapman's_baobab_(4954708191).jpg|100px|left]] Found and named after James Chapman and marked by explorer [[David Livingstone]].  Tree fell in 2016.<ref>https://africageographic.com/blog/chapmans-baobob-one-of-africas-largest-trees-falls/</ref>
# 120 |}
# 121
# 122 ===Asia===
# 123
# 124 ====Living====
# 125 {|class="wikitable"
# 126 |-
# 127 !Name
# 128 !Species
# 129 !Location
# 130 !Age (years)
# 131 !Notes
# 132 |-
# 133 |[[Sarv-e Abarkuh|Cypress of Abarkuh]]
# 134 |[[Cypress]] (''[[Cupressus sempervirens]]'')
# 135 |[[Abarkuh]], [[Yazd Province]], [[Iran]]
# 136 |4,500
# 137 | Cypress of Abarkuh is the second oldest living tree in the world.
# 138 |-
# 139 |[[Sisters Olive Trees of Noah]]
# 140 |[[Olive Tree]] (''[[Olea europaea]]'')
# 141 |[[Bcheale]], [[Batroun District]], [[Lebanon]]
# 142 | Claimed to be 5,000 to 6,000
# 143 | Some claim these are the oldest living trees on earth. Legends refer to these trees as the source of the olive branch in the [[Genesis flood narrative]].<ref>[//upload.wikimedia.org/wikipedia/commons/f/f1/Olive5.jpg Certificate issued by the Lebanese government and the United Nations FAO]</ref><ref>[http://www.oliveoiltimes.com/olive-oil-basics/world/epic-olive-trees/26998 'Epic Olive Trees' by the Olive Oil Times, Article, 2012]</ref><ref>[http://www.dailystar.com.lb/Business/Lebanon/2012/Oct-31/193293-bechealehs-ancient-trees-still-producing-high-end-olive-oil.ashx#axzz2EYVZGXQO 'Bechealeh’s ancient trees still producing high-end olive oil' by The Daily Star Article, 2012]</ref><ref>[http://cma.staging-thetimes.co.uk/tto/arts/books/article2454997.ece 'Ancient olive branches' by The TIMES of London Article, 2006]</ref>
# 180 |-
# 181 |[[Jōmon Sugi]]
# 182 |[[Cryptomeria|Japanese Cedar]] (''[[Cryptomeria japonica]]'')
# 183 |[[Yakushima]] island, [[Japan]] <br/><small> {{coord|30|21|40.76|N|130|31|55.81|E|name=Jōmon Sugi}}</small>
# 184 | -
# 185 | [[File:Jomon Sugi Panorama.jpg|100px|left]] Ancient specimen
# 186 |-
# 187 |[[Great sugi of Kayano]]
# 188 |Cryptomeria|Japanese Cedar (''Cryptomeria japonica'')
# 189 |[[Kaga, Ishikawa|Kaga]], [[Ishikawa Prefecture]], Japan <br/><small> {{coord|36|13|39|N|136|21|36|E|name=Great sugi of Kayano}}</small>
# 190 |2,300
# 191 | [[File:Kayano Ōsugi 20070814.jpg|100px|left]]
# 192 |-
# 193 |[[Natural monuments of South Korea#51-100|Ginkgo Tree of the Confucian Shrine of Seoul]]
# 194 |[[Ginkgo]] (''[[Ginkgo biloba]]'')
# 195 |[[Sungkyunkwan University]], [[Seoul]], [[South Korea]]
# 196 |500
# 197 |A pair of ginkgo trees
# 198 |-
# 199 |[[Big Banyan Tree]]
# 200 |Banyan (''Ficus benghalensis'')
# 201 |[[Ramohalli]], [[Bangalore]], India <br/><small> {{coord|12|54|34|N|77|23|44|E|name=Dodda Aladha Mara}}</small>
# 202 |400
# 203 |[[File:Dod alada mara.jpg|100px|left]]
# 204 |-
# 205 |[[Tree of Life, Bahrain|Tree of Life]]
# 206 |[[Prosopis cineraria|Mesquite]] (''[[Prosopis cineraria]]'')
# 207 |[[Bahrain]] <br/><small> {{coord|25.994073|N|50.583235|E|name=Tree of Life}}</small>
# 208 |400
# 209 | [[File:Tree of Life Bahrain.jpg|100px|left]]
# 210 |-
# 211 |[[Chankiri Tree]] (Killing tree)
# 212 |[[Samanea saman|Samanea saman/Albizzia saman]]<ref>{{cite web |url=http://www.cafaca.com/index.php?option=com_cafaca&view=treetype&id=12&Itemid=110&lang=en}}</ref>
# 213 |[[Cambodia]]n [[Killing Fields]]
# 214 | -
# 215 | [[File:ChoeungEk-Darter-7.jpg|100px|left]] A tree in the [[Killing Fields]] against which children and infants were slung to kill them.
# 216 |-
# 217 |[[Rahmat tree]]
# 218 |[[Platanus|Plane Tree]] (''[[Platanus]]'')
# 219 |[[Kermanshah]], [[Kermanshah Province|Kermanshahan Province]], [[Iran]]
# 220 |700
# 221 |Located in the historical area of [[Taq Bostan]].
# 222 |-
# 223 |The Ying Ke Pine
# 224 |[[Huangshan pine]] (''[[Pinus hwangshanensis]]'')
# 225 |[[Huangshan]], [[China]]
# 226 | Thought to be 1,500
# 227 | [[File:Huangshan pic 2.jpg|100px|left]] Ying Ke, meaning "Welcoming-Guests" pine on Huangshan.
# 228 |-
# 229 |
# 230 |[[Tembusu]] (''[[Fagraea fragrans]]'')
# 231 |[[Singapore Botanical Gardens]], [[Singapore]]
# 232 |100
# 233 |The tree is featured on the reverse of a [[Singapore Portrait Series currency notes#Specifications|$5]] Singapore note.
# 234 |-
# 235 |[[Judean date palm#Germination of 2000-year-old seed|Methuselah]]
# 236 |[[Judean date palm]] (''[[Phoenix dactylifera]]'')
# 237 |[[Israel]]
# 238 | About 12
# 239 | [[File:JudeanDatePalmMethuselah.JPG|100px|left]] The formerly extinct tree was sprouted from a 2,000-year-old seed.
# 240 |-
# 241 |[[Hathi ka pedh]]
# 242 |[[Baobab]] (''Adansonia digitata'')
# 243 |[[Purana Qila]], [[Hyderabad]], [[Telangana]], [[India]]
# 244 | 320
# 245 | A gift from African traders, this huge tree is an iconic landmark of the erstwhile [[Qutb Shahi]] era.
# 246 |-
# 247 |[[Takeshi Kaneshiro Tree]]<br>(金城武樹)
# 248 |[[Bishop wood]] ([[Bischofia javanica]])
# 249 |[[Chishang, Taitung|Chishang]], [[Taitung County|Taitung]], [[Taiwan]]
# 250 | About 40
# 251 | [[File:金城武樹 (14545001530).jpg|100px|left]] Made famous by advertisements for [[EVA Air]] with [[Takeshi Kaneshiro]] made in June 2013 under this tree.
# 252 |}
# 253
# 254 ====Historical====
# 255 {|class="wikitable"
# 256 |-
# 257 !Name
# 258 !Species
# 259 !Location
# 260 !Age (years)
# 261 !Notes
# 262 |-
# 263 |Alishan Sacred Tree
# 264 |[[Cypress]]
# 265 |[[Alishan, Chiayi|Alishan]] train station, [[Taiwan]]
# 266 |3,000
# 267 |The tree fell on July 1, 1997.
# 268 |-
# 269 | The [[Bodhi tree]]
# 270 |Sacred fig (''Ficus religiosa'')
# 271 |[[Bodh Gaya]], India<br/><small>{{coord|24|41|45.29|N|84|59|29.29|E|name=Bodhi Tree}}</small>
# 272 | -
# 273 |The tree under which [[Gautama Buddha|Buddha]] obtained enlightenment. The current tree at the site is a replacement.
# 274 |-
# 275 |[[Guilty Chinese Scholartree]]
# 276 |[[Pagoda Tree]] (''[[Styphnolobium japonicum]]'')
# 277 |[[Jingshan park]]<br/><small>{{coord|39|55|23.22|N|116|23|33.64|E|name=Guilty Chinese Scholartree}}</small>
# 278 |
# 279 |[[File:Guilty Chinese Scholar Tree.jpg|100px|left]] The tree on which the [[Chongzhen Emperor]] hanged himself shortly after escaping the [[Forbidden City]] in [[Beijing]], [[China]]. The original tree died and was replaced by a replica.
# 280 |-
# 281 |[[Changi Tree]]
# 282 |Either
# 283
# 284 ''[[Hopea sangal]]''
# 285
# 286 or
# 287
# 288 ''[[Sindora| Sindora wallichii]]''
# 289
# 290 |[[Singapore]]
# 291 |
# 292 |A historical visual landmark located in Singapore. Thought to be a specimen of ''Sindora wallichii'', with an estimated height of 75 metres (246&nbsp;ft), it was felled with explosive charges during the [[Second World War]] to prevent its use as a ranging aide by the approaching Japanese artillery.
# 293 |-
# 294 |[[Dry tree]]
# 295 |[[Platanus]]
# 296 |Norther [[Persia]], possibly [[Tabriz]] or somewhere in [[Greater Khorasan|Khorasan]]
# 297 |
# 298 |According to a legend, the solitary Dry tree marked the spot of a great battle between [[Alexander the Great]] and [[Darius III|Darius]]. Later recorded by [[Marco Polo]].
# 299 |-
# 346 !Notes
# 347 |-
# 348 |[[Old Tjikko]]
# 349 |[[Norway spruce]] (''[[Picea abies]]'')
# 350 |[[Dalarna]] [[Sweden]] <br/><small>{{coord|61|35|N|12|40|E|name=Old Tjikko (approximate location)}}</small>
# 351 | {{age nts|-7542|04|17}}<ref name=bbc>{{cite news |url=http://news.bbc.co.uk/2/hi/europe/7353357.stm |title=Swedes find 'world's oldest tree' |date=17 April 2008 |accessdate=6 May 2008 |publisher=[[BBC News]] }}</ref>
# 352 | [[File:Old-Tjikko-2011-07-19-001.jpg|100px|left]] The oldest known individual clonal tree in the world.
# 353 |-
# 354 |[[Stara Maslina]]
# 355 |Olive Tree (''Olea europaea'')
# 356 |Bar, Montenegro <br/><small> {{coord|42|04|48|N|19|07|46|E|name=Stara Maslina}}</small>
# 357 |2240
# 358 |
# 359 |-
# 360 |[[Ballyconnell Yew]]
# 361 |[[Taxaceae|Yew]]
# 362 | Grounds of [[Ballyconnell]] House, [[Annagh, County Cavan|Annagh]] townland, [[County Cavan]], [[Ireland]]
# 363 | >2,000
# 364 | Ancient tree reckoned to be well over 2,000 years old with a massive girth.
# 365 |-
# 366 |[[Craigends Yew]] (''Taxus Baccata'')
# 367 |[[Taxaceae|Yew]]
# 368 | Grounds of the old [[Craigends]] estate, [[Houston, Renfrewshire]], [[Scotland]] <br/> <small> {{Coord|55.862413|N|4.5262771|W|name=Craigends Yew}} </small>
# 369 | >700
# 370 | [[File:Craigends Yew grove, Houston, Renfrewshire - view from the old ice house.jpg|100px|left]] Largest layering yew tree in Scotland with a 100-metre circumference of the crown
# 371 |-
# 372 |
# 373 |[[Scots pine]] (''[[Pinus sylvestris]]'')
# 374 |[[Urho Kekkonen National Park]], [[Lapland (Finland)]], [[Finland]]
# 375 | 770
# 376 | Considered one of the oldest trees in Finland. Probably the oldest Scots pine in the world.
# 377 |-
# 378 |[[Fortingall Yew]]
# 379 |[[European yew]] (''[[Taxus baccata]]'')
# 380 |Churchyard of the village of [[Fortingall]] in [[Perthshire]], [[Scotland]]  <br/><small> {{coord|56.598158|N|4.051007|W|name=Fortingall Yew}}</small>
# 381 |2,000–5,000
# 382 | Various estimates have put its age at between 2,000 and 5,000 years.
# 383 |-
# 384 |[[Florencecourt Yew]]
# 385 |[[Irish Yew]] (''Taxus baccata'')
# 386 |[[Florence Court]] estate near [[Enniskillen]], [[Fermanagh]], [[Northern Ireland]] <br/><small> {{coord|54.261004|-7.727313|name=Florencecourt Yew}}</small>
# 387 |{{age|1740|1|1}}
# 388 |Replanted in 1740 as a sapling. Following commercial propagation of the tree after 1820, it is believed that the majority of Irish Yews outside Ireland are derived from this one tree.
# 389 |-
# 390 |[[Bermiego Yew]]
# 391 |European yew (''Taxus baccata'')
# 392 |[[Bermiego]], Asturias, Spain <br/><small>{{coord|43.200930|-5.984258|name=Bermiego Yew }}</small>
# 393 |c.2000
# 394 |[[File:Texu.jpg|100px|left]] Considered one of the oldest yews in Europe.
# 395 |-
# 396 |[[Caesarsboom]] (Caesar's Tree)
# 397 |European yew (''Taxus baccata'')
# 398 | [[Lo, Belgium]] <br/><small> {{coord|50.98028|2.74554|name=Caesarsboom}}</small>
# 399 |
# 400 | [[File:Lo - Caesarsboom.jpg|100px|left]] Noted for the legend that [[Julius Caesar]] tethered his horse to it during his conquest of the region.
# 401 |-
# 402 |Estry Yew
# 403 |Yew
# 404 |[[Estry]], [[Normandy]], [[France]] <br/><small> {{coord|48.896988|-0.734029|name=Estry Yew}} </small>
# 405 | > 1,600
# 406 | Considered one of the oldest trees in France. Its hollow trunk can contain 30 people.
# 407 |-
# 408 |La-Haye-de-Routot Yews
# 409 |Yews
# 410 |[[La Haye-de-Routot]], Normandy, France <br/> <small> {{coord|49|24|19.1|N|0|43|41.9|E|name=La-Haye-de_routot Yews}}</small>
# 411 | ~ 1,500
# 412 |[[File:LaHayeDeRoutotIf1.JPG|100px|left]] A chapel with a door was designed in one of them.
# 413 |-
# 414 |[[Forest swastika]]
# 415 |[[Larch]]
# 416 |[[Zernikow (Uckermark)|Zernikow]], [[Germany]].
# 417 |
# 418 |  A patch of carefully arranged larch trees covering a {{convert|60|yd|adj=on}} square area of [[pine]] forest.
# 419 |-
# 420 |[[The Old Elm]]
# 421 |[[Field Elm]] (''[[Ulmus minor]]'')
# 422 |Center of [[Sliven]], [[Bulgaria]]
# 423 | 1100
# 424 | The Old Elm won the 2014 European Tree of the Year Award. The tree has sat in the center of Sliven for 1100 years, serving as a gathering point and a historical marker. It is also part of the city coat of arms.<ref>{{cite web|title=2014 European Tree of the Year|url=https://www.treeoftheyear.org/Minule-rocniky/2014/Stary-jilm.aspx|accessdate=17 October 2017|date=2014}}</ref>
# 425 |-
# 426 |[[Granit Oak]]
# 427 |[[English Oak]] (''[[Quercus robur]]'')
# 428 |Granit village near [[Stara Zagora]], [[Bulgaria]] <br/><small> {{coord|42.254067|25.136080|name=Granit oak}}</small>
# 429 |1,650
# 430 |One of the oldest trees in [[Europe]], estimated to be about 1,650 years old. Its crown spread covers an area of 1,017 square metres, its girth is 7.45 m, and its height is 23.4 m.
# 431 |-
# 432 |[[Bartek (oak)|Bartek]]
# 433 |[[Oak]]
# 434 |[[Zagnańsk]], [[Świętokrzyskie Province]], [[Poland]] <br/><small> {{coord|50|59|N|20|40|E|name=Bartek}}</small>
# 435 |650–670
# 436 |[[File:Dab Bartek.jpg|100px|left]] A famous tree in [[Poland]], visited by kings, said to be about 1,200 years old (actually 650–670 years according to recent studies{{citation needed|date=February 2013}}). It is 30 m tall, 13.5 m in girth near the ground, with a crown spread of 40 m.
# 437 |-
# 438 |[[Gernikako Arbola]]
# 439 |Oak
# 440 |[[Guernica (town)|Guernica]], [[Basque Country (autonomous community)|Basque Country]], [[Spain]] <br/><small> {{coord|43|18|53|N|2|40|47|W|name=Gernikako Arbola }}</small>
# 441 |
# 442 |[[File:P5393 Guernica Gernikako Arbola Tregenza.jpg|100px|left]] An oak representing the [[Basques|Basque people]]
# 443 |-
# 444 |[[The Great Sequoia]]
# 445 |Sequoia (''Sequoiadendron giganteum'')
# 446 |[[Vitoria-Gasteiz]], [[Basque Country (autonomous community)|Basque Country]], [[Spain]] <br/><small> {{coord|42.846584|-2.678167|name=Great Sequoia}}</small>
# 447 |160
# 448 |[[File:Sequoiadesdeabajo.jpg|100px|left]] Symbol of the city
# 449 |-
# 450 |[[Queen Elizabeth Oak]]
# 451 |English Oak (''Quercus robur'')
# 452 |[[Royal Palace of Hatfield]], [[Hertfordshire]], [[England]] <br/><small> {{coord|50.99613|-0.70066|name=Queen Elizabeth Oak}}</small>
# 453 |800–1000
# 454 |[[File:Queen Elizabeth oak, Cowdray Park, near Lodsworth - geograph.org.uk - 970020.jpg|100px|left]] Said to be the location where [[Elizabeth I of England]] was told she was queen in 1558.
# 455 |-
# 456 |[[Darley Oak]]
# 457 |[[Pedunculate oak]] (''Quercus robur'')
# 458 |[[Darleyford]], Cornwall, England <br/><small> {{coord|50.53396|N|4.43382|W|name=Darley Oak}} </small>
# 459 |1000+
# 460 |Folk tradition attributes healing properties to the tree
# 461 |-
# 462 |[[Kongeegen]] (the King Oak)
# 463 |[[Pedunculate Oak]] (''Quercus robur'')
# 464 |Jægerspris Nordskov, [[Sjælland]], [[Denmark]] <br/><small> {{coord|55|54|37|N|11|59|21|E|name=Kongeegen}}</small>
# 465 |1,200
# 466 |[[File:Kongeegen.jpg|100px|left]] The oldest tree in Denmark.
# 467 |-
# 468 |[[Chêne chapelle]]
# 469 |[[Pedunculate Oak]] (''Quercus robur'')
# 470 |[[Allouville-Bellefosse]], Normandy, France <br/> <small> {{coord|49|35|47|N|0|40|35|E|name=Chêne chapelle}}
# 471 |1,200
# 472 |[[File:Chnedallouville6.jpg|100px|left]] An 800- to 1,200-year-old pedunculate oak, under which [[William the Conqueror]] is to have stopped, according to a local legend. There are two chapels inside.
# 473 |-
# 474 |Poltava Oak
# 475 |Oak
# 476 |[[Poltava]], [[Ukraine]]
# 477 |600
# 478 |An oak under which tsar [[Peter the Great|Peter I]] rested at the [[Battle of Poltava]] in 1709.{{citation needed|date=April 2010}}
# 479 |-
# 480 |Stoke Gabriel Yew
# 481 |Yew
# 482 |[[Stoke Gabriel]] churchyard [[Devon]], [[England]]<br/> <small> {{coord|50.402854|N|3.621049|W|name=Stoke Gabriel Yew}}
# 483 |c.1000
# 484 |[[File:Yew Tree - geograph.org.uk - 787460.jpg|100px|left]] Said to be the oldest tree in England.
# 485 |-
# 486 |[[Major Oak]]
# 487 |Pedunculate Oak (''Quercus robur'')
# 488 |[[Sherwood Forest]], [[Nottinghamshire]], England <br/><small> {{coord|53|12|17|N|1|4|20.80|W|name=Major Oak}} </small>
# 489 |800
# 490 |[[File:Major Oak.JPG|100px|left]] The most famous and most visited tree of [[Great Britain]]. About 800 years old, with a girth at breast height of 10.5 m.
# 491 |-
# 492 |[[Gilwell Oak]]
# 493 |Pedunculate Oak (''Quercus robur'')
# 494 |[[Gilwell Park]], [[Epping Forest]], Essex, United Kingdom <br/> <small> {{coord|51|39|1|N|0|0|8|E|name=Gilwell Oak}} <small>
# 495 |circa 500
# 496 |[[File:Gilwell Oak (5948293396).jpg|100px|left]] Oak tree associated with the early history of the [[Scout Association]]
# 497 |-
# 498 |Ivenack Oak
# 499 |Pedunculate Oak (''Quercus robur'')
# 500 |Ivenack, [[Mecklenburg-Western Pomerania]], [[Germany]]
# 501 |800
# 502 |[[File:Oak Ivenack 08 2015.JPG|100px|left]] A huge and ancient Pedunculate oak thought to be about 800 years old, 35 m tall, 11 m in girth at breast height and 16.5 m near the ground. The largest oak in Germany and (in wood volume) probably in Europe.
# 503 |-
# 504 |[[Baikushev's pine]]
# 505 |[[Bosnian Pine]] (''[[Pinus heldreichii]]'')
# 506 |[[Pirin]] mountains near [[Bansko]], [[Bulgaria]]
# 507 |1,300
# 508 |[[File:Bajkusheva mura1.jpg|100px|left]] An ancient tree estimated to be 1,300 years old. It is one of the oldest trees of Bulgaria and stands 24 m tall with a girth of 6.9 m at breast height.
# 509 |-
# 510 |[[Stelmužė Oak]]
# 511 |Pedunculate Oak (''Quercus robur'')
# 512 |[[Stelmužė]], [[Zarasai district]], [[Lithuania]] <br/> <small> {{coord|55.8299811|26.2175894|name=Stelmužė Oak}} </small>
# 513 |1,500
# 514 |[[File:Stelmužė oak.jpg|100px|left]] Measures a girth at breast height of 9.58 m and 13 m near the ground. The oldest tree in Lithuania and the [[Baltic States]].
# 515 |-
# 516 |[[Chestnut Tree of One Hundred Horses]]
# 517 |[[Sweet Chestnut]] (''[[Castanea sativa]]'')
# 518 |[[Sant'Alfio]], the eastern slope of [[Mount Etna]], [[Italy]] <br/> <small> {{coord|37|45|00.7|N|15|7|49.4|E|name=Chestnut Tree of One Hundred Horses}} </small>
# 519 |2000-4000
# 520 |[[File:Castagno dei Cento Cavalli.jpg|100px|left]] Probably the world's oldest and largest [[chestnut]].
# 521 |-
# 522 |[[Bialbero de Casorzo]] (Grana Double Tree)
# 523 |Outer: [[Mulberry]]
# 524 Inner: [[Cherry|Cherry Tree]]
# 525 |[[Grana, Piedmont|Grana]], [[Piemont]], [[Italy]]
# 526 |
# 527 |[[File:Bialbero di Casorzo.jpg|100px|left]] a tree which grows in a hollow tree near Grana, Piemont, Italy [http://atlasobscura.com/places/grana-double-tree]
# 528 |-
# 529 |Le Gros chêne de [[Liernu]] (the big oak of Liernu)
# 530 |Oak
# 531 | 15 north from [[Namur (city)|Namur]], Belgium <br/> <small> {{coord|50|35|03|N|4|49|40|E|name=Le Gros chêne de Liernu}}
# 532 |900
# 533 |[[File:Liernu JPG01b.jpg|100px|left]] Known as the oldest oak in [[Belgium]]. It is estimated at certainly 800 or 900 years old, maybe more than 1,000 years.
# 534 |-
# 535 |[[Lech, Czech and Rus#Oaks of Rogalin|The Oaks of Rogalin]]
# 536 |Oak
# 537 |[[Rogalin]], [[Greater Poland]]
# 538 |1,000
# 539 |[[File:RogalinOaks.jpg|100px|left]] Thousand-year-old trees named after the three mythic founders of the Slavic nations.
# 540 |-
# 541 |[[Olive tree of Vouves|The Olive tree of Vouves]]
# 542 |Olive Tree (''Olea europaea'')
# 543 |Village of [[Ano Vouves]], [[Kolymvari]], [[Chania (regional unit)|Chania regional unit]], [[Crete]], [[Greece]]<br/><small> {{coord|35|29|12|N|23|47|13|E|name=Olive tree of Vouves}}</small>
# 544 |2,000
# 545 |[[File:Olive tree of Vouves.jpg|100px|left]]  It is confirmed to be at least 2000 years old based on [[Dendrochronology|tree ring analysis]], but it is claimed to be between 3000–4000 years old.
# 546 |-
# 547 |[[Mulberry of the Patriarchate of Peć]]
# 548 |[[Mulberry]]
# 549 |[[Peć, Kosovo]].
# 550 |800
# 551 |One of the oldest verified living trees in Serbia, located in the courtyard of the church complex of the [[Monastery of the Patriarchate of Peć|Patriarchate of Peć]]. It was brought from the [[Syria (region)|Shām]] region by Archbishop Saint [[Sava II]] during his pilgrimage to the [[Holy Land]] and planted between 1263 and 1272.
# 552 |-
# 553 |[[Old Oak]]
# 554 |Oak
# 555 |Exactly 100&nbsp;km from [[Belgrade]], [[Serbia]], next to [[European route E75|E-75]] highway.
# 556 |600
# 557 |
# 558 [[File:Zapis-0002-Markovac-Stari-Hrast 20111114 7960.jpg|100px|left]]
# 559 |-
# 560 |[[Divljana Oak]]
# 561 |Oak
# 562 |[[Divljana]], [[Serbia]]
# 563 |over 1000
# 564 |[[File:Divljanski stari hrast.jpg|100px|left]]
# 565 |-
# 566 |[[Koča's oak]]
# 567 |
# 568 | near [[Jagodina]], [[Serbia]]
# 569 |
# 570 | Named after [[Koča Anđelković]].
# 571 |-
# 572 |[[Veliki Popovac oak]]
# 573 |
# 574 |Village of [[Veliki Popovac]], Serbia
# 575 |
# 576 |
# 577 |-
# 578 |[[Prince Miloš's Residence|Plane tree at Miloš's Residence]]
# 579 |[[Plane tree]]
# 580 |[[Belgrade]], Serbia
# 581 |
# 582 | The oldest plane tree in Belgrade.
# 583 |-
# 584 |[[Cvetni trg#History|Flower Square oak]]
# 585 |English Oak (''Quercus robur'')
# 586 |Belgrade, Serbia
# 587 |~200
# 588 |[[File:Quercus robur at Flower Square, Belgrade.jpg|100px|left]] Around two centuries old, the last remaining of the forest that covered the area.
# 589 |-
# 590 |[[Brian Boru's Oak]]
# 591 |Oak
# 592 |[[Raheen Woods]], [[County Clare]], [[Ireland]]
# 593 |1,000
# 594 |A reputedly 1000-year-old oak tree planted by [[Brian Boru]], Last King of Ireland.
# 595 |-
# 596 |[[Pi de les Tres Branques]]
# 597 |Scots Pine (''Pinus sylvestris'')
# 598 |[[Catalonia]], [[Spain]]
# 599 |
# 600 |[[File:Pi de les Tres Branques 1905.jpg|100px|left]] Regarded as symbolising the unity of the [[Catalan countries]]
# 601 |-
# 602 |[[Midland Oak]]
# 603 |Oak
# 604 |[[Leamington Spa]], [[Warwickshire]], England <br/> <small> {{coord|52.300062|N|1.529750|W|name=Midland Oak}} </small>
# 605 |
# 606 |[[File:Midland Oak.jpg|100px|left]] Reputed to mark the [[centre of England]]. grown from an acorn from the original tree.
# 607 |-
# 608 |[[Najevnikov lipovec|Najevnik Linden Tree]]
# 609 |[[Tilia cordata|Small-leaved Lime]] (''[[Tilia cordata]]'')
# 610 |Najevnik Farm in [[Ludranski Vrh]], [[Municipality of Črna na Koroškem]], northern Slovenia
# 611 |~700
# 612 |[[File:NajevskaLipa1.JPG|100px|left]]The tree with the largest girth in Slovenia (10.70 meters; its height is 24 m). Estimated to be 700 years old. The traditional meeting place of Slovene politicians and a cultural venue.
# 613 |-
# 614 |[[Tamme-Lauri oak]]
# 615 |Oak
# 616 |[[Urvaste Parish]], [[Võru County]], [[Estonia]]
# 617 |690
# 618 |[[File:Tamme-Lauri Tamm suvel.jpg|100px|left]] Thickest and oldest tree in Estonia.
# 619 |-
# 620 |[[Viiralti Oak]]
# 621 |Oak
# 622 |[[Vana-Võidu]] village in [[Viljandi County]], [[Estonia]]
# 623 |400
# 624 |[[File:Viiralti tamm.jpg|100px|left]] Known from the graphic work of [[Eduard Wiiralt]] from 1943
# 625 |-
# 626 |Orissaare Stadium oak
# 627 |Pedunculate Oak (''Quercus robur'')
# 628 |[[Orissaare]], [[Saare County]], [[Estonia]] <br/> <small> {{coord|58|33|32.2|N|23|4|49|E|name=Orissaare Stadium oak}} </small>
# 629 |
# 630 |[[File:Orissaare staadioni tamm.JPG|80px|left]] Grows in the middle of Orissaare stadium. [[European Tree of the Year]] 2015
# 631 |-
# 632 |King's Pine
# 633 |Scots Pine (''Pinus sylvestris'')
# 634 |[[Järvselja]] village, [[Peipsiääre Parish]], [[Tartu County]], [[Estonia]]
# 635 |380
# 636 |[[File:Järvselja kuningamänd 2013 09 2.jpg|80px|left]] This pine has height of 33 m and volume of 11,5 m<sup>3</sup> (1999)
# 637 |-
# 638 |Kelchi linden
# 639 |[[Tilia|Linden]]
# 640 |[[Tallinn]], [[Estonia]]
# 641 |360
# 642 |[[File:Kelchi pärn, 2012.jpg|80px|left]] Named after pastor Christian Kelch who was buried under the linden in 1710
# 643 |-
# 644 |Waldtraut vom Mühlenwald
# 645 |[[Douglas fir]]
# 646 |[[Arboretum Freiburg-Günterstal]] near [[Freiburg im Breisgau]], Germany
# 647 |107 (in 2017)<ref name=":0">{{Cite web|url=https://www.sueddeutsche.de/news/wissen/wissenschaft-waldtraut-ist-deutschlands-hoechster-baum-dpa.urn-newsml-dpa-com-20090101-170424-99-179709|title="Waldtraut" ist Deutschlands höchster Baum - Wissen-News|last=Germany|first=Süddeutsche de GmbH, Munich|website=Süddeutsche.de|language=de|access-date=2019-01-02}}</ref>
# 648 |[[File:Waltraut von Mühlenwald.jpg|95px|left]] Tallest tree in Germany with a heights of 66.58 meters in 2017<ref name=":0" /><ref>{{Cite web|url=https://www.stuttgarter-zeitung.de/inhalt.douglasie-im-schwarzwald-deutschlands-hoechster-baum-heisst-waldtraud.908f3393-cd14-4b28-81c5-f5d7058f4857.html|title=Douglasie im Schwarzwald: Deutschlands höchster Baum heißt Waldtraud|last=Germany|first=Stuttgarter Zeitung, Stuttgart|website=stuttgarter-zeitung.de|language=de|access-date=2019-01-02}}</ref><ref>{{Cite web|url=http://www.badische-zeitung.de/freiburg/freiburgs-waldtraut-ist-der-hoechste-baum-deutschlands|title=Freiburgs Waldtraut ist der höchste Baum Deutschlands|last=Zeitung|first=Badische|website=www.badische-zeitung.de|language=de|access-date=2019-01-02}}</ref>
# 649 |}
# 650
# 651 ====Historical====
# 652 {|class="wikitable"
# 653 |-
# 654 !Name
# 655 !Species
# 656 !Location
# 657 !Age (years)
# 658 !Notes
# 659 |-
# 660 |[[Anne Frank Tree]]
# 661 |[[Horse-chestnut]] (''[[Aesculus hippocastanum]]'')
# 662 |City center of [[Amsterdam]], [[Netherlands]]<br/><small>{{coord|52|22|30.7|N|4|53|4.7|E|name=Ann Frank Tree (former)}}</small>
# 663 |
# 664 | [[File:Annefranktree edit1.jpg|100px|left]] Featured in [[Anne Frank]]'s ''[[The Diary of a Young Girl]]''. The tree was destroyed in a gale in the late summer of 2010.
# 665 |-
# 666 |[[Merlin's Oak]]
# 667 |
# 668 |[[Carmarthen, Wales|Carmarthen]], [[Wales]]
# 669 |
# 670 |
# 671 |-
# 672 |[[Glastonbury Abbey#Glastonbury Thorn|Glastonbury Thorn]]
# 673 |[[Common Hawthorn]] (''[[Crataegus monogyna]]'')
# 674 |
# 675 |
# 676 | Reputed to have been planted by [[Joseph of Arimathea]].
# 677 |-
# 678 |[[Thor's Oak]]
# 679 |Oak
# 680 |
# 681 |
# 682 | a tree sacred to the [[Germanic peoples|Germanic tribe]] of the [[Chatti]], ancestors of the [[Hesse|Hessians]].
# 683 |-
# 684 |[[Sacred tree at Uppsala]]
# 685 |
# 686 | [[Temple at Uppsala]], [[Sweden]]
# 687 |
# 688 |It was a [[sacred tree]] venerated by [[Norse pagan]]s, still extant in the second half of the 11th century.
# 689 |-
# 690 |[[Royal Oak (tree)|Royal Oak]]
# 691 |Pedunculate Oak (''Quercus robur'')
# 692 |[[Boscobel, Shropshire|Boscobel]], England
# 693 |
# 694 | [[Charles II of England|King Charles II]] hid in the tree to escape the [[Roundheads]] following the [[Battle of Worcester]] in 1651. The tree deceased and is replaced by a descendant.
# 695 |-
# 696 |[[Shakespeare]]'s mulberry tree
# 697 |[[Mulberry]]
# 698 |New Place, [[Stratford-upon-Avon]], England
# 699 |
# 700 | Cut down in the mid-18th century and fashioned into mementos.
# 701 |-
# 702 |[[Tree of Hippocrates]]
# 703 |[[Oriental Plane]] (''[[Platanus orientalis]]'')
# 704 |[[Kos]], [[Greece]]
# 705 |
# 706 |The tree under which [[Hippocrates]] is supposed to have taught.
# 707 |-
# 708 |[[Red Forest]]
# 709 |Pines
# 710 |[[Chernobyl Nuclear Power Plant]], [[Ukraine]]
# 711 |
# 712 | Formerly the Worm Wood Forest, refers to the trees growing in the 10&nbsp;km<sup>2</sup> surrounding the Chernobyl Nuclear Power Plant and is one of several of the [[Chernobyl disaster effects]] on April 26, 1986. The name 'Red Forest' comes from the ginger brown colour of the pine trees after they died following the absorption of high levels of radiation.
# 713 |-
# 714 |[[TV-eken]]
# 715 | Oak
# 716 | Stockholm, Sweden
# 717 |
# 718 |The TV-oak or TV-eken was a tree in front of the offices of [[Sveriges Television]]. It was felled in 2011 despite a massive campaign to preserve it.<ref name="expressen">{{cite news|title=Här fälls tv-eken |url=http://www.expressen.se/nyheter/1.2632469/har-falls-tv-eken |work=Expressen |access-date=November 25, 2011}}</ref>
# 719 |-
# 720 |[[Danger Tree]]
# 721 |
# 722 |[[Beaumont-Hamel]], France
# 723 |
# 724 |Marks the area of highest casualties suffered by the [[Royal Newfoundland Regiment]] during their attack at [[Beaumont-Hamel Newfoundland Memorial|Beaumont Hamel]] during the [[Battle of the Somme]].  The current 'tree' is a concrete replica, however growth around the replica may be from the same root system as the original tree.
# 725 |-
# 726 |[[Takovo bush]]
# 727 |Oak
# 728 |[[Takovo]], Serbia
# 729 |
# 730 |Tree under which [[Miloš Obrenović]] started the [[Second Serbian Uprising]].
# 731 |-
# 732 |[[Pine of Tsar Dušan]]
# 733 |Bosnian Pine (''Pinus heldreichii'')
# 734 |[[Uroševac]], Serbia
# 735 |{{age|1336|6|1|1999|6|1}}
# 736 |Planted in 1336 by [[Tsar Dušan]], destroyed by Albanian extremists in 1999.{{citation needed|date=January 2013}}
# 737 |-
# 738 |[[Poplar of Horror]]
# 739 |[[Populus|Poplar]]
# 740 |[[Donja Gradina]], [[Bosnia and Herzegovina]]
# 741 |
# 742 |Used for mass executions of inmates of the [[Jasenovac concentration camp]].
# 743 |-
# 744 |[[Buttington Oak]]
# 745 |Oak
# 746 |[[Buttington]], [[Powys]], Wales
# 747 |
# 748 |Said to have been planted to commemorate the [[Battle of Buttington]] in 893, fell in February 2018
# 749 |-
# 750 |[[Oak at the Gate of the Dead]]
# 751 |Pedunculate Oak (''Quercus robur'')
# 752 |near [[Wrexham]], Wales
# 753 |Circa 1,000
# 754 |[[File:The Oak At The Gate Of The Dead.jpg|100px|left]] Sited on the burial ground of the 1165 [[Battle of Crogen]]
# 755 |-
# 756 |[[Brimmon Oak]]
# 757 |Pedunculate Oak (''Quercus robur'')
# 758 |[[Newtown, Powys]], Wales
# 759 |Circa 500
# 760 |A campaign to save it forced the diversion of the [[A483 road|A483 Newtown Bypass]]
# 761 |-
# 762 |[[Bicycle Tree]]
# 763 |Sycamore (''Acer pseudoplatanus'')
# 764 |[[Brig o' Turk]], Scotland
# 765 |Circa 110–150
# 766 |A landmark tree with a bicycle embedded within it
# 767 |-
# 768 |[[Robin Hood's Larder]]
# 769 |Oak
# 770 |[[Sherwood Forest]]
# 771 |
# 772 |Reputed to have been used by Robin Hood to store food
# 773 |}
# 774
# 775 ====Petrified====
# 776 {|class="wikitable"
# 777 |-
# 778 !Name
# 779 !Species
# 780 !Location
# 781 !Age
# 782 !Notes
# 783 |-
# 784 ||[[Petrified Forest of Lesvos]]
# 785 |
# 786 |[[Lesvos]], [[Greece]]
# 787 |
# 788 |
# 789 |}
# 790
# 791 ===North America===
# 792 {{GeoGroup}} <!--- to display coords. A coord form:  <br/><small>{{coord||||N||||W|name=}}</small>  --->
# 793 {{-}}
# 794
# 795 ====Living====
# 796 {|class="wikitable"
# 797 |-
# 798 !Name
# 799 !Species
# 800 !Location
# 801 !Age
# 802 !Notes
# 803 |-
# 804 |[[Allen Russell (tree)|Allen Russell]]
# 805 |[[Giant sequoia]] (''[[Sequoiadendron giganteum]]'')
# 806 |[[Balch Park]], [[Tulare County, California]], [[US]]
# 807 |
# 808 |The 33rd largest tree worldwide, named in dedication to park ranger Allen I. Russell.
# 809 |-
# 810 |[[Angel Oak]]
# 811 |[[Southern live oak]] (''[[Quercus virginiana]]'')
# 812 |[[Johns Island, South Carolina]], near [[Charleston, South Carolina]], [[US]]<br/><small>{{coord|32|43|4|N|80|4|46|W|name=Angel Oak}}</small>
# 813 |400–500
# 814 |[[File:Angel Oak Tree in SC.jpg|100px|left]]It stands 66.5&nbsp;ft (20 m) tall, measures 28&nbsp;ft (8.5 m) in circumference, and produces shade that covers 17,200 square feet (1,600 m<sup>2</sup>). Its longest branch distance is 187&nbsp;ft.The tree and surrounding park have been owned by the neighboring city of Charleston since 1991.
# 815 |-
# 816
# 817 |Bedford Oak
# 818 |[[Quercus alba|White Oak (''Quercus alba'')]]
# 819 |[[Bedford (town), New York|Bedford, New York]]
# 820 |300–500
# 821 |[[File:Bedford Oak, Bedford, NY - July 2012.jpg|100px|left]]In 1987, this tree was officially recognized by the National Arborist Association and International Society of Arboriculture as a significant tree that was alive at the time of the signing of the United States Constitution.<ref>{{cite news|last1=Fullam|first1=Anne C.|title=Bedford panel considers tougher tree law|work=New York Times|date=September 22, 1996|page=WC8}}</ref><ref>{{cite news|last1=Melvin|first1=Tessa|title=If You're Thinking of Living in/Bedford Village; 'New England' 44 Miles From Broadway|url=https://www.nytimes.com/1993/11/07/realestate/if-you-re-thinking-living-bedford-village-new-england-44-miles-broadway.html?n=Top%2FClassifieds%2FReal%20Estate%2FColumns%2FLiving%20In|accessdate=3 March 2017|work=The New York Times|date=November 7, 1993|quote=The large tree at Hook and Cantitoe Roads is depicted on the Bedford town seal and predates the town's founding in 1680.}}</ref> Its measurements are: circumference {{convert|20.5|ft|m}}; height {{convert|69|ft|m}}; average spread {{convert|100|ft|m}}.
# 822 |-
# 823 |[[Bennett Juniper]]
# 824 |[[Grand Juniper]] (''[[Juniperus grandis]]'')
# 825 |[[Stanislaus National Forest]], [[Tuolumne County, California]] US<br/><small>{{coord|38|18|32|N|119|47|49.56|W|name=Bennett Juniper}}</small>
# 826 |2,000–6,000 (est.)
# 827 |The largest known Juniper in the United States.
# 828 |-
# 829 |[[The Big Oak]]
# 830 |Southern Live Oak (''Quercus virginiana'')
# 831 |[[Thomasville, Georgia]], US
# 832 |
# 833 |One of the oldest Live Oak trees east of the [[Mississippi river]].
# 834 |-
# 835 |[[The Big Tree, Rockport|The Big Tree - Goose Island]]
# 836 |Southern Live Oak (''Quercus virginiana'')
# 837 |[[Rockport, Texas]], US
# 838 |
# 839 |Located in Goose Island State Park.
# 840 |-
# 841 |Bogey's Tree
# 842 |
# 843 |[[Pacific Palisades, Los Angeles|Pacific Palisades, California]], US
# 844 |
# 845 |A tree on the 12th hole at [[Riviera Country Club]], named after [[Humphrey Bogart]].
# 846 |-
# 847 |[[Boyington Oak]]
# 848 |Southern Live Oak (''Quercus virginiana'')
# 849 |[[Mobile, Alabama]], US
# 850 |{{age|1835|2|20}}
# 851 |Reportedly grew from the grave of Charles Boyington in the [[potter's field]] just outside the walls of [[Church Street Graveyard]].  Boyington was tried and executed for the murder of his friend, Nathaniel Frost, on February 20, 1835.  He stated that a tree would spring from his grave as proof of his innocence.<ref>{{cite book |last=Windham |first=Kathryn Tucker |year =1982 |title=Jeffrey's Latest 13: More Alabama Ghosts |publisher=Strode Publishers |location=Huntsville, Alabama |pages=21–32 |isbn=0-8173-0380-4 }}</ref><ref>{{cite web|last=Borland |first=Timothy |title=Mobile Tree Hugger, Part II: The Legend Of The Charles Boyington Oak |publisher=Mobile Bay Magazine |date=June 27, 2011 |url=http://www.mobilebaymag.com/Mobile-Bay/Bay-Buzz/Blog-2011/Mobile-Tree-Hugger-Part-II/ |accessdate=November 9, 2012 |url-status=dead |archiveurl=https://web.archive.org/web/20140512075932/http://www.mobilebaymag.com/Mobile-Bay/Bay-Buzz/Blog-2011/Mobile-Tree-Hugger-Part-II/ |archivedate=May 12, 2014 }}</ref>
# 852 |-
# 853 |[[Buttonball Tree]]
# 854 |[[American sycamore]] (''[[Platanus occidentalis]]'')
# 855 |[[Sunderland, Massachusetts|Sunderland]], [[Massachusetts|MA]], US {{coord|42|28|07.83|N|72|34|42.14|W|type:landmark_region:US|display=inline}}
# 856 | 350–400 (est.)
# 857 |[[File:Buttonball Sycamore - sycamore tree in Sunderland, Massachusetts, May 2012.jpg|100px|left]]Large tourist attraction of the town; the tree is believed to be the largest tree of its kind on the East Coast, or as locals put it, "The widest tree this side of the Mississippi." This tree's measurements are: circumference {{convert|25|ft|m}}; height {{convert|111|ft|m}}; average spread {{convert|140|ft|m}}.
# 858 |-
# 859 |[[Candler Oak Tree]]
# 860 |Oak
# 861 | [[Savannah, Georgia]]
# 862 | ~300
# 863 |[[File:Candler Oak Tree.jpg|100px|left]]A Georgia Landmark and Historic Tree.  It is owned by the [[Savannah Law School]] which protects the tree with fences and security surveillance. The tree serves as the law school's logo.
# 864
# 865 |-
# 866 |[[Chandelier Tree]]
# 867 |[[Coast Redwood]] (''[[Sequoia sempervirens]]'')
# 868 | [[Leggett, California]]
# 869 | ~2,000
# 870 |[[Image:CarRedwoodLeggett01-05.jpg|left|100px]]
# 871 A Coast redwood with a passage for cars cut through.   It is {{convert|276|ft|m|adj = on}} high and {{convert|16|ft|m|adj = on}} ft. in diameter. The name "Chandelier Tree" comes from its unique limbs that resemble a chandelier.
# 872 |-
# 873 |[[Circus Trees]]
# 874 |Various
# 875 |[[California]]
# 876 |
# 877 |A group of trees shaped into artistic forms by arborist [[Axel Erlandson]].
# 878 |-
# 879 |[[Comfort Maple]]
# 880 |[[Sugar maple]] (''[[Acer saccharum]]'')
# 881 |[[Pelham, Ontario]], Canada
# 882 |500
# 883 |A {{convert|24.5|m|ft|adj = on}} tall, approximately 500-year-old Sugar maple.
# 884 |-
# 885
# 886 |[[Council Oak Tree (Hollywood, Florida)|Council Oak Tree]]
# 887 |[[Oak]]
# 888 |[[Hollywood, Florida]]
# 889 |
# 890 |[[image:Council Oak Tree Site on the Hollywood Seminole Indian Reservation 04.JPG|100px|left]]A historic oak tree on the [[Hollywood Seminole Indian Reservation]] that was added to the [[National Register of Historic Places]] in 2012.
# 891 |-
# 892
# 893 |[[Creek Council Oak Tree]]
# 894 |[[White oak]]
# 895 |[[Tulsa, Oklahoma]], US
# 896 |
# 897 |[[image:Creek Council Tree Site.jpg|100px|left]]A large oak tree marking the founding of Tulsa by the Lochapoka Clan of the [[Creek Nation]] in 1836.  Listed in the [[National Register of Historic Places]].
# 898 |-
# 899
# 900 |[[Davie Poplar]]
# 901 |[[Tulip poplar]] (''[[Liriodendron tulipifera]]'')
# 902 |[[Chapel Hill, North Carolina]], US
# 903 |300–375
# 904 |A large tree on the campus of the [[University of North Carolina at Chapel Hill]], it was named in honor of Revolutionary War general and founder of the University [[William Richardson Davie]]. Many legends are associated with the tree.
# 905 |-
# 906
# 907 |[[Devil's Tree]]
# 908 |[[Oak]]
# 909 |[[Bernards Township, New Jersey]], US
# 910 |
# 911 |[[Image:The Devil's Tree.jpg|100px|left]]
# 912 The tree is said to be [[curse]]d.  Local legend says those who damage or disrespect the tree will soon thereafter come to some sort of harm, often in the form of a [[motor vehicle accident|car accident]] or major breakdown as they leave.
# 913 |-
# 914
# 915 |Dewey Oak
# 916 |[[White oak|White oak (''Quercus alba'')]]
# 917 |[[Granby, Connecticut]], US
# 918 | 250–450
# 919 |[[File:Dewey Oak Tree - White Oak, Granby, CT - October 17, 2010.jpg|100px|left]]The Town of [[Granby, Connecticut]] uses an outline of this tree as their town seal, and Connecticut's Notable Trees uses a photo of it on their certificates. This tree was damaged in the [[2011 Halloween nor'easter|October 2011 snow storm (Storm Alfred)]], but it is still alive. This tree's measurements are: circumference {{cvt|20.5|ft}} height {{cvt|78|ft}} average spread {{cvt|129|ft}}.
# 920 |-
# 921 |[[Duffie Oak]]
# 922 |
# 923 |Mobile, [[Alabama]], US
# 924 |300
# ...
# 1452 |approx. 500
# 1453 |The largest American sycamore in the U.S. state of West Virginia until its felling in 2010.
# 1454 |-
# 1455 |Wethersfield Elm
# 1456 |
# 1457 |
# 1458 |
# 1459 |
# 1460 |-
# 1461 |[[Wye Oak]]
# 1462 |[[White oak]]
# 1463 |[[Maryland]], US
# 1464 |
# 1465 |Was the honorary state tree of [[Maryland]], and the largest white oak tree in the United States.
# 1466 |}
# 1467
# 1468 ====Petrified====
# 1469 {|class="wikitable"
# 1470 |-
# 1471 !Name
# 1472 !Species
# 1473 !Location
# 1474 !Age
# 1475 !Notes
# 1476 |-
# 1477 |[[Callixylon tree]]
# 1478 |Archaeopteris
# 1479 |[[Ada, Oklahoma]], U.S.
# 1480 |250,000,000
# 1481 |Discovered on a farm it was the largest example of a petrified tree when it was discovered in 1913. It is estimated to be about 250,000,000 years old. After a 23-year dispute with the Smithsonian Institution in Washington D.C., the tree's fragments were displayed on the East Central Oklahoma State University in March, 1936.<ref>[http://hauntedoklahoma.blogspot.com/2009/05/pontotoc-county.html Haunted Oklahoma: PONTOTOC COUNTY<!-- Bot generated title -->]</ref>
# 1482 |-
# 1483 |[[Ginkgo/Wanapum State Park|Ginkgo Petrified Forest]]
# 1484 |Various
# 1485 |[[Washington (state)|Washington]],  U.S.
# 1486 |
# 1487 |
# 1488 |-
# 1489 |[[Petrified Forest (California)|Petrified Forest]]
# 1490 |Various
# 1491 |[[Sonoma County, California]],  U.S.
# 1492 |
# 1493 |On the [[List of California Historical Landmarks]].
# 1494 |-
# 1495 |[[Petrified Forest National Park]]
# 1496 |Various
# 1497 |[[Arizona]],  U.S.
# 1498 |
# 1499 |
# 1500 |-
# 1501 |[[Mississippi Petrified Forest]]
# 1502 |Various
# 1503 |Near [[Flora, Mississippi]],  U.S.
# 1504 |36 million years old
# 1505 |This forest is believed to have been formed 36 million years ago when fir and maple logs washed down an ancient river channel to the current site where they later became petrified.
# 1506 |}
# 1507
# 1508 ====Other====
# 1509 *[[Anthem Christmas tree]], the tallest [[Christmas tree]] in the United States, erected annually at the [[Outlets at Anthem]] outside [[Phoenix, Arizona]].
# 1510 *[[Boston Christmas Tree]]. Since 1971, given to Boston by the people of [[Nova Scotia]] in thanks for their assistance during the 1917 [[Halifax Explosion]]. Located in the [[Boston Common (park)|Boston Common]].
# 1511 *[[Capitol Christmas Tree]], the tree erected annually on the West Front Lawn of the [[United States Capitol]], in Washington, D.C.
# 1512 *[[Chicago Christmas Tree]], the annual tree located in [[Millennium Park]] in the city of [[Chicago]]. Historically, the tree was located in [[Grant Park (Chicago)|Grant Park]] and [[Daley Plaza]].
# 1513 *[[Grove Christmas Tree]], a 100-foot tree that is lit every year at [[The Grove at Farmer's Market]] in [[Los Angeles, California]].
# 1514 *[[Rockefeller Center Christmas Tree]], a [[Christmas tree]] on display every December in [[Rockefeller Center]], [[New York City]].
# 1515 *[[The Tree of Life (Disney)|The Tree of Life]], a fourteen-story artificial tree in [[Disney's Animal Kingdom]] at [[Walt Disney World]] in [[Florida]].
# 1516
# 1517 ===Central America===
# 1518
# 1519 ====Living====
# 1520 *[[Enterolobium cyclocarpum|Guanacaste]] tree, focal point of [[Guanacaste National Park (Belize)|Guanacaste National Park]], [[Belize]].
# 1521
# 1522 ===South America===
# 1523
# 1524 ====Living====
# 1525 {|class="wikitable"
# 1526 |-
# 1527 !Name
# 1528 !Species
# 1529 !Location
# 1530 !Age
# 1531 !Notes
# 1532 |-
# 1533 |[[Árbol del Tule]]
# 1534 |[[Montezuma Cypress]] (''[[Taxodium mucronatum]]'')
# 1535 |[[Santa María del Tule]], [[Oaxaca]], [[Mexico]]<br /><small>{{coord|17|02|47.4|N|96|38|10|W|name=Árbol del Tule}}</small>
# 1536 | 1,433–1,600 years (est)
# 1537 |[[File:ArbordeTuleOaxaca MX.jpg|left|100px]]The stoutest tree in the world. Its trunk has a [[circumference]] of {{convert|42.0|m|ft|abbr=on}}, equating to a [[diameter]] of {{convert|14.05|m|ft|abbr=on}}. In 2001 it was placed on a [[UNESCO]] tentative list of World Heritage Sites.
# 1538 |-
# 1539 |El Arbolito (The Little Tree)
# 1540 |
# 1541 |[[Managua]], [[Nicaragua]]
# 1542 |
# 1543 |A traditional landmark used to give directions in Managua.<ref>{{cite web|url=https://www.elnuevodiario.com.ni/nacionales/managua/429925-arbolito-madrono-que-es-referencia-testigo/|title=El Arbolito, un madroño que es referencia y testigo|date=5 June 2017|last1=González|first1=Mauricio|publisher=El Nuevo Diario}}</ref>
# 1544 |-
# 1545 |[[Gloomy Night Tree]] ([[Árbol de la Noche Triste]])
# 1546 |
# 1547 |[[Tlacopan|Tacuba]], [[Mexico City]], [[Mexico]]
# 1548 |
# 1549 | An old tree where [[Hernán Cortés]] allegedly mourned after being expelled from [[Tenochtitlan]] before taking the city by force.
# 1550 |-
# 1551 |[[Cashew of Pirangi]]
# 1552 |[[Cashew]]
# 1553 | {{coord|5.978657|S|35.123372|W|name=Cashew of Pirangi}}
# 1554 |
# 1555 | major tourist attraction in [[Natal, Rio Grande do Norte|Natal]], [[Brazil]]. Believed to be the biggest cashew in the world.<br/><small></small><small></small>
# 1556 |-
# 1557 |[[Cajueiro da Praia|Cashew of A Praia]]
# 1558 |[[Cashew]]
# 1559 | [[Cajueiro da Praia]]
# 1560 |
# 1561 |
# 1562 |-
# 1563 |Gran Abuelo
# 1564 | ''[[Fitzroya|Fitzroya cupressoides]]''
# 1565 | [[Alerce Costero National Park]], Chile
# 1566 | ca. 3600<ref>{{cite journal|title=A 3620-Year Temperature Record from Fitzroya cupressoides Tree Rings in Southern South America|first1=Antonio|last1=Lara|first2=Ricardo|last2=Villalba|author-link2=Ricardo Villalba|journal=Science |date=21 May 1993 |volume=260|issue=5111|pages=1104–1106|doi=10.1126/science.260.5111.1104|pmid=17806339}}</ref><ref>{{cite web|url=http://www.conaf.cl/parques/parque-nacional-alerce-costero/|title=Parque Nacional Alerce Costero|website=Conaf.cl|publisher=[[National Forest Corporation (Chile)|National Forest Corporation]]|accessdate=16 March 2014|language=Spanish|url-status=dead|archiveurl=https://web.archive.org/web/20141006104430/http://www.conaf.cl/parques/parque-nacional-alerce-costero/|archivedate=6 October 2014}}</ref>
# 1567 |
# 1568 |}
# 1569
# 1570 ====Historical====
# 1571 {|class="wikitable"
# 1572 |-
# 1573 !Name
# 1574 !Species
# 1575 !Location
# 1576 !Age
# 1577 !Notes
# 1578 |-
# 1579 |[[Arbol de Guacari]]
# 1580 |[[Samanea saman]]
# 1581 |[[Guacarí]], Colombia
# 1582 |
# 1583 |Famous tree engraved in the $500 coin
# 1584 |}
# 1585
# 1586 ===Oceania===
# 1587
# 1588 ====Living====
# 1589 {|class="wikitable"
# 1590 |-
# 1591 !Name
# 1592 !Species
# 1593 !Location
# 1594 !Age
# 1595 !Notes
# 1596
# 1597 |-
# 1598 |[[Banyan tree in Lahaina|The Banyan Tree]]
# 1599 |Banyan (''Ficus benghalensis'')
# 1600 |[[Lahaina, Hawaii]]<br/><small>{{coord|20.886111|N|156.674722|W|name=The Banyan Tree}}</small>
# 1601 | ~150
# 1602 | Planted in the 1860s, it covers an entire city block in the waterfront in Lahaina.
# 1603 |-|[[Dave Evans Bicentennial Tree]]
# 1604 |[[Karri]] (''[[Eucalyptus diversicolor]]'')
# 1605 |near [[Pemberton, Western Australia]]<br><small>{{coord|34|29|35|S|115|58|22|E|name=Dave Evans Bicentennial Tree}}</small>
# 1606 |
# 1607 |Forest fire lookout tree with accessible platform,
# 1608
# 1609 |-
# 1610 |[[Diamond Tree]]
# 1611 |Karri (''Eucalyptus diversicolor'')
# 1612 |10&nbsp;km from [[Manjimup, Western Australia]]
# 1613 |
# 1614 |Forest fire lookout tree with accessible wooden platform (52 m high).
# 1615 |-
# 1616 |[[Dig tree|Dig Tree]]
# 1617 |
# 1618 |[[Cooper Creek]], [[Queensland]], Australia
# 1619 |
# 1620 |[[File:Burke and Wills dig tree 2.JPG|100px|left]]Used as a marker by members of the ill-fated [[Burke and Wills expedition]].
# 1621 |-
# 1622 |[[El Grande (tree)|El Grande]]
# 1623 |
# 1624 |
# 1625 |
# 1626 |At one time, the world's largest flowering plant.
# 1627 |-
# 1628 |Lone Gum
# 1629 |[[Eucalyptus coolabah|Coolabah]] (''[[Eucalyptus coolabah]]'')
# 1630 |[[Simpson Desert]], [[South Australia]], Australia
# 1631 |
# 1632 |A solitary Coolabah, far from the nearest watercourse, normally grows in heavy clay soils. There is no other tree of its kind in the region and how it came to be there remains a mystery.<ref>[http://www.environment.sa.gov.au/parks/Find_a_park/Browse_by_region/Flinders_Ranges_Outback/Simpson_Desert_Conservation_Park_and_Regional_Reserve/Attractions Attractions - Department of Environment, Water and Natural Resources (DEWNR)<!-- Bot generated title -->] {{webarchive|url=https://archive.today/20131008025803/http://www.environment.sa.gov.au/parks/Find_a_park/Browse_by_region/Flinders_Ranges_Outback/Simpson_Desert_Conservation_Park_and_Regional_Reserve/Attractions |date=2013-10-08 }}</ref>
# 1633 |-
# 1634 |[[Gloucester Tree]]
# 1635 |Karri (''Eucalyptus diversicolor'')
# 1636 |[[Gloucester National Park]] [[Pemberton, Western Australia]]
# 1637 |
# 1638 | [[File:ClimbingTheGloucesterTree_2005_SeanMcClean.jpg|left|100px]] [[Western Australia]]'s most famous Karri tree, with accessible aluminium platform, in (61 m high).
# 1639 |-
# 1640 |[[Old Jarrah Tree]]
# 1641 |[[Jarrah]] (''[[Eucalyptus marginata]]'')
# 1642 |[[Perth, Western Australia]]
# 1643 |
# 1644 |
# 1645 |-
# 1646 |King Jarrah
# 1647 |Jarrah (''Eucalyptus marginata'')
# 1648 |[[Manjimup, Western Australia]]
# 1649 |
# 1650 |Giant Jarrah saved by the National Trust upon overhearing two foresters bragging at the pub about a mighty tree they were going to chop down the next morning.{{citation needed|date=April 2012}}
# 1651 |-
# 1652 |[[Curtain Fig Tree]]
# 1653 |[[Strangler Fig]]
# 1654 |Near [[Cairns]], Australia.
# 1655 |
# 1656 |One of the largest trees in North Queensland. The roots dangle 15 metres to the ground to create a curtain-like effect.
# 1657 |-
# 1658 |Cathedral Fig Tree<ref>{{cite web|url=http://www.queensland.com/attraction/cathedral-fig-tree |title=Cathedral Fig Tree |publisher=Queensland}}</ref><ref>{{cite web|url=http://www.nprsr.qld.gov.au/parks/danbulla/about.html |title=About Danbulla|publisher=Queensland}}</ref>
# 1659 |[[Strangler fig]]
# 1660 |[[Yungaburra]], Tablelands Area, Queensland, Australia
# 1661 |500
# 1662 |"A gigantic 500 year old strangler tree", like the Curtain Fig Tree.  Another massive ''Ficus virens'' in the Danbulla Forest.
# 1663 |-
# 1664 |[[Tane Mahuta]] ('Lord of the Forest')
# 1665 |[[Kauri]]
# 1666 |[[Northland Region]], [[New Zealand]]
# 1667 |1,250–2,500
# 1668 |[[File:00_29_0496_Waipoua_Forest_NZ_-_Kauri_Baum_Tane_Mahuta.jpg|left|100px]]It is estimated to be between 1,250 and 2,500 years old.
# 1669 |-
# 1670 |[[Te Matua Ngahere]] ('Father of the Forest')
# 1671 |Kauri
# 1672 |Northland Region, New Zealand.
# 1673 |
# 1674 |
# 1675 |-
# 1676 |[[Bland Oak]]
# 1677 |[[Quercus virginiana]]
# 1678 |[[Sydney]], Australia
# 1679 |>170
# 1680 |[[File:Blandoaktree.jpg|left|100px]]Planted in 1842 by [[William Bland]], it is one of the largest and oldest trees in Sydney. Was the largest in Australia until 1940 when a storm struck parts of it.<ref name="mobbaymag">{{cite web |last=Boulous |first=Chris |title=Nothing Bland about our Oak tree |work=Fairfield City Champion|publisher=[[Fairfax Media]]|date=April 20, 2018 |url=https://www.fairfieldchampion.com.au/story/5354072/nothing-bland-about-our-oak-tree/#slide=2 |accessdate=August 29, 2018}}</ref>
# 1681 |-
# 1682 |[[Boab Prison Tree, Derby]]
# 1683 |[[Adansonia gregorii|Boab tree]] (''[[Adansonia gregorii]]'')
# 1684 | South of [[Derby, Western Australia]]
# 1685 |
# 1686 |[[File:A213, Derby, Western Australia, Prison Boab tree, 2007.JPG|left|100px]]Was used as a prison for [[Indigenous Australian]] prisoners on their way to Derby for sentencing.
# 1687 |-
# 1688 |[[Boab Prison Tree, Wyndham]]
# 1689 |Boab tree (''Adansonia gregorii'')
# 1690 |[[Wyndham, Western Australia]]
# 1691 |
# 1692 | Also used as a prison.
# 1693 |-
# 1694 |[[Centurion (tree)|Centurion]]
# 1695 |''[[Eucalyptus regnans]]''
# 1696 | [[Tasmania]], Australia
# 1697 |
# 1698 | [[File:Centurion_tree_99.82.jpg|100px|left]]At 99.6 metres, it is tallest known eucalypt and the tallest known [[angiosperm]] in the world, second tallest tree species in the world.
# 1699 |-
# 1700 |The Grandis
# 1701 |''[[Eucalyptus grandis|Eucalyptus Grandis]] (Flooded Gum)''
# 1702 | Near [[Bulahdelah]], [[New South Wales]], Australia
# 1703 | >400
# 1704 | At 76.2 metres tall though some sources claim that its past height was 84 metres tall. The Grandis is widely regarded as the tallest tree in New South Wales, and one of the oldest, being over 400 years old.
# 1705 |}
# 1706
# 1707 ====Historical====
# 1708 *The [[Tree of Knowledge (Australia)|Tree of Knowledge]] at [[Barcaldine, Queensland]]  under which the [[Australian Labor Party]] was traditionally founded. In an act of vandalism, the tree was poisoned and was eventually declared dead in October 2006.
# 1748
# 1749 ==External links==
# 1750 *[https://web.archive.org/web/20070429233415/http://www.platial.com/tracy_the_astonishing/map/20992 Map of this list] (in progress)
# 1751 *[http://www.nbcnews.com/id/18178917 World’s first tree reconstructed] 385 million-year-old tree
# 1752
# 1753 {{DEFAULTSORT:Trees}}
# 1754 [[Category:Individual trees|*]]
# 1755 [[Category:Lists of trees| ]]
# 1756 [[Category:Lists of fictional things]]
# 1757
# 1758 [[de:Liste markanter und alter Baumexemplare]]
# 1759 [[fr:Liste des arbres remarquables]]
# 1760 [[lt:Sąrašas:Išskirtiniai medžiai]]
# 1761 [[hu:Híres fák listája]]
# 1762 [[ru:Список знаменитых и легендарных деревьев]]

# %%
items = []
descriptions = []
with open(topic + '_error_log.txt', 'w+', encoding="utf-8") as filepath:
    for index, line in enumerate(lines[77:291]):
        
        if re.match('\*\s*\[\[', line[0:5]):
            #print("%%%Match%%%")
            #print(line)
            try:
                line = re.sub(r'\<ref.*?\</ref>|\<ref.*\/>', '', line)
                
            except:
                topic_error_line = f"{topic} line sub parse error"
                item_line = f"{str(index)}, {line}"
                print(log_error(topic_error_line, item_line))
                
            try:
                
                item = re.search(r'\[\[(.*?)\]\]', line).group(1)
                
            except:
                topic_error_line = f"{topic} item parse error"
                item_line = f"{str(index)}, {line}"
                print(log_error(topic_error_line, item_line))
                
            try:
                
                description = re.search(r'\]\]\:*(.*)', line).group(1)
                
                
            except:
                topic_error_line = f"{topic} description parse error"
                item_line = f"{str(index)}, {line}"
                print(log_error(topic_error_line, item_line))
                
            items.append(item)
            descriptions.append(description)
        else:
            continue
            #print("%%%No%%%")
            #print(line)

# %%
items = [re.sub(r'\:wiktionary\:', '', item) for item in items]
items = [re.sub(r'\|.*', '', item) for item in items]
items

# %%
item_infos = []
for index, title in enumerate(items):
    with open(topic + '_error_log.txt', 'w+', encoding="utf-8") as filepath:
        
        url = 'https://en.wikipedia.org/w/index.php?title=' + title + '&action=info'

        #print(url)
        response = requests.get(url)
        doc = lxml.html.fromstring(response.content)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        try:
            # info_table = doc.xpath('//*[@class="wikitable mw-page-info"]')[0]
            watchers = doc.xpath('//*[@id="mw-pageinfo-watchers"]')[0][1].text
            
        except:
            topic_error_line = f"watchers parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            watchers = "#error#"

        try:
            redirects = doc.xpath('//*[contains(text(),"redirects")]/../../td')[1].text
            #redirects = doc.xpath('//*[contains(text(),"redirects")]/parent::node()/parent::node()')
            #redirects = doc.xpath('/html/body/div[3]/div[3]/div[3]/table[2]/tr[9]/td')[1].text
            
        except:
            topic_error_line = f"redirects parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            redirects = "#error#"
             
        try:
            views = doc.xpath('//*[@id="mw-pvi-month-count"]/td/div')[0].text
            
        except:
            topic_error_line = f"views parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            views = "#error#"        
        
        try:
            edits = doc.xpath('//*[@id="mw-pageinfo-edits"]/td')[1].text
            #edits = doc.xpath('/html/body/div[3]/div[3]/div[3]/table[4]/tr[5]/td')[1].text
    
        except:
            topic_error_line = f"edits parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            edits = "#error#"
        
        item_infos.append({
            topic: title,
            'watchers': watchers,
            'redirects': redirects,
            'views': views,
            'edits': edits
        })

# %%
# transfer item_infos to json file
import json
with open(topic + '_infos.json', 'w') as filepath:
    json.dump(item_infos, filepath)

# %%
error_items = [item[topic] for item in item_infos if item['views'] == '#error#']

for index, title in enumerate(error_items):
    with open('info_error_log.txt', 'w+', encoding="utf-8") as filepath:
        #print(title)
        del_idx = 0
        for index, item in enumerate(item_infos):
            if item[topic] == title:
                del_idx = index
                #del item_infos[index]
        #print(item)
        
        
        if re.match(r'\W*', title):
            print('%%%')
            search = re.search(r'(\w+)?', title).group(1)
            print(search)
            title = search
        
        print(title)
        
        url = 'https://en.wikipedia.org/w/index.php?title=' + title + '&action=info'

        #print(url)
        response = requests.get(url)
        doc = lxml.html.fromstring(response.content)
        soup = BeautifulSoup(response.content, 'html.parser')
  
        try:
            # info_table = doc.xpath('//*[@class="wikitable mw-page-info"]')[0]
            watchers = doc.xpath('//*[@id="mw-pageinfo-watchers"]')[0][1].text
            
        except:
            topic_error_line = f"watchers parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            watchers = "#error#"

        try:
            redirects = doc.xpath('//*[contains(text(),"redirects")]/../../td')[1].text
            #redirects = doc.xpath('//*[contains(text(),"redirects")]/parent::node()/parent::node()')
            #redirects = doc.xpath('/html/body/div[3]/div[3]/div[3]/table[2]/tr[9]/td')[1].text
            
        except:
            topic_error_line = f"redirects parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            redirects = "#error#"
             
        try:
            views = doc.xpath('//*[@id="mw-pvi-month-count"]/td/div')[0].text
            
        except:
            topic_error_line = f"views parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            views = "#error#"        
        
        try:
            edits = doc.xpath('//*[@id="mw-pageinfo-edits"]/td')[1].text
            #edits = doc.xpath('/html/body/div[3]/div[3]/div[3]/table[4]/tr[5]/td')[1].text
    
        except:
            topic_error_line = f"edits parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            edits = "#error#"
            
        item_infos[del_idx] = {
            topic: title,
            'watchers': watchers,
            'redirects': redirects,
            'views': views,
            'edits': edits
        }

# %%
with open('mineral_infos.json', 'r') as jfile:
    data=jfile.read()

# parse file
item_infos = json.loads(data)

# %%
_item_infos = item_infos
len(_item_infos)

# %%
#item_infos = [{item['views']: int(item['views'].replace(',', ''))} for item in item_infos]
for index, item in enumerate(_item_infos):
    if item['views'] != '#error#':
        if item['watchers'] == 'Fewer than 30 watchers':
            item['watchers'] = '29'
        item['views'] = int(item['views'].replace(',', ''))
        item['watchers'] = int(item['watchers'].replace(',', ''))
        #item['edits'] = int(item['edits'].replace(',', ''))

# %%
by_views = sorted(_item_infos, key=lambda k : k['views'], reverse=True)
for index, item in enumerate(by_views):
    item['view_rank'] = index

# %%
by_edits = sorted(_item_infos, key=lambda k : k['edits'], reverse=True)
for index, item in enumerate(by_edits):
    item['edit_rank'] = index

# %%
by_watchers = sorted(_item_infos, key=lambda k : k['watchers'], reverse=True)
for index, item in enumerate(by_watchers):
    item['watcher_rank'] = index

# %%
for item in _item_infos:
    #item['total_rank'] = (item['view_rank'] + item['edit_rank'] + item['watcher_rank']) / 3
    item['total_rank'] = (item['view_rank'] + item['watcher_rank']) / 2

# %%
by_total = sorted(_item_infos, key=lambda k : k['total_rank'], reverse=True)

# %%
dedupe = []
for item in by_total:
    if item[topic] not in dedupe:
        dedupe.append(item[topic])

# %%
start = 0
limit = 44
top_items = dedupe[start:limit]

# %%
with open(f"{topic}_{limit}.txt", 'w+', encoding="utf-8") as fp:
    for item in top_items:
        fp.write(item + '\n')

# %%
min_df = pd.DataFrame(_item_infos)
min_df.head()
min_df.sort_values(by=['total_rank'], ascending=False).head(100)

# %%
min_df = pd.DataFrame(_item_infos)
min_df.head()
min_df.sort_values(by=['views'], ascending=False).head(100)

# %%
min_df.sort_values(by=['watchers'], ascending=False).head(100)

# %%
min_df.sort_values(by=['edits'], ascending=False).head(100)

# %%
for index, line in enumerate(lines[0:30]):
    print(index, line)
# Out:
# 0 {{distinguish|List of trees and shrubs by taxonomic family}}
# 1 The following is a '''list of notable trees''' from around the world. Trees listed here are regarded as important or specific by their historical, national, locational, natural or mythological context.  The list includes actual [[tree]]s located throughout the world, as well as [[#Mythological and religious|trees from myths]].
# 2
# 3 {{Dynamic list}}
# 4 {{GeoGroup}}
# 5 {{TOC left}}
# 6
# 7 ==Real forests and individual trees==
# 8
# 9 ===Africa===
# 10
# 11 ====Living====
# 12 {| class="wikitable"
# 13 |-
# 14 !Name
# 15 !Species
# 16 !Location
# 17 !Age (years)
# 18 !Notes
# 19 |-
# 20 |[[Lost Tree]]
# 21 |[[Acacia]]
# 22 |[[Sahara desert]] <br/><small> {{Coord|20.645|N|11.249|E|name=Lost Tree}}</small>
# 23 | -
# 24 |A very isolated tree and important landmark
# 25 |-
# 26 |[[Cotton Tree (Sierra Leone)|The Cotton Tree]]
# 27 |[[Ceiba pentandra|Kapok]] (''[[Ceiba pentandra]]'')
# 28 |[[Freetown]], [[Sierra Leone]] <br/><small>{{Coord|8.4872|N|13.2356|W|name=The Cotton Tree}}
# 29 | -

# %%
# parse 
#       WikiTable
# data


with open('error_lines.txt', 'w+', encoding="utf-8") as filepath:
    for index, line in enumerate(lines):
        if re.match('==\w', line[0:5]):
            current_grandparent = line.strip().replace("=", "")
        elif re.match('===\w', line[0:5]):
            sec = line.strip().replace("=", "")
        elif re.match('====\w', line[0:5]):

# %%
# parse 
#       WikiText
# data

lines = textDATA["parse"]["wikitext"]["*"].split('\n')[3:-10] # [::-1]
this_sec = {}
sec = ''
sub_sec = ''
with open('error_lines.txt', 'w+', encoding="utf-8") as filepath:
    for index, line in enumerate(lines):
        if index == 23:
            print(line)
        if re.match('==\w', line[0:3]):
            sec = line.strip().replace("=", "")
            if len(this_sec) > 0:
                section_dict[secs[secs.index(sec) - 1]] = this_sec
            this_sec = {}
        if type(section_dict[sec]).__name__ == 'list':
            if re.match('\*\[\[', line[0:3]):
                try:
                    poet = re.search(r'\[\[(.*?)\]\]', line).group(1)
                    #print(poet)

                except:
                    print("##########################")
                    print("#### poet parse error ####")
                    print(poet_method, index, line)
                    filepath.write(line + '\n')
                    print(line[-2:])
                    print("##########################")

                date_m = re.search('\((.*)\)', line)

                try:
                    date = date_m.group(0)
                except:
                    print("##########################")
                    print("#### date parse error ####")
                    print(index, line)
                    filepath.write(line + '\n')
                    date = ""
                    print("##########################")
                try:
                    # description = re.search('\)*,*.*', line).group(1)
                    # description = re.search('\),+.*', line).group(1)
                    # description = re.search('\]\s.*\)(.*)', line).group(1)
                    description = re.search('\]\](\)*,*.*)', line).group(1)
                except Exception as e:
                    print("#################################")
                    print("#### description parse error ####")
                    print(e)
                    print(index, line)
                    filepath.write(line + '\n')
                    print("#################################")
                # print(this_sec)
                # print(sub_sec)
                section_dict[sec].append({
                    'poet': poet,
                    'date': date,
                    'description': description
                })
        else:
            #print(sec)
            if re.match('===\w', line[0:4]):
                sub_sec = line.strip().replace("=", "")
                #print(sub_sec)
            if line.strip().replace("=", "") in section_dict[sec]:
                #print(sub_sec)
                this_sec[sub_sec] = []
            if sub_sec != '':
                if re.match('\*\[\[', line[0:3]):
                    try:
                        poet = re.search(r'\[\[(.*?)\]\]', line).group(1)
                        #print(poet)
                    except:
                        print("##########################")
                        print("#### poet parse error ####")
                        print(index, line)
                        filepath.write(line + '\n')
                        print(line[-2:])
                        print("##########################")
                    date_m = re.search('\((.*)\)', line)
                    try:
                        date = date_m.group(0)
                    except Exception as e:
                        print("##########################")
                        print("#### date parse error ####")
                        print(e)
                        print(index, line)
                        filepath.write(line + '\n')
                        date = ""
                        print("##########################")
                    try:
                        # description = re.search('\)*,*.*', line).group(1)
                        # description = re.search('\),+.*', line).group(0)
                        # description = re.search('\]\s.*\)(.*)', line).group(0)
                        description = re.search('\]\](\)*,*.*)', line).group(1)

                    except Exception as e:
                        print("#################################")
                        print("#### description parse error ####")
                        print(e)
                        print(index, line)
                        filepath.write(line + '\n')
                        description = ""
                        print("#################################")

                    this_sec[sub_sec].append({
                        'poet': poet,
                        'date': date,
                        'description': description
                    })
