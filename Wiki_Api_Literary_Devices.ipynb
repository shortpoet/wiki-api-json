# %%
import requests
from pprint import pprint
import re
import lxml.html
from bs4 import BeautifulSoup
import pandas as pd

# %%
def log_error(line1, line2):
    _line1 = str(line1)
    _line2 = str(line2)
    diff = 0
    chars1 = len(_line1) + 10
    chars2 = len(_line2) + 10
    if chars1 > chars2:
        diff = chars1 - chars2
        if diff % 2 != 0:
            diff = int(diff - .5)
            _line2 = '# ' + _line2
        else:
            _line2 = ' ' + _line2
        main_hashes = ''.join(['#' for i in range(chars1)])
        hashes = ''.join(['#' for i in range(int(diff/2)+4)])
        log_line = (f"{main_hashes}\n"
                    f"#### {_line1} ####\n"
                    f"{hashes}{_line2} {hashes}\n"                    
                    f"{main_hashes}\n")
        return(log_line)
   
    elif chars2 > chars1:
        diff = chars2 - chars1
        if diff % 2 != 0:
            diff = int(diff - .5)
            _line1 = '# ' + _line1
        else:
            _line1 = ' ' + _line1
        main_hashes = ''.join(['#' for i in range(chars2)])
        hashes = ''.join(['#' for i in range(int(diff/2)+4)])
        log_line = (f"{main_hashes}\n"
                    
                    f"{hashes}{_line1} {hashes}\n"
                    f"#### {_line2} ####\n"
                    f"{main_hashes}\n")
        return(log_line)
        
    else:
        hashes = '####'
        main_hashes = ''.join(['#' for i in range(chars2)])
        log_line = (f"{main_hashes}\n"
                    f"#### {_line1} ####\n"
                    f"{hashes} {_line2} {hashes}\n"
                    f"{main_hashes}\n")
        return(log_line)

# %%
# init session 
S = requests.Session()

# set URL
URL = "https://en.wikipedia.org/w/api.php"

# %%
page_id = "77691"
topic = 'rhetoric'

# %%
# get sections
PARAMS = {
    "action": "parse",
    "pageid": page_id,
    "format": "json",
    "prop": "sections"
}

sectionsR = S.get(url=URL, params=PARAMS)
sectionDATA = sectionsR.json()

# %%
sectionDATA
# Out:
# {'parse': {'title': 'Figure of speech',
#   'pageid': 77691,
#   'sections': [{'toclevel': 1,
#     'level': '2',
#     'line': 'Four rhetorical operations',
#     'number': '1',
#     'index': '1',
#     'fromtitle': 'Figure_of_speech',
#     'byteoffset': 1676,
#     'anchor': 'Four_rhetorical_operations'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'Examples',
#     'number': '2',
#     'index': '2',
#     'fromtitle': 'Figure_of_speech',
#     'byteoffset': 4396,
#     'anchor': 'Examples'},
#    {'toclevel': 2,
#     'level': '3',
#     'line': 'Schemes',
#     'number': '2.1',
#     'index': '3',
#     'fromtitle': 'Figure_of_speech',
#     'byteoffset': 8510,
#     'anchor': 'Schemes'},
#    {'toclevel': 2,
#     'level': '3',
#     'line': 'Tropes',
#     'number': '2.2',
#     'index': '4',
#     'fromtitle': 'Figure_of_speech',
#     'byteoffset': 21974,
#     'anchor': 'Tropes'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'See also',
#     'number': '3',
#     'index': '5',
#     'fromtitle': 'Figure_of_speech',
#     'byteoffset': 33920,
#     'anchor': 'See_also'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'References',
#     'number': '4',
#     'index': '6',
#     'fromtitle': 'Figure_of_speech',
#     'byteoffset': 34089,
#     'anchor': 'References'},
#    {'toclevel': 2,
#     'level': '3',
#     'line': 'Citations',
#     'number': '4.1',
#     'index': '7',
#     'fromtitle': 'Figure_of_speech',
#     'byteoffset': 34106,
#     'anchor': 'Citations'},
#    {'toclevel': 2,
#     'level': '3',
#     'line': 'Sources',
#     'number': '4.2',
#     'index': '8',
#     'fromtitle': 'Figure_of_speech',
#     'byteoffset': 34142,
#     'anchor': 'Sources'},
#    {'toclevel': 1,
#     'level': '2',
#     'line': 'External links',
#     'number': '5',
#     'index': '9',
#     'fromtitle': 'Figure_of_speech',
#     'byteoffset': 35056,
#     'anchor': 'External_links'}]}}

# %%
sections = [sec['anchor'] for sec in sectionDATA["parse"]["sections"]]

# %%
# create section list filtering out non-data sections
filt = [
    #'References',
    'See_also',
    'External_links'
]

incl = [
    'Schemes',
    'Tropes'
]

# sec_list = [sec for sec in sectionDATA["parse"]["sections"] if not sec['anchor'] in filt]
sec_list = [sec for sec in sectionDATA["parse"]["sections"] if sec['anchor'] in incl]


len(sec_list)
# Out:
# 2

# %%
# create nested section_dict dictionary from section list based on toclevel
# adding 'Z' section by hand consider refactor
section_dict = {}
is_new_parent = True
parent = ''
for i in range(len(sec_list) - 1):
    if sec_list[i]['toclevel'] == 1 and sec_list[i + 1]['toclevel'] == 1:
        section_dict[sec_list[i]['anchor']] = []
    elif sec_list[i]['toclevel'] == 1 and sec_list[i + 1]['toclevel'] == 2:
        section_dict[sec_list[i]['anchor']] = {}
        parent = sec_list[i]['anchor']
    elif sec_list[i]['toclevel'] == 2:
        section_dict[parent][sec_list[i]['anchor']] = []
section_dict['Z'] = []
#section_dict

# %%
# make list of top level sections
secs = [sec for sec, val in section_dict.items()]

# %%
# make section dict if no nested sections
section_dict = {sec['anchor']:[] for sec in sec_list}

# %%
# get links
PARAMS = {
    "action": "parse",
    "pageid": page_id,
    "format": "json",
    "prop": "links"
}

linkR = S.get(url=URL, params=PARAMS)
linkDATA = linkR.json()

pprint(linkDATA["parse"]["links"])
# Out:
# [{'*': 'Figures of speech', 'exists': '', 'ns': 0},
#  {'*': 'Accismus', 'exists': '', 'ns': 0},
#  {'*': 'Accumulation (figure of speech)', 'exists': '', 'ns': 0},
#  {'*': 'Action (narrative)', 'exists': '', 'ns': 0},
#  {'*': 'Action fiction', 'exists': '', 'ns': 0},
#  {'*': 'Adnomination', 'exists': '', 'ns': 0},
#  {'*': 'Adventure fiction', 'exists': '', 'ns': 0},
#  {'*': 'Adynaton', 'exists': '', 'ns': 0},
#  {'*': 'Allegory', 'exists': '', 'ns': 0},
#  {'*': 'Alliteration', 'exists': '', 'ns': 0},
#  {'*': 'Allusion', 'exists': '', 'ns': 0},
#  {'*': 'Alternate history', 'exists': '', 'ns': 0},
#  {'*': 'Anacoenosis', 'exists': '', 'ns': 0},
#  {'*': 'Anacoluthon', 'exists': '', 'ns': 0},
#  {'*': 'Anadiplosis', 'exists': '', 'ns': 0},
#  {'*': 'Analogy', 'exists': '', 'ns': 0},
#  {'*': 'Anaphora (rhetoric)', 'exists': '', 'ns': 0},
#  {'*': 'Anapodoton', 'exists': '', 'ns': 0},
#  {'*': 'Anastrophe', 'exists': '', 'ns': 0},
#  {'*': 'Antagonist', 'exists': '', 'ns': 0},
#  {'*': 'Antanaclasis', 'exists': '', 'ns': 0},
#  {'*': 'Anthimeria', 'exists': '', 'ns': 0},
#  {'*': 'Anthropomorphism', 'exists': '', 'ns': 0},
#  {'*': 'Anti-climax (figure of speech)', 'exists': '', 'ns': 0},
#  {'*': 'Antihero', 'exists': '', 'ns': 0},
#  {'*': 'Antimetabole', 'exists': '', 'ns': 0},
#  {'*': 'Antiphrasis', 'exists': '', 'ns': 0},
#  {'*': 'Antithesis', 'exists': '', 'ns': 0},
#  {'*': 'Antonomasia', 'exists': '', 'ns': 0},
#  {'*': 'Aphorism', 'exists': '', 'ns': 0},
#  {'*': 'Aphorismus', 'exists': '', 'ns': 0},
#  {'*': 'Apologia', 'exists': '', 'ns': 0},
#  {'*': 'Apophasis', 'exists': '', 'ns': 0},
#  {'*': 'Aporia', 'exists': '', 'ns': 0},
#  {'*': 'Aposiopesis', 'exists': '', 'ns': 0},
#  {'*': 'Apostrophe (rhetoric)', 'exists': '', 'ns': 0},
#  {'*': 'Apposition', 'exists': '', 'ns': 0},
#  {'*': 'Appositive', 'exists': '', 'ns': 0},
#  {'*': 'Archaism', 'exists': '', 'ns': 0},
#  {'*': 'Archenemy', 'exists': '', 'ns': 0},
#  {'*': 'Assonance', 'exists': '', 'ns': 0},
#  {'*': 'Asteismus', 'exists': '', 'ns': 0},
#  {'*': 'Asyndeton', 'exists': '', 'ns': 0},
#  {'*': 'Audience', 'exists': '', 'ns': 0},
#  {'*': 'Author', 'exists': '', 'ns': 0},
#  {'*': 'Auxesis (figure of speech)', 'exists': '', 'ns': 0},
#  {'*': 'Backstory', 'exists': '', 'ns': 0},
#  {'*': 'Bathos', 'exists': '', 'ns': 0},
#  {'*': 'Burlesque metaphor', 'exists': '', 'ns': 0},
#  {'*': 'Cacophony', 'exists': '', 'ns': 0},
#  {'*': 'Cantastoria', 'exists': '', 'ns': 0},
#  {'*': 'Catachresis', 'exists': '', 'ns': 0},
#  {'*': 'Cataphora', 'exists': '', 'ns': 0},
#  {'*': 'Character (arts)', 'exists': '', 'ns': 0},
#  {'*': 'Character arc', 'exists': '', 'ns': 0},
#  {'*': 'Character flaw', 'exists': '', 'ns': 0},
#  {'*': 'Characterization', 'exists': '', 'ns': 0},
#  {'*': "Chekhov's gun", 'exists': '', 'ns': 0},
#  {'*': 'Chiasmus', 'exists': '', 'ns': 0},
#  {'*': 'Chris Baldick', 'exists': '', 'ns': 0},
#  {'*': 'Circumlocution', 'exists': '', 'ns': 0},
#  {'*': 'City of Westminster', 'exists': '', 'ns': 0},
#  {'*': 'Classical rhetoric', 'exists': '', 'ns': 0},
#  {'*': 'Classification (literature & grammar)', 'exists': '', 'ns': 0},
#  {'*': 'Cliché', 'exists': '', 'ns': 0},
#  {'*': 'Cliffhanger', 'exists': '', 'ns': 0},
#  {'*': 'Climax (figure of speech)', 'exists': '', 'ns': 0},
#  {'*': 'Climax (narrative)', 'exists': '', 'ns': 0},
#  {'*': 'Comic novel', 'exists': '', 'ns': 0},
#  {'*': 'Comics', 'exists': '', 'ns': 0},
#  {'*': 'Conflict (narrative)', 'exists': '', 'ns': 0},
#  {'*': 'Congeries', 'exists': '', 'ns': 0},
#  {'*': 'Conversion (word formation)', 'exists': '', 'ns': 0},
#  {'*': 'Correctio', 'exists': '', 'ns': 0},
#  {'*': 'Correlative verse', 'exists': '', 'ns': 0},
#  {'*': 'Creative nonfiction', 'exists': '', 'ns': 0},
#  {'*': 'Crime fiction', 'exists': '', 'ns': 0},
#  {'*': 'Denominatio', 'exists': '', 'ns': 0},
#  {'*': 'Deus ex machina', 'exists': '', 'ns': 0},
#  {'*': 'Deuteragonist', 'exists': '', 'ns': 0},
#  {'*': 'Diacope', 'exists': '', 'ns': 0},
#  {'*': 'Dialogue in writing', 'exists': '', 'ns': 0},
#  {'*': 'Diction', 'exists': '', 'ns': 0},
#  {'*': 'Diegesis', 'exists': '', 'ns': 0},
#  {'*': 'Docufiction', 'exists': '', 'ns': 0},
#  {'*': 'Double negative', 'exists': '', 'ns': 0},
#  {'*': 'Dramatic structure', 'exists': '', 'ns': 0},
#  {'*': 'Dream world (plot device)', 'exists': '', 'ns': 0},
#  {'*': 'Dysphemism', 'exists': '', 'ns': 0},
#  {'*': 'Dystopia', 'exists': '', 'ns': 0},
#  {'*': 'Edward P. J. Corbett', 'exists': '', 'ns': 0},
#  {'*': 'Elision', 'exists': '', 'ns': 0},
#  {'*': 'Ellipsis (linguistics)', 'exists': '', 'ns': 0},
#  {'*': 'Enallage', 'exists': '', 'ns': 0},
#  {'*': 'Enjambment', 'exists': '', 'ns': 0},
#  {'*': 'Enthymeme', 'exists': '', 'ns': 0},
#  {'*': 'Epanalepsis', 'exists': '', 'ns': 0},
#  {'*': 'Epanodos', 'exists': '', 'ns': 0},
#  {'*': 'Epanorthosis', 'exists': '', 'ns': 0},
#  {'*': 'Epic (genre)', 'exists': '', 'ns': 0},
#  {'*': 'Epistolary novel', 'exists': '', 'ns': 0},
#  {'*': 'Epistrophe', 'exists': '', 'ns': 0},
#  {'*': 'Epizeuxis', 'exists': '', 'ns': 0},
#  {'*': 'Erotema', 'exists': '', 'ns': 0},
#  {'*': 'Erotic literature', 'exists': '', 'ns': 0},
#  {'*': 'Eucatastrophe', 'exists': '', 'ns': 0},
#  {'*': 'Euphemism', 'exists': '', 'ns': 0},
#  {'*': 'Euphony', 'exists': '', 'ns': 0},
#  {'*': 'Exposition (narrative)', 'exists': '', 'ns': 0},
#  {'*': 'Fable', 'exists': '', 'ns': 0},
#  {'*': 'Fabliau', 'exists': '', 'ns': 0},
#  {'*': 'Fairy tale', 'exists': '', 'ns': 0},
#  {'*': 'False protagonist', 'exists': '', 'ns': 0},
#  {'*': 'Fantasy', 'exists': '', 'ns': 0},
#  {'*': 'Fiction', 'exists': '', 'ns': 0},
#  {'*': 'Fiction writing', 'exists': '', 'ns': 0},
#  {'*': 'Fictional city', 'exists': '', 'ns': 0},
#  {'*': 'Fictional country', 'exists': '', 'ns': 0},
#  {'*': 'Fictional location', 'exists': '', 'ns': 0},
#  {'*': 'Fictional universe', 'exists': '', 'ns': 0},
#  {'*': 'Figures of Speech', 'exists': '', 'ns': 0},
#  {'*': 'First-person narrative', 'exists': '', 'ns': 0},
#  {'*': 'Flash fiction', 'exists': '', 'ns': 0},
#  {'*': 'Flashback (narrative)', 'exists': '', 'ns': 0},
#  {'*': 'Flashforward', 'exists': '', 'ns': 0},
#  {'*': 'Focal character', 'exists': '', 'ns': 0},
#  {'*': 'Foil (literature)', 'exists': '', 'ns': 0},
#  {'*': 'Folklore', 'exists': '', 'ns': 0},
#  {'*': 'Foreshadowing', 'exists': '', 'ns': 0},
#  {'*': 'Frame story', 'exists': '', 'ns': 0},
#  {'*': 'Freudian slip', 'exists': '', 'ns': 0},
#  {'*': 'Future tense', 'exists': '', 'ns': 0},
#  {'*': 'Gamebook', 'exists': '', 'ns': 0},
#  {'*': 'Gothic fiction', 'exists': '', 'ns': 0},
#  {'*': 'Grammatical tense', 'exists': '', 'ns': 0},
#  {'*': 'Grandiloquence', 'exists': '', 'ns': 0},
#  {'*': 'Half rhyme', 'exists': '', 'ns': 0},
#  {'*': 'Hendiadys', 'exists': '', 'ns': 0},
#  {'*': 'Hendiatris', 'exists': '', 'ns': 0},
#  {'*': 'Henry Peacham (born 1546)', 'exists': '', 'ns': 0},
#  {'*': "Hero's journey", 'exists': '', 'ns': 0},
#  {'*': 'Historical fiction', 'exists': '', 'ns': 0},
#  {'*': 'Homeoptoton', 'exists': '', 'ns': 0},
#  {'*': 'Homeoteleuton', 'exists': '', 'ns': 0},
#  {'*': 'Homographs', 'exists': '', 'ns': 0},
#  {'*': 'Homoioteleuton', 'exists': '', 'ns': 0},
#  {'*': 'Homonyms', 'exists': '', 'ns': 0},
#  {'*': 'Homophones', 'exists': '', 'ns': 0},
#  {'*': 'Horror fiction', 'exists': '', 'ns': 0},
#  {'*': 'Humour', 'exists': '', 'ns': 0},
#  {'*': 'Hypallage', 'exists': '', 'ns': 0},
#  {'*': 'Hyperbaton', 'exists': '', 'ns': 0},
#  {'*': 'Hyperbole', 'exists': '', 'ns': 0},
#  {'*': 'Hypocatastasis', 'exists': '', 'ns': 0},
#  {'*': 'Hypophora', 'exists': '', 'ns': 0},
#  {'*': 'Hypozeuxis', 'exists': '', 'ns': 0},
#  {'*': 'Hysteron proteron', 'exists': '', 'ns': 0},
#  {'*': 'Idiom', 'exists': '', 'ns': 0},
#  {'*': 'Imagery', 'exists': '', 'ns': 0},
#  {'*': 'In medias res', 'exists': '', 'ns': 0},
#  {'*': 'Innuendo', 'exists': '', 'ns': 0},
#  {'*': 'Inspirational fiction', 'exists': '', 'ns': 0},
#  {'*': 'Institutio Oratoria', 'exists': '', 'ns': 0},
#  {'*': 'Internal rhyme', 'exists': '', 'ns': 0},
#  {'*': 'International Standard Book Number', 'exists': '', 'ns': 0},
#  {'*': 'Irony', 'exists': '', 'ns': 0},
#  {'*': 'Isocolon', 'exists': '', 'ns': 0},
#  {'*': 'Kamishibai', 'exists': '', 'ns': 0},
#  {'*': 'Kenning', 'exists': '', 'ns': 0},
#  {'*': 'Kishōtenketsu', 'exists': '', 'ns': 0},
#  {'*': 'Legend', 'exists': '', 'ns': 0},
#  {'*': 'Leitmotif', 'exists': '', 'ns': 0},
#  {'*': 'List of forms of word play', 'exists': '', 'ns': 0},
#  {'*': 'List of narrative forms', 'exists': '', 'ns': 0},
#  {'*': 'List of narrative techniques', 'exists': '', 'ns': 0},
#  {'*': 'List of nonlinear narrative films', 'exists': '', 'ns': 0},
#  {'*': 'List of nonlinear narrative television series', 'exists': '', 'ns': 0},
#  {'*': 'List of writing genres', 'exists': '', 'ns': 0},
#  {'*': 'Literary consonance', 'exists': '', 'ns': 0},
#  {'*': 'Literary genre', 'exists': '', 'ns': 0},
#  {'*': 'Literary science', 'exists': '', 'ns': 0},
#  {'*': 'Literary theory', 'exists': '', 'ns': 0},
#  {'*': 'Litotes', 'exists': '', 'ns': 0},
#  {'*': 'London', 'exists': '', 'ns': 0},
#  {'*': 'MacGuffin', 'exists': '', 'ns': 0},
#  {'*': 'Magic realism', 'exists': '', 'ns': 0},
#  {'*': 'Malapropism', 'exists': '', 'ns': 0},
#  {'*': 'Mark Forsyth', 'exists': '', 'ns': 0},
#  {'*': 'Meiosis (figure of speech)', 'exists': '', 'ns': 0},
#  {'*': 'Merism', 'exists': '', 'ns': 0},
#  {'*': 'Metalepsis', 'exists': '', 'ns': 0},
#  {'*': 'Metaphor', 'exists': '', 'ns': 0},
#  {'*': 'Metonym', 'exists': '', 'ns': 0},
#  {'*': 'Metonymy', 'exists': '', 'ns': 0},
#  {'*': 'Mimesis', 'exists': '', 'ns': 0},
#  {'*': 'Mode (literature)', 'exists': '', 'ns': 0},
#  {'*': 'Mood (literature)', 'exists': '', 'ns': 0},
#  {'*': 'Moral', 'exists': '', 'ns': 0},
#  {'*': 'Motif (narrative)', 'exists': '', 'ns': 0},
#  {'*': 'Multiperspectivity', 'exists': '', 'ns': 0},
#  {'*': 'Mystery fiction', 'exists': '', 'ns': 0},
#  {'*': 'Narration', 'exists': '', 'ns': 0},
#  {'*': 'Narrative', 'exists': '', 'ns': 0},
#  {'*': 'Narrative structure', 'exists': '', 'ns': 0},
#  {'*': 'Narratology', 'exists': '', 'ns': 0},
#  {'*': 'Nautical fiction', 'exists': '', 'ns': 0},
#  {'*': 'Neologism', 'exists': '', 'ns': 0},
#  {'*': 'Non-fiction novel', 'exists': '', 'ns': 0},
#  {'*': 'Non sequitur (literary device)', 'exists': '', 'ns': 0},
#  {'*': 'Nonlinear narrative', 'exists': '', 'ns': 0},
#  {'*': 'Novel', 'exists': '', 'ns': 0},
#  {'*': 'Novella', 'exists': '', 'ns': 0},
#  {'*': 'Object (grammar)', 'exists': '', 'ns': 0},
#  {'*': "Occam's razor", 'exists': '', 'ns': 0},
#  {'*': 'Onomatopoeia', 'exists': '', 'ns': 0},
#  {'*': 'Oxymoron', 'exists': '', 'ns': 0},
#  {'*': 'Pace (narrative)', 'exists': '', 'ns': 0},
#  {'*': "Par'hyponoian", 'exists': '', 'ns': 0},
#  {'*': 'Parable', 'exists': '', 'ns': 0},
#  {'*': 'Paradiastole', 'exists': '', 'ns': 0},
#  {'*': 'Paradox (literature)', 'exists': '', 'ns': 0},
#  {'*': 'Paralipsis', 'exists': '', 'ns': 0},
#  {'*': 'Parallelism (rhetoric)', 'exists': '', 'ns': 0},
#  {'*': 'Paranoid fiction', 'exists': '', 'ns': 0},
#  {'*': 'Paraprosdokian', 'exists': '', 'ns': 0},
#  {'*': 'Parenthesis (rhetoric)', 'exists': '', 'ns': 0},
#  {'*': 'Parody', 'exists': '', 'ns': 0},
#  {'*': 'Paroemion', 'exists': '', 'ns': 0},
#  {'*': 'Paronomasia', 'exists': '', 'ns': 0},
#  {'*': 'Parrhesia', 'exists': '', 'ns': 0},
#  {'*': 'Past tense', 'exists': '', 'ns': 0},
#  {'*': 'Pathetic fallacy', 'exists': '', 'ns': 0},
#  {'*': 'Periphrasis (rhetoric)', 'exists': '', 'ns': 0},
#  {'*': 'Personification', 'exists': '', 'ns': 0},
#  {'*': 'Philo of Alexandria', 'exists': '', 'ns': 0},
#  {'*': 'Philosophical fiction', 'exists': '', 'ns': 0},
#  {'*': 'Phrasal template', 'exists': '', 'ns': 0},
#  {'*': 'Picaresque novel', 'exists': '', 'ns': 0},
#  {'*': 'Play (theatre)', 'exists': '', 'ns': 0},
#  {'*': 'Pleonasm', 'exists': '', 'ns': 0},
#  {'*': 'Plot (narrative)', 'exists': '', 'ns': 0},
#  {'*': 'Plot device', 'exists': '', 'ns': 0},
#  {'*': 'Plot twist', 'exists': '', 'ns': 0},
#  {'*': 'Poetic justice', 'exists': '', 'ns': 0},
#  {'*': 'Poetry', 'exists': '', 'ns': 0},
#  {'*': 'Political fiction', 'exists': '', 'ns': 0},
#  {'*': 'Polyptoton', 'exists': '', 'ns': 0},
#  {'*': 'Polysyndeton', 'exists': '', 'ns': 0},
#  {'*': 'Praeteritio', 'exists': '', 'ns': 0},
#  {'*': 'Present tense', 'exists': '', 'ns': 0},
#  {'*': 'Procatalepsis', 'exists': '', 'ns': 0},
#  {'*': 'Proslepsis', 'exists': '', 'ns': 0},
#  {'*': 'Protagonist', 'exists': '', 'ns': 0},
#  {'*': 'Proverb', 'exists': '', 'ns': 0},
#  {'*': 'Psychological fiction', 'exists': '', 'ns': 0},
#  {'*': 'Pun', 'exists': '', 'ns': 0},
#  {'*': 'Red herring', 'exists': '', 'ns': 0},
#  {'*': 'Renaissance', 'exists': '', 'ns': 0},
#  {'*': 'Repetition (rhetorical device)', 'exists': '', 'ns': 0},
#  {'*': 'Reveal (narrative)', 'exists': '', 'ns': 0},
#  {'*': 'Rhetoric', 'exists': '', 'ns': 0},
#  {'*': 'Rhetorica ad Herennium', 'exists': '', 'ns': 0},
#  {'*': 'Rhetorical device', 'exists': '', 'ns': 0},
#  {'*': 'Rhetorical operations', 'exists': '', 'ns': 0},
#  {'*': 'Rhetorical question', 'exists': '', 'ns': 0},
#  {'*': 'Rhythm', 'exists': '', 'ns': 0},
#  {'*': 'Romance novel', 'exists': '', 'ns': 0},
#  {'*': 'Root word', 'exists': '', 'ns': 0},
#  {'*': 'Saga', 'exists': '', 'ns': 0},
#  {'*': 'Satire', 'exists': '', 'ns': 0},
#  {'*': 'Scheme (linguistics)', 'exists': '', 'ns': 0},
#  {'*': 'Science fiction', 'exists': '', 'ns': 0},
#  {'*': 'Screenplay', 'exists': '', 'ns': 0},
#  {'*': 'Screenwriting', 'exists': '', 'ns': 0},
#  {'*': 'Self-fulfilling prophecy', 'exists': '', 'ns': 0},
#  {'*': 'Self-insertion', 'exists': '', 'ns': 0},
#  {'*': 'Sesquipedalianism', 'exists': '', 'ns': 0},
#  {'*': 'Setting (narrative)', 'exists': '', 'ns': 0},
#  {'*': 'Shaggy dog story', 'exists': '', 'ns': 0},
#  {'*': 'Short story', 'exists': '', 'ns': 0},
#  {'*': 'Sibilance', 'exists': '', 'ns': 0},
#  {'*': 'Simile', 'exists': '', 'ns': 0},
#  {'*': 'Sine dicendo', 'exists': '', 'ns': 0},
#  {'*': 'Snowclone', 'exists': '', 'ns': 0},
#  {'*': 'Solecism', 'exists': '', 'ns': 0},
#  {'*': 'Speculative fiction', 'exists': '', 'ns': 0},
#  {'*': 'Spoonerism', 'exists': '', 'ns': 0},
#  {'*': 'Stock character', 'exists': '', 'ns': 0},
#  {'*': 'Storytelling', 'exists': '', 'ns': 0},
#  {'*': 'Straight man', 'exists': '', 'ns': 0},
#  {'*': 'Stream of consciousness', 'exists': '', 'ns': 0},
#  {'*': 'Stream of unconsciousness (narrative mode)', 'exists': '', 'ns': 0},
#  {'*': 'Stylistic device', 'exists': '', 'ns': 0},
#  {'*': 'Subject (grammar)', 'exists': '', 'ns': 0},
#  {'*': 'Subplot', 'exists': '', 'ns': 0},
#  {'*': 'Superhero fiction', 'exists': '', 'ns': 0},
#  {'*': 'Superlative', 'exists': '', 'ns': 0},
#  {'*': 'Supporting character', 'exists': '', 'ns': 0},
#  {'*': 'Suspense', 'exists': '', 'ns': 0},
#  {'*': 'Suspension of disbelief', 'exists': '', 'ns': 0},
#  {'*': 'Syllepsis', 'exists': '', 'ns': 0},
#  {'*': 'Syllogism', 'exists': '', 'ns': 0},
#  {'*': 'Symbolism (arts)', 'exists': '', 'ns': 0},
#  {'*': 'Symploce', 'exists': '', 'ns': 0},
#  {'*': 'Syncatabasis', 'exists': '', 'ns': 0},
#  {'*': 'Synchysis', 'exists': '', 'ns': 0},
#  {'*': 'Syncope (phonology)', 'exists': '', 'ns': 0},
#  {'*': 'Synecdoche', 'exists': '', 'ns': 0},
#  {'*': 'Synesis', 'exists': '', 'ns': 0},
#  {'*': 'Synesthesia', 'exists': '', 'ns': 0},
#  {'*': 'Synonymia', 'exists': '', 'ns': 0},
#  {'*': 'Tautology (grammar)', 'exists': '', 'ns': 0},
#  {'*': 'Tautology (rhetoric)', 'exists': '', 'ns': 0},
#  {'*': 'Tellability', 'exists': '', 'ns': 0},
#  {'*': 'Theme (narrative)', 'exists': '', 'ns': 0},
#  {'*': 'Theological fiction', 'exists': '', 'ns': 0},
#  {'*': 'Thriller (genre)', 'exists': '', 'ns': 0},
#  {'*': 'Title character', 'exists': '', 'ns': 0},
#  {'*': 'Tmesis', 'exists': '', 'ns': 0},
#  {'*': 'Tone (literature)', 'exists': '', 'ns': 0},
#  {'*': 'Tragic hero', 'exists': '', 'ns': 0},
#  {'*': 'Transferred epithet', 'exists': '', 'ns': 0},
#  {'*': 'Tricolon', 'exists': '', 'ns': 0},
#  {'*': 'Tritagonist', 'exists': '', 'ns': 0},
#  {'*': 'Trope (linguistics)', 'exists': '', 'ns': 0},
#  {'*': 'Trope (literature)', 'exists': '', 'ns': 0},
#  {'*': 'Truism', 'exists': '', 'ns': 0},
#  {'*': 'Types of fiction with multiple endings', 'exists': '', 'ns': 0},
#  {'*': 'Unreliable narrator', 'exists': '', 'ns': 0},
#  {'*': 'Urban fiction', 'exists': '', 'ns': 0},
#  {'*': 'Utopia', 'exists': '', 'ns': 0},
#  {'*': 'Wayback Machine', 'exists': '', 'ns': 0},
#  {'*': 'Western fiction', 'exists': '', 'ns': 0},
#  {'*': 'Whitehall', 'exists': '', 'ns': 0},
#  {'*': 'Writing style', 'exists': '', 'ns': 0},
#  {'*': 'X. J. Kennedy', 'exists': '', 'ns': 0},
#  {'*': 'Zeugma', 'exists': '', 'ns': 0},
#  {'*': 'Zoomorphism', 'exists': '', 'ns': 0},
#  {'*': 'Quadripartita', 'ns': 0},
#  {'*': 'Portal:Linguistics', 'exists': '', 'ns': 100},
#  {'*': 'Portal:Literature', 'exists': '', 'ns': 100},
#  {'*': 'Template:Narrative', 'exists': '', 'ns': 10},
#  {'*': 'Template talk:Narrative', 'exists': '', 'ns': 11},
#  {'*': 'Category:CS1 maint: archived copy as title', 'exists': '', 'ns': 14}]

# %%
links = [link['*'] for link in linkDATA["parse"]["links"]]
for i, link in enumerate(links):
    print(i, link)
# Out:
# 0 Figures of speech
# 1 Accismus
# 2 Accumulation (figure of speech)
# 3 Action (narrative)
# 4 Action fiction
# 5 Adnomination
# 6 Adventure fiction
# 7 Adynaton
# 8 Allegory
# 9 Alliteration
# 10 Allusion
# 11 Alternate history
# 12 Anacoenosis
# 13 Anacoluthon
# 14 Anadiplosis
# 15 Analogy
# 16 Anaphora (rhetoric)
# 17 Anapodoton
# 18 Anastrophe
# 19 Antagonist
# 20 Antanaclasis
# 21 Anthimeria
# 22 Anthropomorphism
# 23 Anti-climax (figure of speech)
# 24 Antihero
# 25 Antimetabole
# 26 Antiphrasis
# 27 Antithesis
# 28 Antonomasia
# 29 Aphorism
# 30 Aphorismus
# 31 Apologia
# 32 Apophasis
# 33 Aporia
# 34 Aposiopesis
# 35 Apostrophe (rhetoric)
# 36 Apposition
# 37 Appositive
# 38 Archaism
# 39 Archenemy
# 40 Assonance
# 41 Asteismus
# 42 Asyndeton
# 43 Audience
# 44 Author
# 45 Auxesis (figure of speech)
# 46 Backstory
# 47 Bathos
# 48 Burlesque metaphor
# 49 Cacophony
# 50 Cantastoria
# 51 Catachresis
# 52 Cataphora
# 53 Character (arts)
# 54 Character arc
# 55 Character flaw
# 56 Characterization
# 57 Chekhov's gun
# 58 Chiasmus
# 59 Chris Baldick
# 60 Circumlocution
# 61 City of Westminster
# 62 Classical rhetoric
# 63 Classification (literature & grammar)
# 64 Cliché
# 65 Cliffhanger
# 66 Climax (figure of speech)
# 67 Climax (narrative)
# 68 Comic novel
# 69 Comics
# 70 Conflict (narrative)
# 71 Congeries
# 72 Conversion (word formation)
# 73 Correctio
# 74 Correlative verse
# 75 Creative nonfiction
# 76 Crime fiction
# 77 Denominatio
# 78 Deus ex machina
# 79 Deuteragonist
# 80 Diacope
# 81 Dialogue in writing
# 82 Diction
# 83 Diegesis
# 84 Docufiction
# 85 Double negative
# 86 Dramatic structure
# 87 Dream world (plot device)
# 88 Dysphemism
# 89 Dystopia
# 90 Edward P. J. Corbett
# 91 Elision
# 92 Ellipsis (linguistics)
# 93 Enallage
# 94 Enjambment
# 95 Enthymeme
# 96 Epanalepsis
# 97 Epanodos
# 98 Epanorthosis
# 99 Epic (genre)
# 100 Epistolary novel
# 101 Epistrophe
# 102 Epizeuxis
# 103 Erotema
# 104 Erotic literature
# 105 Eucatastrophe
# 106 Euphemism
# 107 Euphony
# 108 Exposition (narrative)
# 109 Fable
# 110 Fabliau
# 111 Fairy tale
# 112 False protagonist
# 113 Fantasy
# 114 Fiction
# 115 Fiction writing
# 116 Fictional city
# 117 Fictional country
# 118 Fictional location
# 119 Fictional universe
# 120 Figures of Speech
# 121 First-person narrative
# 122 Flash fiction
# 123 Flashback (narrative)
# 124 Flashforward
# 125 Focal character
# 126 Foil (literature)
# 127 Folklore
# 128 Foreshadowing
# 129 Frame story
# 130 Freudian slip
# 131 Future tense
# 132 Gamebook
# 133 Gothic fiction
# 134 Grammatical tense
# 135 Grandiloquence
# 136 Half rhyme
# 137 Hendiadys
# 138 Hendiatris
# 139 Henry Peacham (born 1546)
# 140 Hero's journey
# 141 Historical fiction
# 142 Homeoptoton
# 143 Homeoteleuton
# 144 Homographs
# 145 Homoioteleuton
# 146 Homonyms
# 147 Homophones
# 148 Horror fiction
# 149 Humour
# 150 Hypallage
# 151 Hyperbaton
# 152 Hyperbole
# 153 Hypocatastasis
# 154 Hypophora
# 155 Hypozeuxis
# 156 Hysteron proteron
# 157 Idiom
# 158 Imagery
# 159 In medias res
# 160 Innuendo
# 161 Inspirational fiction
# 162 Institutio Oratoria
# 163 Internal rhyme
# 164 International Standard Book Number
# 165 Irony
# 166 Isocolon
# 167 Kamishibai
# 168 Kenning
# 169 Kishōtenketsu
# 170 Legend
# 171 Leitmotif
# 172 List of forms of word play
# 173 List of narrative forms
# 174 List of narrative techniques
# 175 List of nonlinear narrative films
# 176 List of nonlinear narrative television series
# 177 List of writing genres
# 178 Literary consonance
# 179 Literary genre
# 180 Literary science
# 181 Literary theory
# 182 Litotes
# 183 London
# 184 MacGuffin
# 185 Magic realism
# 186 Malapropism
# 187 Mark Forsyth
# 188 Meiosis (figure of speech)
# 189 Merism
# 190 Metalepsis
# 191 Metaphor
# 192 Metonym
# 193 Metonymy
# 194 Mimesis
# 195 Mode (literature)
# 196 Mood (literature)
# 197 Moral
# 198 Motif (narrative)
# 199 Multiperspectivity
# 200 Mystery fiction
# 201 Narration
# 202 Narrative
# 203 Narrative structure
# 204 Narratology
# 205 Nautical fiction
# 206 Neologism
# 207 Non-fiction novel
# 208 Non sequitur (literary device)
# 209 Nonlinear narrative
# 210 Novel
# 211 Novella
# 212 Object (grammar)
# 213 Occam's razor
# 214 Onomatopoeia
# 215 Oxymoron
# 216 Pace (narrative)
# 217 Par'hyponoian
# 218 Parable
# 219 Paradiastole
# 220 Paradox (literature)
# 221 Paralipsis
# 222 Parallelism (rhetoric)
# 223 Paranoid fiction
# 224 Paraprosdokian
# 225 Parenthesis (rhetoric)
# 226 Parody
# 227 Paroemion
# 228 Paronomasia
# 229 Parrhesia
# 230 Past tense
# 231 Pathetic fallacy
# 232 Periphrasis (rhetoric)
# 233 Personification
# 234 Philo of Alexandria
# 235 Philosophical fiction
# 236 Phrasal template
# 237 Picaresque novel
# 238 Play (theatre)
# 239 Pleonasm
# 240 Plot (narrative)
# 241 Plot device
# 242 Plot twist
# 243 Poetic justice
# 244 Poetry
# 245 Political fiction
# 246 Polyptoton
# 247 Polysyndeton
# 248 Praeteritio
# 249 Present tense
# 250 Procatalepsis
# 251 Proslepsis
# 252 Protagonist
# 253 Proverb
# 254 Psychological fiction
# 255 Pun
# 256 Red herring
# 257 Renaissance
# 258 Repetition (rhetorical device)
# 259 Reveal (narrative)
# 260 Rhetoric
# 261 Rhetorica ad Herennium
# 262 Rhetorical device
# 263 Rhetorical operations
# 264 Rhetorical question
# 265 Rhythm
# 266 Romance novel
# 267 Root word
# 268 Saga
# 269 Satire
# 270 Scheme (linguistics)
# 271 Science fiction
# 272 Screenplay
# 273 Screenwriting
# 274 Self-fulfilling prophecy
# 275 Self-insertion
# 276 Sesquipedalianism
# 277 Setting (narrative)
# 278 Shaggy dog story
# 279 Short story
# 280 Sibilance
# 281 Simile
# 282 Sine dicendo
# 283 Snowclone
# 284 Solecism
# 285 Speculative fiction
# 286 Spoonerism
# 287 Stock character
# 288 Storytelling
# 289 Straight man
# 290 Stream of consciousness
# 291 Stream of unconsciousness (narrative mode)
# 292 Stylistic device
# 293 Subject (grammar)
# 294 Subplot
# 295 Superhero fiction
# 296 Superlative
# 297 Supporting character
# 298 Suspense
# 299 Suspension of disbelief
# 300 Syllepsis
# 301 Syllogism
# 302 Symbolism (arts)
# 303 Symploce
# 304 Syncatabasis
# 305 Synchysis
# 306 Syncope (phonology)
# 307 Synecdoche
# 308 Synesis
# 309 Synesthesia
# 310 Synonymia
# 311 Tautology (grammar)
# 312 Tautology (rhetoric)
# 313 Tellability
# 314 Theme (narrative)
# 315 Theological fiction
# 316 Thriller (genre)
# 317 Title character
# 318 Tmesis
# 319 Tone (literature)
# 320 Tragic hero
# 321 Transferred epithet
# 322 Tricolon
# 323 Tritagonist
# 324 Trope (linguistics)
# 325 Trope (literature)
# 326 Truism
# 327 Types of fiction with multiple endings
# 328 Unreliable narrator
# 329 Urban fiction
# 330 Utopia
# 331 Wayback Machine
# 332 Western fiction
# 333 Whitehall
# 334 Writing style
# 335 X. J. Kennedy
# 336 Zeugma
# 337 Zoomorphism
# 338 Quadripartita
# 339 Portal:Linguistics
# 340 Portal:Literature
# 341 Template:Narrative
# 342 Template talk:Narrative
# 343 Category:CS1 maint: archived copy as title

# %%
# visualize link data
for link in links[3:4]:
    # get page info
    PARAMS = {
        "action": "query",
        "titles": link,
        "format": "json",
        "prop": "info",
        'inprop': "displaytitle"
    }

    infoR = S.get(url=URL, params=PARAMS)
    infoDATA = infoR.json()
    pprint(infoDATA)

# %%
# get data
PARAMS = {
    "action": "parse",
    "pageid": page_id,
    "format": "json",
    "prop": "wikitext"
}

textR = S.get(url=URL, params=PARAMS)
textDATA = textR.json()

# %%
# parse data

lines = textDATA["parse"]["wikitext"]["*"].split('\n')

# %%
for index, line in enumerate(lines):
    print(index, line)
# Out:
# 0 {{short description|Intentional deviation from ordinary language, chosen to produce a rhetorical effect}}
# 1 {{Redirect|Figures of speech|the hip hop group|Figures of Speech}}
# 2 [[File:Whitehall MOD 45155526.jpg|thumb|[[Whitehall]] is a road in the [[City of Westminster]], [[London]] used synecdochically to refer to the UK civil service, as many government departments  are nearby.]]
# 3
# 4 A '''figure of speech''' or '''rhetorical figure''' is an intentional deviation from ordinary language, chosen to produce a [[rhetoric|rhetorical]] effect.<ref>{{cite web |url=https://books.google.com/books?id=YWBgAAAAcAAJ&pg=PA113 |title=A Grammar of the English Language ... In a series of familiar lectures, etc |accessdate=2015-12-02 |url-status=live |archiveurl=https://web.archive.org/web/20160508135920/https://books.google.com/books?id=YWBgAAAAcAAJ&pg=PA113 |archivedate=2016-05-08 |last1=Mar |first1=Emanuel del |year=1842 }}</ref> Figures of speech are traditionally classified into ''[[scheme (linguistics)|schemes]],'' which vary the ordinary sequence or pattern of words, and ''[[trope (literature)|tropes]],'' where words are made to carry a meaning other than what they ordinarily signify. A type of scheme is [[polysyndeton]], the repeating of a conjunction before every element in a list, where normally the conjunction would appear only before the last element, as in "Lions and tigers and bears, oh my!"—emphasizing the danger and number of animals more than the prosaic wording with only the second "and". A type of trope is [[metaphor]], describing one thing as something that it clearly is not, in order to lead the mind to compare them, as in "All the world's a stage."
# 5
# 6 == Four rhetorical operations ==
# 7 {{Main|Rhetorical operations}}
# 8
# 9 [[Classical rhetoric]]ians classified figures of speech into [[rhetorical operations|four categories]] or ''[[quadripartita]] ratio'':<ref name="Jansen">Jansen, Jeroen (2008) ''[http://www.verloren.nl/boeken/2086/263/2126/renaissance/imitatio Imitatio] {{webarchive|url=https://web.archive.org/web/20150714140654/http://www.verloren.nl/boeken/2086/263/2126/renaissance/imitatio |date=2015-07-14 }}'' {{ISBN|978-90-8704-027-7}} [http://home.medewerker.uva.nl/j.jansen/page1.html Summary] {{webarchive|url=https://web.archive.org/web/20081205211147/http://home.medewerker.uva.nl/j.jansen/page1.html |date=2008-12-05 }} translated to English by Kristine Steenbergh. Quote from the summary: <blockquote>Using these formulas, a pupil could render the same subject or theme in a myriad of ways. For the mature author, this principle offered a set of tools to rework source texts into a new creation. In short, the quadripartita ratio offered the student or author a ready-made framework, whether for changing words or the transformation of entire texts. Since it concerned relatively mechanical procedures of adaptation that for the most part could be learned, the techniques concerned could be taught at school at a relatively early age, for example in the improvement of pupils’ own writing.</blockquote></ref>
# 10
# 11 * addition (''adiectio''), also called repetition/expansion/superabundance
# 12 * omission (''detractio''), also called subtraction/abridgement/lack
# 13 * transposition (''transmutatio''), also called transferring
# 14 * permutation (''immutatio''), also called switching/interchange/substitution/transmutation
# 15
# 16 These categories are often still used. The earliest known text listing them, though not explicitly as a system, is the ''[[Rhetorica ad Herennium]]'', of unknown authorship, where they are called πλεονασμός (pleonasmos - addition), ἔνδεια (endeia - omission), μετάθεσις (metathesis - transposition) and ἐναλλαγή (enallage - permutation).<ref>Book V, 21.29, pp.303–5</ref> Quintillian then mentioned them in ''[[Institutio Oratoria]]''.<ref>Institutio Oratoria, Vol. I, Book I, [http://penelope.uchicago.edu/Thayer/E/Roman/Texts/Quintilian/Institutio_Oratoria/1B*.html Chapter 5], paragraphs 6 and 38–41. And also in Book VI [http://penelope.uchicago.edu/Thayer/E/Roman/Texts/Quintilian/Institutio_Oratoria/6C*.html Chapter 3]</ref> [[Philo of Alexandria]] also listed them as addition (πρόσθεσις - prosthesis), subtraction (ἀφαίρεσις - afairesis), transposition (μετάθεσις - metathesis), and transmutation (ἀλλοίωσις - alloiosis).<ref>[http://penelope.uchicago.edu/Thayer/E/Roman/Texts/Rhetorica_ad_Herennium/4B*.html Rhetorica ad Herennium]</ref>
# 17
# 18 == Examples ==
# 19 Figures of speech come in many varieties. The aim is to use the language inventively to accentuate the effect of what is being said. A few examples follow:
# 20
# 21 * "Around the rugged rocks the ragged rascal ran" is an example of [[alliteration]], where the consonant ''r'' is used repeatedly.
# 22 :Whereas, "Sister Suzy‘s sewing socks for soldiers" is a particular form of alliteration called [[sibilance]], because it repeats the letter ''s''.
# 23 :Both are commonly used in poetry.
# 24 * "She would run up the stairs and then a new set of curtains" is a variety of [[zeugma]] called a [[syllepsis]]. ''Run up'' refers to ascending and also to manufacturing. The effect is enhanced by the momentary suggestion, through a [[pun]], that she might be climbing up the curtains. The [[ellipsis (linguistics)|ellipsis]] or omission of the second use of the verb makes the reader think harder about what is being said.
# 25 * "Painful pride" is an [[oxymoron]] where two contradictory ideas are placed in the same sentence.
# 26 *"An Einstein" is an example of [[synecdoche]], as it uses a particular name to represent a class of people: geniuses.
# 27 * "I had butterflies in my stomach" is a [[metaphor]], referring to a nervous feeling as if there were flying insects in one's stomach.
# 28 :To say "it was like having some butterflies in my stomach" would be a [[simile]], because it uses the word ''like'' which is missing in the metaphor.
# 29 :To say "It was like having a butterfly farm in my stomach", "It felt like a butterfly farm in my stomach", or "I was so nervous that I had a butterfly farm in my stomach" could be a [[hyperbole]], because it is exaggerated.
# 30 *"That filthy place was really dirty" is an example of [[Tautology (grammar)|tautology]], as there are the two words ('filthy' and 'dirty') having almost the same meaning and are repeated so as to make the text more emphatic.
# 31 <!--
# 32 The following figures of speech have not been added to the visible text of this article yet. Please remove from this comment each one you add.
# 33
# 34 * Adolescents
# 35 * Analogy
# 36 * Colors
# 37 * Colors of rhetoric
# 38 * Conversion
# 39 * Ecphonesis
# 40 * Elegant variation
# 41 * Embellishment
# 42 * Embroidery
# 43 * Emphasis
# 44 * Exclamation
# 45 * fine writing
# 46 * floridity
# 47 * floridness
# 48 * flourish
# 49 * floweriness
# 50 * flowers of speech
# 51 * frill
# 52 * gemination
# 53 * inversion
# 54 * lushness
# 55 * luxuriance
# 56 * ornament
# 57 * ornamentation
# 58 * rhyme
# 59 * rhythm
# 60 * paregmenon
# 61 * preterition
# 62 * purple patches
# 63 * regression
# 64 * sarcasm
# 65 * simile
# 66 * syllepsis
# 67 -->
# 68
# 69 Scholars of classical Western rhetoric have divided figures of speech into two main categories: schemes and tropes. ''[[Scheme (linguistics)|Schemes]]'' (from the Greek {{lang|grc-Latn|schēma}}, 'form or shape') are figures of speech that change the ordinary or expected pattern of words. For example, the phrase, "John, my best friend" uses the scheme known as [[apposition]]. ''[[Trope (linguistics)|Tropes]]'' (from Greek {{lang|grc-Latn|trepein}}, 'to turn') change the general meaning of words. An example of a trope is irony, which is the use of words to convey the opposite of their usual meaning ("For Brutus is an honorable man; / So are they all, all honorable men").
# 70
# 71 During the [[Renaissance]], scholars meticulously enumerated and classified figures of speech. [[Henry Peacham (born 1546)|Henry Peacham]], for example, in his ''The Garden of Eloquence'' (1577), enumerated 184 different figures of speech. Professor Robert DiYanni, in his book "Literature – Reading Fiction, Poetry, Drama and the Essay"<ref>Second Edition, McGraw-Hill, {{ISBN|0-07-557112-9}}, pp.451</ref> wrote: "Rhetoricians have catalogued more than 250 different ''figures of speech'', expressions or ways of using words in a nonliteral sense."
# 72
# 73 For simplicity, this article divides the figures between schemes and tropes, but does not further sub-classify them (e.g., "Figures of Disorder"). Within each category, words are listed alphabetically. Most entries link to a page that provides greater detail and relevant examples, but a short definition is placed here for convenience. Some of those listed may be considered [[rhetorical device]]s, which are similar in many ways.
# 74
# 75 === Schemes ===
# 76
# 77 * [[Accumulation (figure of speech)|accumulation]]: Accumulating arguments in a concise forceful manner.
# 78 * [[adnomination]]: Repetition of words with the same [[root word]].
# 79 * [[alliteration]]: a literary stylistic device, where a series of words in a row have the same first consonant sound.
# 80 *:E.g.: "She sells sea shells by the sea shore".
# 81 * [[adynaton]]: [[Hyperbole]] It is an extreme exaggeration used to make a point. It is like the opposite of "understatement".
# 82 *:E.g.: "I've told you a million times."
# 83 * [[anacoluthon]]: Transposition of clauses to achieve an unnatural order in a sentence.
# 84 * [[anadiplosis]]: Repetition of a word at the end of a clause and then at the beginning of its succeeding clause.
# 85 * [[anaphora (rhetoric)|anaphora]]: Repetition of the same word or set of words in a paragraph.
# 86 * [[anastrophe]]: Changing the [[object (grammar)|object]], [[subject (grammar)|subject]] and verb order in a clause.
# 87 * [[Anti-climax (figure of speech)|anti-climax]]: It is when a specific point, expectations are raised, everything is built-up and then suddenly something boring or disappointing happens.
# 88 *:E.g.: "Men, dogs and houses,  all are dead."
# 89 * [[antanaclasis]]: Repetition of a single word, but with different meanings.
# 90 * [[anthimeria]]: Transformation of a word of a certain word class to another word class.
# 91 * [[antimetabole]]: A sentence consisting of the repetition of words in successive clauses, but in reverse order.
# 92 * [[:wiktionary:antirrhesis|antirrhesis]]: Disproving an opponent's argument.
# 93 * [[epistrophe|antistrophe]]: Repetition of the same word or group of words in a paragraph in the end of sentences.
# 94 * [[antithesis]]: Juxtaposition of opposing or contrasting ideas.
# 95 * [[aphorismus]]: Statement that calls into question the definition of a word.
# 96 * [[aposiopesis]]: Breaking off or pausing speech for dramatic or emotional effect.
# 97 * [[apposition]]: Placing of two statements side by side, in which the second defines the first.
# 98 * [[assonance]]: Repetition of vowel sounds.
# 99 * [[asteismus]]: Mocking answer or humorous answer that plays on a word.
# 100 * [[:wiktionary:asterismos|asterismos]]: Beginning a segment of speech with an exclamation of a word.
# 101 * [[asyndeton]]: Omission of conjunctions between related clauses.
# 102 * [[cacophony]]: Words producing a harsh sound.
# 103 * [[cataphora]]: Co-reference of one expression with another expression which follows it, in which the latter defines the first. (example: If you need one, there's a towel in the top drawer.)
# 104 * [[classification (literature & grammar)|classification]]: Linking a proper noun and a common noun with an article
# 105 * [[chiasmus]]: Two or more clauses are related to each other through a reversal of structures in order to make a larger point
# 106 * [[climax (figure of speech)|climax]]: Arrangement of words in order of descending to ascending order.
# 107 * commoratio: Repetition of an idea, re-worded
# 108 * conduplicatio: Repetition of a key word
# 109 * [[conversion (word formation)]]: An unaltered transformation of a word of one word class into another word class
# 110 * [[Literary consonance|consonance]]: Repetition of consonant sounds, most commonly within a short passage of verse
# 111 * [[correlative verse]]: Matching items in two sequences
# 112 * [[diacope]]: Repetition of a word or phrase with one or two intervening words
# 113 * [[:wiktionary:asterismos|dubitatio]]: Expressing doubt and uncertainty about oneself
# 114 * [[:wiktionary:tmesis|dystmesis]]: A synonym for [[tmesis]]
# 115 * [[Ellipsis (linguistics)|ellipsis]]: Omission of words
# 116 * [[elision]]: Omission of one or more letters in speech, making it colloquial
# 117 * [[enallage]]: Wording ignoring grammatical rules or conventions
# 118 * [[enjambment]]: Incomplete sentences at the end of lines in poetry
# 119 * [[enthymeme]]: An informal [[syllogism]]
# 120 * [[epanalepsis]]: Ending sentences with their beginning.
# 121 * [[epanodos]]: Word repetition.<ref>{{cite book |url=https://books.google.com/?id=mWw3sbiCWtAC&pg=PT239&dq=epanodos+%22figure+of+speech%22 |title=The scientific and literary treasury – Samuel Maunder – Google Books |accessdate=2013-05-23 |url-status=live |archiveurl=https://web.archive.org/web/20170906005240/https://books.google.com/books?id=mWw3sbiCWtAC&pg=PT239&dq=epanodos+%22figure+of+speech%22&hl=en&sa=X&ei=ft2QUYmaMces4ATRz4GIDw&redir_esc=y |archivedate=2017-09-06 |last1=Maunder |first1=Samuel |year=1841 }}</ref><ref>{{cite book |url=https://books.google.com/?id=jlZBAAAAcAAJ&pg=PT616&dq=epanodos+%22figure+of+speech%22 |title=Universal Technological Dictionary Or Familiar Explanation of the Terms Used … – George Crabb – Google Books |accessdate=2013-05-23 |url-status=live |archiveurl=https://web.archive.org/web/20170906005240/https://books.google.com/books?id=jlZBAAAAcAAJ&pg=PT616&dq=epanodos+%22figure+of+speech%22&hl=en&sa=X&ei=ft2QUYmaMces4ATRz4GIDw&redir_esc=y |archivedate=2017-09-06 |last1=Crabb |first1=George |year=1823 }}</ref><ref>{{cite book |url=https://books.google.com/?id=Ztu2AAAAIAAJ&q=epanodos+%22figure+of+speech%22&dq=epanodos+%22figure+of+speech%22 |title=Naming-day in Eden: The Creation and Recreation of Language – Noah Jonathan Jacobs – Google Books |accessdate=2013-05-23 |url-status=live |archiveurl=https://web.archive.org/web/20170906005240/https://books.google.com/books?id=Ztu2AAAAIAAJ&q=epanodos+%22figure+of+speech%22&dq=epanodos+%22figure+of+speech%22&hl=en&sa=X&ei=od6QUd-NJeKC4ATTmYHwAw&redir_esc=y |archivedate=2017-09-06 |last1=Jacobs |first1=Noah Jonathan |year=1969 }}</ref>
# 122 * [[epistrophe]]: (also known as antistrophe) Repetition of the same word or group of words at the end of successive clauses. The counterpart of [[anaphora (rhetoric)|anaphora]]
# 123 * [[epizeuxis]]: Repetition of a single word, with no other words in between
# 124 * [[euphony]]: Opposite of [[cacophony]] – i.e. pleasant-sounding
# 125 * [[half rhyme]]: Partially rhyming words
# 126 * [[hendiadys]]: Use of two nouns to express an idea when it normally would consist of an adjective and a noun
# 127 * [[hendiatris]]: Use of three nouns to express one idea
# 128 * [[homeoptoton]]: ending the last parts of words with the same syllable or letter.<ref>{{cite web|title=Henry Peachum., The Garden of Eloquence (1593): Schemas|url=http://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.03.0096%3Apart%3DSchemates+Rhetorical%3Asubpart%3DThe+first+order%3Asection%3DFigures+of+Conjunction%3Asubsection%3DHomeoptoton|accessdate=22 April 2013|url-status=live|archiveurl=https://web.archive.org/web/20130925080118/http://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.03.0096%3Apart%3DSchemates+Rhetorical%3Asubpart%3DThe+first+order%3Asection%3DFigures+of+Conjunction%3Asubsection%3DHomeoptoton|archivedate=25 September 2013}}</ref>
# 129 * [[homographs]]: Words we write identically but which have a differing meaning
# 130 * [[homoioteleuton]]: Multiple words with the same ending
# 131 * [[homonyms]]: Words that are identical with each other in pronunciation and spelling, but different in meaning
# 132 * [[homophones]]: Words that are identical with each other in pronunciation, but different in meaning
# 133 * [[homeoteleuton]]: Words with the same ending
# 134 * [[hypallage]]: A transferred epithet from a conventional choice of wording.<ref>{{cite book|author=Bernard Marie Dupriez|title=A Dictionary of Literary Devices: Gradius, A-Z|url=https://books.google.com/books?id=uff2N62Jx9wC&pg=PA213|accessdate=31 May 2013|year=1991|publisher=University of Toronto Press|isbn=978-0-8020-6803-3|page=213|url-status=live|archiveurl=https://web.archive.org/web/20140107172724/http://books.google.com/books?id=uff2N62Jx9wC&pg=PA213|archivedate=7 January 2014}}{{cite book|last=Dupriez|first=Bernard Marie|title=A Dictionary of Literary Devices: Gradus, A-Z|url=https://books.google.com/books?id=uff2N62Jx9wC&pg=PA213|year=1991|publisher=University of Toronto Press|isbn=978-0-8020-6803-3|page=213|url-status=live|archiveurl=https://web.archive.org/web/20140107172724/http://books.google.com/books?id=uff2N62Jx9wC&pg=PA213|archivedate=2014-01-07}}</ref>
# 135 * [[hyperbaton]]: Two ordinary associated words are detached.<ref name="WilsonWauson2010">{{cite book|author1=Kevin Wilson|author2=Jennifer Wauson|title=The AMA Handbook of Business Writing: The Ultimate Guide to Style, Grammar, Usage, Punctuation, Construction, and Formatting|url=https://books.google.com/books?id=g0cnr5SaMm8C&pg=PA224|year=2010|publisher=AMACOM Div American Mgmt Assn|isbn=978-0-8144-1589-4|page=224|url-status=live|archiveurl=https://web.archive.org/web/20131205125237/http://books.google.com/books?id=g0cnr5SaMm8C&pg=PA224|archivedate=2013-12-05}}</ref><ref name="CushmanCavanagh2012">{{cite book|author1=Stephen Cushman|author2=Clare Cavanagh|author3=Jahan Ramazani|author4=Paul Rouzer|title=The Princeton Encyclopedia of Poetry and Poetics: Fourth Edition|url=https://books.google.com/books?id=uKiC6IeFR2UC&pg=PA648|date=26 August 2012|publisher=Princeton University Press|isbn=978-1-4008-4142-4|page=647|url-status=live|archiveurl=https://web.archive.org/web/20131103181052/http://books.google.com/books?id=uKiC6IeFR2UC&pg=PA648|archivedate=3 November 2013}}</ref> The term may also be used more generally for all different figures of speech which transpose natural word order in sentences.<ref name="CushmanCavanagh2012" />
# 136 * [[hyperbole]]: Exaggeration of a statement
# 137 * [[hypozeuxis]]: Every clause having its own independent subject and predicate
# 138 * [[hysteron proteron]]: The inversion of the usual temporal or causal order between two elements
# 139 * [[isocolon]]: Use of parallel structures of the same length in successive clauses
# 140 * [[internal rhyme]]: Using two or more rhyming words in the same sentence
# 141 * [[kenning]]: Using a compound word neologism to form a [[metonym]]
# 142 *[[litotes]] derived from a Greek word meaning "simple", is a figure of speech which employs an understatement by using double negatives or, in other words, positive statement is expressed by negating its opposite expressions.
# 143 *:Examples: "not too bad" for "very good" is an understatement as well as a double negative statement that confirms a positive idea by negating the opposite. Similarly, saying "She is not a beauty queen," means "She is ugly" or saying "I am not as young as I used to be" in order to avoid saying "I am old". Litotes, therefore, is an intentional use of understatement that renders an ironical effect.
# 144 * [[merism]]: Referring to a whole by enumerating some of its parts
# 145 * [[mimesis]]: Imitation of a person's speech or writing
# 146 * [[onomatopoeia]]: Word that imitates a real sound (e.g. tick-tock or boom)
# 147 * [[paradiastole]]: Repetition of the disjunctive pair "neither" and "nor"
# 148 * [[parallelism (rhetoric)|parallelism]]: The use of similar structures in two or more clauses
# 149 * [[paraprosdokian]]: Unexpected ending or truncation of a clause
# 150 * paremvolia: Interference of speak by speaking <ref>Cosmo, Lepota L (2019). Superspeech and Its Rhetoric Figures. ''Education Journal'', II (2): 21-28. [https://dx.doi.org/10.31058/j.edu.2019.22001 doi: 10.31058/j.edu.2019.22001]</ref>
# 151 * [[parenthesis (rhetoric)|parenthesis]]: A parenthetical entry
# 152 * [[paroemion]]: Alliteration in which every word in a sentence or phrase begins with the same letter
# 153 * [[parrhesia]]: Speaking openly or boldly, in a situation where it is unexpected (e.g. politics)
# 154 * [[pleonasm]]: The use of more words than are needed to express meaning
# 155 * [[polyptoton]]: Repetition of words derived from the same root
# 156 * [[polysyndeton]]: Close repetition of conjunctions
# 157 * [[pun]]: When a word or phrase is used in two (or more) different senses
# 158 * [[rhythm]]: A synonym for [[parallelism (rhetoric)|parallelism]]<ref>{{cite web |url=http://grammar.about.com/od/rs/g/rhythmterm.htm |title=rhythm – definition and examples of rhythm in phonetics and poetics |publisher=Grammar.about.com |accessdate=2013-05-23 |url-status=live |archiveurl=https://web.archive.org/web/20130514050709/http://grammar.about.com/od/rs/g/rhythmterm.htm |archivedate=2013-05-14 }}</ref>
# 159 * [[sibilance]]: Repetition of letter 's', it is a form of [[Literary consonance|consonance]]
# 160 * [[sine dicendo]]: An inherently superfluous statement, the truth value of which can easily be taken for granted. When held under scrutiny, it becomes readily apparent that the statement has not in fact added any new or useful information to the conversation (e.g. 'It's always in the last place you look.')
# 161 * [[solecism]]: Trespassing grammatical and syntactical rules
# 162 * [[spoonerism]]: Switching place of syllables within two words in a sentence yielding amusement
# 163 * [[superlative]]: Declaring something the best within its class i.e. the ugliest, the most precious
# 164 * [[:wiktionary:synathroesmus|synathroesmus]]: Agglomeration of adjectives to describe something or someone
# 165 * [[syncope (phonology)|syncope]]: Omission of parts of a word or phrase
# 166 * [[symploce]]: Simultaneous use of anaphora and epistrophe: the repetition of the same word or group of words at the beginning and the end of successive clauses
# 167 * [[synchysis]]: Words that are intentionally scattered to create perplexment
# 168 * [[synesis]]: Agreement of words according to the sense, and not the grammatical form
# 169 * [[synecdoche]]: Referring to a part by its whole or vice versa
# 170 * [[synonymia]]: Use of two or more synonyms in the same clause or sentence
# 171 * [[tautology (rhetoric)|tautology]]: Redundancy due to superfluous qualification; saying the same thing twice
# 172 * [[tmesis]]: Insertions of content within a compound word
# 173 * [[zeugma]]: The using of one verb for two or more actions
# 174
# 175 === Tropes ===
# 176
# 177 * [[accismus]]: expressing the want of something by denying it<ref>{{cite book | last1 = Shipley | first = Joseph T. | year = 1943 | title = Dictionary of World Literature: Criticism, Forms, Technique | chapter-url = https://www.questia.com/read/37059251/dictionary-of-world-literature-criticism-forms | publisher = Philosophical Library | page = 595 | chapter = Trope | url-status = live | archiveurl = https://web.archive.org/web/20160310184615/https://www.questia.com/read/37059251/dictionary-of-world-literature-criticism-forms | archivedate = 2016-03-10 }}</ref>
# 178 * [[allegory]]: A [[metaphor|metaphoric]] narrative in which the literal elements indirectly reveal a parallel story of symbolic or abstract significance.<ref>Kennedy et al, 2006 p. 4-5</ref><ref>Quinn, 1999. p. 12</ref><ref> Baldick,2008. p. 7</ref>
# 179 * [[allusion]]: Covert reference to another work of literature or art
# 180 * [[Circumlocution|ambiguity]]: Phrasing which can have two meanings
# 181 * [[anacoenosis]]: Posing a question to an audience, often with the implication that it shares a common interest with the speaker
# 182 * [[analogy]]: A comparison
# 183 * [[anapodoton]]: Leaving a common known saying unfinished
# 184 * [[antanaclasis]]: A form of [[pun]] in which a word is repeated in two different senses.<ref> Corbett and Connors, 1999. p.62</ref>
# 185 * [[anthimeria]]: A substitution of one part of speech for another, such as noun for a verb and vice versa.<ref>Corbett and Connors, 1999. p. 64-65</ref>
# 186 * [[anthropomorphism]]: Ascribing human characteristics to something that is not human, such as an animal or a god (see [[zoomorphism]])
# 187 * [[antimetabole]]: Repetition of words in successive clauses, but in switched order
# 188 * [[antiphrasis]]: A name or a phrase used ironically.
# 189 * [[:wiktionary:antistasis|antistasis]]: Repetition of a word in a different sense.
# 190 * [[antonomasia]]: Substitution of a proper name for a phrase or vice versa
# 191 * [[aphorism]]: Briefly phrased, easily memorable statement of a truth or opinion, an adage
# 192 * [[apologia]]: Justifying one's actions
# 193 * [[aporia]]: Faked or sincere puzzled questioning
# 194 * [[apophasis]]: (Invoking) an idea by denying its (invocation)
# 195 * [[appositive]]: Insertion of a parenthetical entry
# 196 * [[apostrophe (rhetoric)|apostrophe]]: Directing the attention away from the audience to an absent third party, often in the form of a personified abstraction or inanimate object.
# 197 * [[archaism]]: Use of an obsolete, archaic word (a word used in olden language, e.g. Shakespeare's language)
# 198 * [[auxesis (figure of speech)|auxesis]]: Form of [[hyperbole]], in which a more important-sounding word is used in place of a more descriptive term
# 199 * [[bathos]]: Pompous speech with a ludicrously mundane worded [[anti-climax (figure of speech)|anti-climax]]
# 200 * [[burlesque metaphor]]: An amusing, overstated or grotesque comparison or example.
# 201 * [[catachresis]]: Blatant misuse of words or phrases.
# 202 * [[cataphora]]: Repetition of a cohesive device at the end
# 203 * [[:wiktionary:categoria|categoria]]: Candidly revealing an opponent's weakness
# 204 * [[cliché]]: Overused phrase or theme
# 205 * [[circumlocution]]: Talking around a topic by substituting or adding words, as in [[euphemism]] or [[periphrasis (rhetoric)|periphrasis]]
# 206 * [[congeries]]: Accumulation of synonymous or different words or phrases together forming a single message
# 207 * [[correctio]]: Linguistic device used for correcting one's mistakes, a form of which is [[epanorthosis]]
# 208 * [[:wiktionary:dehortatio|dehortatio]]: discouraging advice given with seeming sagacity
# 209 * [[denominatio]]: Another word for [[metonymy]]
# 210 * [[:wiktionary:diatyposis|diatyposis]]: The act of giving counsel
# 211 * [[double negative]]: Grammar construction that can be used as an expression and it is the repetition of negative words
# 212 * [[:wiktionary:dirimens copulatio|dirimens copulatio]]: Balances one statement with a contrary, qualifying statement<ref>{{cite web |url=http://rhetoric.byu.edu/Figures/D/DIRIMENS%20COPULATIO-v.HTM |title=Archived copy |accessdate=2017-03-15 |url-status=live |archiveurl=https://web.archive.org/web/20160710200218/http://rhetoric.byu.edu/Figures/D/DIRIMENS%20COPULATIO-v.HTM |archivedate=2016-07-10 }}</ref>
# 213 * [[:wiktionary:distinctio|distinctio]]: Defining or specifying the meaning of a word or phrase you use
# 214 * [[dysphemism]]: Substitution of a harsher, more offensive, or more disagreeable term for another.  Opposite of [[euphemism]]
# 215 * [[:wiktionary:dubitatio|dubitatio]]: Expressing doubt over one's ability to hold speeches, or doubt over other ability
# 216 * [[:wiktionary:ekphrasis|ekphrasis]]: Lively describing something you see, often a painting
# 217 * [[epanorthosis]]: Immediate and emphatic self-correction, often following a [[Freudian slip|slip of the tongue]]
# 218 * [[:wiktionary:encomium|encomium]]: A speech consisting of praise; a eulogy
# 219 * [[:wiktionary:enumeratio|enumeratio]]: A sort of amplification and accumulation in which specific aspects are added up to make a point
# 220 * [[:wiktionary:epicrisis|epicrisis]]: Mentioning a saying and then commenting on it
# 221 * [[:wiktionary:epiplexis|epiplexis]]: Rhetorical question displaying disapproval or debunks
# 222 * [[:wiktionary:epitrope|epitrope]]: Initially pretending to agree with an opposing debater or invite one to do something
# 223 * [[erotema]]: Synonym for [[rhetorical question]]
# 224 * [[:wiktionary:erotesis|erotesis]]: [[Rhetorical question]] asked in confident expectation of a negative answer
# 225 * [[euphemism]]: Substitution of a less offensive or more agreeable term for another
# 226 * [[grandiloquence]]: Pompous speech
# 227 * [[:wiktionary:exclamation|exclamation]]: A loud calling or crying out
# 228 * [[humour]]: Provoking laughter and providing amusement
# 229 * [[hyperbaton]]: Words that naturally belong together separated from each other for emphasis or effect
# 230 * [[hyperbole]]: Use of exaggerated terms for emphasis
# 231 * [[hypocatastasis]]: An implication or declaration of resemblance that does not directly name both terms
# 232 * [[hypophora]]: Answering one's own [[rhetorical question]] at length
# 233 * [[hysteron proteron]]: Reversal of anticipated order of events; a form of hyperbaton
# 234 * [[innuendo]]: Having a hidden meaning in a sentence that makes sense whether it is detected or not
# 235 * [[:wiktionary:inversion|inversion]]: A reversal of normal word order, especially the placement of a verb ahead of the subject (subject-verb inversion).
# 236 * [[irony]]: Use of word in a way that conveys a meaning opposite to its usual meaning.<ref>Corbett and Connors. 1999. p.69-70</ref>
# 237 * [[litotes]]: Emphasizing the magnitude of a statement by denying its opposite
# 238 * [[malapropism]]: Using a word through confusion with a word that sounds similar
# 239 * [[meiosis (figure of speech)|meiosis]]: Use of understatement, usually to diminish the importance of something
# 240 * memento verbum: Word at the top of the tongue, recordabantur
# 241 * [[merism]]: Referring to a whole by enumerating some of its parts
# 242 * [[metalepsis]]: Figurative speech is used in a new context
# 243 * [[metaphor]]: An implied comparison between two things, attributing the properties of one thing to another that it does not literally possess.<ref> Corbett and Connors, 1999. p.60</ref>
# 244 * [[metonymy]]: A thing or concept is called not by its own name but rather by the name of something associated in meaning with that thing or concept
# 245 * [[neologism]]: The use of a word or term that has recently been created, or has been in use for a short time. Opposite of [[archaism]]
# 246 * [[non sequitur (literary device)|non sequitur]]: Statement that bears no relationship to the context preceding
# 247 * occupatio see [[apophasis]]: Mentioning something by reportedly not mentioning it
# 248 * [[onomatopoeia]]: Words that sound like their meaning
# 249 * [[oxymoron]]: Using two terms together, that normally contradict each other
# 250 * [[par'hyponoian]]: Replacing in a phrase or text a second part, that would have been logically expected.
# 251 * [[parable]]: Extended [[metaphor]] told as an anecdote to illustrate or teach a moral lesson
# 252 * [[paradiastole]]: Extenuating a vice in order to flatter or soothe
# 253 * [[Paradox (literature)|paradox]]: Use of apparently contradictory ideas to point out some underlying truth
# 254 * [[paraprosdokian]]: Phrase in which the latter part causes a rethinking or reframing of the beginning
# 255 * [[paralipsis]]: Drawing attention to something while pretending to pass it over
# 256 * [[parody]]: Humouristic imitation
# 257 * [[paronomasia]]: [[Pun]], in which similar-sounding words but words having a different meaning are used
# 258 * [[pathetic fallacy]]: Ascribing human conduct and feelings to nature
# 259 * [[:wiktionary:periphrasis|periphrasis]]: A synonym for [[circumlocution]]
# 260 * [[personification]]/prosopopoeia/anthropomorphism: Attributing or applying human qualities to inanimate objects, animals, or natural phenomena
# 261 * [[pleonasm]]: The use of more words than is necessary for clear expression
# 262 * [[praeteritio]]: Another word for [[paralipsis]]
# 263 * [[procatalepsis]]: Refuting anticipated objections as part of the main argument
# 264 * [[proslepsis]]: Extreme form of [[paralipsis]] in which the speaker provides great detail while feigning to pass over a topic
# 265 * [[:wiktionary:prothesis|prothesis]]: Adding a syllable to the beginning of a word
# 266 * [[proverb]]: Succinct or pithy, often metaphorical, expression of wisdom commonly believed to be true
# 267 * [[pun]]: Play on words that will have two meanings
# 268 * [[rhetorical question]]: Asking a question as a way of asserting something. Asking a question which already has the answer hidden in it. Or asking a question not for the sake of getting an answer but for asserting something (or as in a poem for creating a poetic effect)
# 269 * [[satire]]: Humoristic criticism of society
# 270 * sensory detail imagery: sight, sound, taste, touch, smell
# 271 * [[sesquipedalianism]]: use of long and obscure words
# 272 * [[simile]]: Comparison between two things using ''like'' or ''as''
# 273 * [[snowclone]]: Alteration of [[cliché]] or [[phrasal template]]
# 274 * [[:wiktionary:style|style]]: how information is presented
# 275 * [[superlative]]: Saying that something is the best of something or has the most of some quality, e.g. the ugliest, the most precious etc.
# 276 * [[syllepsis]]: The use of a word in its figurative and literal sense at the same time ''or'' a single word used in relation to two other parts of a sentence although the word grammatically or logically applies to only one
# 277 * [[syncatabasis]] (condescension, accommodation): adaptation of style to the level of the audience
# 278 * [[:wiktionary:synchoresis|synchoresis]]: A concession made for the purpose of retorting with greater force.
# 279 * [[synecdoche]]: Form of [[metonymy]], referring to a part by its whole, or a whole by its part
# 280 * [[synesthesia]]: Description of one kind of sense impression by using words that normally describe another.
# 281 * [[tautology (rhetoric)|tautology]]: Superfluous repetition of the same sense in different words Example: The children gathered in a round circle
# 282 * [[transferred epithet]]: A synonym for [[hypallage]].
# 283 * [[truism]]: a self-evident statement
# 284 * [[tricolon|tricolon diminuens]]: Combination of three elements, each decreasing in size
# 285 * [[tricolon|tricolon crescens]]: Combination of three elements, each increasing in size
# 286 * verbal paradox: Paradox specified to language
# 287 * verba ex ore: Taking the words out of someone’s mouth, speaking of what the interlocutor wanted to say.<ref>Cosmo, Lepota L (2019). Superspeech and Its Rhetoric Figures. ''Education Journal'', II (2): 21-28. [https://dx.doi.org/10.31058/j.edu.2019.22001 doi: 10.31058/j.edu.2019.22001]</ref>
# 288 * verbum volitans: A word that floats in the air, on which everyone is thinking and is just about to be imposed.<ref>Cosmo, Lepota L (2019). Superspeech and Its Rhetoric Figures. ''Education Journal'', II (2): 21-28. [https://dx.doi.org/10.31058/j.edu.2019.22001 doi: 10.31058/j.edu.2019.22001 ibid.]</ref>
# 289 * [[zeugma]]: Use of a single verb to describe two or more actions
# 290 * [[zoomorphism]]: Applying animal characteristics to humans or gods
# 291
# 292 == See also ==
# 293 {{Portal|Linguistics}}
# 294
# 295 * [[Idiom]]
# 296 * [[List of forms of word play]]
# 297 * [[Repetition (rhetorical device)]]
# 298 * [[Rhetorical device]]
# 299 * [[Stylistic device]]
# 300
# 301 == References ==
# 302 === Citations ===
# 303 {{Reflist|30em}}
# 304
# 305 === Sources ===
# 306 {{refbegin}}
# 307 * [[Chris Baldick|Baldrick, Chris]]. 2008. ''Oxford Dictionary of Literary Terms''. Oxford University Press. New York. {{ISBN|978-0-19-920827-2}}
# 308 * [[Edward P. J. Corbett |Corbett, Edward P. J.]] and Connors, Robert J. 1999. ''Style and Statement''. Oxford University Press. New York, Oxford. {{ISBN|0-19-511543-0}}
# 309 * [[X. J. Kennedy|Kennedy, X.J.]] et al. 2006. ''The Longman Dictionary of Literary Terms: Vocabulary for the Informed Reader''. Pearson, Longman. New York. {{ISBN|0-321-33194-X}}
# 310 * [[Mark Forsyth|Forsyth, Mark]]. 2014. ''The Elements of Eloquence''. Berkley Publishing Group/Penguin Publishing. New York. {{ISBN|978-0-425-27618-1}}
# 311 * Quinn, Edward. 1999. ''A Dictionary of Literary and Thematic Terms''. Checkmark Books. New York. {{ISBN| 0-8160-4394-9}}
# 312 * {{cite web |url = http://rhetoric.byu.edu |title = Silva Rhetorica |website = rhetoric.byu.edu }}
# 313 {{refend}}
# 314
# 315
# 316 == External links ==
# 317 {{wiktionary}}
# 318
# 319 {{Narrative modes}}
# 320
# 321 [[Category:Figures of speech| ]]
# 322 [[Category:Rhetoric]]

# %%
items = []
descriptions = []
with open(topic + '_error_log.txt', 'w+', encoding="utf-8") as filepath:
    for index, line in enumerate(lines[77:291]):
        
        if re.match('\*\s*\[\[', line[0:5]):
            #print("%%%Match%%%")
            #print(line)
            try:
                line = re.sub(r'\<ref.*?\</ref>|\<ref.*\/>', '', line)
                
            except:
                topic_error_line = f"{topic} line sub parse error"
                item_line = f"{str(index)}, {line}"
                print(log_error(topic_error_line, item_line))
                
            try:
                
                item = re.search(r'\[\[(.*?)\]\]', line).group(1)
                
            except:
                topic_error_line = f"{topic} item parse error"
                item_line = f"{str(index)}, {line}"
                print(log_error(topic_error_line, item_line))
                
            try:
                
                description = re.search(r'\]\]\:*(.*)', line).group(1)
                
                
            except:
                topic_error_line = f"{topic} description parse error"
                item_line = f"{str(index)}, {line}"
                print(log_error(topic_error_line, item_line))
                
            items.append(item)
            descriptions.append(description)
        else:
            continue
            #print("%%%No%%%")
            #print(line)

# %%
items = [re.sub(r'\:wiktionary\:', '', item) for item in items]
items = [re.sub(r'\|.*', '', item) for item in items]
items
# Out:
# ['Accumulation (figure of speech)',
#  'adnomination',
#  'alliteration',
#  'adynaton',
#  'anacoluthon',
#  'anadiplosis',
#  'anaphora (rhetoric)',
#  'anastrophe',
#  'Anti-climax (figure of speech)',
#  'antanaclasis',
#  'anthimeria',
#  'antimetabole',
#  'antirrhesis',
#  'epistrophe',
#  'antithesis',
#  'aphorismus',
#  'aposiopesis',
#  'apposition',
#  'assonance',
#  'asteismus',
#  'asterismos',
#  'asyndeton',
#  'cacophony',
#  'cataphora',
#  'classification (literature & grammar)',
#  'chiasmus',
#  'climax (figure of speech)',
#  'conversion (word formation)',
#  'Literary consonance',
#  'correlative verse',
#  'diacope',
#  'asterismos',
#  'tmesis',
#  'Ellipsis (linguistics)',
#  'elision',
#  'enallage',
#  'enjambment',
#  'enthymeme',
#  'epanalepsis',
#  'epanodos',
#  'epistrophe',
#  'epizeuxis',
#  'euphony',
#  'half rhyme',
#  'hendiadys',
#  'hendiatris',
#  'homeoptoton',
#  'homographs',
#  'homoioteleuton',
#  'homonyms',
#  'homophones',
#  'homeoteleuton',
#  'hypallage',
#  'hyperbaton',
#  'hyperbole',
#  'hypozeuxis',
#  'hysteron proteron',
#  'isocolon',
#  'internal rhyme',
#  'kenning',
#  'litotes',
#  'merism',
#  'mimesis',
#  'onomatopoeia',
#  'paradiastole',
#  'parallelism (rhetoric)',
#  'paraprosdokian',
#  'parenthesis (rhetoric)',
#  'paroemion',
#  'parrhesia',
#  'pleonasm',
#  'polyptoton',
#  'polysyndeton',
#  'pun',
#  'rhythm',
#  'sibilance',
#  'sine dicendo',
#  'solecism',
#  'spoonerism',
#  'superlative',
#  'synathroesmus',
#  'syncope (phonology)',
#  'symploce',
#  'synchysis',
#  'synesis',
#  'synecdoche',
#  'synonymia',
#  'tautology (rhetoric)',
#  'tmesis',
#  'zeugma',
#  'accismus',
#  'allegory',
#  'allusion',
#  'Circumlocution',
#  'anacoenosis',
#  'analogy',
#  'anapodoton',
#  'antanaclasis',
#  'anthimeria',
#  'anthropomorphism',
#  'antimetabole',
#  'antiphrasis',
#  'antistasis',
#  'antonomasia',
#  'aphorism',
#  'apologia',
#  'aporia',
#  'apophasis',
#  'appositive',
#  'apostrophe (rhetoric)',
#  'archaism',
#  'auxesis (figure of speech)',
#  'bathos',
#  'burlesque metaphor',
#  'catachresis',
#  'cataphora',
#  'categoria',
#  'cliché',
#  'circumlocution',
#  'congeries',
#  'correctio',
#  'dehortatio',
#  'denominatio',
#  'diatyposis',
#  'double negative',
#  'dirimens copulatio',
#  'distinctio',
#  'dysphemism',
#  'dubitatio',
#  'ekphrasis',
#  'epanorthosis',
#  'encomium',
#  'enumeratio',
#  'epicrisis',
#  'epiplexis',
#  'epitrope',
#  'erotema',
#  'erotesis',
#  'euphemism',
#  'grandiloquence',
#  'exclamation',
#  'humour',
#  'hyperbaton',
#  'hyperbole',
#  'hypocatastasis',
#  'hypophora',
#  'hysteron proteron',
#  'innuendo',
#  'inversion',
#  'irony',
#  'litotes',
#  'malapropism',
#  'meiosis (figure of speech)',
#  'merism',
#  'metalepsis',
#  'metaphor',
#  'metonymy',
#  'neologism',
#  'non sequitur (literary device)',
#  'onomatopoeia',
#  'oxymoron',
#  "par'hyponoian",
#  'parable',
#  'paradiastole',
#  'Paradox (literature)',
#  'paraprosdokian',
#  'paralipsis',
#  'parody',
#  'paronomasia',
#  'pathetic fallacy',
#  'periphrasis',
#  'personification',
#  'pleonasm',
#  'praeteritio',
#  'procatalepsis',
#  'proslepsis',
#  'prothesis',
#  'proverb',
#  'pun',
#  'rhetorical question',
#  'satire',
#  'sesquipedalianism',
#  'simile',
#  'snowclone',
#  'style',
#  'superlative',
#  'syllepsis',
#  'syncatabasis',
#  'synchoresis',
#  'synecdoche',
#  'synesthesia',
#  'tautology (rhetoric)',
#  'transferred epithet',
#  'truism',
#  'tricolon',
#  'tricolon',
#  'zeugma',
#  'zoomorphism']

# %%
item_infos = []
for index, title in enumerate(items):
    with open(topic + '_error_log.txt', 'w+', encoding="utf-8") as filepath:
        
        url = 'https://en.wikipedia.org/w/index.php?title=' + title + '&action=info'

        #print(url)
        response = requests.get(url)
        doc = lxml.html.fromstring(response.content)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        try:
            # info_table = doc.xpath('//*[@class="wikitable mw-page-info"]')[0]
            watchers = doc.xpath('//*[@id="mw-pageinfo-watchers"]')[0][1].text
            
        except:
            topic_error_line = f"watchers parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            watchers = "#error#"

        try:
            redirects = doc.xpath('//*[contains(text(),"redirects")]/../../td')[1].text
            #redirects = doc.xpath('//*[contains(text(),"redirects")]/parent::node()/parent::node()')
            #redirects = doc.xpath('/html/body/div[3]/div[3]/div[3]/table[2]/tr[9]/td')[1].text
            
        except:
            topic_error_line = f"redirects parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            redirects = "#error#"
             
        try:
            views = doc.xpath('//*[@id="mw-pvi-month-count"]/td/div')[0].text
            
        except:
            topic_error_line = f"views parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            views = "#error#"        
        
        try:
            edits = doc.xpath('//*[@id="mw-pageinfo-edits"]/td')[1].text
            #edits = doc.xpath('/html/body/div[3]/div[3]/div[3]/table[4]/tr[5]/td')[1].text
    
        except:
            topic_error_line = f"edits parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            edits = "#error#"
        
        item_infos.append({
            topic: title,
            'watchers': watchers,
            'redirects': redirects,
            'views': views,
            'edits': edits
        })
# Out:
# #############################################################################################
# ##################################### edits parse error #####################################
# #### 12, antirrhesis, https://en.wikipedia.org/w/index.php?title=antirrhesis&action=info ####
# #############################################################################################
#
# ###########################################################################################
# #################################### edits parse error ####################################
# #### 20, asterismos, https://en.wikipedia.org/w/index.php?title=asterismos&action=info ####
# ###########################################################################################
#
# #################################################################################################################################################
# ############################################################### edits parse error ###############################################################
# #### 24, classification (literature & grammar), https://en.wikipedia.org/w/index.php?title=classification (literature & grammar)&action=info ####
# #################################################################################################################################################
#
# ###########################################################################################
# #################################### edits parse error ####################################
# #### 31, asterismos, https://en.wikipedia.org/w/index.php?title=asterismos&action=info ####
# ###########################################################################################
#
# #################################################################################################
# ####################################### edits parse error #######################################
# #### 80, synathroesmus, https://en.wikipedia.org/w/index.php?title=synathroesmus&action=info ####
# #################################################################################################
#
# ############################################################################################
# ##################################### edits parse error ####################################
# #### 102, antistasis, https://en.wikipedia.org/w/index.php?title=antistasis&action=info ####
# ############################################################################################
#
# ##########################################################################################
# #################################### edits parse error ###################################
# #### 116, categoria, https://en.wikipedia.org/w/index.php?title=categoria&action=info ####
# ##########################################################################################
#
# ############################################################################################
# ##################################### edits parse error ####################################
# #### 121, dehortatio, https://en.wikipedia.org/w/index.php?title=dehortatio&action=info ####
# ############################################################################################
#
# ############################################################################################
# ##################################### edits parse error ####################################
# #### 123, diatyposis, https://en.wikipedia.org/w/index.php?title=diatyposis&action=info ####
# ############################################################################################
#
# ############################################################################################################
# ############################################# edits parse error ############################################
# #### 125, dirimens copulatio, https://en.wikipedia.org/w/index.php?title=dirimens copulatio&action=info ####
# ############################################################################################################
#
# ############################################################################################
# ##################################### edits parse error ####################################
# #### 126, distinctio, https://en.wikipedia.org/w/index.php?title=distinctio&action=info ####
# ############################################################################################
#
# ##########################################################################################
# #################################### edits parse error ###################################
# #### 133, epicrisis, https://en.wikipedia.org/w/index.php?title=epicrisis&action=info ####
# ##########################################################################################
#
# ##########################################################################################
# #################################### edits parse error ###################################
# #### 134, epiplexis, https://en.wikipedia.org/w/index.php?title=epiplexis&action=info ####
# ##########################################################################################
#
# ########################################################################################
# ################################### edits parse error ##################################
# #### 135, epitrope, https://en.wikipedia.org/w/index.php?title=epitrope&action=info ####
# ########################################################################################
#
# ########################################################################################
# ################################### edits parse error ##################################
# #### 137, erotesis, https://en.wikipedia.org/w/index.php?title=erotesis&action=info ####
# ########################################################################################
#
# ##############################################################################################
# ###################################### edits parse error #####################################
# #### 188, synchoresis, https://en.wikipedia.org/w/index.php?title=synchoresis&action=info ####
# ##############################################################################################

# %%
# transfer item_infos to json file
import json
with open(topic + '_infos.json', 'w') as filepath:
    json.dump(item_infos, filepath)

# %%
error_items = [item[topic] for item in item_infos if item['views'] == '#error#']

for index, title in enumerate(error_items):
    with open('info_error_log.txt', 'w+', encoding="utf-8") as filepath:
        #print(title)
        del_idx = 0
        for index, item in enumerate(item_infos):
            if item[topic] == title:
                del_idx = index
                #del item_infos[index]
        #print(item)
        
        
        if re.match(r'\W*', title):
            print('%%%')
            search = re.search(r'(\w+)?', title).group(1)
            print(search)
            title = search
        
        print(title)
        
        url = 'https://en.wikipedia.org/w/index.php?title=' + title + '&action=info'

        #print(url)
        response = requests.get(url)
        doc = lxml.html.fromstring(response.content)
        soup = BeautifulSoup(response.content, 'html.parser')
  
        try:
            # info_table = doc.xpath('//*[@class="wikitable mw-page-info"]')[0]
            watchers = doc.xpath('//*[@id="mw-pageinfo-watchers"]')[0][1].text
            
        except:
            topic_error_line = f"watchers parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            watchers = "#error#"

        try:
            redirects = doc.xpath('//*[contains(text(),"redirects")]/../../td')[1].text
            #redirects = doc.xpath('//*[contains(text(),"redirects")]/parent::node()/parent::node()')
            #redirects = doc.xpath('/html/body/div[3]/div[3]/div[3]/table[2]/tr[9]/td')[1].text
            
        except:
            topic_error_line = f"redirects parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            redirects = "#error#"
             
        try:
            views = doc.xpath('//*[@id="mw-pvi-month-count"]/td/div')[0].text
            
        except:
            topic_error_line = f"views parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            views = "#error#"        
        
        try:
            edits = doc.xpath('//*[@id="mw-pageinfo-edits"]/td')[1].text
            #edits = doc.xpath('/html/body/div[3]/div[3]/div[3]/table[4]/tr[5]/td')[1].text
    
        except:
            topic_error_line = f"edits parse error"
            item_line = f"{str(index)}, {title}, {url}"
            print(log_error(topic_error_line, item_line))
            filepath.write(str(index) + ' : ' + title + ' : ' + url + '\n')
            edits = "#error#"
            
        item_infos[del_idx] = {
            topic: title,
            'watchers': watchers,
            'redirects': redirects,
            'views': views,
            'edits': edits
        }

# %%
with open(f'{topic}_infos.json', 'r') as jfile:
    data=jfile.read()

# parse file
item_infos = json.loads(data)

# %%
_item_infos = item_infos
len(_item_infos)
# Out:
# 198

# %%
#item_infos = [{item['views']: int(item['views'].replace(',', ''))} for item in item_infos]
for index, item in enumerate(_item_infos):
    if item['views'] != '#error#':
        if item['watchers'] == 'Fewer than 30 watchers':
            item['watchers'] = '29'
        item['views'] = int(item['views'].replace(',', ''))
        item['watchers'] = int(item['watchers'].replace(',', ''))
        #item['edits'] = int(item['edits'].replace(',', ''))

# %%
by_views = sorted(_item_infos, key=lambda k : k['views'], reverse=True)
for index, item in enumerate(by_views):
    item['view_rank'] = index

# %%
by_edits = sorted(_item_infos, key=lambda k : k['edits'], reverse=True)
for index, item in enumerate(by_edits):
    item['edit_rank'] = index

# %%
by_watchers = sorted(_item_infos, key=lambda k : k['watchers'], reverse=True)
for index, item in enumerate(by_watchers):
    item['watcher_rank'] = index

# %%
for item in _item_infos:
    #item['total_rank'] = (item['view_rank'] + item['edit_rank'] + item['watcher_rank']) / 3
    item['total_rank'] = (item['view_rank'] + item['watcher_rank']) / 2

# %%
by_total = sorted(_item_infos, key=lambda k : k['total_rank'], reverse=True)

# %%
start = 0
limit = 44
top_items = [item[topic] for item in by_total]

# %%
with open(f"{topic}_{limit}.txt", 'w+', encoding="utf-8") as fp:
    for item in top_items[start:limit]:
        fp.write(item + '\n')

# %%
min_df = pd.DataFrame(_item_infos)
min_df.head()
min_df.sort_values(by=['total_rank'], ascending=True).head(100)
# Out:
#      edit_rank  edits redirects                        rhetoric  total_rank  \
# 190        124  3,605        27                     synesthesia         0.0
# 99          42  1,999        51                anthropomorphism         1.0
# 155        147  5,030        13                        metaphor         4.0
# 180        139  4,465        27                          satire         4.0
# 157         38  1,646        10                       neologism         4.0
# 156         31  1,281         9                        metonymy         5.5
# 63         120  3,072        46                    onomatopoeia         7.5
# 138        125  3,755        22                       euphemism         8.0
# 91          39  1,707        11                        allegory         8.0
# 159        121  3,072        46                    onomatopoeia         8.5
# 149        148  5,446        18                           irony        10.0
# 104         32  1,286        12                        aphorism        12.0
# 141        165  6,750        23                          humour        13.5
# 85          24  1,088        13                      synecdoche        14.0
# 73          95  2,315        15                             pun        14.5
# 189         25  1,088        13                      synecdoche        15.0
# 178         96  2,315        15                             pun        15.5
# 78          91  2,081         7                      spoonerism        17.0
# 151         40  1,746        10                     malapropism        18.0
# 177         92  2,104         9                         proverb        21.0
# 167         41  1,920        13                          parody        21.5
# 74          37  1,629        22                          rhythm        22.0
# 160        122  3,203        10                        oxymoron        22.0
# 95          33  1,335        10                         analogy        24.0
# 2          119  3,053        13                    alliteration        26.0
# 66         179    721         1                  paraprosdokian        26.5
# 62         153    503         6                         mimesis        26.5
# 165        180    721         1                  paraprosdokian        27.5
# 147        187    864         6                        innuendo        27.5
# 158        168    624         5  non sequitur (literary device)        28.0
# ..         ...    ...       ...                             ...         ...
# 114         83    191         2                     catachresis        72.5
# 32         133    352         0                          tmesis        74.0
# 28         144    453         1             Literary consonance        74.5
# 27          59    122         9     conversion (word formation)        74.5
# 88         134    352         0                          tmesis        75.0
# 170         47    102         6                     periphrasis        76.0
# 11         112    270         0                    antimetabole        77.5
# 100        113    270         0                    antimetabole        78.5
# 197         79    186         5                     zoomorphism        79.5
# 72          70    153         2                    polysyndeton        80.0
# 103         98    215         3                     antonomasia        80.5
# 21          60    123         3                       asyndeton        81.0
# 44          72    160         3                       hendiadys        81.5
# 89          18      1         0                          zeugma        81.5
# 196         22      1         0                          zeugma        82.5
# 45         101    221         1                      hendiatris        85.0
# 81         108    245         2             syncope (phonology)        85.5
# 61         183     80         2                          merism        86.0
# 154         49    104         1                      metalepsis        86.5
# 9           84    194         0                    antanaclasis        86.5
# 153        184     80         2                          merism        87.0
# 97          85    194         0                    antanaclasis        87.5
# 58         138    387         2                  internal rhyme        89.5
# 152         78    183         2      meiosis (figure of speech)        93.0
# 43         111    261         0                      half rhyme        96.5
# 23         173     69         6                       cataphora        97.5
# 3           87    196         3                        adynaton        98.0
# 115        174     69         6                       cataphora        98.5
# 4           75    165         1                     anacoluthon        99.0
# 131         48    103         7                        encomium        99.0
#
#      view_rank   views  watcher_rank  watchers
# 190          0  326564             0       986
# 99           1   56314             1       701
# 155          3   33063             5       481
# 180          2   46563             6       474
# 157          6   31018             2       579
# 156          8   29980             3       540
# 63           4   32190            11       382
# 138         12   24397             4       525
# 91           7   30022             9       406
# 159          5   32190            12       382
# 149         13   23935             7       467
# 104         14   22774            10       385
# 141         19   18621             8       425
# 85          15   21770            13       314
# 73          10   28733            19       283
# 189         16   21770            14       314
# 178         11   28733            20       283
# 78          18   18624            16       292
# 151         21   17539            15       298
# 177          9   29960            33       192
# 167         17   18671            26       232
# 74          20   18402            24       247
# 160         22   16335            22       269
# 95          27   14391            21       280
# 2           24   15624            28       204
# 66          36    9608            17       288
# 62          26   14485            27       215
# 165         37    9608            18       288
# 147         23   15931            32       193
# 158         25   15034            31       196
# ..         ...     ...           ...       ...
# 114         81    1909            64        71
# 32          82    1873            66        65
# 28          76    2293            73        58
# 27          54    4874            95        40
# 88          83    1873            67        65
# 170         72    2585            80        52
# 11          84    1866            71        59
# 100         85    1866            72        59
# 197         80    1983            79        53
# 72          62    3198            98        37
# 103         78    2099            83        50
# 21          75    2474            87        48
# 44          86    1843            77        53
# 89         105    1219            58        90
# 196        106    1219            59        90
# 45         108    1180            62        75
# 81          93    1631            78        53
# 61          91    1699            81        51
# 154         79    1998            94        42
# 9           89    1700            84        49
# 153         92    1699            82        51
# 97          90    1700            85        49
# 58          77    2153           102        32
# 152         95    1504            91        45
# 43          66    2914           127        29
# 23         103    1252            92        42
# 3          100    1329            96        39
# 115        104    1252            93        42
# 4           99    1359            99        36
# 131         94    1549           104        30
#
# [100 rows x 9 columns]

# %%
min_df = pd.DataFrame(_item_infos)
min_df.head()
min_df.sort_values(by=['views'], ascending=False).head(100)
# Out:
#      edits redirects                        rhetoric  total_rank  view_rank  \
# 190  3,605        27                     synesthesia       197.0        197
# 99   1,999        51                anthropomorphism       196.0        196
# 180  4,465        27                          satire       195.0        195
# 155  5,030        13                        metaphor       194.0        194
# 63   3,072        46                    onomatopoeia       192.0        192
# 159  3,072        46                    onomatopoeia       193.0        193
# 157  1,646        10                       neologism       191.0        191
# 91   1,707        11                        allegory       190.0        190
# 156  1,281         9                        metonymy       189.0        189
# 177  2,104         9                         proverb       188.0        188
# 178  2,315        15                             pun       187.0        187
# 73   2,315        15                             pun       186.0        186
# 138  3,755        22                       euphemism       185.0        185
# 149  5,446        18                           irony       184.0        184
# 104  1,286        12                        aphorism       183.0        183
# 85   1,088        13                      synecdoche       181.0        181
# 189  1,088        13                      synecdoche       182.0        182
# 167  1,920        13                          parody       180.0        180
# 78   2,081         7                      spoonerism       179.0        179
# 141  6,750        23                          humour       178.0        178
# 74   1,629        22                          rhythm       177.0        177
# 151  1,746        10                     malapropism       176.0        176
# 160  3,203        10                        oxymoron       175.0        175
# 147    864         6                        innuendo       174.0        174
# 2    3,053        13                    alliteration       173.0        173
# 158    624         5  non sequitur (literary device)       172.0        172
# 62     503         6                         mimesis       171.0        171
# 95   1,335        10                         analogy       170.0        170
# 54   2,226         4                       hyperbole       168.0        168
# 143  2,226         4                       hyperbole       169.0        169
# ..     ...       ...                             ...         ...        ...
# 93     216        11                  Circumlocution       126.0        126
# 118    216        11                  circumlocution       127.0        127
# 170    102         6                     periphrasis       125.0        125
# 37     306         2                       enthymeme       124.0        124
# 193    194         2                          truism       123.0        123
# 21     123         3                       asyndeton       122.0        122
# 28     453         1             Literary consonance       121.0        121
# 58     387         2                  internal rhyme       120.0        120
# 103    215         3                     antonomasia       119.0        119
# 154    104         1                      metalepsis       118.0        118
# 197    186         5                     zoomorphism       117.0        117
# 114    191         2                     catachresis       116.0        116
# 88     352         0                          tmesis       115.0        115
# 32     352         0                          tmesis       114.0        114
# 100    270         0                    antimetabole       113.0        113
# 11     270         0                    antimetabole       112.0        112
# 44     160         3                       hendiadys       111.0        111
# 191  1,172         0            tautology (rhetoric)       110.0        110
# 87   1,172         0            tautology (rhetoric)       109.0        109
# 9      194         0                    antanaclasis       107.0        107
# 97     194         0                    antanaclasis       108.0        108
# 61      80         2                          merism       105.0        105
# 153     80         2                          merism       106.0        106
# 81     245         2             syncope (phonology)       104.0        104
# 131    103         7                        encomium       103.0        103
# 152    183         2      meiosis (figure of speech)       102.0        102
# 65     165         0          parallelism (rhetoric)       101.0        101
# 10      61         1                      anthimeria        99.0         99
# 98      61         1                      anthimeria       100.0        100
# 4      165         1                     anacoluthon        98.0         98
#
#       views  watcher_rank  watchers
# 190  326564           197       986
# 99    56314           196       701
# 180   46563           195       474
# 155   33063           194       481
# 63    32190           192       382
# 159   32190           193       382
# 157   31018           191       579
# 91    30022           190       406
# 156   29980           189       540
# 177   29960           188       192
# 178   28733           187       283
# 73    28733           186       283
# 138   24397           185       525
# 149   23935           184       467
# 104   22774           183       385
# 85    21770           181       314
# 189   21770           182       314
# 167   18671           180       232
# 78    18624           179       292
# 141   18621           178       425
# 74    18402           177       247
# 151   17539           176       298
# 160   16335           175       269
# 147   15931           174       193
# 2     15624           173       204
# 158   15034           172       196
# 62    14485           171       215
# 95    14391           170       280
# 54    14377           168       204
# 143   14377           169       204
# ..      ...           ...       ...
# 93     2647           126        94
# 118    2647           127        94
# 170    2585           125        52
# 37     2568           124       103
# 193    2518           123        64
# 21     2474           122        48
# 28     2293           121        58
# 58     2153           120        32
# 103    2099           119        50
# 154    1998           118        42
# 197    1983           117        53
# 114    1909           116        71
# 88     1873           115        65
# 32     1873           114        65
# 100    1866           113        59
# 11     1866           112        59
# 44     1843           111        53
# 191    1736           110       181
# 87     1736           109       181
# 9      1700           107        49
# 97     1700           108        49
# 61     1699           105        51
# 153    1699           106        51
# 81     1631           104        53
# 131    1549           103        30
# 152    1504           102        45
# 65     1373           101        29
# 10     1367            99        29
# 98     1367           100        29
# 4      1359            98        36
#
# [100 rows x 8 columns]

# %%
min_df.sort_values(by=['watchers'], ascending=False).head(100)
# Out:
#      edits redirects                     rhetoric  total_rank  view_rank  \
# 190  3,605        27                  synesthesia       197.0        197
# 99   1,999        51             anthropomorphism       196.0        196
# 157  1,646        10                    neologism       191.0        191
# 156  1,281         9                     metonymy       189.0        189
# 138  3,755        22                    euphemism       185.0        185
# 155  5,030        13                     metaphor       194.0        194
# 180  4,465        27                       satire       195.0        195
# 149  5,446        18                        irony       184.0        184
# 141  6,750        23                       humour       178.0        178
# 91   1,707        11                     allegory       190.0        190
# 104  1,286        12                     aphorism       183.0        183
# 159  3,072        46                 onomatopoeia       193.0        193
# 63   3,072        46                 onomatopoeia       192.0        192
# 189  1,088        13                   synecdoche       182.0        182
# 85   1,088        13                   synecdoche       181.0        181
# 151  1,746        10                  malapropism       176.0        176
# 78   2,081         7                   spoonerism       179.0        179
# 165    721         1               paraprosdokian       161.0        161
# 66     721         1               paraprosdokian       160.0        160
# 178  2,315        15                          pun       187.0        187
# 73   2,315        15                          pun       186.0        186
# 95   1,335        10                      analogy       170.0        170
# 160  3,203        10                     oxymoron       175.0        175
# 183    991        12                    snowclone       151.0        151
# 74   1,629        22                       rhythm       177.0        177
# 117  1,388         8                       cliché       164.0        164
# 167  1,920        13                       parody       180.0        180
# 62     503         6                      mimesis       171.0        171
# 143  2,226         4                    hyperbole       169.0        169
# 2    3,053        13                 alliteration       173.0        173
# ..     ...       ...                          ...         ...        ...
# 33     240        11       Ellipsis (linguistics)       137.0        137
# 11     270         0                 antimetabole       112.0        112
# 100    270         0                 antimetabole       113.0        113
# 28     453         1          Literary consonance       121.0        121
# 36     376         4                   enjambment       138.0        138
# 69     189         4                    parrhesia       132.0        132
# 184    409        11                        style       145.0        145
# 81     245         2          syncope (phonology)       104.0        104
# 197    186         5                  zoomorphism       117.0        117
# 44     160         3                    hendiadys       111.0        111
# 170    102         6                  periphrasis       125.0        125
# 61      80         2                       merism       105.0        105
# 153     80         2                       merism       106.0        106
# 103    215         3                  antonomasia       119.0        119
# 9      194         0                 antanaclasis       107.0        107
# 97     194         0                 antanaclasis       108.0        108
# 16     152         1                  aposiopesis        83.0         83
# 21     123         3                    asyndeton       122.0        122
# 185    543         0                  superlative        77.0         77
# 171  1,475         2              personification       154.0        154
# 79     543         0                  superlative        76.0         76
# 152    183         2   meiosis (figure of speech)       102.0        102
# 115     69         6                    cataphora        94.0         94
# 154    104         1                   metalepsis       118.0        118
# 23      69         6                    cataphora        93.0         93
# 27     122         9  conversion (word formation)       143.0        143
# 3      196         3                     adynaton        97.0         97
# 72     153         2                 polysyndeton       135.0        135
# 7      138         3                   anastrophe       153.0        153
# 4      165         1                  anacoluthon        98.0         98
#
#       views  watcher_rank  watchers
# 190  326564           197       986
# 99    56314           196       701
# 157   31018           191       579
# 156   29980           189       540
# 138   24397           185       525
# 155   33063           194       481
# 180   46563           195       474
# 149   23935           184       467
# 141   18621           178       425
# 91    30022           190       406
# 104   22774           183       385
# 159   32190           193       382
# 63    32190           192       382
# 189   21770           182       314
# 85    21770           181       314
# 151   17539           176       298
# 78    18624           179       292
# 165    9608           161       288
# 66     9608           160       288
# 178   28733           187       283
# 73    28733           186       283
# 95    14391           170       280
# 160   16335           175       269
# 183    6447           151       269
# 74    18402           177       247
# 117   13843           164       233
# 167   18671           180       232
# 62    14485           171       215
# 143   14377           169       204
# 2     15624           173       204
# ..      ...           ...       ...
# 33     3765           137        60
# 11     1866           112        59
# 100    1866           113        59
# 28     2293           121        58
# 36     4187           138        56
# 69     3072           132        54
# 184    5210           145        54
# 81     1631           104        53
# 197    1983           117        53
# 44     1843           111        53
# 170    2585           125        52
# 61     1699           105        51
# 153    1699           106        51
# 103    2099           119        50
# 9      1700           107        49
# 97     1700           108        49
# 16     1127            83        48
# 21     2474           122        48
# 185     773            77        47
# 171    7099           154        47
# 79      773            76        47
# 152    1504           102        45
# 115    1252            94        42
# 154    1998           118        42
# 23     1252            93        42
# 27     4874           143        40
# 3      1329            97        39
# 72     3198           135        37
# 7      7038           153        37
# 4      1359            98        36
#
# [100 rows x 8 columns]

# %%
min_df.sort_values(by=['edits'], ascending=False).head(100)

# %%
# parse data

lines = textDATA["parse"]["wikitext"]["*"].split('\n')[3:-10] # [::-1]
this_sec = {}
sec = ''
sub_sec = ''
with open('error_lines.txt', 'w+', encoding="utf-8") as filepath:
    for index, line in enumerate(lines):
        if index == 23:
            print(line)
        if re.match('==\w', line[0:3]):
            sec = line.strip().replace("=", "")
            if len(this_sec) > 0:
                section_dict[secs[secs.index(sec) - 1]] = this_sec
            this_sec = {}
        if type(section_dict[sec]).__name__ == 'list':
            if re.match('\*\[\[', line[0:3]):
                try:
                    poet = re.search(r'\[\[(.*?)\]\]', line).group(1)
                    #print(poet)

                except:
                    print("##########################")
                    print("#### poet parse error ####")
                    print(poet_method, index, line)
                    filepath.write(line + '\n')
                    print(line[-2:])
                    print("##########################")

                date_m = re.search('\((.*)\)', line)

                try:
                    date = date_m.group(0)
                except:
                    print("##########################")
                    print("#### date parse error ####")
                    print(index, line)
                    filepath.write(line + '\n')
                    date = ""
                    print("##########################")
                try:
                    # description = re.search('\)*,*.*', line).group(1)
                    # description = re.search('\),+.*', line).group(1)
                    # description = re.search('\]\s.*\)(.*)', line).group(1)
                    description = re.search('\]\](\)*,*.*)', line).group(1)
                except Exception as e:
                    print("#################################")
                    print("#### description parse error ####")
                    print(e)
                    print(index, line)
                    filepath.write(line + '\n')
                    print("#################################")
                # print(this_sec)
                # print(sub_sec)
                section_dict[sec].append({
                    'poet': poet,
                    'date': date,
                    'description': description
                })
        else:
            #print(sec)
            if re.match('===\w', line[0:4]):
                sub_sec = line.strip().replace("=", "")
                #print(sub_sec)
            if line.strip().replace("=", "") in section_dict[sec]:
                #print(sub_sec)
                this_sec[sub_sec] = []
            if sub_sec != '':
                if re.match('\*\[\[', line[0:3]):
                    try:
                        poet = re.search(r'\[\[(.*?)\]\]', line).group(1)
                        #print(poet)
                    except:
                        print("##########################")
                        print("#### poet parse error ####")
                        print(index, line)
                        filepath.write(line + '\n')
                        print(line[-2:])
                        print("##########################")
                    date_m = re.search('\((.*)\)', line)
                    try:
                        date = date_m.group(0)
                    except Exception as e:
                        print("##########################")
                        print("#### date parse error ####")
                        print(e)
                        print(index, line)
                        filepath.write(line + '\n')
                        date = ""
                        print("##########################")
                    try:
                        # description = re.search('\)*,*.*', line).group(1)
                        # description = re.search('\),+.*', line).group(0)
                        # description = re.search('\]\s.*\)(.*)', line).group(0)
                        description = re.search('\]\](\)*,*.*)', line).group(1)

                    except Exception as e:
                        print("#################################")
                        print("#### description parse error ####")
                        print(e)
                        print(index, line)
                        filepath.write(line + '\n')
                        description = ""
                        print("#################################")

                    this_sec[sub_sec].append({
                        'poet': poet,
                        'date': date,
                        'description': description
                    })
